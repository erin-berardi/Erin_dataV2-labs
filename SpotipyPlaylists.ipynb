# %%
#!pip install spotipy

# %%
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials

# %%
secrets_file = open("SpotifySecret.txt","r")

# %%
string = secrets_file.read()

# %%
string.split('\n')
# Out:
# ['cid:da00ed264eaf4f94ba2adf23ff058567',
#  'cs:80b98527a70043438b54ed1ce6460e5c',
#  '']

# %%
secrets_dict={}
for line in string.split('\n'):
    if len(line)>0:
        secrets_dict[line.split(':')[0]]=line.split(':')[1]

# %%
secrets_dict
# Out:
# {'cid': 'da00ed264eaf4f94ba2adf23ff058567',
#  'cs': '80b98527a70043438b54ed1ce6460e5c'}

# %%
sp = spotipy.Spotify(auth_manager=SpotifyClientCredentials(client_id=secrets_dict['cid'],client_secret=secrets_dict['cs']))

# %%
results = sp.search(q='The Cure',limit=50)
results
# Out:
# {'tracks': {'href': 'https://api.spotify.com/v1/search?query=The+Cure&type=track&offset=0&limit=50',
#   'items': [{'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1HY2Jd0NmPuamShAr6KMms'},
#        'href': 'https://api.spotify.com/v1/artists/1HY2Jd0NmPuamShAr6KMms',
#        'id': '1HY2Jd0NmPuamShAr6KMms',
#        'name': 'Lady Gaga',
#        'type': 'artist',
#        'uri': 'spotify:artist:1HY2Jd0NmPuamShAr6KMms'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AO',
#       'AR',
#       'AT',
#       'AU',
#       'AZ',
#       'BA',
#       'BB',
#       'BD',
#       'BE',
#       'BF',
#       'BG',
#       'BH',
#       'BI',
#       'BJ',
#       'BN',
#       'BO',
#       'BR',
#       'BS',
#       'BT',
#       'BW',
#       'BY',
#       'BZ',
#       'CA',
#       'CD',
#       'CG',
#       'CH',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CV',
#       'CW',
#       'CY',
#       'CZ',
#       'DE',
#       'DJ',
#       'DK',
#       'DM',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FJ',
#       'FM',
#       'FR',
#       'GA',
#       'GB',
#       'GD',
#       'GE',
#       'GH',
#       'GM',
#       'GN',
#       'GQ',
#       'GR',
#       'GT',
#       'GW',
#       'GY',
#       'HK',
#       'HN',
#       'HR',
#       'HT',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IQ',
#       'IS',
#       'IT',
#       'JM',
#       'JO',
#       'JP',
#       'KE',
#       'KG',
#       'KH',
#       'KI',
#       'KM',
#       'KN',
#       'KR',
#       'KW',
#       'KZ',
#       'LA',
#       'LB',
#       'LC',
#       'LI',
#       'LK',
#       'LR',
#       'LS',
#       'LT',
#       'LU',
#       'LV',
#       'LY',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MG',
#       'MH',
#       'MK',
#       'ML',
#       'MN',
#       'MO',
#       'MR',
#       'MT',
#       'MU',
#       'MV',
#       'MW',
#       'MX',
#       'MY',
#       'MZ',
#       'NA',
#       'NE',
#       'NG',
#       'NI',
#       'NL',
#       'NO',
#       'NP',
#       'NR',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PG',
#       'PH',
#       'PK',
#       'PL',
#       'PS',
#       'PT',
#       'PW',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RW',
#       'SA',
#       'SB',
#       'SC',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SL',
#       'SM',
#       'SN',
#       'SR',
#       'ST',
#       'SV',
#       'SZ',
#       'TD',
#       'TG',
#       'TH',
#       'TJ',
#       'TL',
#       'TN',
#       'TO',
#       'TR',
#       'TT',
#       'TV',
#       'TW',
#       'TZ',
#       'UA',
#       'UG',
#       'US',
#       'UY',
#       'UZ',
#       'VC',
#       'VE',
#       'VN',
#       'VU',
#       'WS',
#       'XK',
#       'ZA',
#       'ZM',
#       'ZW'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/2yaSZnZhaxsbQ5xhgGbw3g'},
#      'href': 'https://api.spotify.com/v1/albums/2yaSZnZhaxsbQ5xhgGbw3g',
#      'id': '2yaSZnZhaxsbQ5xhgGbw3g',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b27331cc5716a5c922b0482787b7',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e0231cc5716a5c922b0482787b7',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d0000485131cc5716a5c922b0482787b7',
#        'width': 64}],
#      'name': 'The Cure',
#      'release_date': '2017-04-16',
#      'release_date_precision': 'day',
#      'total_tracks': 1,
#      'type': 'album',
#      'uri': 'spotify:album:2yaSZnZhaxsbQ5xhgGbw3g'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1HY2Jd0NmPuamShAr6KMms'},
#       'href': 'https://api.spotify.com/v1/artists/1HY2Jd0NmPuamShAr6KMms',
#       'id': '1HY2Jd0NmPuamShAr6KMms',
#       'name': 'Lady Gaga',
#       'type': 'artist',
#       'uri': 'spotify:artist:1HY2Jd0NmPuamShAr6KMms'}],
#     'available_markets': ['AD',
#      'AE',
#      'AG',
#      'AL',
#      'AM',
#      'AO',
#      'AR',
#      'AT',
#      'AU',
#      'AZ',
#      'BA',
#      'BB',
#      'BD',
#      'BE',
#      'BF',
#      'BG',
#      'BH',
#      'BI',
#      'BJ',
#      'BN',
#      'BO',
#      'BR',
#      'BS',
#      'BT',
#      'BW',
#      'BY',
#      'BZ',
#      'CA',
#      'CD',
#      'CG',
#      'CH',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CV',
#      'CW',
#      'CY',
#      'CZ',
#      'DE',
#      'DJ',
#      'DK',
#      'DM',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FJ',
#      'FM',
#      'FR',
#      'GA',
#      'GB',
#      'GD',
#      'GE',
#      'GH',
#      'GM',
#      'GN',
#      'GQ',
#      'GR',
#      'GT',
#      'GW',
#      'GY',
#      'HK',
#      'HN',
#      'HR',
#      'HT',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IQ',
#      'IS',
#      'IT',
#      'JM',
#      'JO',
#      'JP',
#      'KE',
#      'KG',
#      'KH',
#      'KI',
#      'KM',
#      'KN',
#      'KR',
#      'KW',
#      'KZ',
#      'LA',
#      'LB',
#      'LC',
#      'LI',
#      'LK',
#      'LR',
#      'LS',
#      'LT',
#      'LU',
#      'LV',
#      'LY',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MG',
#      'MH',
#      'MK',
#      'ML',
#      'MN',
#      'MO',
#      'MR',
#      'MT',
#      'MU',
#      'MV',
#      'MW',
#      'MX',
#      'MY',
#      'MZ',
#      'NA',
#      'NE',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NP',
#      'NR',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PG',
#      'PH',
#      'PK',
#      'PL',
#      'PS',
#      'PT',
#      'PW',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RW',
#      'SA',
#      'SB',
#      'SC',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SL',
#      'SM',
#      'SN',
#      'SR',
#      'ST',
#      'SV',
#      'SZ',
#      'TD',
#      'TG',
#      'TH',
#      'TJ',
#      'TL',
#      'TN',
#      'TO',
#      'TR',
#      'TT',
#      'TV',
#      'TW',
#      'TZ',
#      'UA',
#      'UG',
#      'US',
#      'UY',
#      'UZ',
#      'VC',
#      'VE',
#      'VN',
#      'VU',
#      'WS',
#      'XK',
#      'ZA',
#      'ZM',
#      'ZW'],
#     'disc_number': 1,
#     'duration_ms': 211363,
#     'explicit': False,
#     'external_ids': {'isrc': 'USUM71703782'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/34oB5r0lcN3fYWCs2uA1k5'},
#     'href': 'https://api.spotify.com/v1/tracks/34oB5r0lcN3fYWCs2uA1k5',
#     'id': '34oB5r0lcN3fYWCs2uA1k5',
#     'is_local': False,
#     'name': 'The Cure',
#     'popularity': 64,
#     'preview_url': None,
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:34oB5r0lcN3fYWCs2uA1k5'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7bu3H8JO7d0UbMoVzbo70s'},
#        'href': 'https://api.spotify.com/v1/artists/7bu3H8JO7d0UbMoVzbo70s',
#        'id': '7bu3H8JO7d0UbMoVzbo70s',
#        'name': 'The Cure',
#        'type': 'artist',
#        'uri': 'spotify:artist:7bu3H8JO7d0UbMoVzbo70s'}],
#      'available_markets': ['CA', 'US'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/3x1CmNdXWU0DzpTZXFFRZu'},
#      'href': 'https://api.spotify.com/v1/albums/3x1CmNdXWU0DzpTZXFFRZu',
#      'id': '3x1CmNdXWU0DzpTZXFFRZu',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273e410fa31e3dfcc7521cde86d',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02e410fa31e3dfcc7521cde86d',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851e410fa31e3dfcc7521cde86d',
#        'width': 64}],
#      'name': 'Wish',
#      'release_date': '1992-04-21',
#      'release_date_precision': 'day',
#      'total_tracks': 12,
#      'type': 'album',
#      'uri': 'spotify:album:3x1CmNdXWU0DzpTZXFFRZu'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7bu3H8JO7d0UbMoVzbo70s'},
#       'href': 'https://api.spotify.com/v1/artists/7bu3H8JO7d0UbMoVzbo70s',
#       'id': '7bu3H8JO7d0UbMoVzbo70s',
#       'name': 'The Cure',
#       'type': 'artist',
#       'uri': 'spotify:artist:7bu3H8JO7d0UbMoVzbo70s'}],
#     'available_markets': ['CA', 'US'],
#     'disc_number': 1,
#     'duration_ms': 214400,
#     'explicit': False,
#     'external_ids': {'isrc': 'USEE10180267'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/263aNAQCeFSWipk896byo6'},
#     'href': 'https://api.spotify.com/v1/tracks/263aNAQCeFSWipk896byo6',
#     'id': '263aNAQCeFSWipk896byo6',
#     'is_local': False,
#     'name': "Friday I'm in Love",
#     'popularity': 66,
#     'preview_url': 'https://p.scdn.co/mp3-preview/958e347444599fa593cb2d86459e67ad18719c72?cid=da00ed264eaf4f94ba2adf23ff058567',
#     'track_number': 7,
#     'type': 'track',
#     'uri': 'spotify:track:263aNAQCeFSWipk896byo6'},
#    {'album': {'album_type': 'compilation',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0LyfQWJT6nXafLPZqxe9Of'},
#        'href': 'https://api.spotify.com/v1/artists/0LyfQWJT6nXafLPZqxe9Of',
#        'id': '0LyfQWJT6nXafLPZqxe9Of',
#        'name': 'Various Artists',
#        'type': 'artist',
#        'uri': 'spotify:artist:0LyfQWJT6nXafLPZqxe9Of'}],
#      'available_markets': ['AE',
#       'AL',
#       'AR',
#       'AT',
#       'AU',
#       'BA',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'CA',
#       'CH',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GH',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HR',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JP',
#       'KE',
#       'KH',
#       'KR',
#       'KW',
#       'LB',
#       'LK',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'ME',
#       'MK',
#       'MT',
#       'MX',
#       'MY',
#       'NG',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'SA',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SN',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TT',
#       'TW',
#       'UA',
#       'US',
#       'UY',
#       'VE',
#       'VN',
#       'XK',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/0V7t8K29zrXonTFzzz6Z3V'},
#      'href': 'https://api.spotify.com/v1/albums/0V7t8K29zrXonTFzzz6Z3V',
#      'id': '0V7t8K29zrXonTFzzz6Z3V',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273a0331d0633619818dda00ea9',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02a0331d0633619818dda00ea9',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851a0331d0633619818dda00ea9',
#        'width': 64}],
#      'name': "Sun's Out, Bums Out",
#      'release_date': '2022-04-20',
#      'release_date_precision': 'day',
#      'total_tracks': 28,
#      'type': 'album',
#      'uri': 'spotify:album:0V7t8K29zrXonTFzzz6Z3V'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1HY2Jd0NmPuamShAr6KMms'},
#       'href': 'https://api.spotify.com/v1/artists/1HY2Jd0NmPuamShAr6KMms',
#       'id': '1HY2Jd0NmPuamShAr6KMms',
#       'name': 'Lady Gaga',
#       'type': 'artist',
#       'uri': 'spotify:artist:1HY2Jd0NmPuamShAr6KMms'}],
#     'available_markets': ['AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'CA',
#      'CH',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GH',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JP',
#      'KE',
#      'KH',
#      'KR',
#      'KW',
#      'LB',
#      'LK',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SN',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TT',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VE',
#      'VN',
#      'XK',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 211363,
#     'explicit': False,
#     'external_ids': {'isrc': 'USUM71703782'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/3pzMbk1YjjRsofZvNnRBoH'},
#     'href': 'https://api.spotify.com/v1/tracks/3pzMbk1YjjRsofZvNnRBoH',
#     'id': '3pzMbk1YjjRsofZvNnRBoH',
#     'is_local': False,
#     'name': 'The Cure',
#     'popularity': 3,
#     'preview_url': None,
#     'track_number': 20,
#     'type': 'track',
#     'uri': 'spotify:track:3pzMbk1YjjRsofZvNnRBoH'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7bu3H8JO7d0UbMoVzbo70s'},
#        'href': 'https://api.spotify.com/v1/artists/7bu3H8JO7d0UbMoVzbo70s',
#        'id': '7bu3H8JO7d0UbMoVzbo70s',
#        'name': 'The Cure',
#        'type': 'artist',
#        'uri': 'spotify:artist:7bu3H8JO7d0UbMoVzbo70s'}],
#      'available_markets': ['CA', 'US'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/37Q22g0n9PzBLX6lNddrIa'},
#      'href': 'https://api.spotify.com/v1/albums/37Q22g0n9PzBLX6lNddrIa',
#      'id': '37Q22g0n9PzBLX6lNddrIa',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2737f22337546d61faca55e0f4f',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e027f22337546d61faca55e0f4f',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048517f22337546d61faca55e0f4f',
#        'width': 64}],
#      'name': 'Kiss Me, Kiss Me, Kiss Me',
#      'release_date': '1987-05-25',
#      'release_date_precision': 'day',
#      'total_tracks': 17,
#      'type': 'album',
#      'uri': 'spotify:album:37Q22g0n9PzBLX6lNddrIa'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7bu3H8JO7d0UbMoVzbo70s'},
#       'href': 'https://api.spotify.com/v1/artists/7bu3H8JO7d0UbMoVzbo70s',
#       'id': '7bu3H8JO7d0UbMoVzbo70s',
#       'name': 'The Cure',
#       'type': 'artist',
#       'uri': 'spotify:artist:7bu3H8JO7d0UbMoVzbo70s'}],
#     'available_markets': ['CA', 'US'],
#     'disc_number': 1,
#     'duration_ms': 212000,
#     'explicit': False,
#     'external_ids': {'isrc': 'USEE18700009'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/76GlO5H5RT6g7y0gev86Nk'},
#     'href': 'https://api.spotify.com/v1/tracks/76GlO5H5RT6g7y0gev86Nk',
#     'id': '76GlO5H5RT6g7y0gev86Nk',
#     'is_local': False,
#     'name': 'Just like Heaven',
#     'popularity': 65,
#     'preview_url': 'https://p.scdn.co/mp3-preview/ef101f28ecd0df21cc7726ee48c1e6c7879f7d48?cid=da00ed264eaf4f94ba2adf23ff058567',
#     'track_number': 8,
#     'type': 'track',
#     'uri': 'spotify:track:76GlO5H5RT6g7y0gev86Nk'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0Z88iXWc4YVhtu1eFtsGk6'},
#        'href': 'https://api.spotify.com/v1/artists/0Z88iXWc4YVhtu1eFtsGk6',
#        'id': '0Z88iXWc4YVhtu1eFtsGk6',
#        'name': 'Wolves At The Gate',
#        'type': 'artist',
#        'uri': 'spotify:artist:0Z88iXWc4YVhtu1eFtsGk6'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AO',
#       'AR',
#       'AT',
#       'AU',
#       'AZ',
#       'BA',
#       'BB',
#       'BD',
#       'BE',
#       'BF',
#       'BG',
#       'BH',
#       'BI',
#       'BJ',
#       'BN',
#       'BO',
#       'BR',
#       'BS',
#       'BT',
#       'BW',
#       'BY',
#       'BZ',
#       'CA',
#       'CD',
#       'CG',
#       'CH',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CV',
#       'CY',
#       'CZ',
#       'DE',
#       'DJ',
#       'DK',
#       'DM',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FJ',
#       'FM',
#       'FR',
#       'GA',
#       'GB',
#       'GD',
#       'GE',
#       'GH',
#       'GM',
#       'GN',
#       'GQ',
#       'GR',
#       'GT',
#       'GW',
#       'GY',
#       'HK',
#       'HN',
#       'HR',
#       'HT',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IQ',
#       'IS',
#       'IT',
#       'JM',
#       'JO',
#       'JP',
#       'KE',
#       'KG',
#       'KH',
#       'KI',
#       'KM',
#       'KN',
#       'KR',
#       'KW',
#       'KZ',
#       'LA',
#       'LB',
#       'LC',
#       'LI',
#       'LK',
#       'LR',
#       'LS',
#       'LT',
#       'LU',
#       'LV',
#       'LY',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MG',
#       'MH',
#       'MK',
#       'ML',
#       'MN',
#       'MO',
#       'MR',
#       'MT',
#       'MU',
#       'MV',
#       'MW',
#       'MX',
#       'MY',
#       'MZ',
#       'NA',
#       'NE',
#       'NG',
#       'NI',
#       'NL',
#       'NO',
#       'NP',
#       'NR',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PG',
#       'PH',
#       'PK',
#       'PL',
#       'PS',
#       'PT',
#       'PW',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RW',
#       'SA',
#       'SB',
#       'SC',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SL',
#       'SM',
#       'SN',
#       'SR',
#       'ST',
#       'SV',
#       'SZ',
#       'TD',
#       'TG',
#       'TH',
#       'TJ',
#       'TL',
#       'TN',
#       'TO',
#       'TR',
#       'TT',
#       'TV',
#       'TW',
#       'TZ',
#       'UA',
#       'UG',
#       'US',
#       'UY',
#       'UZ',
#       'VC',
#       'VE',
#       'VN',
#       'VU',
#       'WS',
#       'XK',
#       'ZA',
#       'ZM',
#       'ZW'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/6L8gLKCluioceYP7WNmcol'},
#      'href': 'https://api.spotify.com/v1/albums/6L8gLKCluioceYP7WNmcol',
#      'id': '6L8gLKCluioceYP7WNmcol',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273dc4299ee6013d5522734c4e7',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02dc4299ee6013d5522734c4e7',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851dc4299ee6013d5522734c4e7',
#        'width': 64}],
#      'name': 'Eclipse',
#      'release_date': '2019-07-26',
#      'release_date_precision': 'day',
#      'total_tracks': 13,
#      'type': 'album',
#      'uri': 'spotify:album:6L8gLKCluioceYP7WNmcol'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0Z88iXWc4YVhtu1eFtsGk6'},
#       'href': 'https://api.spotify.com/v1/artists/0Z88iXWc4YVhtu1eFtsGk6',
#       'id': '0Z88iXWc4YVhtu1eFtsGk6',
#       'name': 'Wolves At The Gate',
#       'type': 'artist',
#       'uri': 'spotify:artist:0Z88iXWc4YVhtu1eFtsGk6'}],
#     'available_markets': ['AD',
#      'AE',
#      'AG',
#      'AL',
#      'AM',
#      'AO',
#      'AR',
#      'AT',
#      'AU',
#      'AZ',
#      'BA',
#      'BB',
#      'BD',
#      'BE',
#      'BF',
#      'BG',
#      'BH',
#      'BI',
#      'BJ',
#      'BN',
#      'BO',
#      'BR',
#      'BS',
#      'BT',
#      'BW',
#      'BY',
#      'BZ',
#      'CA',
#      'CD',
#      'CG',
#      'CH',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CV',
#      'CY',
#      'CZ',
#      'DE',
#      'DJ',
#      'DK',
#      'DM',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FJ',
#      'FM',
#      'FR',
#      'GA',
#      'GB',
#      'GD',
#      'GE',
#      'GH',
#      'GM',
#      'GN',
#      'GQ',
#      'GR',
#      'GT',
#      'GW',
#      'GY',
#      'HK',
#      'HN',
#      'HR',
#      'HT',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IQ',
#      'IS',
#      'IT',
#      'JM',
#      'JO',
#      'JP',
#      'KE',
#      'KG',
#      'KH',
#      'KI',
#      'KM',
#      'KN',
#      'KR',
#      'KW',
#      'KZ',
#      'LA',
#      'LB',
#      'LC',
#      'LI',
#      'LK',
#      'LR',
#      'LS',
#      'LT',
#      'LU',
#      'LV',
#      'LY',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MG',
#      'MH',
#      'MK',
#      'ML',
#      'MN',
#      'MO',
#      'MR',
#      'MT',
#      'MU',
#      'MV',
#      'MW',
#      'MX',
#      'MY',
#      'MZ',
#      'NA',
#      'NE',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NP',
#      'NR',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PG',
#      'PH',
#      'PK',
#      'PL',
#      'PS',
#      'PT',
#      'PW',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RW',
#      'SA',
#      'SB',
#      'SC',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SL',
#      'SM',
#      'SN',
#      'SR',
#      'ST',
#      'SV',
#      'SZ',
#      'TD',
#      'TG',
#      'TH',
#      'TJ',
#      'TL',
#      'TN',
#      'TO',
#      'TR',
#      'TT',
#      'TV',
#      'TW',
#      'TZ',
#      'UA',
#      'UG',
#      'US',
#      'UY',
#      'UZ',
#      'VC',
#      'VE',
#      'VN',
#      'VU',
#      'WS',
#      'XK',
#      'ZA',
#      'ZM',
#      'ZW'],
#     'disc_number': 1,
#     'duration_ms': 256693,
#     'explicit': False,
#     'external_ids': {'isrc': 'QMGVJ1900011'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/3bimN1JcQkbLWcUJexAEyh'},
#     'href': 'https://api.spotify.com/v1/tracks/3bimN1JcQkbLWcUJexAEyh',
#     'id': '3bimN1JcQkbLWcUJexAEyh',
#     'is_local': False,
#     'name': 'The Cure',
#     'popularity': 35,
#     'preview_url': 'https://p.scdn.co/mp3-preview/27120fe278e19dd9288d1f4883a0d9860f7a02ff?cid=da00ed264eaf4f94ba2adf23ff058567',
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:3bimN1JcQkbLWcUJexAEyh'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7bu3H8JO7d0UbMoVzbo70s'},
#        'href': 'https://api.spotify.com/v1/artists/7bu3H8JO7d0UbMoVzbo70s',
#        'id': '7bu3H8JO7d0UbMoVzbo70s',
#        'name': 'The Cure',
#        'type': 'artist',
#        'uri': 'spotify:artist:7bu3H8JO7d0UbMoVzbo70s'}],
#      'available_markets': ['CA', 'US'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/7gPql7GFpBMOxeO80vMMsC'},
#      'href': 'https://api.spotify.com/v1/albums/7gPql7GFpBMOxeO80vMMsC',
#      'id': '7gPql7GFpBMOxeO80vMMsC',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2735d0d65102be8606e439e54cc',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e025d0d65102be8606e439e54cc',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048515d0d65102be8606e439e54cc',
#        'width': 64}],
#      'name': 'Three Imaginary Boys (Deluxe Edition)',
#      'release_date': '1979-05-11',
#      'release_date_precision': 'day',
#      'total_tracks': 33,
#      'type': 'album',
#      'uri': 'spotify:album:7gPql7GFpBMOxeO80vMMsC'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7bu3H8JO7d0UbMoVzbo70s'},
#       'href': 'https://api.spotify.com/v1/artists/7bu3H8JO7d0UbMoVzbo70s',
#       'id': '7bu3H8JO7d0UbMoVzbo70s',
#       'name': 'The Cure',
#       'type': 'artist',
#       'uri': 'spotify:artist:7bu3H8JO7d0UbMoVzbo70s'}],
#     'available_markets': ['CA', 'US'],
#     'disc_number': 1,
#     'duration_ms': 157533,
#     'explicit': False,
#     'external_ids': {'isrc': 'USEE10413404'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/4dneV7C1yDt9UtyxrQY375'},
#     'href': 'https://api.spotify.com/v1/tracks/4dneV7C1yDt9UtyxrQY375',
#     'id': '4dneV7C1yDt9UtyxrQY375',
#     'is_local': False,
#     'name': "Boys Don't Cry - Single Version",
#     'popularity': 61,
#     'preview_url': 'https://p.scdn.co/mp3-preview/7fedf0d2730a71fcc3870f4e09ec4d5464969414?cid=da00ed264eaf4f94ba2adf23ff058567',
#     'track_number': 29,
#     'type': 'track',
#     'uri': 'spotify:track:4dneV7C1yDt9UtyxrQY375'},
#    {'album': {'album_type': 'compilation',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7bu3H8JO7d0UbMoVzbo70s'},
#        'href': 'https://api.spotify.com/v1/artists/7bu3H8JO7d0UbMoVzbo70s',
#        'id': '7bu3H8JO7d0UbMoVzbo70s',
#        'name': 'The Cure',
#        'type': 'artist',
#        'uri': 'spotify:artist:7bu3H8JO7d0UbMoVzbo70s'}],
#      'available_markets': ['CA', 'US'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/0BRThmbAV1p2CxAuxgpHRj'},
#      'href': 'https://api.spotify.com/v1/albums/0BRThmbAV1p2CxAuxgpHRj',
#      'id': '0BRThmbAV1p2CxAuxgpHRj',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2732780880a9583a363c28c60d5',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e022780880a9583a363c28c60d5',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048512780880a9583a363c28c60d5',
#        'width': 64}],
#      'name': 'Galore',
#      'release_date': '1997-10-17',
#      'release_date_precision': 'day',
#      'total_tracks': 18,
#      'type': 'album',
#      'uri': 'spotify:album:0BRThmbAV1p2CxAuxgpHRj'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7bu3H8JO7d0UbMoVzbo70s'},
#       'href': 'https://api.spotify.com/v1/artists/7bu3H8JO7d0UbMoVzbo70s',
#       'id': '7bu3H8JO7d0UbMoVzbo70s',
#       'name': 'The Cure',
#       'type': 'artist',
#       'uri': 'spotify:artist:7bu3H8JO7d0UbMoVzbo70s'}],
#     'available_markets': ['CA', 'US'],
#     'disc_number': 1,
#     'duration_ms': 208000,
#     'explicit': False,
#     'external_ids': {'isrc': 'GBALB8900003'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/1jeZTGhJ3C0txPw188XCQ8'},
#     'href': 'https://api.spotify.com/v1/tracks/1jeZTGhJ3C0txPw188XCQ8',
#     'id': '1jeZTGhJ3C0txPw188XCQ8',
#     'is_local': False,
#     'name': 'Lovesong',
#     'popularity': 25,
#     'preview_url': 'https://p.scdn.co/mp3-preview/96971dae4c776626199b0c3abb14e397f489f89e?cid=da00ed264eaf4f94ba2adf23ff058567',
#     'track_number': 7,
#     'type': 'track',
#     'uri': 'spotify:track:1jeZTGhJ3C0txPw188XCQ8'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7bu3H8JO7d0UbMoVzbo70s'},
#        'href': 'https://api.spotify.com/v1/artists/7bu3H8JO7d0UbMoVzbo70s',
#        'id': '7bu3H8JO7d0UbMoVzbo70s',
#        'name': 'The Cure',
#        'type': 'artist',
#        'uri': 'spotify:artist:7bu3H8JO7d0UbMoVzbo70s'}],
#      'available_markets': ['CA', 'US'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/6vQB3ZBxnQPP3jQcGV2qzg'},
#      'href': 'https://api.spotify.com/v1/albums/6vQB3ZBxnQPP3jQcGV2qzg',
#      'id': '6vQB3ZBxnQPP3jQcGV2qzg',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273c7ca2db25ad377e022bc3975',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02c7ca2db25ad377e022bc3975',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851c7ca2db25ad377e022bc3975',
#        'width': 64}],
#      'name': 'Disintegration (Deluxe Edition)',
#      'release_date': '1989-05-02',
#      'release_date_precision': 'day',
#      'total_tracks': 44,
#      'type': 'album',
#      'uri': 'spotify:album:6vQB3ZBxnQPP3jQcGV2qzg'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7bu3H8JO7d0UbMoVzbo70s'},
#       'href': 'https://api.spotify.com/v1/artists/7bu3H8JO7d0UbMoVzbo70s',
#       'id': '7bu3H8JO7d0UbMoVzbo70s',
#       'name': 'The Cure',
#       'type': 'artist',
#       'uri': 'spotify:artist:7bu3H8JO7d0UbMoVzbo70s'}],
#     'available_markets': ['CA', 'US'],
#     'disc_number': 1,
#     'duration_ms': 209573,
#     'explicit': False,
#     'external_ids': {'isrc': 'USEE10901455'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/0X5C4WjQNubRysTkHOubz3'},
#     'href': 'https://api.spotify.com/v1/tracks/0X5C4WjQNubRysTkHOubz3',
#     'id': '0X5C4WjQNubRysTkHOubz3',
#     'is_local': False,
#     'name': 'Lovesong - 2010 Remaster',
#     'popularity': 60,
#     'preview_url': 'https://p.scdn.co/mp3-preview/f9b7d686922b260b092b2c8e5186d40e2c63fd06?cid=da00ed264eaf4f94ba2adf23ff058567',
#     'track_number': 4,
#     'type': 'track',
#     'uri': 'spotify:track:0X5C4WjQNubRysTkHOubz3'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3e7awlrlDSwF3iM0WBjGMp'},
#        'href': 'https://api.spotify.com/v1/artists/3e7awlrlDSwF3iM0WBjGMp',
#        'id': '3e7awlrlDSwF3iM0WBjGMp',
#        'name': 'Little Mix',
#        'type': 'artist',
#        'uri': 'spotify:artist:3e7awlrlDSwF3iM0WBjGMp'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AO',
#       'AR',
#       'AT',
#       'AU',
#       'AZ',
#       'BA',
#       'BB',
#       'BD',
#       'BE',
#       'BF',
#       'BG',
#       'BH',
#       'BI',
#       'BJ',
#       'BN',
#       'BO',
#       'BR',
#       'BS',
#       'BT',
#       'BW',
#       'BY',
#       'BZ',
#       'CA',
#       'CD',
#       'CG',
#       'CH',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CV',
#       'CW',
#       'CY',
#       'CZ',
#       'DE',
#       'DJ',
#       'DK',
#       'DM',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FJ',
#       'FM',
#       'FR',
#       'GA',
#       'GB',
#       'GD',
#       'GE',
#       'GH',
#       'GM',
#       'GN',
#       'GQ',
#       'GR',
#       'GT',
#       'GW',
#       'GY',
#       'HK',
#       'HN',
#       'HR',
#       'HT',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IQ',
#       'IS',
#       'IT',
#       'JM',
#       'JO',
#       'JP',
#       'KE',
#       'KG',
#       'KH',
#       'KI',
#       'KM',
#       'KN',
#       'KR',
#       'KW',
#       'KZ',
#       'LA',
#       'LB',
#       'LC',
#       'LI',
#       'LK',
#       'LR',
#       'LS',
#       'LT',
#       'LU',
#       'LV',
#       'LY',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MG',
#       'MH',
#       'MK',
#       'ML',
#       'MN',
#       'MO',
#       'MR',
#       'MT',
#       'MU',
#       'MV',
#       'MW',
#       'MX',
#       'MY',
#       'MZ',
#       'NA',
#       'NE',
#       'NG',
#       'NI',
#       'NL',
#       'NO',
#       'NP',
#       'NR',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PG',
#       'PH',
#       'PK',
#       'PL',
#       'PS',
#       'PT',
#       'PW',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RW',
#       'SA',
#       'SB',
#       'SC',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SL',
#       'SM',
#       'SN',
#       'SR',
#       'ST',
#       'SV',
#       'SZ',
#       'TD',
#       'TG',
#       'TH',
#       'TJ',
#       'TL',
#       'TN',
#       'TO',
#       'TR',
#       'TT',
#       'TV',
#       'TW',
#       'TZ',
#       'UA',
#       'UG',
#       'US',
#       'UY',
#       'UZ',
#       'VC',
#       'VE',
#       'VN',
#       'VU',
#       'WS',
#       'XK',
#       'ZA',
#       'ZM',
#       'ZW'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/7Ho8gAx4haSxv1eFLQwvTj'},
#      'href': 'https://api.spotify.com/v1/albums/7Ho8gAx4haSxv1eFLQwvTj',
#      'id': '7Ho8gAx4haSxv1eFLQwvTj',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b27315174e2b2347b5ffbea6dbf0',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e0215174e2b2347b5ffbea6dbf0',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d0000485115174e2b2347b5ffbea6dbf0',
#        'width': 64}],
#      'name': 'LM5 (Deluxe)',
#      'release_date': '2018-11-16',
#      'release_date_precision': 'day',
#      'total_tracks': 18,
#      'type': 'album',
#      'uri': 'spotify:album:7Ho8gAx4haSxv1eFLQwvTj'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3e7awlrlDSwF3iM0WBjGMp'},
#       'href': 'https://api.spotify.com/v1/artists/3e7awlrlDSwF3iM0WBjGMp',
#       'id': '3e7awlrlDSwF3iM0WBjGMp',
#       'name': 'Little Mix',
#       'type': 'artist',
#       'uri': 'spotify:artist:3e7awlrlDSwF3iM0WBjGMp'}],
#     'available_markets': ['AD',
#      'AE',
#      'AG',
#      'AL',
#      'AM',
#      'AO',
#      'AR',
#      'AT',
#      'AU',
#      'AZ',
#      'BA',
#      'BB',
#      'BD',
#      'BE',
#      'BF',
#      'BG',
#      'BH',
#      'BI',
#      'BJ',
#      'BN',
#      'BO',
#      'BR',
#      'BS',
#      'BT',
#      'BW',
#      'BY',
#      'BZ',
#      'CA',
#      'CD',
#      'CG',
#      'CH',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CV',
#      'CW',
#      'CY',
#      'CZ',
#      'DE',
#      'DJ',
#      'DK',
#      'DM',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FJ',
#      'FM',
#      'FR',
#      'GA',
#      'GB',
#      'GD',
#      'GE',
#      'GH',
#      'GM',
#      'GN',
#      'GQ',
#      'GR',
#      'GT',
#      'GW',
#      'GY',
#      'HK',
#      'HN',
#      'HR',
#      'HT',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IQ',
#      'IS',
#      'IT',
#      'JM',
#      'JO',
#      'JP',
#      'KE',
#      'KG',
#      'KH',
#      'KI',
#      'KM',
#      'KN',
#      'KR',
#      'KW',
#      'KZ',
#      'LA',
#      'LB',
#      'LC',
#      'LI',
#      'LK',
#      'LR',
#      'LS',
#      'LT',
#      'LU',
#      'LV',
#      'LY',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MG',
#      'MH',
#      'MK',
#      'ML',
#      'MN',
#      'MO',
#      'MR',
#      'MT',
#      'MU',
#      'MV',
#      'MW',
#      'MX',
#      'MY',
#      'MZ',
#      'NA',
#      'NE',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NP',
#      'NR',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PG',
#      'PH',
#      'PK',
#      'PL',
#      'PS',
#      'PT',
#      'PW',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RW',
#      'SA',
#      'SB',
#      'SC',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SL',
#      'SM',
#      'SN',
#      'SR',
#      'ST',
#      'SV',
#      'SZ',
#      'TD',
#      'TG',
#      'TH',
#      'TJ',
#      'TL',
#      'TN',
#      'TO',
#      'TR',
#      'TT',
#      'TV',
#      'TW',
#      'TZ',
#      'UA',
#      'UG',
#      'US',
#      'UY',
#      'UZ',
#      'VC',
#      'VE',
#      'VN',
#      'VU',
#      'WS',
#      'XK',
#      'ZA',
#      'ZM',
#      'ZW'],
#     'disc_number': 1,
#     'duration_ms': 215333,
#     'explicit': False,
#     'external_ids': {'isrc': 'GBHMU1800101'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/1HiNWMc7vmFVM5mdwrNKnO'},
#     'href': 'https://api.spotify.com/v1/tracks/1HiNWMc7vmFVM5mdwrNKnO',
#     'id': '1HiNWMc7vmFVM5mdwrNKnO',
#     'is_local': False,
#     'name': 'The Cure',
#     'popularity': 52,
#     'preview_url': 'https://p.scdn.co/mp3-preview/0022ae86f60ed73a8e56144a0b7fd2a0ea7c404d?cid=da00ed264eaf4f94ba2adf23ff058567',
#     'track_number': 14,
#     'type': 'track',
#     'uri': 'spotify:track:1HiNWMc7vmFVM5mdwrNKnO'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6h4DZCXvwXapWw1C2vygaC'},
#        'href': 'https://api.spotify.com/v1/artists/6h4DZCXvwXapWw1C2vygaC',
#        'id': '6h4DZCXvwXapWw1C2vygaC',
#        'name': 'Sam Lans!',
#        'type': 'artist',
#        'uri': 'spotify:artist:6h4DZCXvwXapWw1C2vygaC'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AM',
#       'AO',
#       'AR',
#       'AT',
#       'AU',
#       'AZ',
#       'BB',
#       'BD',
#       'BE',
#       'BF',
#       'BG',
#       'BH',
#       'BI',
#       'BJ',
#       'BN',
#       'BO',
#       'BR',
#       'BS',
#       'BT',
#       'BW',
#       'BZ',
#       'CA',
#       'CG',
#       'CH',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CV',
#       'CW',
#       'CY',
#       'CZ',
#       'DE',
#       'DJ',
#       'DK',
#       'DM',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FJ',
#       'FM',
#       'FR',
#       'GA',
#       'GB',
#       'GD',
#       'GE',
#       'GH',
#       'GM',
#       'GN',
#       'GQ',
#       'GR',
#       'GT',
#       'GW',
#       'GY',
#       'HK',
#       'HN',
#       'HT',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JM',
#       'JO',
#       'JP',
#       'KE',
#       'KG',
#       'KH',
#       'KI',
#       'KM',
#       'KN',
#       'KR',
#       'KW',
#       'KZ',
#       'LA',
#       'LB',
#       'LC',
#       'LI',
#       'LK',
#       'LS',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'MG',
#       'MH',
#       'ML',
#       'MN',
#       'MO',
#       'MR',
#       'MT',
#       'MU',
#       'MV',
#       'MW',
#       'MX',
#       'MY',
#       'MZ',
#       'NA',
#       'NE',
#       'NG',
#       'NI',
#       'NL',
#       'NO',
#       'NP',
#       'NR',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PG',
#       'PH',
#       'PK',
#       'PL',
#       'PS',
#       'PT',
#       'PW',
#       'PY',
#       'QA',
#       'RO',
#       'RW',
#       'SA',
#       'SB',
#       'SC',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SL',
#       'SM',
#       'SN',
#       'SR',
#       'ST',
#       'SV',
#       'SZ',
#       'TD',
#       'TG',
#       'TH',
#       'TJ',
#       'TL',
#       'TN',
#       'TO',
#       'TR',
#       'TT',
#       'TV',
#       'TW',
#       'TZ',
#       'UA',
#       'UG',
#       'US',
#       'UY',
#       'UZ',
#       'VC',
#       'VE',
#       'VN',
#       'VU',
#       'WS',
#       'ZA',
#       'ZM'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/09F3pYMyjgdEj2rOD4aZhx'},
#      'href': 'https://api.spotify.com/v1/albums/09F3pYMyjgdEj2rOD4aZhx',
#      'id': '09F3pYMyjgdEj2rOD4aZhx',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273eae50582ee86f25f5504abd5',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02eae50582ee86f25f5504abd5',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851eae50582ee86f25f5504abd5',
#        'width': 64}],
#      'name': 'Mk Ultra',
#      'release_date': '2017-10-06',
#      'release_date_precision': 'day',
#      'total_tracks': 13,
#      'type': 'album',
#      'uri': 'spotify:album:09F3pYMyjgdEj2rOD4aZhx'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6h4DZCXvwXapWw1C2vygaC'},
#       'href': 'https://api.spotify.com/v1/artists/6h4DZCXvwXapWw1C2vygaC',
#       'id': '6h4DZCXvwXapWw1C2vygaC',
#       'name': 'Sam Lans!',
#       'type': 'artist',
#       'uri': 'spotify:artist:6h4DZCXvwXapWw1C2vygaC'}],
#     'available_markets': ['AD',
#      'AE',
#      'AG',
#      'AM',
#      'AO',
#      'AR',
#      'AT',
#      'AU',
#      'AZ',
#      'BB',
#      'BD',
#      'BE',
#      'BF',
#      'BG',
#      'BH',
#      'BI',
#      'BJ',
#      'BN',
#      'BO',
#      'BR',
#      'BS',
#      'BT',
#      'BW',
#      'BZ',
#      'CA',
#      'CG',
#      'CH',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CV',
#      'CW',
#      'CY',
#      'CZ',
#      'DE',
#      'DJ',
#      'DK',
#      'DM',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FJ',
#      'FM',
#      'FR',
#      'GA',
#      'GB',
#      'GD',
#      'GE',
#      'GH',
#      'GM',
#      'GN',
#      'GQ',
#      'GR',
#      'GT',
#      'GW',
#      'GY',
#      'HK',
#      'HN',
#      'HT',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JM',
#      'JO',
#      'JP',
#      'KE',
#      'KG',
#      'KH',
#      'KI',
#      'KM',
#      'KN',
#      'KR',
#      'KW',
#      'KZ',
#      'LA',
#      'LB',
#      'LC',
#      'LI',
#      'LK',
#      'LS',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'MG',
#      'MH',
#      'ML',
#      'MN',
#      'MO',
#      'MR',
#      'MT',
#      'MU',
#      'MV',
#      'MW',
#      'MX',
#      'MY',
#      'MZ',
#      'NA',
#      'NE',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NP',
#      'NR',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PG',
#      'PH',
#      'PK',
#      'PL',
#      'PS',
#      'PT',
#      'PW',
#      'PY',
#      'QA',
#      'RO',
#      'RW',
#      'SA',
#      'SB',
#      'SC',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SL',
#      'SM',
#      'SN',
#      'SR',
#      'ST',
#      'SV',
#      'SZ',
#      'TD',
#      'TG',
#      'TH',
#      'TJ',
#      'TL',
#      'TN',
#      'TO',
#      'TR',
#      'TT',
#      'TV',
#      'TW',
#      'TZ',
#      'UA',
#      'UG',
#      'US',
#      'UY',
#      'UZ',
#      'VC',
#      'VE',
#      'VN',
#      'VU',
#      'WS',
#      'ZA',
#      'ZM'],
#     'disc_number': 1,
#     'duration_ms': 186959,
#     'explicit': True,
#     'external_ids': {'isrc': 'TCADJ1714578'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/3EeKXJWkNTQTqqzRehTG7H'},
#     'href': 'https://api.spotify.com/v1/tracks/3EeKXJWkNTQTqqzRehTG7H',
#     'id': '3EeKXJWkNTQTqqzRehTG7H',
#     'is_local': False,
#     'name': 'The Cure',
#     'popularity': 55,
#     'preview_url': 'https://p.scdn.co/mp3-preview/dd9cb0ba5f9ef3f9a62414bedcc8f9089927c3aa?cid=da00ed264eaf4f94ba2adf23ff058567',
#     'track_number': 13,
#     'type': 'track',
#     'uri': 'spotify:track:3EeKXJWkNTQTqqzRehTG7H'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7bu3H8JO7d0UbMoVzbo70s'},
#        'href': 'https://api.spotify.com/v1/artists/7bu3H8JO7d0UbMoVzbo70s',
#        'id': '7bu3H8JO7d0UbMoVzbo70s',
#        'name': 'The Cure',
#        'type': 'artist',
#        'uri': 'spotify:artist:7bu3H8JO7d0UbMoVzbo70s'}],
#      'available_markets': ['CA', 'US'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/6HhpmJekzDCRu2K64ZbWqw'},
#      'href': 'https://api.spotify.com/v1/albums/6HhpmJekzDCRu2K64ZbWqw',
#      'id': '6HhpmJekzDCRu2K64ZbWqw',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2731b54add5c2a3a337e512941b',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e021b54add5c2a3a337e512941b',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048511b54add5c2a3a337e512941b',
#        'width': 64}],
#      'name': 'The Head on the Door',
#      'release_date': '1985-08-26',
#      'release_date_precision': 'day',
#      'total_tracks': 10,
#      'type': 'album',
#      'uri': 'spotify:album:6HhpmJekzDCRu2K64ZbWqw'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7bu3H8JO7d0UbMoVzbo70s'},
#       'href': 'https://api.spotify.com/v1/artists/7bu3H8JO7d0UbMoVzbo70s',
#       'id': '7bu3H8JO7d0UbMoVzbo70s',
#       'name': 'The Cure',
#       'type': 'artist',
#       'uri': 'spotify:artist:7bu3H8JO7d0UbMoVzbo70s'}],
#     'available_markets': ['CA', 'US'],
#     'disc_number': 1,
#     'duration_ms': 203266,
#     'explicit': False,
#     'external_ids': {'isrc': 'USEE10608884'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/7ABE6G4uQxbNtYgVrpBBPA'},
#     'href': 'https://api.spotify.com/v1/tracks/7ABE6G4uQxbNtYgVrpBBPA',
#     'id': '7ABE6G4uQxbNtYgVrpBBPA',
#     'is_local': False,
#     'name': 'Close to Me - 2006 Remaster',
#     'popularity': 58,
#     'preview_url': 'https://p.scdn.co/mp3-preview/c296ae38843f51f32552788b1adcb28b872c312f?cid=da00ed264eaf4f94ba2adf23ff058567',
#     'track_number': 7,
#     'type': 'track',
#     'uri': 'spotify:track:7ABE6G4uQxbNtYgVrpBBPA'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0CqDqmyIQ9VQHQp52OEbB0'},
#        'href': 'https://api.spotify.com/v1/artists/0CqDqmyIQ9VQHQp52OEbB0',
#        'id': '0CqDqmyIQ9VQHQp52OEbB0',
#        'name': 'Unspoken',
#        'type': 'artist',
#        'uri': 'spotify:artist:0CqDqmyIQ9VQHQp52OEbB0'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AO',
#       'AR',
#       'AT',
#       'AU',
#       'AZ',
#       'BA',
#       'BB',
#       'BD',
#       'BE',
#       'BF',
#       'BG',
#       'BH',
#       'BI',
#       'BJ',
#       'BN',
#       'BO',
#       'BR',
#       'BS',
#       'BT',
#       'BW',
#       'BY',
#       'BZ',
#       'CA',
#       'CD',
#       'CG',
#       'CH',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CV',
#       'CW',
#       'CY',
#       'CZ',
#       'DE',
#       'DJ',
#       'DK',
#       'DM',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FJ',
#       'FM',
#       'FR',
#       'GA',
#       'GB',
#       'GD',
#       'GE',
#       'GH',
#       'GM',
#       'GN',
#       'GQ',
#       'GR',
#       'GT',
#       'GW',
#       'GY',
#       'HK',
#       'HN',
#       'HR',
#       'HT',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IQ',
#       'IS',
#       'IT',
#       'JM',
#       'JO',
#       'JP',
#       'KE',
#       'KG',
#       'KH',
#       'KI',
#       'KM',
#       'KN',
#       'KR',
#       'KW',
#       'KZ',
#       'LA',
#       'LB',
#       'LC',
#       'LI',
#       'LK',
#       'LR',
#       'LS',
#       'LT',
#       'LU',
#       'LV',
#       'LY',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MG',
#       'MH',
#       'MK',
#       'ML',
#       'MN',
#       'MO',
#       'MR',
#       'MT',
#       'MU',
#       'MV',
#       'MW',
#       'MX',
#       'MY',
#       'MZ',
#       'NA',
#       'NE',
#       'NG',
#       'NI',
#       'NL',
#       'NO',
#       'NP',
#       'NR',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PG',
#       'PH',
#       'PK',
#       'PL',
#       'PS',
#       'PT',
#       'PW',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RW',
#       'SA',
#       'SB',
#       'SC',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SL',
#       'SM',
#       'SN',
#       'SR',
#       'ST',
#       'SV',
#       'SZ',
#       'TD',
#       'TG',
#       'TH',
#       'TJ',
#       'TL',
#       'TN',
#       'TO',
#       'TR',
#       'TT',
#       'TV',
#       'TW',
#       'TZ',
#       'UA',
#       'UG',
#       'US',
#       'UY',
#       'UZ',
#       'VC',
#       'VE',
#       'VN',
#       'VU',
#       'WS',
#       'XK',
#       'ZA',
#       'ZM',
#       'ZW'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/2kxksyPx2mFZGj5L6Ztq3I'},
#      'href': 'https://api.spotify.com/v1/albums/2kxksyPx2mFZGj5L6Ztq3I',
#      'id': '2kxksyPx2mFZGj5L6Ztq3I',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273733b0f6179cad37c21657fb5',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02733b0f6179cad37c21657fb5',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851733b0f6179cad37c21657fb5',
#        'width': 64}],
#      'name': 'Follow Through (Deluxe Edition)',
#      'release_date': '2016-08-26',
#      'release_date_precision': 'day',
#      'total_tracks': 14,
#      'type': 'album',
#      'uri': 'spotify:album:2kxksyPx2mFZGj5L6Ztq3I'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0CqDqmyIQ9VQHQp52OEbB0'},
#       'href': 'https://api.spotify.com/v1/artists/0CqDqmyIQ9VQHQp52OEbB0',
#       'id': '0CqDqmyIQ9VQHQp52OEbB0',
#       'name': 'Unspoken',
#       'type': 'artist',
#       'uri': 'spotify:artist:0CqDqmyIQ9VQHQp52OEbB0'}],
#     'available_markets': ['AD',
#      'AE',
#      'AG',
#      'AL',
#      'AM',
#      'AO',
#      'AR',
#      'AT',
#      'AU',
#      'AZ',
#      'BA',
#      'BB',
#      'BD',
#      'BE',
#      'BF',
#      'BG',
#      'BH',
#      'BI',
#      'BJ',
#      'BN',
#      'BO',
#      'BR',
#      'BS',
#      'BT',
#      'BW',
#      'BY',
#      'BZ',
#      'CA',
#      'CD',
#      'CG',
#      'CH',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CV',
#      'CW',
#      'CY',
#      'CZ',
#      'DE',
#      'DJ',
#      'DK',
#      'DM',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FJ',
#      'FM',
#      'FR',
#      'GA',
#      'GB',
#      'GD',
#      'GE',
#      'GH',
#      'GM',
#      'GN',
#      'GQ',
#      'GR',
#      'GT',
#      'GW',
#      'GY',
#      'HK',
#      'HN',
#      'HR',
#      'HT',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IQ',
#      'IS',
#      'IT',
#      'JM',
#      'JO',
#      'JP',
#      'KE',
#      'KG',
#      'KH',
#      'KI',
#      'KM',
#      'KN',
#      'KR',
#      'KW',
#      'KZ',
#      'LA',
#      'LB',
#      'LC',
#      'LI',
#      'LK',
#      'LR',
#      'LS',
#      'LT',
#      'LU',
#      'LV',
#      'LY',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MG',
#      'MH',
#      'MK',
#      'ML',
#      'MN',
#      'MO',
#      'MR',
#      'MT',
#      'MU',
#      'MV',
#      'MW',
#      'MX',
#      'MY',
#      'MZ',
#      'NA',
#      'NE',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NP',
#      'NR',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PG',
#      'PH',
#      'PK',
#      'PL',
#      'PS',
#      'PT',
#      'PW',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RW',
#      'SA',
#      'SB',
#      'SC',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SL',
#      'SM',
#      'SN',
#      'SR',
#      'ST',
#      'SV',
#      'SZ',
#      'TD',
#      'TG',
#      'TH',
#      'TJ',
#      'TL',
#      'TN',
#      'TO',
# ...
#        'width': 64}],
#      'name': 'Limbs & Branches',
#      'release_date': '2008-10-28',
#      'release_date_precision': 'day',
#      'total_tracks': 12,
#      'type': 'album',
#      'uri': 'spotify:album:6i971rX8SB9Ad5IcpDRysI'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5D3h9ZoobhetjXw3dKhcaq'},
#       'href': 'https://api.spotify.com/v1/artists/5D3h9ZoobhetjXw3dKhcaq',
#       'id': '5D3h9ZoobhetjXw3dKhcaq',
#       'name': 'Jon Foreman',
#       'type': 'artist',
#       'uri': 'spotify:artist:5D3h9ZoobhetjXw3dKhcaq'}],
#     'available_markets': ['AD',
#      'AE',
#      'AG',
#      'AL',
#      'AM',
#      'AO',
#      'AR',
#      'AT',
#      'AU',
#      'AZ',
#      'BA',
#      'BB',
#      'BD',
#      'BE',
#      'BF',
#      'BG',
#      'BH',
#      'BI',
#      'BJ',
#      'BN',
#      'BO',
#      'BR',
#      'BS',
#      'BT',
#      'BW',
#      'BY',
#      'BZ',
#      'CA',
#      'CD',
#      'CG',
#      'CH',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CV',
#      'CW',
#      'CY',
#      'CZ',
#      'DE',
#      'DJ',
#      'DK',
#      'DM',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FJ',
#      'FM',
#      'FR',
#      'GA',
#      'GB',
#      'GD',
#      'GE',
#      'GH',
#      'GM',
#      'GN',
#      'GQ',
#      'GR',
#      'GT',
#      'GW',
#      'GY',
#      'HK',
#      'HN',
#      'HR',
#      'HT',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IQ',
#      'IS',
#      'IT',
#      'JM',
#      'JO',
#      'JP',
#      'KE',
#      'KG',
#      'KH',
#      'KI',
#      'KM',
#      'KN',
#      'KR',
#      'KW',
#      'KZ',
#      'LA',
#      'LB',
#      'LC',
#      'LI',
#      'LK',
#      'LR',
#      'LS',
#      'LT',
#      'LU',
#      'LV',
#      'LY',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MG',
#      'MH',
#      'MK',
#      'ML',
#      'MN',
#      'MO',
#      'MR',
#      'MT',
#      'MU',
#      'MV',
#      'MW',
#      'MX',
#      'MY',
#      'MZ',
#      'NA',
#      'NE',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NP',
#      'NR',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PG',
#      'PH',
#      'PK',
#      'PL',
#      'PS',
#      'PT',
#      'PW',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RW',
#      'SA',
#      'SB',
#      'SC',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SL',
#      'SM',
#      'SN',
#      'SR',
#      'ST',
#      'SV',
#      'SZ',
#      'TD',
#      'TG',
#      'TH',
#      'TJ',
#      'TL',
#      'TN',
#      'TO',
#      'TR',
#      'TT',
#      'TV',
#      'TW',
#      'TZ',
#      'UA',
#      'UG',
#      'US',
#      'UY',
#      'UZ',
#      'VC',
#      'VE',
#      'VN',
#      'VU',
#      'WS',
#      'XK',
#      'ZA',
#      'ZM',
#      'ZW'],
#     'disc_number': 1,
#     'duration_ms': 285266,
#     'explicit': False,
#     'external_ids': {'isrc': 'QM5GK1500030'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/2Sngau33mxsVFYOCKlqXhi'},
#     'href': 'https://api.spotify.com/v1/tracks/2Sngau33mxsVFYOCKlqXhi',
#     'id': '2Sngau33mxsVFYOCKlqXhi',
#     'is_local': False,
#     'name': 'The Cure For Pain',
#     'popularity': 34,
#     'preview_url': None,
#     'track_number': 3,
#     'type': 'track',
#     'uri': 'spotify:track:2Sngau33mxsVFYOCKlqXhi'},
#    {'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0Upxnyh9nIUNSOmNE8WF4R'},
#        'href': 'https://api.spotify.com/v1/artists/0Upxnyh9nIUNSOmNE8WF4R',
#        'id': '0Upxnyh9nIUNSOmNE8WF4R',
#        'name': 'BYOR',
#        'type': 'artist',
#        'uri': 'spotify:artist:0Upxnyh9nIUNSOmNE8WF4R'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AO',
#       'AR',
#       'AT',
#       'AU',
#       'AZ',
#       'BA',
#       'BB',
#       'BD',
#       'BE',
#       'BF',
#       'BG',
#       'BH',
#       'BI',
#       'BJ',
#       'BN',
#       'BO',
#       'BR',
#       'BS',
#       'BT',
#       'BW',
#       'BY',
#       'BZ',
#       'CA',
#       'CD',
#       'CG',
#       'CH',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CV',
#       'CW',
#       'CY',
#       'CZ',
#       'DE',
#       'DJ',
#       'DK',
#       'DM',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FJ',
#       'FM',
#       'FR',
#       'GA',
#       'GB',
#       'GD',
#       'GE',
#       'GH',
#       'GM',
#       'GN',
#       'GQ',
#       'GR',
#       'GT',
#       'GW',
#       'GY',
#       'HK',
#       'HN',
#       'HR',
#       'HT',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IQ',
#       'IS',
#       'IT',
#       'JM',
#       'JO',
#       'JP',
#       'KE',
#       'KG',
#       'KH',
#       'KI',
#       'KM',
#       'KN',
#       'KR',
#       'KW',
#       'KZ',
#       'LA',
#       'LB',
#       'LC',
#       'LI',
#       'LK',
#       'LR',
#       'LS',
#       'LT',
#       'LU',
#       'LV',
#       'LY',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MG',
#       'MH',
#       'MK',
#       'ML',
#       'MN',
#       'MO',
#       'MR',
#       'MT',
#       'MU',
#       'MV',
#       'MW',
#       'MX',
#       'MY',
#       'MZ',
#       'NA',
#       'NE',
#       'NG',
#       'NI',
#       'NL',
#       'NO',
#       'NP',
#       'NR',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PG',
#       'PH',
#       'PK',
#       'PL',
#       'PS',
#       'PT',
#       'PW',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RW',
#       'SA',
#       'SB',
#       'SC',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SL',
#       'SM',
#       'SN',
#       'SR',
#       'ST',
#       'SV',
#       'SZ',
#       'TD',
#       'TG',
#       'TH',
#       'TJ',
#       'TL',
#       'TN',
#       'TO',
#       'TR',
#       'TT',
#       'TV',
#       'TW',
#       'TZ',
#       'UA',
#       'UG',
#       'US',
#       'UY',
#       'UZ',
#       'VC',
#       'VE',
#       'VN',
#       'VU',
#       'WS',
#       'XK',
#       'ZA',
#       'ZM',
#       'ZW'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/0GoiTL7JcNLGlkpDQYPoMa'},
#      'href': 'https://api.spotify.com/v1/albums/0GoiTL7JcNLGlkpDQYPoMa',
#      'id': '0GoiTL7JcNLGlkpDQYPoMa',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b27359b4ea0802b108188dfdf022',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e0259b4ea0802b108188dfdf022',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d0000485159b4ea0802b108188dfdf022',
#        'width': 64}],
#      'name': 'The Cure',
#      'release_date': '2021-02-26',
#      'release_date_precision': 'day',
#      'total_tracks': 1,
#      'type': 'album',
#      'uri': 'spotify:album:0GoiTL7JcNLGlkpDQYPoMa'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0Upxnyh9nIUNSOmNE8WF4R'},
#       'href': 'https://api.spotify.com/v1/artists/0Upxnyh9nIUNSOmNE8WF4R',
#       'id': '0Upxnyh9nIUNSOmNE8WF4R',
#       'name': 'BYOR',
#       'type': 'artist',
#       'uri': 'spotify:artist:0Upxnyh9nIUNSOmNE8WF4R'}],
#     'available_markets': ['AD',
#      'AE',
#      'AG',
#      'AL',
#      'AM',
#      'AO',
#      'AR',
#      'AT',
#      'AU',
#      'AZ',
#      'BA',
#      'BB',
#      'BD',
#      'BE',
#      'BF',
#      'BG',
#      'BH',
#      'BI',
#      'BJ',
#      'BN',
#      'BO',
#      'BR',
#      'BS',
#      'BT',
#      'BW',
#      'BY',
#      'BZ',
#      'CA',
#      'CD',
#      'CG',
#      'CH',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CV',
#      'CW',
#      'CY',
#      'CZ',
#      'DE',
#      'DJ',
#      'DK',
#      'DM',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FJ',
#      'FM',
#      'FR',
#      'GA',
#      'GB',
#      'GD',
#      'GE',
#      'GH',
#      'GM',
#      'GN',
#      'GQ',
#      'GR',
#      'GT',
#      'GW',
#      'GY',
#      'HK',
#      'HN',
#      'HR',
#      'HT',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IQ',
#      'IS',
#      'IT',
#      'JM',
#      'JO',
#      'JP',
#      'KE',
#      'KG',
#      'KH',
#      'KI',
#      'KM',
#      'KN',
#      'KR',
#      'KW',
#      'KZ',
#      'LA',
#      'LB',
#      'LC',
#      'LI',
#      'LK',
#      'LR',
#      'LS',
#      'LT',
#      'LU',
#      'LV',
#      'LY',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MG',
#      'MH',
#      'MK',
#      'ML',
#      'MN',
#      'MO',
#      'MR',
#      'MT',
#      'MU',
#      'MV',
#      'MW',
#      'MX',
#      'MY',
#      'MZ',
#      'NA',
#      'NE',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NP',
#      'NR',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PG',
#      'PH',
#      'PK',
#      'PL',
#      'PS',
#      'PT',
#      'PW',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RW',
#      'SA',
#      'SB',
#      'SC',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SL',
#      'SM',
#      'SN',
#      'SR',
#      'ST',
#      'SV',
#      'SZ',
#      'TD',
#      'TG',
#      'TH',
#      'TJ',
#      'TL',
#      'TN',
#      'TO',
#      'TR',
#      'TT',
#      'TV',
#      'TW',
#      'TZ',
#      'UA',
#      'UG',
#      'US',
#      'UY',
#      'UZ',
#      'VC',
#      'VE',
#      'VN',
#      'VU',
#      'WS',
#      'XK',
#      'ZA',
#      'ZM',
#      'ZW'],
#     'disc_number': 1,
#     'duration_ms': 236190,
#     'explicit': False,
#     'external_ids': {'isrc': 'CYA112000817'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/714EIYBfjoDLtuU81fnfij'},
#     'href': 'https://api.spotify.com/v1/tracks/714EIYBfjoDLtuU81fnfij',
#     'id': '714EIYBfjoDLtuU81fnfij',
#     'is_local': False,
#     'name': 'The Cure',
#     'popularity': 34,
#     'preview_url': 'https://p.scdn.co/mp3-preview/afd8b7d8e0df40728e05dff33ce4f0028e6e3592?cid=da00ed264eaf4f94ba2adf23ff058567',
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:714EIYBfjoDLtuU81fnfij'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5k979N1TnPncUyqlXlaRSv'},
#        'href': 'https://api.spotify.com/v1/artists/5k979N1TnPncUyqlXlaRSv',
#        'id': '5k979N1TnPncUyqlXlaRSv',
#        'name': 'The Longest Johns',
#        'type': 'artist',
#        'uri': 'spotify:artist:5k979N1TnPncUyqlXlaRSv'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AO',
#       'AR',
#       'AT',
#       'AU',
#       'AZ',
#       'BA',
#       'BB',
#       'BD',
#       'BE',
#       'BF',
#       'BG',
#       'BH',
#       'BI',
#       'BJ',
#       'BN',
#       'BO',
#       'BR',
#       'BS',
#       'BT',
#       'BW',
#       'BY',
#       'BZ',
#       'CA',
#       'CD',
#       'CG',
#       'CH',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CV',
#       'CW',
#       'CY',
#       'CZ',
#       'DE',
#       'DJ',
#       'DK',
#       'DM',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FJ',
#       'FM',
#       'FR',
#       'GA',
#       'GB',
#       'GD',
#       'GE',
#       'GH',
#       'GM',
#       'GN',
#       'GQ',
#       'GR',
#       'GT',
#       'GW',
#       'GY',
#       'HK',
#       'HN',
#       'HR',
#       'HT',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IQ',
#       'IS',
#       'IT',
#       'JM',
#       'JO',
#       'JP',
#       'KE',
#       'KG',
#       'KH',
#       'KI',
#       'KM',
#       'KN',
#       'KR',
#       'KW',
#       'KZ',
#       'LA',
#       'LB',
#       'LC',
#       'LI',
#       'LK',
#       'LR',
#       'LS',
#       'LT',
#       'LU',
#       'LV',
#       'LY',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MG',
#       'MH',
#       'MK',
#       'ML',
#       'MN',
#       'MO',
#       'MR',
#       'MT',
#       'MU',
#       'MV',
#       'MW',
#       'MX',
#       'MY',
#       'MZ',
#       'NA',
#       'NE',
#       'NG',
#       'NI',
#       'NL',
#       'NO',
#       'NP',
#       'NR',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PG',
#       'PH',
#       'PK',
#       'PL',
#       'PS',
#       'PT',
#       'PW',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RW',
#       'SA',
#       'SB',
#       'SC',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SL',
#       'SM',
#       'SN',
#       'SR',
#       'ST',
#       'SV',
#       'SZ',
#       'TD',
#       'TG',
#       'TH',
#       'TJ',
#       'TL',
#       'TN',
#       'TO',
#       'TR',
#       'TT',
#       'TV',
#       'TW',
#       'TZ',
#       'UA',
#       'UG',
#       'US',
#       'UY',
#       'UZ',
#       'VC',
#       'VE',
#       'VN',
#       'VU',
#       'WS',
#       'XK',
#       'ZA',
#       'ZM',
#       'ZW'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/23FGerfaTcQOlEdySv5Wdq'},
#      'href': 'https://api.spotify.com/v1/albums/23FGerfaTcQOlEdySv5Wdq',
#      'id': '23FGerfaTcQOlEdySv5Wdq',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2730e344b28681e6ee72eb67f78',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e020e344b28681e6ee72eb67f78',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048510e344b28681e6ee72eb67f78',
#        'width': 64}],
#      'name': 'Cures What Ails Ya',
#      'release_date': '2020-06-10',
#      'release_date_precision': 'day',
#      'total_tracks': 12,
#      'type': 'album',
#      'uri': 'spotify:album:23FGerfaTcQOlEdySv5Wdq'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5k979N1TnPncUyqlXlaRSv'},
#       'href': 'https://api.spotify.com/v1/artists/5k979N1TnPncUyqlXlaRSv',
#       'id': '5k979N1TnPncUyqlXlaRSv',
#       'name': 'The Longest Johns',
#       'type': 'artist',
#       'uri': 'spotify:artist:5k979N1TnPncUyqlXlaRSv'}],
#     'available_markets': ['AD',
#      'AE',
#      'AG',
#      'AL',
#      'AM',
#      'AO',
#      'AR',
#      'AT',
#      'AU',
#      'AZ',
#      'BA',
#      'BB',
#      'BD',
#      'BE',
#      'BF',
#      'BG',
#      'BH',
#      'BI',
#      'BJ',
#      'BN',
#      'BO',
#      'BR',
#      'BS',
#      'BT',
#      'BW',
#      'BY',
#      'BZ',
#      'CA',
#      'CD',
#      'CG',
#      'CH',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CV',
#      'CW',
#      'CY',
#      'CZ',
#      'DE',
#      'DJ',
#      'DK',
#      'DM',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FJ',
#      'FM',
#      'FR',
#      'GA',
#      'GB',
#      'GD',
#      'GE',
#      'GH',
#      'GM',
#      'GN',
#      'GQ',
#      'GR',
#      'GT',
#      'GW',
#      'GY',
#      'HK',
#      'HN',
#      'HR',
#      'HT',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IQ',
#      'IS',
#      'IT',
#      'JM',
#      'JO',
#      'JP',
#      'KE',
#      'KG',
#      'KH',
#      'KI',
#      'KM',
#      'KN',
#      'KR',
#      'KW',
#      'KZ',
#      'LA',
#      'LB',
#      'LC',
#      'LI',
#      'LK',
#      'LR',
#      'LS',
#      'LT',
#      'LU',
#      'LV',
#      'LY',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MG',
#      'MH',
#      'MK',
#      'ML',
#      'MN',
#      'MO',
#      'MR',
#      'MT',
#      'MU',
#      'MV',
#      'MW',
#      'MX',
#      'MY',
#      'MZ',
#      'NA',
#      'NE',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NP',
#      'NR',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PG',
#      'PH',
#      'PK',
#      'PL',
#      'PS',
#      'PT',
#      'PW',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RW',
#      'SA',
#      'SB',
#      'SC',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SL',
#      'SM',
#      'SN',
#      'SR',
#      'ST',
#      'SV',
#      'SZ',
#      'TD',
#      'TG',
#      'TH',
#      'TJ',
#      'TL',
#      'TN',
#      'TO',
#      'TR',
#      'TT',
#      'TV',
#      'TW',
#      'TZ',
#      'UA',
#      'UG',
#      'US',
#      'UY',
#      'UZ',
#      'VC',
#      'VE',
#      'VN',
#      'VU',
#      'WS',
#      'XK',
#      'ZA',
#      'ZM',
#      'ZW'],
#     'disc_number': 1,
#     'duration_ms': 201000,
#     'explicit': False,
#     'external_ids': {'isrc': 'UKPGJ1800034'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/74D4H6tg3QnZ1SpEA9pjGk'},
#     'href': 'https://api.spotify.com/v1/tracks/74D4H6tg3QnZ1SpEA9pjGk',
#     'id': '74D4H6tg3QnZ1SpEA9pjGk',
#     'is_local': False,
#     'name': 'Ashes',
#     'popularity': 50,
#     'preview_url': 'https://p.scdn.co/mp3-preview/a88304f97e5d5445fa76f308d3336508e6067aa4?cid=da00ed264eaf4f94ba2adf23ff058567',
#     'track_number': 6,
#     'type': 'track',
#     'uri': 'spotify:track:74D4H6tg3QnZ1SpEA9pjGk'}],
#   'limit': 50,
#   'next': 'https://api.spotify.com/v1/search?query=The+Cure&type=track&offset=50&limit=50',
#   'offset': 0,
#   'previous': None,
#   'total': 10119}}

# %%
results.keys()
# Out:
# dict_keys(['tracks'])

# %%
results['tracks']['href']
# Out:
# 'https://api.spotify.com/v1/search?query=The+Cure&type=track&offset=0&limit=50'

# %%
len(results['tracks']['items'])
# Out:
# 50

# %%
results['tracks']['items']
# Out:
# [{'album': {'album_type': 'single',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1HY2Jd0NmPuamShAr6KMms'},
#      'href': 'https://api.spotify.com/v1/artists/1HY2Jd0NmPuamShAr6KMms',
#      'id': '1HY2Jd0NmPuamShAr6KMms',
#      'name': 'Lady Gaga',
#      'type': 'artist',
#      'uri': 'spotify:artist:1HY2Jd0NmPuamShAr6KMms'}],
#    'available_markets': ['AD',
#     'AE',
#     'AG',
#     'AL',
#     'AM',
#     'AO',
#     'AR',
#     'AT',
#     'AU',
#     'AZ',
#     'BA',
#     'BB',
#     'BD',
#     'BE',
#     'BF',
#     'BG',
#     'BH',
#     'BI',
#     'BJ',
#     'BN',
#     'BO',
#     'BR',
#     'BS',
#     'BT',
#     'BW',
#     'BY',
#     'BZ',
#     'CA',
#     'CD',
#     'CG',
#     'CH',
#     'CI',
#     'CL',
#     'CM',
#     'CO',
#     'CR',
#     'CV',
#     'CW',
#     'CY',
#     'CZ',
#     'DE',
#     'DJ',
#     'DK',
#     'DM',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FJ',
#     'FM',
#     'FR',
#     'GA',
#     'GB',
#     'GD',
#     'GE',
#     'GH',
#     'GM',
#     'GN',
#     'GQ',
#     'GR',
#     'GT',
#     'GW',
#     'GY',
#     'HK',
#     'HN',
#     'HR',
#     'HT',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IQ',
#     'IS',
#     'IT',
#     'JM',
#     'JO',
#     'JP',
#     'KE',
#     'KG',
#     'KH',
#     'KI',
#     'KM',
#     'KN',
#     'KR',
#     'KW',
#     'KZ',
#     'LA',
#     'LB',
#     'LC',
#     'LI',
#     'LK',
#     'LR',
#     'LS',
#     'LT',
#     'LU',
#     'LV',
#     'LY',
#     'MA',
#     'MC',
#     'MD',
#     'ME',
#     'MG',
#     'MH',
#     'MK',
#     'ML',
#     'MN',
#     'MO',
#     'MR',
#     'MT',
#     'MU',
#     'MV',
#     'MW',
#     'MX',
#     'MY',
#     'MZ',
#     'NA',
#     'NE',
#     'NG',
#     'NI',
#     'NL',
#     'NO',
#     'NP',
#     'NR',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PG',
#     'PH',
#     'PK',
#     'PL',
#     'PS',
#     'PT',
#     'PW',
#     'PY',
#     'QA',
#     'RO',
#     'RS',
#     'RW',
#     'SA',
#     'SB',
#     'SC',
#     'SE',
#     'SG',
#     'SI',
#     'SK',
#     'SL',
#     'SM',
#     'SN',
#     'SR',
#     'ST',
#     'SV',
#     'SZ',
#     'TD',
#     'TG',
#     'TH',
#     'TJ',
#     'TL',
#     'TN',
#     'TO',
#     'TR',
#     'TT',
#     'TV',
#     'TW',
#     'TZ',
#     'UA',
#     'UG',
#     'US',
#     'UY',
#     'UZ',
#     'VC',
#     'VE',
#     'VN',
#     'VU',
#     'WS',
#     'XK',
#     'ZA',
#     'ZM',
#     'ZW'],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/2yaSZnZhaxsbQ5xhgGbw3g'},
#    'href': 'https://api.spotify.com/v1/albums/2yaSZnZhaxsbQ5xhgGbw3g',
#    'id': '2yaSZnZhaxsbQ5xhgGbw3g',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b27331cc5716a5c922b0482787b7',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/ab67616d00001e0231cc5716a5c922b0482787b7',
#      'width': 300},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/ab67616d0000485131cc5716a5c922b0482787b7',
#      'width': 64}],
#    'name': 'The Cure',
#    'release_date': '2017-04-16',
#    'release_date_precision': 'day',
#    'total_tracks': 1,
#    'type': 'album',
#    'uri': 'spotify:album:2yaSZnZhaxsbQ5xhgGbw3g'},
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1HY2Jd0NmPuamShAr6KMms'},
#     'href': 'https://api.spotify.com/v1/artists/1HY2Jd0NmPuamShAr6KMms',
#     'id': '1HY2Jd0NmPuamShAr6KMms',
#     'name': 'Lady Gaga',
#     'type': 'artist',
#     'uri': 'spotify:artist:1HY2Jd0NmPuamShAr6KMms'}],
#   'available_markets': ['AD',
#    'AE',
#    'AG',
#    'AL',
#    'AM',
#    'AO',
#    'AR',
#    'AT',
#    'AU',
#    'AZ',
#    'BA',
#    'BB',
#    'BD',
#    'BE',
#    'BF',
#    'BG',
#    'BH',
#    'BI',
#    'BJ',
#    'BN',
#    'BO',
#    'BR',
#    'BS',
#    'BT',
#    'BW',
#    'BY',
#    'BZ',
#    'CA',
#    'CD',
#    'CG',
#    'CH',
#    'CI',
#    'CL',
#    'CM',
#    'CO',
#    'CR',
#    'CV',
#    'CW',
#    'CY',
#    'CZ',
#    'DE',
#    'DJ',
#    'DK',
#    'DM',
#    'DO',
#    'DZ',
#    'EC',
#    'EE',
#    'EG',
#    'ES',
#    'FI',
#    'FJ',
#    'FM',
#    'FR',
#    'GA',
#    'GB',
#    'GD',
#    'GE',
#    'GH',
#    'GM',
#    'GN',
#    'GQ',
#    'GR',
#    'GT',
#    'GW',
#    'GY',
#    'HK',
#    'HN',
#    'HR',
#    'HT',
#    'HU',
#    'ID',
#    'IE',
#    'IL',
#    'IN',
#    'IQ',
#    'IS',
#    'IT',
#    'JM',
#    'JO',
#    'JP',
#    'KE',
#    'KG',
#    'KH',
#    'KI',
#    'KM',
#    'KN',
#    'KR',
#    'KW',
#    'KZ',
#    'LA',
#    'LB',
#    'LC',
#    'LI',
#    'LK',
#    'LR',
#    'LS',
#    'LT',
#    'LU',
#    'LV',
#    'LY',
#    'MA',
#    'MC',
#    'MD',
#    'ME',
#    'MG',
#    'MH',
#    'MK',
#    'ML',
#    'MN',
#    'MO',
#    'MR',
#    'MT',
#    'MU',
#    'MV',
#    'MW',
#    'MX',
#    'MY',
#    'MZ',
#    'NA',
#    'NE',
#    'NG',
#    'NI',
#    'NL',
#    'NO',
#    'NP',
#    'NR',
#    'NZ',
#    'OM',
#    'PA',
#    'PE',
#    'PG',
#    'PH',
#    'PK',
#    'PL',
#    'PS',
#    'PT',
#    'PW',
#    'PY',
#    'QA',
#    'RO',
#    'RS',
#    'RW',
#    'SA',
#    'SB',
#    'SC',
#    'SE',
#    'SG',
#    'SI',
#    'SK',
#    'SL',
#    'SM',
#    'SN',
#    'SR',
#    'ST',
#    'SV',
#    'SZ',
#    'TD',
#    'TG',
#    'TH',
#    'TJ',
#    'TL',
#    'TN',
#    'TO',
#    'TR',
#    'TT',
#    'TV',
#    'TW',
#    'TZ',
#    'UA',
#    'UG',
#    'US',
#    'UY',
#    'UZ',
#    'VC',
#    'VE',
#    'VN',
#    'VU',
#    'WS',
#    'XK',
#    'ZA',
#    'ZM',
#    'ZW'],
#   'disc_number': 1,
#   'duration_ms': 211363,
#   'explicit': False,
#   'external_ids': {'isrc': 'USUM71703782'},
#   'external_urls': {'spotify': 'https://open.spotify.com/track/34oB5r0lcN3fYWCs2uA1k5'},
#   'href': 'https://api.spotify.com/v1/tracks/34oB5r0lcN3fYWCs2uA1k5',
#   'id': '34oB5r0lcN3fYWCs2uA1k5',
#   'is_local': False,
#   'name': 'The Cure',
#   'popularity': 64,
#   'preview_url': None,
#   'track_number': 1,
#   'type': 'track',
#   'uri': 'spotify:track:34oB5r0lcN3fYWCs2uA1k5'},
#  {'album': {'album_type': 'album',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7bu3H8JO7d0UbMoVzbo70s'},
#      'href': 'https://api.spotify.com/v1/artists/7bu3H8JO7d0UbMoVzbo70s',
#      'id': '7bu3H8JO7d0UbMoVzbo70s',
#      'name': 'The Cure',
#      'type': 'artist',
#      'uri': 'spotify:artist:7bu3H8JO7d0UbMoVzbo70s'}],
#    'available_markets': ['CA', 'US'],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/3x1CmNdXWU0DzpTZXFFRZu'},
#    'href': 'https://api.spotify.com/v1/albums/3x1CmNdXWU0DzpTZXFFRZu',
#    'id': '3x1CmNdXWU0DzpTZXFFRZu',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b273e410fa31e3dfcc7521cde86d',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/ab67616d00001e02e410fa31e3dfcc7521cde86d',
#      'width': 300},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/ab67616d00004851e410fa31e3dfcc7521cde86d',
#      'width': 64}],
#    'name': 'Wish',
#    'release_date': '1992-04-21',
#    'release_date_precision': 'day',
#    'total_tracks': 12,
#    'type': 'album',
#    'uri': 'spotify:album:3x1CmNdXWU0DzpTZXFFRZu'},
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7bu3H8JO7d0UbMoVzbo70s'},
#     'href': 'https://api.spotify.com/v1/artists/7bu3H8JO7d0UbMoVzbo70s',
#     'id': '7bu3H8JO7d0UbMoVzbo70s',
#     'name': 'The Cure',
#     'type': 'artist',
#     'uri': 'spotify:artist:7bu3H8JO7d0UbMoVzbo70s'}],
#   'available_markets': ['CA', 'US'],
#   'disc_number': 1,
#   'duration_ms': 214400,
#   'explicit': False,
#   'external_ids': {'isrc': 'USEE10180267'},
#   'external_urls': {'spotify': 'https://open.spotify.com/track/263aNAQCeFSWipk896byo6'},
#   'href': 'https://api.spotify.com/v1/tracks/263aNAQCeFSWipk896byo6',
#   'id': '263aNAQCeFSWipk896byo6',
#   'is_local': False,
#   'name': "Friday I'm in Love",
#   'popularity': 66,
#   'preview_url': 'https://p.scdn.co/mp3-preview/958e347444599fa593cb2d86459e67ad18719c72?cid=da00ed264eaf4f94ba2adf23ff058567',
#   'track_number': 7,
#   'type': 'track',
#   'uri': 'spotify:track:263aNAQCeFSWipk896byo6'},
#  {'album': {'album_type': 'compilation',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0LyfQWJT6nXafLPZqxe9Of'},
#      'href': 'https://api.spotify.com/v1/artists/0LyfQWJT6nXafLPZqxe9Of',
#      'id': '0LyfQWJT6nXafLPZqxe9Of',
#      'name': 'Various Artists',
#      'type': 'artist',
#      'uri': 'spotify:artist:0LyfQWJT6nXafLPZqxe9Of'}],
#    'available_markets': ['AE',
#     'AL',
#     'AR',
#     'AT',
#     'AU',
#     'BA',
#     'BE',
#     'BG',
#     'BH',
#     'BO',
#     'BR',
#     'CA',
#     'CH',
#     'CI',
#     'CL',
#     'CM',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DE',
#     'DK',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FR',
#     'GB',
#     'GH',
#     'GR',
#     'GT',
#     'HK',
#     'HN',
#     'HR',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IS',
#     'IT',
#     'JP',
#     'KE',
#     'KH',
#     'KR',
#     'KW',
#     'LB',
#     'LK',
#     'LT',
#     'LU',
#     'LV',
#     'MA',
#     'ME',
#     'MK',
#     'MT',
#     'MX',
#     'MY',
#     'NG',
#     'NI',
#     'NL',
#     'NO',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PH',
#     'PL',
#     'PT',
#     'PY',
#     'QA',
#     'RO',
#     'RS',
#     'SA',
#     'SE',
#     'SG',
#     'SI',
#     'SK',
#     'SN',
#     'SV',
#     'TH',
#     'TN',
#     'TR',
#     'TT',
#     'TW',
#     'UA',
#     'US',
#     'UY',
#     'VE',
#     'VN',
#     'XK',
#     'ZA'],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/0V7t8K29zrXonTFzzz6Z3V'},
#    'href': 'https://api.spotify.com/v1/albums/0V7t8K29zrXonTFzzz6Z3V',
#    'id': '0V7t8K29zrXonTFzzz6Z3V',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b273a0331d0633619818dda00ea9',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/ab67616d00001e02a0331d0633619818dda00ea9',
#      'width': 300},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/ab67616d00004851a0331d0633619818dda00ea9',
#      'width': 64}],
#    'name': "Sun's Out, Bums Out",
#    'release_date': '2022-04-20',
#    'release_date_precision': 'day',
#    'total_tracks': 28,
#    'type': 'album',
#    'uri': 'spotify:album:0V7t8K29zrXonTFzzz6Z3V'},
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1HY2Jd0NmPuamShAr6KMms'},
#     'href': 'https://api.spotify.com/v1/artists/1HY2Jd0NmPuamShAr6KMms',
#     'id': '1HY2Jd0NmPuamShAr6KMms',
#     'name': 'Lady Gaga',
#     'type': 'artist',
#     'uri': 'spotify:artist:1HY2Jd0NmPuamShAr6KMms'}],
#   'available_markets': ['AE',
#    'AL',
#    'AR',
#    'AT',
#    'AU',
#    'BA',
#    'BE',
#    'BG',
#    'BH',
#    'BO',
#    'BR',
#    'CA',
#    'CH',
#    'CI',
#    'CL',
#    'CM',
#    'CO',
#    'CR',
#    'CY',
#    'CZ',
#    'DE',
#    'DK',
#    'DO',
#    'DZ',
#    'EC',
#    'EE',
#    'EG',
#    'ES',
#    'FI',
#    'FR',
#    'GB',
#    'GH',
#    'GR',
#    'GT',
#    'HK',
#    'HN',
#    'HR',
#    'HU',
#    'ID',
#    'IE',
#    'IL',
#    'IN',
#    'IS',
#    'IT',
#    'JP',
#    'KE',
#    'KH',
#    'KR',
#    'KW',
#    'LB',
#    'LK',
#    'LT',
#    'LU',
#    'LV',
#    'MA',
#    'ME',
#    'MK',
#    'MT',
#    'MX',
#    'MY',
#    'NG',
#    'NI',
#    'NL',
#    'NO',
#    'NZ',
#    'OM',
#    'PA',
#    'PE',
#    'PH',
#    'PL',
#    'PT',
#    'PY',
#    'QA',
#    'RO',
#    'RS',
#    'SA',
#    'SE',
#    'SG',
#    'SI',
#    'SK',
#    'SN',
#    'SV',
#    'TH',
#    'TN',
#    'TR',
#    'TT',
#    'TW',
#    'UA',
#    'US',
#    'UY',
#    'VE',
#    'VN',
#    'XK',
#    'ZA'],
#   'disc_number': 1,
#   'duration_ms': 211363,
#   'explicit': False,
#   'external_ids': {'isrc': 'USUM71703782'},
#   'external_urls': {'spotify': 'https://open.spotify.com/track/3pzMbk1YjjRsofZvNnRBoH'},
#   'href': 'https://api.spotify.com/v1/tracks/3pzMbk1YjjRsofZvNnRBoH',
#   'id': '3pzMbk1YjjRsofZvNnRBoH',
#   'is_local': False,
#   'name': 'The Cure',
#   'popularity': 3,
#   'preview_url': None,
#   'track_number': 20,
#   'type': 'track',
#   'uri': 'spotify:track:3pzMbk1YjjRsofZvNnRBoH'},
#  {'album': {'album_type': 'album',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7bu3H8JO7d0UbMoVzbo70s'},
#      'href': 'https://api.spotify.com/v1/artists/7bu3H8JO7d0UbMoVzbo70s',
#      'id': '7bu3H8JO7d0UbMoVzbo70s',
#      'name': 'The Cure',
#      'type': 'artist',
#      'uri': 'spotify:artist:7bu3H8JO7d0UbMoVzbo70s'}],
#    'available_markets': ['CA', 'US'],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/37Q22g0n9PzBLX6lNddrIa'},
#    'href': 'https://api.spotify.com/v1/albums/37Q22g0n9PzBLX6lNddrIa',
#    'id': '37Q22g0n9PzBLX6lNddrIa',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b2737f22337546d61faca55e0f4f',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/ab67616d00001e027f22337546d61faca55e0f4f',
#      'width': 300},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/ab67616d000048517f22337546d61faca55e0f4f',
#      'width': 64}],
#    'name': 'Kiss Me, Kiss Me, Kiss Me',
#    'release_date': '1987-05-25',
#    'release_date_precision': 'day',
#    'total_tracks': 17,
#    'type': 'album',
#    'uri': 'spotify:album:37Q22g0n9PzBLX6lNddrIa'},
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7bu3H8JO7d0UbMoVzbo70s'},
#     'href': 'https://api.spotify.com/v1/artists/7bu3H8JO7d0UbMoVzbo70s',
#     'id': '7bu3H8JO7d0UbMoVzbo70s',
#     'name': 'The Cure',
#     'type': 'artist',
#     'uri': 'spotify:artist:7bu3H8JO7d0UbMoVzbo70s'}],
#   'available_markets': ['CA', 'US'],
#   'disc_number': 1,
#   'duration_ms': 212000,
#   'explicit': False,
#   'external_ids': {'isrc': 'USEE18700009'},
#   'external_urls': {'spotify': 'https://open.spotify.com/track/76GlO5H5RT6g7y0gev86Nk'},
#   'href': 'https://api.spotify.com/v1/tracks/76GlO5H5RT6g7y0gev86Nk',
#   'id': '76GlO5H5RT6g7y0gev86Nk',
#   'is_local': False,
#   'name': 'Just like Heaven',
#   'popularity': 65,
#   'preview_url': 'https://p.scdn.co/mp3-preview/ef101f28ecd0df21cc7726ee48c1e6c7879f7d48?cid=da00ed264eaf4f94ba2adf23ff058567',
#   'track_number': 8,
#   'type': 'track',
#   'uri': 'spotify:track:76GlO5H5RT6g7y0gev86Nk'},
#  {'album': {'album_type': 'album',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0Z88iXWc4YVhtu1eFtsGk6'},
#      'href': 'https://api.spotify.com/v1/artists/0Z88iXWc4YVhtu1eFtsGk6',
#      'id': '0Z88iXWc4YVhtu1eFtsGk6',
#      'name': 'Wolves At The Gate',
#      'type': 'artist',
#      'uri': 'spotify:artist:0Z88iXWc4YVhtu1eFtsGk6'}],
#    'available_markets': ['AD',
#     'AE',
#     'AG',
#     'AL',
#     'AM',
#     'AO',
#     'AR',
#     'AT',
#     'AU',
#     'AZ',
#     'BA',
#     'BB',
#     'BD',
#     'BE',
#     'BF',
#     'BG',
#     'BH',
#     'BI',
#     'BJ',
#     'BN',
#     'BO',
#     'BR',
#     'BS',
#     'BT',
#     'BW',
#     'BY',
#     'BZ',
#     'CA',
#     'CD',
#     'CG',
#     'CH',
#     'CI',
#     'CL',
#     'CM',
#     'CO',
#     'CR',
#     'CV',
#     'CY',
#     'CZ',
#     'DE',
#     'DJ',
#     'DK',
#     'DM',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FJ',
#     'FM',
#     'FR',
#     'GA',
#     'GB',
#     'GD',
#     'GE',
#     'GH',
#     'GM',
#     'GN',
#     'GQ',
#     'GR',
#     'GT',
#     'GW',
#     'GY',
#     'HK',
#     'HN',
#     'HR',
#     'HT',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IQ',
#     'IS',
#     'IT',
#     'JM',
#     'JO',
#     'JP',
#     'KE',
#     'KG',
#     'KH',
#     'KI',
#     'KM',
#     'KN',
#     'KR',
#     'KW',
#     'KZ',
#     'LA',
#     'LB',
#     'LC',
#     'LI',
#     'LK',
#     'LR',
#     'LS',
#     'LT',
#     'LU',
#     'LV',
#     'LY',
#     'MA',
#     'MC',
#     'MD',
#     'ME',
#     'MG',
#     'MH',
#     'MK',
#     'ML',
#     'MN',
#     'MO',
#     'MR',
#     'MT',
#     'MU',
#     'MV',
#     'MW',
#     'MX',
#     'MY',
#     'MZ',
#     'NA',
#     'NE',
#     'NG',
#     'NI',
#     'NL',
#     'NO',
#     'NP',
#     'NR',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PG',
#     'PH',
#     'PK',
#     'PL',
#     'PS',
#     'PT',
#     'PW',
#     'PY',
#     'QA',
#     'RO',
#     'RS',
#     'RW',
#     'SA',
#     'SB',
#     'SC',
#     'SE',
#     'SG',
#     'SI',
#     'SK',
#     'SL',
#     'SM',
#     'SN',
#     'SR',
#     'ST',
#     'SV',
#     'SZ',
#     'TD',
#     'TG',
#     'TH',
#     'TJ',
#     'TL',
#     'TN',
#     'TO',
#     'TR',
#     'TT',
#     'TV',
#     'TW',
#     'TZ',
#     'UA',
#     'UG',
#     'US',
#     'UY',
#     'UZ',
#     'VC',
#     'VE',
#     'VN',
#     'VU',
#     'WS',
#     'XK',
#     'ZA',
#     'ZM',
#     'ZW'],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/6L8gLKCluioceYP7WNmcol'},
#    'href': 'https://api.spotify.com/v1/albums/6L8gLKCluioceYP7WNmcol',
#    'id': '6L8gLKCluioceYP7WNmcol',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b273dc4299ee6013d5522734c4e7',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/ab67616d00001e02dc4299ee6013d5522734c4e7',
#      'width': 300},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/ab67616d00004851dc4299ee6013d5522734c4e7',
#      'width': 64}],
#    'name': 'Eclipse',
#    'release_date': '2019-07-26',
#    'release_date_precision': 'day',
#    'total_tracks': 13,
#    'type': 'album',
#    'uri': 'spotify:album:6L8gLKCluioceYP7WNmcol'},
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0Z88iXWc4YVhtu1eFtsGk6'},
#     'href': 'https://api.spotify.com/v1/artists/0Z88iXWc4YVhtu1eFtsGk6',
#     'id': '0Z88iXWc4YVhtu1eFtsGk6',
#     'name': 'Wolves At The Gate',
#     'type': 'artist',
#     'uri': 'spotify:artist:0Z88iXWc4YVhtu1eFtsGk6'}],
#   'available_markets': ['AD',
#    'AE',
#    'AG',
#    'AL',
#    'AM',
#    'AO',
#    'AR',
#    'AT',
#    'AU',
#    'AZ',
#    'BA',
#    'BB',
#    'BD',
#    'BE',
#    'BF',
#    'BG',
#    'BH',
#    'BI',
#    'BJ',
#    'BN',
#    'BO',
#    'BR',
#    'BS',
#    'BT',
#    'BW',
#    'BY',
#    'BZ',
#    'CA',
#    'CD',
#    'CG',
#    'CH',
#    'CI',
#    'CL',
#    'CM',
#    'CO',
#    'CR',
#    'CV',
#    'CY',
#    'CZ',
#    'DE',
#    'DJ',
#    'DK',
#    'DM',
#    'DO',
#    'DZ',
#    'EC',
#    'EE',
#    'EG',
#    'ES',
#    'FI',
#    'FJ',
#    'FM',
#    'FR',
#    'GA',
#    'GB',
#    'GD',
#    'GE',
#    'GH',
#    'GM',
#    'GN',
#    'GQ',
#    'GR',
#    'GT',
#    'GW',
#    'GY',
#    'HK',
#    'HN',
#    'HR',
#    'HT',
#    'HU',
#    'ID',
#    'IE',
#    'IL',
#    'IN',
#    'IQ',
#    'IS',
#    'IT',
#    'JM',
#    'JO',
#    'JP',
#    'KE',
#    'KG',
#    'KH',
#    'KI',
#    'KM',
#    'KN',
#    'KR',
#    'KW',
#    'KZ',
#    'LA',
#    'LB',
#    'LC',
#    'LI',
#    'LK',
#    'LR',
#    'LS',
#    'LT',
#    'LU',
#    'LV',
#    'LY',
#    'MA',
#    'MC',
#    'MD',
#    'ME',
#    'MG',
#    'MH',
#    'MK',
#    'ML',
#    'MN',
#    'MO',
#    'MR',
#    'MT',
#    'MU',
#    'MV',
#    'MW',
#    'MX',
#    'MY',
#    'MZ',
#    'NA',
#    'NE',
#    'NG',
#    'NI',
#    'NL',
#    'NO',
#    'NP',
#    'NR',
#    'NZ',
#    'OM',
#    'PA',
#    'PE',
#    'PG',
#    'PH',
#    'PK',
#    'PL',
#    'PS',
#    'PT',
#    'PW',
#    'PY',
#    'QA',
#    'RO',
#    'RS',
#    'RW',
#    'SA',
#    'SB',
#    'SC',
#    'SE',
#    'SG',
#    'SI',
#    'SK',
#    'SL',
#    'SM',
#    'SN',
#    'SR',
#    'ST',
#    'SV',
#    'SZ',
#    'TD',
#    'TG',
#    'TH',
#    'TJ',
#    'TL',
#    'TN',
#    'TO',
#    'TR',
#    'TT',
#    'TV',
#    'TW',
#    'TZ',
#    'UA',
#    'UG',
#    'US',
#    'UY',
#    'UZ',
#    'VC',
#    'VE',
#    'VN',
#    'VU',
#    'WS',
#    'XK',
#    'ZA',
#    'ZM',
#    'ZW'],
#   'disc_number': 1,
#   'duration_ms': 256693,
#   'explicit': False,
#   'external_ids': {'isrc': 'QMGVJ1900011'},
#   'external_urls': {'spotify': 'https://open.spotify.com/track/3bimN1JcQkbLWcUJexAEyh'},
#   'href': 'https://api.spotify.com/v1/tracks/3bimN1JcQkbLWcUJexAEyh',
#   'id': '3bimN1JcQkbLWcUJexAEyh',
#   'is_local': False,
#   'name': 'The Cure',
#   'popularity': 35,
#   'preview_url': 'https://p.scdn.co/mp3-preview/27120fe278e19dd9288d1f4883a0d9860f7a02ff?cid=da00ed264eaf4f94ba2adf23ff058567',
#   'track_number': 1,
#   'type': 'track',
#   'uri': 'spotify:track:3bimN1JcQkbLWcUJexAEyh'},
#  {'album': {'album_type': 'album',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7bu3H8JO7d0UbMoVzbo70s'},
#      'href': 'https://api.spotify.com/v1/artists/7bu3H8JO7d0UbMoVzbo70s',
#      'id': '7bu3H8JO7d0UbMoVzbo70s',
#      'name': 'The Cure',
#      'type': 'artist',
#      'uri': 'spotify:artist:7bu3H8JO7d0UbMoVzbo70s'}],
#    'available_markets': ['CA', 'US'],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/7gPql7GFpBMOxeO80vMMsC'},
#    'href': 'https://api.spotify.com/v1/albums/7gPql7GFpBMOxeO80vMMsC',
#    'id': '7gPql7GFpBMOxeO80vMMsC',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b2735d0d65102be8606e439e54cc',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/ab67616d00001e025d0d65102be8606e439e54cc',
#      'width': 300},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/ab67616d000048515d0d65102be8606e439e54cc',
#      'width': 64}],
#    'name': 'Three Imaginary Boys (Deluxe Edition)',
#    'release_date': '1979-05-11',
#    'release_date_precision': 'day',
#    'total_tracks': 33,
#    'type': 'album',
#    'uri': 'spotify:album:7gPql7GFpBMOxeO80vMMsC'},
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7bu3H8JO7d0UbMoVzbo70s'},
#     'href': 'https://api.spotify.com/v1/artists/7bu3H8JO7d0UbMoVzbo70s',
#     'id': '7bu3H8JO7d0UbMoVzbo70s',
#     'name': 'The Cure',
#     'type': 'artist',
#     'uri': 'spotify:artist:7bu3H8JO7d0UbMoVzbo70s'}],
#   'available_markets': ['CA', 'US'],
#   'disc_number': 1,
#   'duration_ms': 157533,
#   'explicit': False,
#   'external_ids': {'isrc': 'USEE10413404'},
#   'external_urls': {'spotify': 'https://open.spotify.com/track/4dneV7C1yDt9UtyxrQY375'},
#   'href': 'https://api.spotify.com/v1/tracks/4dneV7C1yDt9UtyxrQY375',
#   'id': '4dneV7C1yDt9UtyxrQY375',
#   'is_local': False,
#   'name': "Boys Don't Cry - Single Version",
#   'popularity': 61,
#   'preview_url': 'https://p.scdn.co/mp3-preview/7fedf0d2730a71fcc3870f4e09ec4d5464969414?cid=da00ed264eaf4f94ba2adf23ff058567',
#   'track_number': 29,
#   'type': 'track',
#   'uri': 'spotify:track:4dneV7C1yDt9UtyxrQY375'},
#  {'album': {'album_type': 'compilation',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7bu3H8JO7d0UbMoVzbo70s'},
#      'href': 'https://api.spotify.com/v1/artists/7bu3H8JO7d0UbMoVzbo70s',
#      'id': '7bu3H8JO7d0UbMoVzbo70s',
#      'name': 'The Cure',
#      'type': 'artist',
#      'uri': 'spotify:artist:7bu3H8JO7d0UbMoVzbo70s'}],
#    'available_markets': ['CA', 'US'],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/0BRThmbAV1p2CxAuxgpHRj'},
#    'href': 'https://api.spotify.com/v1/albums/0BRThmbAV1p2CxAuxgpHRj',
#    'id': '0BRThmbAV1p2CxAuxgpHRj',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b2732780880a9583a363c28c60d5',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/ab67616d00001e022780880a9583a363c28c60d5',
#      'width': 300},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/ab67616d000048512780880a9583a363c28c60d5',
#      'width': 64}],
#    'name': 'Galore',
#    'release_date': '1997-10-17',
#    'release_date_precision': 'day',
#    'total_tracks': 18,
#    'type': 'album',
#    'uri': 'spotify:album:0BRThmbAV1p2CxAuxgpHRj'},
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7bu3H8JO7d0UbMoVzbo70s'},
#     'href': 'https://api.spotify.com/v1/artists/7bu3H8JO7d0UbMoVzbo70s',
#     'id': '7bu3H8JO7d0UbMoVzbo70s',
#     'name': 'The Cure',
#     'type': 'artist',
#     'uri': 'spotify:artist:7bu3H8JO7d0UbMoVzbo70s'}],
#   'available_markets': ['CA', 'US'],
#   'disc_number': 1,
#   'duration_ms': 208000,
#   'explicit': False,
#   'external_ids': {'isrc': 'GBALB8900003'},
#   'external_urls': {'spotify': 'https://open.spotify.com/track/1jeZTGhJ3C0txPw188XCQ8'},
#   'href': 'https://api.spotify.com/v1/tracks/1jeZTGhJ3C0txPw188XCQ8',
#   'id': '1jeZTGhJ3C0txPw188XCQ8',
#   'is_local': False,
#   'name': 'Lovesong',
#   'popularity': 25,
#   'preview_url': 'https://p.scdn.co/mp3-preview/96971dae4c776626199b0c3abb14e397f489f89e?cid=da00ed264eaf4f94ba2adf23ff058567',
#   'track_number': 7,
#   'type': 'track',
#   'uri': 'spotify:track:1jeZTGhJ3C0txPw188XCQ8'},
#  {'album': {'album_type': 'album',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7bu3H8JO7d0UbMoVzbo70s'},
#      'href': 'https://api.spotify.com/v1/artists/7bu3H8JO7d0UbMoVzbo70s',
#      'id': '7bu3H8JO7d0UbMoVzbo70s',
#      'name': 'The Cure',
#      'type': 'artist',
#      'uri': 'spotify:artist:7bu3H8JO7d0UbMoVzbo70s'}],
#    'available_markets': ['CA', 'US'],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/6vQB3ZBxnQPP3jQcGV2qzg'},
#    'href': 'https://api.spotify.com/v1/albums/6vQB3ZBxnQPP3jQcGV2qzg',
#    'id': '6vQB3ZBxnQPP3jQcGV2qzg',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b273c7ca2db25ad377e022bc3975',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/ab67616d00001e02c7ca2db25ad377e022bc3975',
#      'width': 300},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/ab67616d00004851c7ca2db25ad377e022bc3975',
#      'width': 64}],
#    'name': 'Disintegration (Deluxe Edition)',
#    'release_date': '1989-05-02',
#    'release_date_precision': 'day',
#    'total_tracks': 44,
#    'type': 'album',
#    'uri': 'spotify:album:6vQB3ZBxnQPP3jQcGV2qzg'},
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7bu3H8JO7d0UbMoVzbo70s'},
#     'href': 'https://api.spotify.com/v1/artists/7bu3H8JO7d0UbMoVzbo70s',
#     'id': '7bu3H8JO7d0UbMoVzbo70s',
#     'name': 'The Cure',
#     'type': 'artist',
#     'uri': 'spotify:artist:7bu3H8JO7d0UbMoVzbo70s'}],
#   'available_markets': ['CA', 'US'],
#   'disc_number': 1,
#   'duration_ms': 209573,
#   'explicit': False,
#   'external_ids': {'isrc': 'USEE10901455'},
#   'external_urls': {'spotify': 'https://open.spotify.com/track/0X5C4WjQNubRysTkHOubz3'},
#   'href': 'https://api.spotify.com/v1/tracks/0X5C4WjQNubRysTkHOubz3',
#   'id': '0X5C4WjQNubRysTkHOubz3',
#   'is_local': False,
#   'name': 'Lovesong - 2010 Remaster',
#   'popularity': 60,
#   'preview_url': 'https://p.scdn.co/mp3-preview/f9b7d686922b260b092b2c8e5186d40e2c63fd06?cid=da00ed264eaf4f94ba2adf23ff058567',
#   'track_number': 4,
#   'type': 'track',
#   'uri': 'spotify:track:0X5C4WjQNubRysTkHOubz3'},
#  {'album': {'album_type': 'album',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3e7awlrlDSwF3iM0WBjGMp'},
#      'href': 'https://api.spotify.com/v1/artists/3e7awlrlDSwF3iM0WBjGMp',
#      'id': '3e7awlrlDSwF3iM0WBjGMp',
#      'name': 'Little Mix',
#      'type': 'artist',
#      'uri': 'spotify:artist:3e7awlrlDSwF3iM0WBjGMp'}],
#    'available_markets': ['AD',
#     'AE',
#     'AG',
#     'AL',
#     'AM',
#     'AO',
#     'AR',
#     'AT',
#     'AU',
#     'AZ',
#     'BA',
#     'BB',
#     'BD',
#     'BE',
#     'BF',
#     'BG',
#     'BH',
#     'BI',
#     'BJ',
#     'BN',
#     'BO',
#     'BR',
#     'BS',
#     'BT',
#     'BW',
#     'BY',
#     'BZ',
#     'CA',
#     'CD',
#     'CG',
#     'CH',
#     'CI',
#     'CL',
#     'CM',
#     'CO',
#     'CR',
#     'CV',
#     'CW',
#     'CY',
#     'CZ',
#     'DE',
#     'DJ',
#     'DK',
#     'DM',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FJ',
#     'FM',
#     'FR',
#     'GA',
#     'GB',
#     'GD',
#     'GE',
#     'GH',
#     'GM',
#     'GN',
#     'GQ',
#     'GR',
#     'GT',
#     'GW',
#     'GY',
#     'HK',
#     'HN',
#     'HR',
#     'HT',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IQ',
#     'IS',
#     'IT',
#     'JM',
#     'JO',
#     'JP',
#     'KE',
#     'KG',
#     'KH',
#     'KI',
#     'KM',
#     'KN',
#     'KR',
#     'KW',
#     'KZ',
#     'LA',
#     'LB',
#     'LC',
#     'LI',
#     'LK',
#     'LR',
#     'LS',
#     'LT',
#     'LU',
#     'LV',
#     'LY',
#     'MA',
#     'MC',
#     'MD',
#     'ME',
#     'MG',
#     'MH',
#     'MK',
#     'ML',
#     'MN',
#     'MO',
#     'MR',
#     'MT',
#     'MU',
#     'MV',
#     'MW',
#     'MX',
#     'MY',
#     'MZ',
#     'NA',
#     'NE',
#     'NG',
#     'NI',
#     'NL',
#     'NO',
#     'NP',
#     'NR',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PG',
#     'PH',
#     'PK',
#     'PL',
#     'PS',
#     'PT',
#     'PW',
#     'PY',
#     'QA',
#     'RO',
#     'RS',
#     'RW',
#     'SA',
#     'SB',
#     'SC',
#     'SE',
#     'SG',
#     'SI',
#     'SK',
#     'SL',
#     'SM',
#     'SN',
#     'SR',
#     'ST',
#     'SV',
#     'SZ',
#     'TD',
#     'TG',
#     'TH',
#     'TJ',
#     'TL',
#     'TN',
#     'TO',
#     'TR',
#     'TT',
#     'TV',
#     'TW',
#     'TZ',
#     'UA',
#     'UG',
#     'US',
#     'UY',
#     'UZ',
#     'VC',
#     'VE',
#     'VN',
#     'VU',
#     'WS',
#     'XK',
#     'ZA',
#     'ZM',
#     'ZW'],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/7Ho8gAx4haSxv1eFLQwvTj'},
#    'href': 'https://api.spotify.com/v1/albums/7Ho8gAx4haSxv1eFLQwvTj',
#    'id': '7Ho8gAx4haSxv1eFLQwvTj',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b27315174e2b2347b5ffbea6dbf0',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/ab67616d00001e0215174e2b2347b5ffbea6dbf0',
#      'width': 300},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/ab67616d0000485115174e2b2347b5ffbea6dbf0',
#      'width': 64}],
#    'name': 'LM5 (Deluxe)',
#    'release_date': '2018-11-16',
#    'release_date_precision': 'day',
#    'total_tracks': 18,
#    'type': 'album',
#    'uri': 'spotify:album:7Ho8gAx4haSxv1eFLQwvTj'},
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3e7awlrlDSwF3iM0WBjGMp'},
#     'href': 'https://api.spotify.com/v1/artists/3e7awlrlDSwF3iM0WBjGMp',
#     'id': '3e7awlrlDSwF3iM0WBjGMp',
#     'name': 'Little Mix',
#     'type': 'artist',
#     'uri': 'spotify:artist:3e7awlrlDSwF3iM0WBjGMp'}],
#   'available_markets': ['AD',
#    'AE',
#    'AG',
#    'AL',
#    'AM',
#    'AO',
#    'AR',
#    'AT',
#    'AU',
#    'AZ',
#    'BA',
#    'BB',
#    'BD',
#    'BE',
#    'BF',
#    'BG',
#    'BH',
#    'BI',
#    'BJ',
#    'BN',
#    'BO',
#    'BR',
#    'BS',
#    'BT',
#    'BW',
#    'BY',
#    'BZ',
#    'CA',
#    'CD',
#    'CG',
#    'CH',
#    'CI',
#    'CL',
#    'CM',
#    'CO',
#    'CR',
#    'CV',
#    'CW',
#    'CY',
#    'CZ',
#    'DE',
#    'DJ',
#    'DK',
#    'DM',
#    'DO',
#    'DZ',
#    'EC',
#    'EE',
#    'EG',
#    'ES',
#    'FI',
#    'FJ',
#    'FM',
#    'FR',
#    'GA',
#    'GB',
#    'GD',
#    'GE',
#    'GH',
#    'GM',
#    'GN',
#    'GQ',
#    'GR',
#    'GT',
#    'GW',
#    'GY',
#    'HK',
#    'HN',
#    'HR',
#    'HT',
#    'HU',
#    'ID',
#    'IE',
#    'IL',
#    'IN',
#    'IQ',
#    'IS',
#    'IT',
#    'JM',
#    'JO',
#    'JP',
#    'KE',
#    'KG',
#    'KH',
#    'KI',
#    'KM',
#    'KN',
#    'KR',
#    'KW',
#    'KZ',
#    'LA',
#    'LB',
#    'LC',
#    'LI',
#    'LK',
#    'LR',
#    'LS',
#    'LT',
#    'LU',
#    'LV',
#    'LY',
#    'MA',
#    'MC',
#    'MD',
#    'ME',
#    'MG',
#    'MH',
#    'MK',
#    'ML',
#    'MN',
#    'MO',
#    'MR',
#    'MT',
#    'MU',
#    'MV',
#    'MW',
#    'MX',
#    'MY',
#    'MZ',
#    'NA',
#    'NE',
#    'NG',
#    'NI',
#    'NL',
#    'NO',
#    'NP',
#    'NR',
#    'NZ',
#    'OM',
#    'PA',
#    'PE',
#    'PG',
#    'PH',
#    'PK',
#    'PL',
#    'PS',
#    'PT',
#    'PW',
#    'PY',
#    'QA',
#    'RO',
#    'RS',
#    'RW',
#    'SA',
#    'SB',
#    'SC',
#    'SE',
#    'SG',
#    'SI',
#    'SK',
#    'SL',
#    'SM',
#    'SN',
#    'SR',
#    'ST',
#    'SV',
#    'SZ',
#    'TD',
#    'TG',
#    'TH',
#    'TJ',
#    'TL',
#    'TN',
#    'TO',
#    'TR',
#    'TT',
#    'TV',
#    'TW',
#    'TZ',
#    'UA',
#    'UG',
#    'US',
#    'UY',
#    'UZ',
#    'VC',
#    'VE',
#    'VN',
#    'VU',
#    'WS',
#    'XK',
#    'ZA',
#    'ZM',
#    'ZW'],
#   'disc_number': 1,
#   'duration_ms': 215333,
#   'explicit': False,
#   'external_ids': {'isrc': 'GBHMU1800101'},
#   'external_urls': {'spotify': 'https://open.spotify.com/track/1HiNWMc7vmFVM5mdwrNKnO'},
#   'href': 'https://api.spotify.com/v1/tracks/1HiNWMc7vmFVM5mdwrNKnO',
#   'id': '1HiNWMc7vmFVM5mdwrNKnO',
#   'is_local': False,
#   'name': 'The Cure',
#   'popularity': 52,
#   'preview_url': 'https://p.scdn.co/mp3-preview/0022ae86f60ed73a8e56144a0b7fd2a0ea7c404d?cid=da00ed264eaf4f94ba2adf23ff058567',
#   'track_number': 14,
#   'type': 'track',
#   'uri': 'spotify:track:1HiNWMc7vmFVM5mdwrNKnO'},
#  {'album': {'album_type': 'album',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6h4DZCXvwXapWw1C2vygaC'},
#      'href': 'https://api.spotify.com/v1/artists/6h4DZCXvwXapWw1C2vygaC',
#      'id': '6h4DZCXvwXapWw1C2vygaC',
#      'name': 'Sam Lans!',
#      'type': 'artist',
#      'uri': 'spotify:artist:6h4DZCXvwXapWw1C2vygaC'}],
#    'available_markets': ['AD',
#     'AE',
#     'AG',
#     'AM',
#     'AO',
#     'AR',
#     'AT',
#     'AU',
#     'AZ',
#     'BB',
#     'BD',
#     'BE',
#     'BF',
#     'BG',
#     'BH',
#     'BI',
#     'BJ',
#     'BN',
#     'BO',
#     'BR',
#     'BS',
#     'BT',
#     'BW',
#     'BZ',
#     'CA',
#     'CG',
#     'CH',
#     'CL',
#     'CM',
#     'CO',
#     'CR',
#     'CV',
#     'CW',
#     'CY',
#     'CZ',
#     'DE',
#     'DJ',
#     'DK',
#     'DM',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FJ',
#     'FM',
#     'FR',
#     'GA',
#     'GB',
#     'GD',
#     'GE',
#     'GH',
#     'GM',
#     'GN',
#     'GQ',
#     'GR',
#     'GT',
#     'GW',
#     'GY',
#     'HK',
#     'HN',
#     'HT',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IS',
#     'IT',
#     'JM',
#     'JO',
#     'JP',
#     'KE',
#     'KG',
#     'KH',
#     'KI',
#     'KM',
#     'KN',
#     'KR',
#     'KW',
#     'KZ',
#     'LA',
#     'LB',
#     'LC',
#     'LI',
#     'LK',
#     'LS',
#     'LT',
#     'LU',
#     'LV',
#     'MA',
#     'MC',
#     'MD',
#     'MG',
#     'MH',
#     'ML',
#     'MN',
#     'MO',
#     'MR',
#     'MT',
#     'MU',
#     'MV',
#     'MW',
#     'MX',
#     'MY',
#     'MZ',
#     'NA',
#     'NE',
#     'NG',
#     'NI',
#     'NL',
#     'NO',
#     'NP',
#     'NR',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PG',
#     'PH',
#     'PK',
#     'PL',
#     'PS',
#     'PT',
#     'PW',
#     'PY',
#     'QA',
#     'RO',
#     'RW',
#     'SA',
#     'SB',
#     'SC',
#     'SE',
#     'SG',
#     'SI',
#     'SK',
#     'SL',
#     'SM',
#     'SN',
#     'SR',
#     'ST',
#     'SV',
#     'SZ',
#     'TD',
#     'TG',
#     'TH',
#     'TJ',
#     'TL',
#     'TN',
#     'TO',
#     'TR',
#     'TT',
#     'TV',
#     'TW',
#     'TZ',
#     'UA',
#     'UG',
#     'US',
#     'UY',
#     'UZ',
#     'VC',
#     'VE',
#     'VN',
#     'VU',
#     'WS',
#     'ZA',
#     'ZM'],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/09F3pYMyjgdEj2rOD4aZhx'},
#    'href': 'https://api.spotify.com/v1/albums/09F3pYMyjgdEj2rOD4aZhx',
#    'id': '09F3pYMyjgdEj2rOD4aZhx',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b273eae50582ee86f25f5504abd5',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/ab67616d00001e02eae50582ee86f25f5504abd5',
#      'width': 300},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/ab67616d00004851eae50582ee86f25f5504abd5',
#      'width': 64}],
#    'name': 'Mk Ultra',
#    'release_date': '2017-10-06',
#    'release_date_precision': 'day',
#    'total_tracks': 13,
#    'type': 'album',
#    'uri': 'spotify:album:09F3pYMyjgdEj2rOD4aZhx'},
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6h4DZCXvwXapWw1C2vygaC'},
#     'href': 'https://api.spotify.com/v1/artists/6h4DZCXvwXapWw1C2vygaC',
#     'id': '6h4DZCXvwXapWw1C2vygaC',
#     'name': 'Sam Lans!',
#     'type': 'artist',
#     'uri': 'spotify:artist:6h4DZCXvwXapWw1C2vygaC'}],
#   'available_markets': ['AD',
#    'AE',
#    'AG',
#    'AM',
#    'AO',
#    'AR',
#    'AT',
#    'AU',
#    'AZ',
#    'BB',
#    'BD',
#    'BE',
#    'BF',
#    'BG',
#    'BH',
#    'BI',
#    'BJ',
#    'BN',
#    'BO',
#    'BR',
#    'BS',
#    'BT',
#    'BW',
#    'BZ',
#    'CA',
#    'CG',
#    'CH',
#    'CL',
#    'CM',
#    'CO',
#    'CR',
#    'CV',
#    'CW',
#    'CY',
#    'CZ',
#    'DE',
#    'DJ',
#    'DK',
#    'DM',
#    'DO',
#    'DZ',
#    'EC',
#    'EE',
#    'EG',
#    'ES',
#    'FI',
#    'FJ',
#    'FM',
#    'FR',
#    'GA',
#    'GB',
#    'GD',
#    'GE',
#    'GH',
#    'GM',
#    'GN',
#    'GQ',
#    'GR',
#    'GT',
#    'GW',
#    'GY',
#    'HK',
#    'HN',
#    'HT',
#    'HU',
#    'ID',
#    'IE',
#    'IL',
#    'IN',
#    'IS',
#    'IT',
#    'JM',
#    'JO',
#    'JP',
#    'KE',
#    'KG',
#    'KH',
#    'KI',
#    'KM',
#    'KN',
#    'KR',
#    'KW',
#    'KZ',
#    'LA',
#    'LB',
#    'LC',
#    'LI',
#    'LK',
#    'LS',
#    'LT',
#    'LU',
#    'LV',
#    'MA',
#    'MC',
#    'MD',
#    'MG',
#    'MH',
#    'ML',
#    'MN',
#    'MO',
#    'MR',
#    'MT',
#    'MU',
#    'MV',
#    'MW',
#    'MX',
#    'MY',
#    'MZ',
#    'NA',
#    'NE',
#    'NG',
#    'NI',
#    'NL',
#    'NO',
#    'NP',
#    'NR',
#    'NZ',
#    'OM',
#    'PA',
#    'PE',
#    'PG',
#    'PH',
#    'PK',
#    'PL',
#    'PS',
#    'PT',
#    'PW',
#    'PY',
#    'QA',
#    'RO',
#    'RW',
#    'SA',
#    'SB',
#    'SC',
#    'SE',
#    'SG',
#    'SI',
#    'SK',
#    'SL',
#    'SM',
#    'SN',
#    'SR',
#    'ST',
#    'SV',
#    'SZ',
#    'TD',
#    'TG',
#    'TH',
#    'TJ',
#    'TL',
#    'TN',
#    'TO',
#    'TR',
#    'TT',
#    'TV',
#    'TW',
#    'TZ',
#    'UA',
#    'UG',
#    'US',
#    'UY',
#    'UZ',
#    'VC',
#    'VE',
#    'VN',
#    'VU',
#    'WS',
#    'ZA',
#    'ZM'],
#   'disc_number': 1,
#   'duration_ms': 186959,
#   'explicit': True,
#   'external_ids': {'isrc': 'TCADJ1714578'},
#   'external_urls': {'spotify': 'https://open.spotify.com/track/3EeKXJWkNTQTqqzRehTG7H'},
#   'href': 'https://api.spotify.com/v1/tracks/3EeKXJWkNTQTqqzRehTG7H',
#   'id': '3EeKXJWkNTQTqqzRehTG7H',
#   'is_local': False,
#   'name': 'The Cure',
#   'popularity': 55,
#   'preview_url': 'https://p.scdn.co/mp3-preview/dd9cb0ba5f9ef3f9a62414bedcc8f9089927c3aa?cid=da00ed264eaf4f94ba2adf23ff058567',
#   'track_number': 13,
#   'type': 'track',
#   'uri': 'spotify:track:3EeKXJWkNTQTqqzRehTG7H'},
#  {'album': {'album_type': 'album',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7bu3H8JO7d0UbMoVzbo70s'},
#      'href': 'https://api.spotify.com/v1/artists/7bu3H8JO7d0UbMoVzbo70s',
#      'id': '7bu3H8JO7d0UbMoVzbo70s',
#      'name': 'The Cure',
#      'type': 'artist',
#      'uri': 'spotify:artist:7bu3H8JO7d0UbMoVzbo70s'}],
#    'available_markets': ['CA', 'US'],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/6HhpmJekzDCRu2K64ZbWqw'},
#    'href': 'https://api.spotify.com/v1/albums/6HhpmJekzDCRu2K64ZbWqw',
#    'id': '6HhpmJekzDCRu2K64ZbWqw',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b2731b54add5c2a3a337e512941b',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/ab67616d00001e021b54add5c2a3a337e512941b',
#      'width': 300},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/ab67616d000048511b54add5c2a3a337e512941b',
#      'width': 64}],
#    'name': 'The Head on the Door',
#    'release_date': '1985-08-26',
#    'release_date_precision': 'day',
#    'total_tracks': 10,
#    'type': 'album',
#    'uri': 'spotify:album:6HhpmJekzDCRu2K64ZbWqw'},
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7bu3H8JO7d0UbMoVzbo70s'},
#     'href': 'https://api.spotify.com/v1/artists/7bu3H8JO7d0UbMoVzbo70s',
#     'id': '7bu3H8JO7d0UbMoVzbo70s',
#     'name': 'The Cure',
#     'type': 'artist',
#     'uri': 'spotify:artist:7bu3H8JO7d0UbMoVzbo70s'}],
#   'available_markets': ['CA', 'US'],
#   'disc_number': 1,
#   'duration_ms': 203266,
#   'explicit': False,
#   'external_ids': {'isrc': 'USEE10608884'},
#   'external_urls': {'spotify': 'https://open.spotify.com/track/7ABE6G4uQxbNtYgVrpBBPA'},
#   'href': 'https://api.spotify.com/v1/tracks/7ABE6G4uQxbNtYgVrpBBPA',
#   'id': '7ABE6G4uQxbNtYgVrpBBPA',
#   'is_local': False,
#   'name': 'Close to Me - 2006 Remaster',
#   'popularity': 58,
#   'preview_url': 'https://p.scdn.co/mp3-preview/c296ae38843f51f32552788b1adcb28b872c312f?cid=da00ed264eaf4f94ba2adf23ff058567',
#   'track_number': 7,
#   'type': 'track',
#   'uri': 'spotify:track:7ABE6G4uQxbNtYgVrpBBPA'},
#  {'album': {'album_type': 'album',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0CqDqmyIQ9VQHQp52OEbB0'},
#      'href': 'https://api.spotify.com/v1/artists/0CqDqmyIQ9VQHQp52OEbB0',
#      'id': '0CqDqmyIQ9VQHQp52OEbB0',
#      'name': 'Unspoken',
#      'type': 'artist',
#      'uri': 'spotify:artist:0CqDqmyIQ9VQHQp52OEbB0'}],
#    'available_markets': ['AD',
#     'AE',
#     'AG',
#     'AL',
#     'AM',
#     'AO',
#     'AR',
#     'AT',
#     'AU',
#     'AZ',
#     'BA',
#     'BB',
#     'BD',
#     'BE',
#     'BF',
#     'BG',
#     'BH',
#     'BI',
#     'BJ',
#     'BN',
#     'BO',
#     'BR',
#     'BS',
#     'BT',
#     'BW',
#     'BY',
#     'BZ',
#     'CA',
#     'CD',
#     'CG',
#     'CH',
#     'CI',
#     'CL',
#     'CM',
#     'CO',
#     'CR',
#     'CV',
#     'CW',
#     'CY',
#     'CZ',
#     'DE',
#     'DJ',
#     'DK',
#     'DM',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FJ',
#     'FM',
#     'FR',
#     'GA',
#     'GB',
#     'GD',
#     'GE',
#     'GH',
#     'GM',
#     'GN',
#     'GQ',
#     'GR',
#     'GT',
#     'GW',
#     'GY',
#     'HK',
#     'HN',
#     'HR',
#     'HT',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IQ',
#     'IS',
#     'IT',
#     'JM',
#     'JO',
#     'JP',
#     'KE',
#     'KG',
#     'KH',
#     'KI',
#     'KM',
#     'KN',
#     'KR',
#     'KW',
#     'KZ',
#     'LA',
#     'LB',
#     'LC',
#     'LI',
#     'LK',
#     'LR',
#     'LS',
#     'LT',
#     'LU',
#     'LV',
#     'LY',
#     'MA',
#     'MC',
#     'MD',
#     'ME',
#     'MG',
#     'MH',
#     'MK',
#     'ML',
#     'MN',
#     'MO',
#     'MR',
#     'MT',
#     'MU',
#     'MV',
#     'MW',
#     'MX',
#     'MY',
#     'MZ',
#     'NA',
#     'NE',
#     'NG',
#     'NI',
#     'NL',
#     'NO',
#     'NP',
#     'NR',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PG',
#     'PH',
#     'PK',
#     'PL',
#     'PS',
#     'PT',
#     'PW',
#     'PY',
#     'QA',
#     'RO',
#     'RS',
#     'RW',
#     'SA',
#     'SB',
#     'SC',
#     'SE',
#     'SG',
#     'SI',
#     'SK',
#     'SL',
#     'SM',
#     'SN',
#     'SR',
#     'ST',
#     'SV',
#     'SZ',
#     'TD',
#     'TG',
#     'TH',
#     'TJ',
#     'TL',
#     'TN',
#     'TO',
#     'TR',
#     'TT',
#     'TV',
#     'TW',
#     'TZ',
#     'UA',
#     'UG',
#     'US',
#     'UY',
#     'UZ',
#     'VC',
#     'VE',
#     'VN',
#     'VU',
#     'WS',
#     'XK',
#     'ZA',
#     'ZM',
#     'ZW'],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/2kxksyPx2mFZGj5L6Ztq3I'},
#    'href': 'https://api.spotify.com/v1/albums/2kxksyPx2mFZGj5L6Ztq3I',
#    'id': '2kxksyPx2mFZGj5L6Ztq3I',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b273733b0f6179cad37c21657fb5',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/ab67616d00001e02733b0f6179cad37c21657fb5',
#      'width': 300},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/ab67616d00004851733b0f6179cad37c21657fb5',
#      'width': 64}],
#    'name': 'Follow Through (Deluxe Edition)',
#    'release_date': '2016-08-26',
#    'release_date_precision': 'day',
#    'total_tracks': 14,
#    'type': 'album',
#    'uri': 'spotify:album:2kxksyPx2mFZGj5L6Ztq3I'},
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0CqDqmyIQ9VQHQp52OEbB0'},
#     'href': 'https://api.spotify.com/v1/artists/0CqDqmyIQ9VQHQp52OEbB0',
#     'id': '0CqDqmyIQ9VQHQp52OEbB0',
#     'name': 'Unspoken',
#     'type': 'artist',
#     'uri': 'spotify:artist:0CqDqmyIQ9VQHQp52OEbB0'}],
#   'available_markets': ['AD',
#    'AE',
#    'AG',
#    'AL',
#    'AM',
#    'AO',
#    'AR',
#    'AT',
#    'AU',
#    'AZ',
#    'BA',
#    'BB',
#    'BD',
#    'BE',
#    'BF',
#    'BG',
#    'BH',
#    'BI',
#    'BJ',
#    'BN',
#    'BO',
#    'BR',
#    'BS',
#    'BT',
#    'BW',
#    'BY',
#    'BZ',
#    'CA',
#    'CD',
#    'CG',
#    'CH',
#    'CI',
#    'CL',
#    'CM',
#    'CO',
#    'CR',
#    'CV',
#    'CW',
#    'CY',
#    'CZ',
#    'DE',
#    'DJ',
#    'DK',
#    'DM',
#    'DO',
#    'DZ',
#    'EC',
#    'EE',
#    'EG',
#    'ES',
#    'FI',
#    'FJ',
#    'FM',
#    'FR',
#    'GA',
#    'GB',
#    'GD',
#    'GE',
#    'GH',
#    'GM',
#    'GN',
#    'GQ',
#    'GR',
#    'GT',
#    'GW',
#    'GY',
#    'HK',
#    'HN',
#    'HR',
#    'HT',
#    'HU',
#    'ID',
#    'IE',
#    'IL',
#    'IN',
#    'IQ',
#    'IS',
#    'IT',
#    'JM',
#    'JO',
#    'JP',
#    'KE',
#    'KG',
#    'KH',
#    'KI',
#    'KM',
#    'KN',
#    'KR',
#    'KW',
#    'KZ',
#    'LA',
#    'LB',
#    'LC',
#    'LI',
#    'LK',
#    'LR',
#    'LS',
#    'LT',
#    'LU',
#    'LV',
#    'LY',
#    'MA',
#    'MC',
#    'MD',
#    'ME',
#    'MG',
#    'MH',
#    'MK',
#    'ML',
#    'MN',
#    'MO',
#    'MR',
#    'MT',
#    'MU',
#    'MV',
#    'MW',
#    'MX',
#    'MY',
#    'MZ',
#    'NA',
#    'NE',
#    'NG',
#    'NI',
#    'NL',
#    'NO',
#    'NP',
#    'NR',
#    'NZ',
#    'OM',
#    'PA',
#    'PE',
#    'PG',
#    'PH',
#    'PK',
#    'PL',
#    'PS',
#    'PT',
#    'PW',
#    'PY',
#    'QA',
#    'RO',
#    'RS',
#    'RW',
#    'SA',
#    'SB',
#    'SC',
#    'SE',
#    'SG',
#    'SI',
#    'SK',
#    'SL',
#    'SM',
#    'SN',
#    'SR',
#    'ST',
#    'SV',
#    'SZ',
#    'TD',
#    'TG',
#    'TH',
#    'TJ',
#    'TL',
#    'TN',
#    'TO',
#    'TR',
#    'TT',
#    'TV',
#    'TW',
#    'TZ',
#    'UA',
#    'UG',
#    'US',
#    'UY',
#    'UZ',
#    'VC',
#    'VE',
#    'VN',
#    'VU',
#    'WS',
#    'XK',
#    'ZA',
#    'ZM',
#    'ZW'],
#   'disc_number': 1,
#   'duration_ms': 209106,
#   'explicit': False,
#   'external_ids': {'isrc': 'US8391600080'},
#   'external_urls': {'spotify': 'https://open.spotify.com/track/66J8DSBxHe5QZPF9rQG98p'},
#   'href': 'https://api.spotify.com/v1/tracks/66J8DSBxHe5QZPF9rQG98p',
#   'id': '66J8DSBxHe5QZPF9rQG98p',
#   'is_local': False,
#   'name': 'The Cure',
#   'popularity': 41,
#   'preview_url': 'https://p.scdn.co/mp3-preview/1d149b44db570054a0f834c31a9939a044bdf9c9?cid=da00ed264eaf4f94ba2adf23ff058567',
#   'track_number': 2,
#   'type': 'track',
#   'uri': 'spotify:track:66J8DSBxHe5QZPF9rQG98p'},
#  {'album': {'album_type': 'compilation',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0LyfQWJT6nXafLPZqxe9Of'},
#      'href': 'https://api.spotify.com/v1/artists/0LyfQWJT6nXafLPZqxe9Of',
#      'id': '0LyfQWJT6nXafLPZqxe9Of',
#      'name': 'Various Artists',
#      'type': 'artist',
#      'uri': 'spotify:artist:0LyfQWJT6nXafLPZqxe9Of'}],
#    'available_markets': ['US'],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/5nljKvkMmaWY54VCPVi2uy'},
#    'href': 'https://api.spotify.com/v1/albums/5nljKvkMmaWY54VCPVi2uy',
#    'id': '5nljKvkMmaWY54VCPVi2uy',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b273a88433b365563bc02539a059',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/ab67616d00001e02a88433b365563bc02539a059',
#      'width': 300},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/ab67616d00004851a88433b365563bc02539a059',
#      'width': 64}],
#    'name': '90s',
#    'release_date': '2022-04-29',
#    'release_date_precision': 'day',
#    'total_tracks': 50,
#    'type': 'album',
#    'uri': 'spotify:album:5nljKvkMmaWY54VCPVi2uy'},
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7bu3H8JO7d0UbMoVzbo70s'},
#     'href': 'https://api.spotify.com/v1/artists/7bu3H8JO7d0UbMoVzbo70s',
#     'id': '7bu3H8JO7d0UbMoVzbo70s',
#     'name': 'The Cure',
#     'type': 'artist',
#     'uri': 'spotify:artist:7bu3H8JO7d0UbMoVzbo70s'}],
#   'available_markets': ['US'],
#   'disc_number': 1,
#   'duration_ms': 216333,
#   'explicit': False,
#   'external_ids': {'isrc': 'USEE19200008'},
#   'external_urls': {'spotify': 'https://open.spotify.com/track/2HOJGkppH6gYrpbC2g906R'},
#   'href': 'https://api.spotify.com/v1/tracks/2HOJGkppH6gYrpbC2g906R',
#   'id': '2HOJGkppH6gYrpbC2g906R',
#   'is_local': False,
#   'name': "Friday I'm In Love",
#   'popularity': 0,
#   'preview_url': 'https://p.scdn.co/mp3-preview/01c8e7a1ec188d3eedd21bfee289220214a60ba8?cid=da00ed264eaf4f94ba2adf23ff058567',
#   'track_number': 2,
#   'type': 'track',
#   'uri': 'spotify:track:2HOJGkppH6gYrpbC2g906R'},
#  {'album': {'album_type': 'album',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3e7awlrlDSwF3iM0WBjGMp'},
#      'href': 'https://api.spotify.com/v1/artists/3e7awlrlDSwF3iM0WBjGMp',
#      'id': '3e7awlrlDSwF3iM0WBjGMp',
#      'name': 'Little Mix',
#      'type': 'artist',
#      'uri': 'spotify:artist:3e7awlrlDSwF3iM0WBjGMp'}],
#    'available_markets': ['AD',
#     'AE',
#     'AG',
#     'AL',
#     'AM',
#     'AO',
#     'AR',
#     'AT',
#     'AU',
#     'AZ',
#     'BA',
#     'BB',
#     'BD',
#     'BE',
#     'BF',
#     'BG',
#     'BH',
#     'BI',
#     'BJ',
#     'BN',
#     'BO',
#     'BR',
#     'BS',
#     'BT',
#     'BW',
#     'BY',
#     'BZ',
#     'CA',
#     'CD',
#     'CG',
#     'CH',
#     'CI',
#     'CL',
#     'CM',
#     'CO',
#     'CR',
#     'CV',
#     'CW',
#     'CY',
#     'CZ',
#     'DE',
#     'DJ',
#     'DK',
#     'DM',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FJ',
#     'FM',
#     'FR',
#     'GA',
#     'GB',
#     'GD',
#     'GE',
#     'GH',
#     'GM',
#     'GN',
#     'GQ',
#     'GR',
#     'GT',
#     'GW',
#     'GY',
#     'HK',
#     'HN',
#     'HR',
#     'HT',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IQ',
#     'IS',
#     'IT',
#     'JM',
#     'JO',
#     'JP',
#     'KE',
#     'KG',
#     'KH',
#     'KI',
#     'KM',
#     'KN',
#     'KR',
#     'KW',
#     'KZ',
#     'LA',
#     'LB',
#     'LC',
#     'LI',
#     'LK',
#     'LR',
#     'LS',
#     'LT',
#     'LU',
#     'LV',
#     'LY',
#     'MA',
#     'MC',
#     'MD',
#     'ME',
#     'MG',
#     'MH',
#     'MK',
#     'ML',
#     'MN',
#     'MO',
#     'MR',
#     'MT',
#     'MU',
#     'MV',
#     'MW',
#     'MX',
#     'MY',
#     'MZ',
#     'NA',
#     'NE',
#     'NG',
#     'NI',
#     'NL',
#     'NO',
#     'NP',
#     'NR',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PG',
#     'PH',
#     'PK',
#     'PL',
#     'PS',
#     'PT',
#     'PW',
#     'PY',
#     'QA',
#     'RO',
#     'RS',
#     'RW',
#     'SA',
#     'SB',
#     'SC',
#     'SE',
#     'SG',
#     'SI',
#     'SK',
#     'SL',
#     'SM',
#     'SN',
#     'SR',
#     'ST',
#     'SV',
#     'SZ',
#     'TD',
#     'TG',
#     'TH',
#     'TJ',
#     'TL',
#     'TN',
#     'TO',
#     'TR',
#     'TT',
#     'TV',
#     'TW',
#     'TZ',
#     'UA',
#     'UG',
#     'US',
#     'UY',
#     'UZ',
#     'VC',
#     'VE',
#     'VN',
#     'VU',
#     'WS',
#     'XK',
#     'ZA',
#     'ZM',
#     'ZW'],
# ...
#     'BE',
#     'BF',
#     'BG',
#     'BH',
#     'BI',
#     'BJ',
#     'BN',
#     'BO',
#     'BR',
#     'BS',
#     'BT',
#     'BW',
#     'BY',
#     'BZ',
#     'CA',
#     'CD',
#     'CG',
#     'CH',
#     'CI',
#     'CL',
#     'CM',
#     'CO',
#     'CR',
#     'CV',
#     'CW',
#     'CY',
#     'CZ',
#     'DE',
#     'DJ',
#     'DK',
#     'DM',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FJ',
#     'FM',
#     'FR',
#     'GA',
#     'GB',
#     'GD',
#     'GE',
#     'GH',
#     'GM',
#     'GN',
#     'GQ',
#     'GR',
#     'GT',
#     'GW',
#     'GY',
#     'HK',
#     'HN',
#     'HR',
#     'HT',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IQ',
#     'IS',
#     'IT',
#     'JM',
#     'JO',
#     'JP',
#     'KE',
#     'KG',
#     'KH',
#     'KI',
#     'KM',
#     'KN',
#     'KR',
#     'KW',
#     'KZ',
#     'LA',
#     'LB',
#     'LC',
#     'LI',
#     'LK',
#     'LR',
#     'LS',
#     'LT',
#     'LU',
#     'LV',
#     'LY',
#     'MA',
#     'MC',
#     'MD',
#     'ME',
#     'MG',
#     'MH',
#     'MK',
#     'ML',
#     'MN',
#     'MO',
#     'MR',
#     'MT',
#     'MU',
#     'MV',
#     'MW',
#     'MX',
#     'MY',
#     'MZ',
#     'NA',
#     'NE',
#     'NG',
#     'NI',
#     'NL',
#     'NO',
#     'NP',
#     'NR',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PG',
#     'PH',
#     'PK',
#     'PL',
#     'PS',
#     'PT',
#     'PW',
#     'PY',
#     'QA',
#     'RO',
#     'RS',
#     'RW',
#     'SA',
#     'SB',
#     'SC',
#     'SE',
#     'SG',
#     'SI',
#     'SK',
#     'SL',
#     'SM',
#     'SN',
#     'SR',
#     'ST',
#     'SV',
#     'SZ',
#     'TD',
#     'TG',
#     'TH',
#     'TJ',
#     'TL',
#     'TN',
#     'TO',
#     'TR',
#     'TT',
#     'TV',
#     'TW',
#     'TZ',
#     'UA',
#     'UG',
#     'US',
#     'UY',
#     'UZ',
#     'VC',
#     'VE',
#     'VN',
#     'VU',
#     'WS',
#     'XK',
#     'ZA',
#     'ZM',
#     'ZW'],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/6i971rX8SB9Ad5IcpDRysI'},
#    'href': 'https://api.spotify.com/v1/albums/6i971rX8SB9Ad5IcpDRysI',
#    'id': '6i971rX8SB9Ad5IcpDRysI',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b27336805261375a3daf7209ae13',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/ab67616d00001e0236805261375a3daf7209ae13',
#      'width': 300},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/ab67616d0000485136805261375a3daf7209ae13',
#      'width': 64}],
#    'name': 'Limbs & Branches',
#    'release_date': '2008-10-28',
#    'release_date_precision': 'day',
#    'total_tracks': 12,
#    'type': 'album',
#    'uri': 'spotify:album:6i971rX8SB9Ad5IcpDRysI'},
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5D3h9ZoobhetjXw3dKhcaq'},
#     'href': 'https://api.spotify.com/v1/artists/5D3h9ZoobhetjXw3dKhcaq',
#     'id': '5D3h9ZoobhetjXw3dKhcaq',
#     'name': 'Jon Foreman',
#     'type': 'artist',
#     'uri': 'spotify:artist:5D3h9ZoobhetjXw3dKhcaq'}],
#   'available_markets': ['AD',
#    'AE',
#    'AG',
#    'AL',
#    'AM',
#    'AO',
#    'AR',
#    'AT',
#    'AU',
#    'AZ',
#    'BA',
#    'BB',
#    'BD',
#    'BE',
#    'BF',
#    'BG',
#    'BH',
#    'BI',
#    'BJ',
#    'BN',
#    'BO',
#    'BR',
#    'BS',
#    'BT',
#    'BW',
#    'BY',
#    'BZ',
#    'CA',
#    'CD',
#    'CG',
#    'CH',
#    'CI',
#    'CL',
#    'CM',
#    'CO',
#    'CR',
#    'CV',
#    'CW',
#    'CY',
#    'CZ',
#    'DE',
#    'DJ',
#    'DK',
#    'DM',
#    'DO',
#    'DZ',
#    'EC',
#    'EE',
#    'EG',
#    'ES',
#    'FI',
#    'FJ',
#    'FM',
#    'FR',
#    'GA',
#    'GB',
#    'GD',
#    'GE',
#    'GH',
#    'GM',
#    'GN',
#    'GQ',
#    'GR',
#    'GT',
#    'GW',
#    'GY',
#    'HK',
#    'HN',
#    'HR',
#    'HT',
#    'HU',
#    'ID',
#    'IE',
#    'IL',
#    'IN',
#    'IQ',
#    'IS',
#    'IT',
#    'JM',
#    'JO',
#    'JP',
#    'KE',
#    'KG',
#    'KH',
#    'KI',
#    'KM',
#    'KN',
#    'KR',
#    'KW',
#    'KZ',
#    'LA',
#    'LB',
#    'LC',
#    'LI',
#    'LK',
#    'LR',
#    'LS',
#    'LT',
#    'LU',
#    'LV',
#    'LY',
#    'MA',
#    'MC',
#    'MD',
#    'ME',
#    'MG',
#    'MH',
#    'MK',
#    'ML',
#    'MN',
#    'MO',
#    'MR',
#    'MT',
#    'MU',
#    'MV',
#    'MW',
#    'MX',
#    'MY',
#    'MZ',
#    'NA',
#    'NE',
#    'NG',
#    'NI',
#    'NL',
#    'NO',
#    'NP',
#    'NR',
#    'NZ',
#    'OM',
#    'PA',
#    'PE',
#    'PG',
#    'PH',
#    'PK',
#    'PL',
#    'PS',
#    'PT',
#    'PW',
#    'PY',
#    'QA',
#    'RO',
#    'RS',
#    'RW',
#    'SA',
#    'SB',
#    'SC',
#    'SE',
#    'SG',
#    'SI',
#    'SK',
#    'SL',
#    'SM',
#    'SN',
#    'SR',
#    'ST',
#    'SV',
#    'SZ',
#    'TD',
#    'TG',
#    'TH',
#    'TJ',
#    'TL',
#    'TN',
#    'TO',
#    'TR',
#    'TT',
#    'TV',
#    'TW',
#    'TZ',
#    'UA',
#    'UG',
#    'US',
#    'UY',
#    'UZ',
#    'VC',
#    'VE',
#    'VN',
#    'VU',
#    'WS',
#    'XK',
#    'ZA',
#    'ZM',
#    'ZW'],
#   'disc_number': 1,
#   'duration_ms': 285266,
#   'explicit': False,
#   'external_ids': {'isrc': 'QM5GK1500030'},
#   'external_urls': {'spotify': 'https://open.spotify.com/track/2Sngau33mxsVFYOCKlqXhi'},
#   'href': 'https://api.spotify.com/v1/tracks/2Sngau33mxsVFYOCKlqXhi',
#   'id': '2Sngau33mxsVFYOCKlqXhi',
#   'is_local': False,
#   'name': 'The Cure For Pain',
#   'popularity': 34,
#   'preview_url': None,
#   'track_number': 3,
#   'type': 'track',
#   'uri': 'spotify:track:2Sngau33mxsVFYOCKlqXhi'},
#  {'album': {'album_type': 'single',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0Upxnyh9nIUNSOmNE8WF4R'},
#      'href': 'https://api.spotify.com/v1/artists/0Upxnyh9nIUNSOmNE8WF4R',
#      'id': '0Upxnyh9nIUNSOmNE8WF4R',
#      'name': 'BYOR',
#      'type': 'artist',
#      'uri': 'spotify:artist:0Upxnyh9nIUNSOmNE8WF4R'}],
#    'available_markets': ['AD',
#     'AE',
#     'AG',
#     'AL',
#     'AM',
#     'AO',
#     'AR',
#     'AT',
#     'AU',
#     'AZ',
#     'BA',
#     'BB',
#     'BD',
#     'BE',
#     'BF',
#     'BG',
#     'BH',
#     'BI',
#     'BJ',
#     'BN',
#     'BO',
#     'BR',
#     'BS',
#     'BT',
#     'BW',
#     'BY',
#     'BZ',
#     'CA',
#     'CD',
#     'CG',
#     'CH',
#     'CI',
#     'CL',
#     'CM',
#     'CO',
#     'CR',
#     'CV',
#     'CW',
#     'CY',
#     'CZ',
#     'DE',
#     'DJ',
#     'DK',
#     'DM',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FJ',
#     'FM',
#     'FR',
#     'GA',
#     'GB',
#     'GD',
#     'GE',
#     'GH',
#     'GM',
#     'GN',
#     'GQ',
#     'GR',
#     'GT',
#     'GW',
#     'GY',
#     'HK',
#     'HN',
#     'HR',
#     'HT',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IQ',
#     'IS',
#     'IT',
#     'JM',
#     'JO',
#     'JP',
#     'KE',
#     'KG',
#     'KH',
#     'KI',
#     'KM',
#     'KN',
#     'KR',
#     'KW',
#     'KZ',
#     'LA',
#     'LB',
#     'LC',
#     'LI',
#     'LK',
#     'LR',
#     'LS',
#     'LT',
#     'LU',
#     'LV',
#     'LY',
#     'MA',
#     'MC',
#     'MD',
#     'ME',
#     'MG',
#     'MH',
#     'MK',
#     'ML',
#     'MN',
#     'MO',
#     'MR',
#     'MT',
#     'MU',
#     'MV',
#     'MW',
#     'MX',
#     'MY',
#     'MZ',
#     'NA',
#     'NE',
#     'NG',
#     'NI',
#     'NL',
#     'NO',
#     'NP',
#     'NR',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PG',
#     'PH',
#     'PK',
#     'PL',
#     'PS',
#     'PT',
#     'PW',
#     'PY',
#     'QA',
#     'RO',
#     'RS',
#     'RW',
#     'SA',
#     'SB',
#     'SC',
#     'SE',
#     'SG',
#     'SI',
#     'SK',
#     'SL',
#     'SM',
#     'SN',
#     'SR',
#     'ST',
#     'SV',
#     'SZ',
#     'TD',
#     'TG',
#     'TH',
#     'TJ',
#     'TL',
#     'TN',
#     'TO',
#     'TR',
#     'TT',
#     'TV',
#     'TW',
#     'TZ',
#     'UA',
#     'UG',
#     'US',
#     'UY',
#     'UZ',
#     'VC',
#     'VE',
#     'VN',
#     'VU',
#     'WS',
#     'XK',
#     'ZA',
#     'ZM',
#     'ZW'],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/0GoiTL7JcNLGlkpDQYPoMa'},
#    'href': 'https://api.spotify.com/v1/albums/0GoiTL7JcNLGlkpDQYPoMa',
#    'id': '0GoiTL7JcNLGlkpDQYPoMa',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b27359b4ea0802b108188dfdf022',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/ab67616d00001e0259b4ea0802b108188dfdf022',
#      'width': 300},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/ab67616d0000485159b4ea0802b108188dfdf022',
#      'width': 64}],
#    'name': 'The Cure',
#    'release_date': '2021-02-26',
#    'release_date_precision': 'day',
#    'total_tracks': 1,
#    'type': 'album',
#    'uri': 'spotify:album:0GoiTL7JcNLGlkpDQYPoMa'},
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0Upxnyh9nIUNSOmNE8WF4R'},
#     'href': 'https://api.spotify.com/v1/artists/0Upxnyh9nIUNSOmNE8WF4R',
#     'id': '0Upxnyh9nIUNSOmNE8WF4R',
#     'name': 'BYOR',
#     'type': 'artist',
#     'uri': 'spotify:artist:0Upxnyh9nIUNSOmNE8WF4R'}],
#   'available_markets': ['AD',
#    'AE',
#    'AG',
#    'AL',
#    'AM',
#    'AO',
#    'AR',
#    'AT',
#    'AU',
#    'AZ',
#    'BA',
#    'BB',
#    'BD',
#    'BE',
#    'BF',
#    'BG',
#    'BH',
#    'BI',
#    'BJ',
#    'BN',
#    'BO',
#    'BR',
#    'BS',
#    'BT',
#    'BW',
#    'BY',
#    'BZ',
#    'CA',
#    'CD',
#    'CG',
#    'CH',
#    'CI',
#    'CL',
#    'CM',
#    'CO',
#    'CR',
#    'CV',
#    'CW',
#    'CY',
#    'CZ',
#    'DE',
#    'DJ',
#    'DK',
#    'DM',
#    'DO',
#    'DZ',
#    'EC',
#    'EE',
#    'EG',
#    'ES',
#    'FI',
#    'FJ',
#    'FM',
#    'FR',
#    'GA',
#    'GB',
#    'GD',
#    'GE',
#    'GH',
#    'GM',
#    'GN',
#    'GQ',
#    'GR',
#    'GT',
#    'GW',
#    'GY',
#    'HK',
#    'HN',
#    'HR',
#    'HT',
#    'HU',
#    'ID',
#    'IE',
#    'IL',
#    'IN',
#    'IQ',
#    'IS',
#    'IT',
#    'JM',
#    'JO',
#    'JP',
#    'KE',
#    'KG',
#    'KH',
#    'KI',
#    'KM',
#    'KN',
#    'KR',
#    'KW',
#    'KZ',
#    'LA',
#    'LB',
#    'LC',
#    'LI',
#    'LK',
#    'LR',
#    'LS',
#    'LT',
#    'LU',
#    'LV',
#    'LY',
#    'MA',
#    'MC',
#    'MD',
#    'ME',
#    'MG',
#    'MH',
#    'MK',
#    'ML',
#    'MN',
#    'MO',
#    'MR',
#    'MT',
#    'MU',
#    'MV',
#    'MW',
#    'MX',
#    'MY',
#    'MZ',
#    'NA',
#    'NE',
#    'NG',
#    'NI',
#    'NL',
#    'NO',
#    'NP',
#    'NR',
#    'NZ',
#    'OM',
#    'PA',
#    'PE',
#    'PG',
#    'PH',
#    'PK',
#    'PL',
#    'PS',
#    'PT',
#    'PW',
#    'PY',
#    'QA',
#    'RO',
#    'RS',
#    'RW',
#    'SA',
#    'SB',
#    'SC',
#    'SE',
#    'SG',
#    'SI',
#    'SK',
#    'SL',
#    'SM',
#    'SN',
#    'SR',
#    'ST',
#    'SV',
#    'SZ',
#    'TD',
#    'TG',
#    'TH',
#    'TJ',
#    'TL',
#    'TN',
#    'TO',
#    'TR',
#    'TT',
#    'TV',
#    'TW',
#    'TZ',
#    'UA',
#    'UG',
#    'US',
#    'UY',
#    'UZ',
#    'VC',
#    'VE',
#    'VN',
#    'VU',
#    'WS',
#    'XK',
#    'ZA',
#    'ZM',
#    'ZW'],
#   'disc_number': 1,
#   'duration_ms': 236190,
#   'explicit': False,
#   'external_ids': {'isrc': 'CYA112000817'},
#   'external_urls': {'spotify': 'https://open.spotify.com/track/714EIYBfjoDLtuU81fnfij'},
#   'href': 'https://api.spotify.com/v1/tracks/714EIYBfjoDLtuU81fnfij',
#   'id': '714EIYBfjoDLtuU81fnfij',
#   'is_local': False,
#   'name': 'The Cure',
#   'popularity': 34,
#   'preview_url': 'https://p.scdn.co/mp3-preview/afd8b7d8e0df40728e05dff33ce4f0028e6e3592?cid=da00ed264eaf4f94ba2adf23ff058567',
#   'track_number': 1,
#   'type': 'track',
#   'uri': 'spotify:track:714EIYBfjoDLtuU81fnfij'},
#  {'album': {'album_type': 'album',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5k979N1TnPncUyqlXlaRSv'},
#      'href': 'https://api.spotify.com/v1/artists/5k979N1TnPncUyqlXlaRSv',
#      'id': '5k979N1TnPncUyqlXlaRSv',
#      'name': 'The Longest Johns',
#      'type': 'artist',
#      'uri': 'spotify:artist:5k979N1TnPncUyqlXlaRSv'}],
#    'available_markets': ['AD',
#     'AE',
#     'AG',
#     'AL',
#     'AM',
#     'AO',
#     'AR',
#     'AT',
#     'AU',
#     'AZ',
#     'BA',
#     'BB',
#     'BD',
#     'BE',
#     'BF',
#     'BG',
#     'BH',
#     'BI',
#     'BJ',
#     'BN',
#     'BO',
#     'BR',
#     'BS',
#     'BT',
#     'BW',
#     'BY',
#     'BZ',
#     'CA',
#     'CD',
#     'CG',
#     'CH',
#     'CI',
#     'CL',
#     'CM',
#     'CO',
#     'CR',
#     'CV',
#     'CW',
#     'CY',
#     'CZ',
#     'DE',
#     'DJ',
#     'DK',
#     'DM',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FJ',
#     'FM',
#     'FR',
#     'GA',
#     'GB',
#     'GD',
#     'GE',
#     'GH',
#     'GM',
#     'GN',
#     'GQ',
#     'GR',
#     'GT',
#     'GW',
#     'GY',
#     'HK',
#     'HN',
#     'HR',
#     'HT',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IQ',
#     'IS',
#     'IT',
#     'JM',
#     'JO',
#     'JP',
#     'KE',
#     'KG',
#     'KH',
#     'KI',
#     'KM',
#     'KN',
#     'KR',
#     'KW',
#     'KZ',
#     'LA',
#     'LB',
#     'LC',
#     'LI',
#     'LK',
#     'LR',
#     'LS',
#     'LT',
#     'LU',
#     'LV',
#     'LY',
#     'MA',
#     'MC',
#     'MD',
#     'ME',
#     'MG',
#     'MH',
#     'MK',
#     'ML',
#     'MN',
#     'MO',
#     'MR',
#     'MT',
#     'MU',
#     'MV',
#     'MW',
#     'MX',
#     'MY',
#     'MZ',
#     'NA',
#     'NE',
#     'NG',
#     'NI',
#     'NL',
#     'NO',
#     'NP',
#     'NR',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PG',
#     'PH',
#     'PK',
#     'PL',
#     'PS',
#     'PT',
#     'PW',
#     'PY',
#     'QA',
#     'RO',
#     'RS',
#     'RW',
#     'SA',
#     'SB',
#     'SC',
#     'SE',
#     'SG',
#     'SI',
#     'SK',
#     'SL',
#     'SM',
#     'SN',
#     'SR',
#     'ST',
#     'SV',
#     'SZ',
#     'TD',
#     'TG',
#     'TH',
#     'TJ',
#     'TL',
#     'TN',
#     'TO',
#     'TR',
#     'TT',
#     'TV',
#     'TW',
#     'TZ',
#     'UA',
#     'UG',
#     'US',
#     'UY',
#     'UZ',
#     'VC',
#     'VE',
#     'VN',
#     'VU',
#     'WS',
#     'XK',
#     'ZA',
#     'ZM',
#     'ZW'],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/23FGerfaTcQOlEdySv5Wdq'},
#    'href': 'https://api.spotify.com/v1/albums/23FGerfaTcQOlEdySv5Wdq',
#    'id': '23FGerfaTcQOlEdySv5Wdq',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b2730e344b28681e6ee72eb67f78',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/ab67616d00001e020e344b28681e6ee72eb67f78',
#      'width': 300},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/ab67616d000048510e344b28681e6ee72eb67f78',
#      'width': 64}],
#    'name': 'Cures What Ails Ya',
#    'release_date': '2020-06-10',
#    'release_date_precision': 'day',
#    'total_tracks': 12,
#    'type': 'album',
#    'uri': 'spotify:album:23FGerfaTcQOlEdySv5Wdq'},
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5k979N1TnPncUyqlXlaRSv'},
#     'href': 'https://api.spotify.com/v1/artists/5k979N1TnPncUyqlXlaRSv',
#     'id': '5k979N1TnPncUyqlXlaRSv',
#     'name': 'The Longest Johns',
#     'type': 'artist',
#     'uri': 'spotify:artist:5k979N1TnPncUyqlXlaRSv'}],
#   'available_markets': ['AD',
#    'AE',
#    'AG',
#    'AL',
#    'AM',
#    'AO',
#    'AR',
#    'AT',
#    'AU',
#    'AZ',
#    'BA',
#    'BB',
#    'BD',
#    'BE',
#    'BF',
#    'BG',
#    'BH',
#    'BI',
#    'BJ',
#    'BN',
#    'BO',
#    'BR',
#    'BS',
#    'BT',
#    'BW',
#    'BY',
#    'BZ',
#    'CA',
#    'CD',
#    'CG',
#    'CH',
#    'CI',
#    'CL',
#    'CM',
#    'CO',
#    'CR',
#    'CV',
#    'CW',
#    'CY',
#    'CZ',
#    'DE',
#    'DJ',
#    'DK',
#    'DM',
#    'DO',
#    'DZ',
#    'EC',
#    'EE',
#    'EG',
#    'ES',
#    'FI',
#    'FJ',
#    'FM',
#    'FR',
#    'GA',
#    'GB',
#    'GD',
#    'GE',
#    'GH',
#    'GM',
#    'GN',
#    'GQ',
#    'GR',
#    'GT',
#    'GW',
#    'GY',
#    'HK',
#    'HN',
#    'HR',
#    'HT',
#    'HU',
#    'ID',
#    'IE',
#    'IL',
#    'IN',
#    'IQ',
#    'IS',
#    'IT',
#    'JM',
#    'JO',
#    'JP',
#    'KE',
#    'KG',
#    'KH',
#    'KI',
#    'KM',
#    'KN',
#    'KR',
#    'KW',
#    'KZ',
#    'LA',
#    'LB',
#    'LC',
#    'LI',
#    'LK',
#    'LR',
#    'LS',
#    'LT',
#    'LU',
#    'LV',
#    'LY',
#    'MA',
#    'MC',
#    'MD',
#    'ME',
#    'MG',
#    'MH',
#    'MK',
#    'ML',
#    'MN',
#    'MO',
#    'MR',
#    'MT',
#    'MU',
#    'MV',
#    'MW',
#    'MX',
#    'MY',
#    'MZ',
#    'NA',
#    'NE',
#    'NG',
#    'NI',
#    'NL',
#    'NO',
#    'NP',
#    'NR',
#    'NZ',
#    'OM',
#    'PA',
#    'PE',
#    'PG',
#    'PH',
#    'PK',
#    'PL',
#    'PS',
#    'PT',
#    'PW',
#    'PY',
#    'QA',
#    'RO',
#    'RS',
#    'RW',
#    'SA',
#    'SB',
#    'SC',
#    'SE',
#    'SG',
#    'SI',
#    'SK',
#    'SL',
#    'SM',
#    'SN',
#    'SR',
#    'ST',
#    'SV',
#    'SZ',
#    'TD',
#    'TG',
#    'TH',
#    'TJ',
#    'TL',
#    'TN',
#    'TO',
#    'TR',
#    'TT',
#    'TV',
#    'TW',
#    'TZ',
#    'UA',
#    'UG',
#    'US',
#    'UY',
#    'UZ',
#    'VC',
#    'VE',
#    'VN',
#    'VU',
#    'WS',
#    'XK',
#    'ZA',
#    'ZM',
#    'ZW'],
#   'disc_number': 1,
#   'duration_ms': 201000,
#   'explicit': False,
#   'external_ids': {'isrc': 'UKPGJ1800034'},
#   'external_urls': {'spotify': 'https://open.spotify.com/track/74D4H6tg3QnZ1SpEA9pjGk'},
#   'href': 'https://api.spotify.com/v1/tracks/74D4H6tg3QnZ1SpEA9pjGk',
#   'id': '74D4H6tg3QnZ1SpEA9pjGk',
#   'is_local': False,
#   'name': 'Ashes',
#   'popularity': 50,
#   'preview_url': 'https://p.scdn.co/mp3-preview/a88304f97e5d5445fa76f308d3336508e6067aa4?cid=da00ed264eaf4f94ba2adf23ff058567',
#   'track_number': 6,
#   'type': 'track',
#   'uri': 'spotify:track:74D4H6tg3QnZ1SpEA9pjGk'}]

# %%
results['tracks']['limit']
# Out:
# 50

# %%
results['tracks']['next']
# Out:
# 'https://api.spotify.com/v1/search?query=The+Cure&type=track&offset=50&limit=50'

# %%
results['tracks']['offset']
# Out:
# 0

# %%
results['tracks']['previous']

# %%
len(results['tracks']['items'])
# Out:
# 50

# %%
results['tracks']['items'][0]
# Out:
# {'album': {'album_type': 'single',
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1HY2Jd0NmPuamShAr6KMms'},
#     'href': 'https://api.spotify.com/v1/artists/1HY2Jd0NmPuamShAr6KMms',
#     'id': '1HY2Jd0NmPuamShAr6KMms',
#     'name': 'Lady Gaga',
#     'type': 'artist',
#     'uri': 'spotify:artist:1HY2Jd0NmPuamShAr6KMms'}],
#   'available_markets': ['AD',
#    'AE',
#    'AG',
#    'AL',
#    'AM',
#    'AO',
#    'AR',
#    'AT',
#    'AU',
#    'AZ',
#    'BA',
#    'BB',
#    'BD',
#    'BE',
#    'BF',
#    'BG',
#    'BH',
#    'BI',
#    'BJ',
#    'BN',
#    'BO',
#    'BR',
#    'BS',
#    'BT',
#    'BW',
#    'BY',
#    'BZ',
#    'CA',
#    'CD',
#    'CG',
#    'CH',
#    'CI',
#    'CL',
#    'CM',
#    'CO',
#    'CR',
#    'CV',
#    'CW',
#    'CY',
#    'CZ',
#    'DE',
#    'DJ',
#    'DK',
#    'DM',
#    'DO',
#    'DZ',
#    'EC',
#    'EE',
#    'EG',
#    'ES',
#    'FI',
#    'FJ',
#    'FM',
#    'FR',
#    'GA',
#    'GB',
#    'GD',
#    'GE',
#    'GH',
#    'GM',
#    'GN',
#    'GQ',
#    'GR',
#    'GT',
#    'GW',
#    'GY',
#    'HK',
#    'HN',
#    'HR',
#    'HT',
#    'HU',
#    'ID',
#    'IE',
#    'IL',
#    'IN',
#    'IQ',
#    'IS',
#    'IT',
#    'JM',
#    'JO',
#    'JP',
#    'KE',
#    'KG',
#    'KH',
#    'KI',
#    'KM',
#    'KN',
#    'KR',
#    'KW',
#    'KZ',
#    'LA',
#    'LB',
#    'LC',
#    'LI',
#    'LK',
#    'LR',
#    'LS',
#    'LT',
#    'LU',
#    'LV',
#    'LY',
#    'MA',
#    'MC',
#    'MD',
#    'ME',
#    'MG',
#    'MH',
#    'MK',
#    'ML',
#    'MN',
#    'MO',
#    'MR',
#    'MT',
#    'MU',
#    'MV',
#    'MW',
#    'MX',
#    'MY',
#    'MZ',
#    'NA',
#    'NE',
#    'NG',
#    'NI',
#    'NL',
#    'NO',
#    'NP',
#    'NR',
#    'NZ',
#    'OM',
#    'PA',
#    'PE',
#    'PG',
#    'PH',
#    'PK',
#    'PL',
#    'PS',
#    'PT',
#    'PW',
#    'PY',
#    'QA',
#    'RO',
#    'RS',
#    'RW',
#    'SA',
#    'SB',
#    'SC',
#    'SE',
#    'SG',
#    'SI',
#    'SK',
#    'SL',
#    'SM',
#    'SN',
#    'SR',
#    'ST',
#    'SV',
#    'SZ',
#    'TD',
#    'TG',
#    'TH',
#    'TJ',
#    'TL',
#    'TN',
#    'TO',
#    'TR',
#    'TT',
#    'TV',
#    'TW',
#    'TZ',
#    'UA',
#    'UG',
#    'US',
#    'UY',
#    'UZ',
#    'VC',
#    'VE',
#    'VN',
#    'VU',
#    'WS',
#    'XK',
#    'ZA',
#    'ZM',
#    'ZW'],
#   'external_urls': {'spotify': 'https://open.spotify.com/album/2yaSZnZhaxsbQ5xhgGbw3g'},
#   'href': 'https://api.spotify.com/v1/albums/2yaSZnZhaxsbQ5xhgGbw3g',
#   'id': '2yaSZnZhaxsbQ5xhgGbw3g',
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab67616d0000b27331cc5716a5c922b0482787b7',
#     'width': 640},
#    {'height': 300,
#     'url': 'https://i.scdn.co/image/ab67616d00001e0231cc5716a5c922b0482787b7',
#     'width': 300},
#    {'height': 64,
#     'url': 'https://i.scdn.co/image/ab67616d0000485131cc5716a5c922b0482787b7',
#     'width': 64}],
#   'name': 'The Cure',
#   'release_date': '2017-04-16',
#   'release_date_precision': 'day',
#   'total_tracks': 1,
#   'type': 'album',
#   'uri': 'spotify:album:2yaSZnZhaxsbQ5xhgGbw3g'},
#  'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1HY2Jd0NmPuamShAr6KMms'},
#    'href': 'https://api.spotify.com/v1/artists/1HY2Jd0NmPuamShAr6KMms',
#    'id': '1HY2Jd0NmPuamShAr6KMms',
#    'name': 'Lady Gaga',
#    'type': 'artist',
#    'uri': 'spotify:artist:1HY2Jd0NmPuamShAr6KMms'}],
#  'available_markets': ['AD',
#   'AE',
#   'AG',
#   'AL',
#   'AM',
#   'AO',
#   'AR',
#   'AT',
#   'AU',
#   'AZ',
#   'BA',
#   'BB',
#   'BD',
#   'BE',
#   'BF',
#   'BG',
#   'BH',
#   'BI',
#   'BJ',
#   'BN',
#   'BO',
#   'BR',
#   'BS',
#   'BT',
#   'BW',
#   'BY',
#   'BZ',
#   'CA',
#   'CD',
#   'CG',
#   'CH',
#   'CI',
#   'CL',
#   'CM',
#   'CO',
#   'CR',
#   'CV',
#   'CW',
#   'CY',
#   'CZ',
#   'DE',
#   'DJ',
#   'DK',
#   'DM',
#   'DO',
#   'DZ',
#   'EC',
#   'EE',
#   'EG',
#   'ES',
#   'FI',
#   'FJ',
#   'FM',
#   'FR',
#   'GA',
#   'GB',
#   'GD',
#   'GE',
#   'GH',
#   'GM',
#   'GN',
#   'GQ',
#   'GR',
#   'GT',
#   'GW',
#   'GY',
#   'HK',
#   'HN',
#   'HR',
#   'HT',
#   'HU',
#   'ID',
#   'IE',
#   'IL',
#   'IN',
#   'IQ',
#   'IS',
#   'IT',
#   'JM',
#   'JO',
#   'JP',
#   'KE',
#   'KG',
#   'KH',
#   'KI',
#   'KM',
#   'KN',
#   'KR',
#   'KW',
#   'KZ',
#   'LA',
#   'LB',
#   'LC',
#   'LI',
#   'LK',
#   'LR',
#   'LS',
#   'LT',
#   'LU',
#   'LV',
#   'LY',
#   'MA',
#   'MC',
#   'MD',
#   'ME',
#   'MG',
#   'MH',
#   'MK',
#   'ML',
#   'MN',
#   'MO',
#   'MR',
#   'MT',
#   'MU',
#   'MV',
#   'MW',
#   'MX',
#   'MY',
#   'MZ',
#   'NA',
#   'NE',
#   'NG',
#   'NI',
#   'NL',
#   'NO',
#   'NP',
#   'NR',
#   'NZ',
#   'OM',
#   'PA',
#   'PE',
#   'PG',
#   'PH',
#   'PK',
#   'PL',
#   'PS',
#   'PT',
#   'PW',
#   'PY',
#   'QA',
#   'RO',
#   'RS',
#   'RW',
#   'SA',
#   'SB',
#   'SC',
#   'SE',
#   'SG',
#   'SI',
#   'SK',
#   'SL',
#   'SM',
#   'SN',
#   'SR',
#   'ST',
#   'SV',
#   'SZ',
#   'TD',
#   'TG',
#   'TH',
#   'TJ',
#   'TL',
#   'TN',
#   'TO',
#   'TR',
#   'TT',
#   'TV',
#   'TW',
#   'TZ',
#   'UA',
#   'UG',
#   'US',
#   'UY',
#   'UZ',
#   'VC',
#   'VE',
#   'VN',
#   'VU',
#   'WS',
#   'XK',
#   'ZA',
#   'ZM',
#   'ZW'],
#  'disc_number': 1,
#  'duration_ms': 211363,
#  'explicit': False,
#  'external_ids': {'isrc': 'USUM71703782'},
#  'external_urls': {'spotify': 'https://open.spotify.com/track/34oB5r0lcN3fYWCs2uA1k5'},
#  'href': 'https://api.spotify.com/v1/tracks/34oB5r0lcN3fYWCs2uA1k5',
#  'id': '34oB5r0lcN3fYWCs2uA1k5',
#  'is_local': False,
#  'name': 'The Cure',
#  'popularity': 64,
#  'preview_url': None,
#  'track_number': 1,
#  'type': 'track',
#  'uri': 'spotify:track:34oB5r0lcN3fYWCs2uA1k5'}

# %%
results['tracks']['items'][0].keys()
# Out:
# dict_keys(['album', 'artists', 'available_markets', 'disc_number', 'duration_ms', 'explicit', 'external_ids', 'external_urls', 'href', 'id', 'is_local', 'name', 'popularity', 'preview_url', 'track_number', 'type', 'uri'])

# %%
results['tracks']['items'][0]['album']
# Out:
# {'album_type': 'single',
#  'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1HY2Jd0NmPuamShAr6KMms'},
#    'href': 'https://api.spotify.com/v1/artists/1HY2Jd0NmPuamShAr6KMms',
#    'id': '1HY2Jd0NmPuamShAr6KMms',
#    'name': 'Lady Gaga',
#    'type': 'artist',
#    'uri': 'spotify:artist:1HY2Jd0NmPuamShAr6KMms'}],
#  'available_markets': ['AD',
#   'AE',
#   'AG',
#   'AL',
#   'AM',
#   'AO',
#   'AR',
#   'AT',
#   'AU',
#   'AZ',
#   'BA',
#   'BB',
#   'BD',
#   'BE',
#   'BF',
#   'BG',
#   'BH',
#   'BI',
#   'BJ',
#   'BN',
#   'BO',
#   'BR',
#   'BS',
#   'BT',
#   'BW',
#   'BY',
#   'BZ',
#   'CA',
#   'CD',
#   'CG',
#   'CH',
#   'CI',
#   'CL',
#   'CM',
#   'CO',
#   'CR',
#   'CV',
#   'CW',
#   'CY',
#   'CZ',
#   'DE',
#   'DJ',
#   'DK',
#   'DM',
#   'DO',
#   'DZ',
#   'EC',
#   'EE',
#   'EG',
#   'ES',
#   'FI',
#   'FJ',
#   'FM',
#   'FR',
#   'GA',
#   'GB',
#   'GD',
#   'GE',
#   'GH',
#   'GM',
#   'GN',
#   'GQ',
#   'GR',
#   'GT',
#   'GW',
#   'GY',
#   'HK',
#   'HN',
#   'HR',
#   'HT',
#   'HU',
#   'ID',
#   'IE',
#   'IL',
#   'IN',
#   'IQ',
#   'IS',
#   'IT',
#   'JM',
#   'JO',
#   'JP',
#   'KE',
#   'KG',
#   'KH',
#   'KI',
#   'KM',
#   'KN',
#   'KR',
#   'KW',
#   'KZ',
#   'LA',
#   'LB',
#   'LC',
#   'LI',
#   'LK',
#   'LR',
#   'LS',
#   'LT',
#   'LU',
#   'LV',
#   'LY',
#   'MA',
#   'MC',
#   'MD',
#   'ME',
#   'MG',
#   'MH',
#   'MK',
#   'ML',
#   'MN',
#   'MO',
#   'MR',
#   'MT',
#   'MU',
#   'MV',
#   'MW',
#   'MX',
#   'MY',
#   'MZ',
#   'NA',
#   'NE',
#   'NG',
#   'NI',
#   'NL',
#   'NO',
#   'NP',
#   'NR',
#   'NZ',
#   'OM',
#   'PA',
#   'PE',
#   'PG',
#   'PH',
#   'PK',
#   'PL',
#   'PS',
#   'PT',
#   'PW',
#   'PY',
#   'QA',
#   'RO',
#   'RS',
#   'RW',
#   'SA',
#   'SB',
#   'SC',
#   'SE',
#   'SG',
#   'SI',
#   'SK',
#   'SL',
#   'SM',
#   'SN',
#   'SR',
#   'ST',
#   'SV',
#   'SZ',
#   'TD',
#   'TG',
#   'TH',
#   'TJ',
#   'TL',
#   'TN',
#   'TO',
#   'TR',
#   'TT',
#   'TV',
#   'TW',
#   'TZ',
#   'UA',
#   'UG',
#   'US',
#   'UY',
#   'UZ',
#   'VC',
#   'VE',
#   'VN',
#   'VU',
#   'WS',
#   'XK',
#   'ZA',
#   'ZM',
#   'ZW'],
#  'external_urls': {'spotify': 'https://open.spotify.com/album/2yaSZnZhaxsbQ5xhgGbw3g'},
#  'href': 'https://api.spotify.com/v1/albums/2yaSZnZhaxsbQ5xhgGbw3g',
#  'id': '2yaSZnZhaxsbQ5xhgGbw3g',
#  'images': [{'height': 640,
#    'url': 'https://i.scdn.co/image/ab67616d0000b27331cc5716a5c922b0482787b7',
#    'width': 640},
#   {'height': 300,
#    'url': 'https://i.scdn.co/image/ab67616d00001e0231cc5716a5c922b0482787b7',
#    'width': 300},
#   {'height': 64,
#    'url': 'https://i.scdn.co/image/ab67616d0000485131cc5716a5c922b0482787b7',
#    'width': 64}],
#  'name': 'The Cure',
#  'release_date': '2017-04-16',
#  'release_date_precision': 'day',
#  'total_tracks': 1,
#  'type': 'album',
#  'uri': 'spotify:album:2yaSZnZhaxsbQ5xhgGbw3g'}

# %%
results['tracks']['items'][0]['album'].keys()
# Out:
# dict_keys(['album_type', 'artists', 'available_markets', 'external_urls', 'href', 'id', 'images', 'name', 'release_date', 'release_date_precision', 'total_tracks', 'type', 'uri'])

# %%
results['tracks']['items'][0]['album']['name']
# Out:
# 'The Cure'

# %%
results['tracks']['items'][0]['album']['artists']
# Out:
# [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1HY2Jd0NmPuamShAr6KMms'},
#   'href': 'https://api.spotify.com/v1/artists/1HY2Jd0NmPuamShAr6KMms',
#   'id': '1HY2Jd0NmPuamShAr6KMms',
#   'name': 'Lady Gaga',
#   'type': 'artist',
#   'uri': 'spotify:artist:1HY2Jd0NmPuamShAr6KMms'}]

# %%
results['tracks']['items'][0]['album']['total_tracks']
# Out:
# 1

# %%
results['tracks']['items'][0]['name']
# Out:
# 'The Cure'

# %%
results['tracks']['items'][0]['artists']
# Out:
# [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1HY2Jd0NmPuamShAr6KMms'},
#   'href': 'https://api.spotify.com/v1/artists/1HY2Jd0NmPuamShAr6KMms',
#   'id': '1HY2Jd0NmPuamShAr6KMms',
#   'name': 'Lady Gaga',
#   'type': 'artist',
#   'uri': 'spotify:artist:1HY2Jd0NmPuamShAr6KMms'}]

# %%
results['tracks']['items'][0]['id']
# Out:
# '34oB5r0lcN3fYWCs2uA1k5'

# %%
results['tracks']['items'][0]['popularity']
# Out:
# 64

# %% [markdown]
# # Function to get name of song and artist

# %%
def get_name_artist(track):
    return [(track['name'],artist['name']) for artist in track['artists']]

# %%
my_track = results['tracks']['items'][0]

# %%
get_name_artist(my_track)
# Out:
# [('The Cure', 'Lady Gaga')]

# %%
all_songs_artists = list(map(get_name_artist,results['tracks']['items']))
all_songs_artists
# Out:
# [[('The Cure', 'Lady Gaga')],
#  [("Friday I'm in Love", 'The Cure')],
#  [('The Cure', 'Lady Gaga')],
#  [('Just like Heaven', 'The Cure')],
#  [('The Cure', 'Wolves At The Gate')],
#  [("Boys Don't Cry - Single Version", 'The Cure')],
#  [('Lovesong', 'The Cure')],
#  [('Lovesong - 2010 Remaster', 'The Cure')],
#  [('The Cure', 'Little Mix')],
#  [('The Cure', 'Sam Lans!')],
#  [('Close to Me - 2006 Remaster', 'The Cure')],
#  [('The Cure', 'Unspoken')],
#  [("Friday I'm In Love", 'The Cure')],
#  [('The Cure', 'Little Mix')],
#  [('In Between Days', 'The Cure')],
#  [('The Cure (Stripped)', 'Little Mix')],
#  [('The Cure', 'Jadu Heart')],
#  [('Pictures of You - 2010 Remaster', 'The Cure')],
#  [('Burn', 'The Cure')],
#  [('The Cure', 'Watkins Family Hour')],
#  [('In Between Days - 2006 Remaster', 'The Cure')],
#  [('The Cure', 'Wake Up Hate')],
#  [('A Forest - 2006 Remaster', 'The Cure')],
#  [('The Cure & The Cause - Radio Edit', 'Fish Go Deep'),
#   ('The Cure & The Cause - Radio Edit', 'Tracey K')],
#  [('The Cure', 'Nas')],
#  [('Lullaby - 2010 Remaster', 'The Cure')],
#  [('The Lovecats', 'The Cure')],
#  [('Cure For Me', 'AURORA')],
#  [('Cure for the Itch', 'Linkin Park')],
#  [("Boys Don't Cry", 'The Cure')],
#  [('The Cure', 'Mark Battles'),
#   ('The Cure', 'King Los'),
#   ('The Cure', 'Forever M.C.')],
#  [('Lose My Mind (feat. Mr Gabriel)', 'Jai Wolf')],
#  [('The Cure', 'Non Prophets')],
#  [('A Letter to Elise', 'The Cure')],
#  [('The Cure', 'Alazka')],
#  [('Oak & Ash & Thorn', 'The Longest Johns')],
#  [('The Cure', 'Attila')],
#  [('Lovesong', 'The Cure')],
#  [('The Cure', 'Flite'), ('The Cure', 'Justin Hawkes')],
#  [('The Cure & The Cause - Dennis Ferrer Remix', 'Fish Go Deep'),
#   ('The Cure & The Cause - Dennis Ferrer Remix', 'Tracey K'),
#   ('The Cure & The Cause - Dennis Ferrer Remix', 'Dennis Ferrer')],
#  [('The Cure', 'EQRIC'),
#   ('The Cure', 'PHARAØH'),
#   ('The Cure', 'Ceara Cavalieri')],
#  [('Fascination Street - 2010 Remaster', 'The Cure')],
#  [('The Cure', 'Tegan and Sara')],
#  [('Just like Heaven - 2006 Remaster', 'The Cure')],
#  [('The Cure', 'Lipstick Gypsy')],
#  [('Disintegration - 2010 Remaster', 'The Cure')],
#  [('The Cure', 'Fortunate Youth')],
#  [('The Cure For Pain', 'Jon Foreman')],
#  [('The Cure', 'BYOR')],
#  [('Ashes', 'The Longest Johns')]]

# %%
#flattening the list
def flatten(input_list):
    return [item for sublist in input_list for item in sublist]

# %%
flatten(all_songs_artists)
# Out:
# [('The Cure', 'Lady Gaga'),
#  ("Friday I'm in Love", 'The Cure'),
#  ('The Cure', 'Lady Gaga'),
#  ('Just like Heaven', 'The Cure'),
#  ('The Cure', 'Wolves At The Gate'),
#  ("Boys Don't Cry - Single Version", 'The Cure'),
#  ('Lovesong', 'The Cure'),
#  ('Lovesong - 2010 Remaster', 'The Cure'),
#  ('The Cure', 'Little Mix'),
#  ('The Cure', 'Sam Lans!'),
#  ('Close to Me - 2006 Remaster', 'The Cure'),
#  ('The Cure', 'Unspoken'),
#  ("Friday I'm In Love", 'The Cure'),
#  ('The Cure', 'Little Mix'),
#  ('In Between Days', 'The Cure'),
#  ('The Cure (Stripped)', 'Little Mix'),
#  ('The Cure', 'Jadu Heart'),
#  ('Pictures of You - 2010 Remaster', 'The Cure'),
#  ('Burn', 'The Cure'),
#  ('The Cure', 'Watkins Family Hour'),
#  ('In Between Days - 2006 Remaster', 'The Cure'),
#  ('The Cure', 'Wake Up Hate'),
#  ('A Forest - 2006 Remaster', 'The Cure'),
#  ('The Cure & The Cause - Radio Edit', 'Fish Go Deep'),
#  ('The Cure & The Cause - Radio Edit', 'Tracey K'),
#  ('The Cure', 'Nas'),
#  ('Lullaby - 2010 Remaster', 'The Cure'),
#  ('The Lovecats', 'The Cure'),
#  ('Cure For Me', 'AURORA'),
#  ('Cure for the Itch', 'Linkin Park'),
#  ("Boys Don't Cry", 'The Cure'),
#  ('The Cure', 'Mark Battles'),
#  ('The Cure', 'King Los'),
#  ('The Cure', 'Forever M.C.'),
#  ('Lose My Mind (feat. Mr Gabriel)', 'Jai Wolf'),
#  ('The Cure', 'Non Prophets'),
#  ('A Letter to Elise', 'The Cure'),
#  ('The Cure', 'Alazka'),
#  ('Oak & Ash & Thorn', 'The Longest Johns'),
#  ('The Cure', 'Attila'),
#  ('Lovesong', 'The Cure'),
#  ('The Cure', 'Flite'),
#  ('The Cure', 'Justin Hawkes'),
#  ('The Cure & The Cause - Dennis Ferrer Remix', 'Fish Go Deep'),
#  ('The Cure & The Cause - Dennis Ferrer Remix', 'Tracey K'),
#  ('The Cure & The Cause - Dennis Ferrer Remix', 'Dennis Ferrer'),
#  ('The Cure', 'EQRIC'),
#  ('The Cure', 'PHARAØH'),
#  ('The Cure', 'Ceara Cavalieri'),
#  ('Fascination Street - 2010 Remaster', 'The Cure'),
#  ('The Cure', 'Tegan and Sara'),
#  ('Just like Heaven - 2006 Remaster', 'The Cure'),
#  ('The Cure', 'Lipstick Gypsy'),
#  ('Disintegration - 2010 Remaster', 'The Cure'),
#  ('The Cure', 'Fortunate Youth'),
#  ('The Cure For Pain', 'Jon Foreman'),
#  ('The Cure', 'BYOR'),
#  ('Ashes', 'The Longest Johns')]

# %%
def get_name_artist_from_list(tracks):
    return flatten(list(map(get_name_artist,tracks['items'])))

# %%
get_name_artist_from_list(results['tracks'])
# Out:
# [('The Cure', 'Lady Gaga'),
#  ("Friday I'm in Love", 'The Cure'),
#  ('The Cure', 'Lady Gaga'),
#  ('Just like Heaven', 'The Cure'),
#  ('The Cure', 'Wolves At The Gate'),
#  ("Boys Don't Cry - Single Version", 'The Cure'),
#  ('Lovesong', 'The Cure'),
#  ('Lovesong - 2010 Remaster', 'The Cure'),
#  ('The Cure', 'Little Mix'),
#  ('The Cure', 'Sam Lans!'),
#  ('Close to Me - 2006 Remaster', 'The Cure'),
#  ('The Cure', 'Unspoken'),
#  ("Friday I'm In Love", 'The Cure'),
#  ('The Cure', 'Little Mix'),
#  ('In Between Days', 'The Cure'),
#  ('The Cure (Stripped)', 'Little Mix'),
#  ('The Cure', 'Jadu Heart'),
#  ('Pictures of You - 2010 Remaster', 'The Cure'),
#  ('Burn', 'The Cure'),
#  ('The Cure', 'Watkins Family Hour'),
#  ('In Between Days - 2006 Remaster', 'The Cure'),
#  ('The Cure', 'Wake Up Hate'),
#  ('A Forest - 2006 Remaster', 'The Cure'),
#  ('The Cure & The Cause - Radio Edit', 'Fish Go Deep'),
#  ('The Cure & The Cause - Radio Edit', 'Tracey K'),
#  ('The Cure', 'Nas'),
#  ('Lullaby - 2010 Remaster', 'The Cure'),
#  ('The Lovecats', 'The Cure'),
#  ('Cure For Me', 'AURORA'),
#  ('Cure for the Itch', 'Linkin Park'),
#  ("Boys Don't Cry", 'The Cure'),
#  ('The Cure', 'Mark Battles'),
#  ('The Cure', 'King Los'),
#  ('The Cure', 'Forever M.C.'),
#  ('Lose My Mind (feat. Mr Gabriel)', 'Jai Wolf'),
#  ('The Cure', 'Non Prophets'),
#  ('A Letter to Elise', 'The Cure'),
#  ('The Cure', 'Alazka'),
#  ('Oak & Ash & Thorn', 'The Longest Johns'),
#  ('The Cure', 'Attila'),
#  ('Lovesong', 'The Cure'),
#  ('The Cure', 'Flite'),
#  ('The Cure', 'Justin Hawkes'),
#  ('The Cure & The Cause - Dennis Ferrer Remix', 'Fish Go Deep'),
#  ('The Cure & The Cause - Dennis Ferrer Remix', 'Tracey K'),
#  ('The Cure & The Cause - Dennis Ferrer Remix', 'Dennis Ferrer'),
#  ('The Cure', 'EQRIC'),
#  ('The Cure', 'PHARAØH'),
#  ('The Cure', 'Ceara Cavalieri'),
#  ('Fascination Street - 2010 Remaster', 'The Cure'),
#  ('The Cure', 'Tegan and Sara'),
#  ('Just like Heaven - 2006 Remaster', 'The Cure'),
#  ('The Cure', 'Lipstick Gypsy'),
#  ('Disintegration - 2010 Remaster', 'The Cure'),
#  ('The Cure', 'Fortunate Youth'),
#  ('The Cure For Pain', 'Jon Foreman'),
#  ('The Cure', 'BYOR'),
#  ('Ashes', 'The Longest Johns')]

# %% [markdown]
# # Playlists

# %%
playlist = sp.user_playlist_tracks("spotify", "1UV8OzKszYVhBHoyUAuSvV")

# %%
playlist
# Out:
# {'href': 'https://api.spotify.com/v1/playlists/1UV8OzKszYVhBHoyUAuSvV/tracks?offset=0&limit=100&additional_types=track',
#  'items': [{'added_at': '2021-08-25T13:17:18Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/janmolendijk'},
#     'href': 'https://api.spotify.com/v1/users/janmolendijk',
#     'id': 'janmolendijk',
#     'type': 'user',
#     'uri': 'spotify:user:janmolendijk'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1OxJzMLmR9l5zPLap9OxuO'},
#        'href': 'https://api.spotify.com/v1/artists/1OxJzMLmR9l5zPLap9OxuO',
#        'id': '1OxJzMLmR9l5zPLap9OxuO',
#        'name': 'Rose Royce',
#        'type': 'artist',
#        'uri': 'spotify:artist:1OxJzMLmR9l5zPLap9OxuO'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AO',
#       'AR',
#       'AT',
#       'AU',
#       'AZ',
#       'BA',
#       'BB',
#       'BD',
#       'BE',
#       'BF',
#       'BG',
#       'BH',
#       'BI',
#       'BJ',
#       'BN',
#       'BO',
#       'BR',
#       'BS',
#       'BT',
#       'BW',
#       'BY',
#       'BZ',
#       'CA',
#       'CD',
#       'CG',
#       'CH',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CV',
#       'CW',
#       'CY',
#       'CZ',
#       'DE',
#       'DJ',
#       'DK',
#       'DM',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FJ',
#       'FM',
#       'FR',
#       'GA',
#       'GB',
#       'GD',
#       'GE',
#       'GH',
#       'GM',
#       'GN',
#       'GQ',
#       'GR',
#       'GT',
#       'GW',
#       'GY',
#       'HK',
#       'HN',
#       'HR',
#       'HT',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IQ',
#       'IS',
#       'IT',
#       'JM',
#       'JO',
#       'JP',
#       'KE',
#       'KG',
#       'KH',
#       'KI',
#       'KM',
#       'KN',
#       'KR',
#       'KW',
#       'KZ',
#       'LA',
#       'LB',
#       'LC',
#       'LI',
#       'LK',
#       'LR',
#       'LS',
#       'LT',
#       'LU',
#       'LV',
#       'LY',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MG',
#       'MH',
#       'MK',
#       'ML',
#       'MN',
#       'MO',
#       'MR',
#       'MT',
#       'MU',
#       'MV',
#       'MW',
#       'MX',
#       'MY',
#       'MZ',
#       'NA',
#       'NE',
#       'NG',
#       'NI',
#       'NL',
#       'NO',
#       'NP',
#       'NR',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PG',
#       'PH',
#       'PK',
#       'PL',
#       'PS',
#       'PT',
#       'PW',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RW',
#       'SA',
#       'SB',
#       'SC',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SL',
#       'SM',
#       'SN',
#       'SR',
#       'ST',
#       'SV',
#       'SZ',
#       'TD',
#       'TG',
#       'TH',
#       'TJ',
#       'TL',
#       'TN',
#       'TO',
#       'TR',
#       'TT',
#       'TV',
#       'TW',
#       'TZ',
#       'UA',
#       'UG',
#       'US',
#       'UY',
#       'UZ',
#       'VC',
#       'VE',
#       'VN',
#       'VU',
#       'WS',
#       'XK',
#       'ZA',
#       'ZM',
#       'ZW'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/19fTeMlAjRVFT9jTTkHvRk'},
#      'href': 'https://api.spotify.com/v1/albums/19fTeMlAjRVFT9jTTkHvRk',
#      'id': '19fTeMlAjRVFT9jTTkHvRk',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273731ea6e7b5da9da4130c071d',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02731ea6e7b5da9da4130c071d',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851731ea6e7b5da9da4130c071d',
#        'width': 64}],
#      'name': 'In Full Bloom',
#      'release_date': '1977',
#      'release_date_precision': 'year',
#      'total_tracks': 8,
#      'type': 'album',
#      'uri': 'spotify:album:19fTeMlAjRVFT9jTTkHvRk'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1OxJzMLmR9l5zPLap9OxuO'},
#       'href': 'https://api.spotify.com/v1/artists/1OxJzMLmR9l5zPLap9OxuO',
#       'id': '1OxJzMLmR9l5zPLap9OxuO',
#       'name': 'Rose Royce',
#       'type': 'artist',
#       'uri': 'spotify:artist:1OxJzMLmR9l5zPLap9OxuO'}],
#     'available_markets': ['AD',
#      'AE',
#      'AG',
#      'AL',
#      'AM',
#      'AO',
#      'AR',
#      'AT',
#      'AU',
#      'AZ',
#      'BA',
#      'BB',
#      'BD',
#      'BE',
#      'BF',
#      'BG',
#      'BH',
#      'BI',
#      'BJ',
#      'BN',
#      'BO',
#      'BR',
#      'BS',
#      'BT',
#      'BW',
#      'BY',
#      'BZ',
#      'CA',
#      'CD',
#      'CG',
#      'CH',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CV',
#      'CW',
#      'CY',
#      'CZ',
#      'DE',
#      'DJ',
#      'DK',
#      'DM',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FJ',
#      'FM',
#      'FR',
#      'GA',
#      'GB',
#      'GD',
#      'GE',
#      'GH',
#      'GM',
#      'GN',
#      'GQ',
#      'GR',
#      'GT',
#      'GW',
#      'GY',
#      'HK',
#      'HN',
#      'HR',
#      'HT',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IQ',
#      'IS',
#      'IT',
#      'JM',
#      'JO',
#      'JP',
#      'KE',
#      'KG',
#      'KH',
#      'KI',
#      'KM',
#      'KN',
#      'KR',
#      'KW',
#      'KZ',
#      'LA',
#      'LB',
#      'LC',
#      'LI',
#      'LK',
#      'LR',
#      'LS',
#      'LT',
#      'LU',
#      'LV',
#      'LY',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MG',
#      'MH',
#      'MK',
#      'ML',
#      'MN',
#      'MO',
#      'MR',
#      'MT',
#      'MU',
#      'MV',
#      'MW',
#      'MX',
#      'MY',
#      'MZ',
#      'NA',
#      'NE',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NP',
#      'NR',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PG',
#      'PH',
#      'PK',
#      'PL',
#      'PS',
#      'PT',
#      'PW',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RW',
#      'SA',
#      'SB',
#      'SC',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SL',
#      'SM',
#      'SN',
#      'SR',
#      'ST',
#      'SV',
#      'SZ',
#      'TD',
#      'TG',
#      'TH',
#      'TJ',
#      'TL',
#      'TN',
#      'TO',
#      'TR',
#      'TT',
#      'TV',
#      'TW',
#      'TZ',
#      'UA',
#      'UG',
#      'US',
#      'UY',
#      'UZ',
#      'VC',
#      'VE',
#      'VN',
#      'VU',
#      'WS',
#      'XK',
#      'ZA',
#      'ZM',
#      'ZW'],
#     'disc_number': 1,
#     'duration_ms': 291760,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'USWB10903804'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/0u2CGItUO2jYEiFaXD7n5S'},
#     'href': 'https://api.spotify.com/v1/tracks/0u2CGItUO2jYEiFaXD7n5S',
#     'id': '0u2CGItUO2jYEiFaXD7n5S',
#     'is_local': False,
#     'name': 'Wishing on a Star',
#     'popularity': 53,
#     'preview_url': 'https://p.scdn.co/mp3-preview/e446c7508899ae5b3e7beb8e02898dae804708f5?cid=da00ed264eaf4f94ba2adf23ff058567',
#     'track': True,
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:0u2CGItUO2jYEiFaXD7n5S'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2021-08-25T13:17:45Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/janmolendijk'},
#     'href': 'https://api.spotify.com/v1/users/janmolendijk',
#     'id': 'janmolendijk',
#     'type': 'user',
#     'uri': 'spotify:user:janmolendijk'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6c5rmJFl0g7SnRiqOPrOJe'},
#        'href': 'https://api.spotify.com/v1/artists/6c5rmJFl0g7SnRiqOPrOJe',
#        'id': '6c5rmJFl0g7SnRiqOPrOJe',
#        'name': 'The Affordable Floors',
#        'type': 'artist',
#        'uri': 'spotify:artist:6c5rmJFl0g7SnRiqOPrOJe'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AO',
#       'AR',
#       'AT',
#       'AU',
#       'AZ',
#       'BA',
#       'BB',
#       'BD',
#       'BE',
#       'BF',
#       'BG',
#       'BH',
#       'BI',
#       'BJ',
#       'BN',
#       'BO',
#       'BR',
#       'BS',
#       'BT',
#       'BW',
#       'BY',
#       'BZ',
#       'CA',
#       'CD',
#       'CG',
#       'CH',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CV',
#       'CY',
#       'CZ',
#       'DE',
#       'DJ',
#       'DK',
#       'DM',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FJ',
#       'FM',
#       'FR',
#       'GA',
#       'GB',
#       'GD',
#       'GE',
#       'GH',
#       'GM',
#       'GN',
#       'GQ',
#       'GR',
#       'GT',
#       'GW',
#       'GY',
#       'HK',
#       'HN',
#       'HR',
#       'HT',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IQ',
#       'IS',
#       'IT',
#       'JM',
#       'JO',
#       'JP',
#       'KE',
#       'KG',
#       'KH',
#       'KI',
#       'KM',
#       'KN',
#       'KR',
#       'KW',
#       'KZ',
#       'LA',
#       'LB',
#       'LC',
#       'LI',
#       'LK',
#       'LR',
#       'LS',
#       'LT',
#       'LU',
#       'LV',
#       'LY',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MG',
#       'MH',
#       'MK',
#       'ML',
#       'MN',
#       'MO',
#       'MR',
#       'MT',
#       'MU',
#       'MV',
#       'MW',
#       'MX',
#       'MY',
#       'MZ',
#       'NA',
#       'NE',
#       'NG',
#       'NI',
#       'NL',
#       'NO',
#       'NP',
#       'NR',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PG',
#       'PH',
#       'PK',
#       'PL',
#       'PS',
#       'PT',
#       'PW',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RW',
#       'SA',
#       'SB',
#       'SC',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SL',
#       'SM',
#       'SN',
#       'SR',
#       'ST',
#       'SV',
#       'SZ',
#       'TD',
#       'TG',
#       'TH',
#       'TJ',
#       'TL',
#       'TN',
#       'TO',
#       'TR',
#       'TT',
#       'TV',
#       'TW',
#       'TZ',
#       'UA',
#       'UG',
#       'US',
#       'UY',
#       'UZ',
#       'VC',
#       'VE',
#       'VN',
#       'VU',
#       'WS',
#       'XK',
#       'ZA',
#       'ZM',
#       'ZW'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/5Sh4mdyF9zCpRWh2aFEhuQ'},
#      'href': 'https://api.spotify.com/v1/albums/5Sh4mdyF9zCpRWh2aFEhuQ',
#      'id': '5Sh4mdyF9zCpRWh2aFEhuQ',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2732341caf5174e7eb20518ce1d',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e022341caf5174e7eb20518ce1d',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048512341caf5174e7eb20518ce1d',
#        'width': 64}],
#      'name': 'Drumming On The Walls',
#      'release_date': '2013-11-06',
#      'release_date_precision': 'day',
#      'total_tracks': 10,
#      'type': 'album',
#      'uri': 'spotify:album:5Sh4mdyF9zCpRWh2aFEhuQ'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6c5rmJFl0g7SnRiqOPrOJe'},
#       'href': 'https://api.spotify.com/v1/artists/6c5rmJFl0g7SnRiqOPrOJe',
#       'id': '6c5rmJFl0g7SnRiqOPrOJe',
#       'name': 'The Affordable Floors',
#       'type': 'artist',
#       'uri': 'spotify:artist:6c5rmJFl0g7SnRiqOPrOJe'}],
#     'available_markets': ['AD',
#      'AE',
#      'AG',
#      'AL',
#      'AM',
#      'AO',
#      'AR',
#      'AT',
#      'AU',
#      'AZ',
#      'BA',
#      'BB',
#      'BD',
#      'BE',
#      'BF',
#      'BG',
#      'BH',
#      'BI',
#      'BJ',
#      'BN',
#      'BO',
#      'BR',
#      'BS',
#      'BT',
#      'BW',
#      'BY',
#      'BZ',
#      'CA',
#      'CD',
#      'CG',
#      'CH',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CV',
#      'CY',
#      'CZ',
#      'DE',
#      'DJ',
#      'DK',
#      'DM',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FJ',
#      'FM',
#      'FR',
#      'GA',
#      'GB',
#      'GD',
#      'GE',
#      'GH',
#      'GM',
#      'GN',
#      'GQ',
#      'GR',
#      'GT',
#      'GW',
#      'GY',
#      'HK',
#      'HN',
#      'HR',
#      'HT',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IQ',
#      'IS',
#      'IT',
#      'JM',
#      'JO',
#      'JP',
#      'KE',
#      'KG',
#      'KH',
#      'KI',
#      'KM',
#      'KN',
#      'KR',
#      'KW',
#      'KZ',
#      'LA',
#      'LB',
#      'LC',
#      'LI',
#      'LK',
#      'LR',
#      'LS',
#      'LT',
#      'LU',
#      'LV',
#      'LY',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MG',
#      'MH',
#      'MK',
#      'ML',
#      'MN',
#      'MO',
#      'MR',
#      'MT',
#      'MU',
#      'MV',
#      'MW',
#      'MX',
#      'MY',
#      'MZ',
#      'NA',
#      'NE',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NP',
#      'NR',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PG',
#      'PH',
#      'PK',
#      'PL',
#      'PS',
#      'PT',
#      'PW',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RW',
#      'SA',
#      'SB',
#      'SC',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SL',
#      'SM',
#      'SN',
#      'SR',
#      'ST',
#      'SV',
#      'SZ',
#      'TD',
#      'TG',
#      'TH',
#      'TJ',
#      'TL',
#      'TN',
#      'TO',
#      'TR',
#      'TT',
#      'TV',
#      'TW',
#      'TZ',
#      'UA',
#      'UG',
#      'US',
#      'UY',
#      'UZ',
#      'VC',
#      'VE',
#      'VN',
#      'VU',
#      'WS',
#      'XK',
#      'ZA',
#      'ZM',
#      'ZW'],
#     'disc_number': 1,
#     'duration_ms': 243435,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'QMPKX1322552'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/7FvHQLMbpf3AhbmJTXBfe1'},
#     'href': 'https://api.spotify.com/v1/tracks/7FvHQLMbpf3AhbmJTXBfe1',
#     'id': '7FvHQLMbpf3AhbmJTXBfe1',
#     'is_local': False,
#     'name': 'Berkeley Square',
#     'popularity': 1,
#     'preview_url': 'https://p.scdn.co/mp3-preview/6c64b90ec6c34409bc9e4eaba4cf5372f7722f3f?cid=da00ed264eaf4f94ba2adf23ff058567',
#     'track': True,
#     'track_number': 2,
#     'type': 'track',
#     'uri': 'spotify:track:7FvHQLMbpf3AhbmJTXBfe1'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2021-08-25T13:18:26Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/janmolendijk'},
#     'href': 'https://api.spotify.com/v1/users/janmolendijk',
#     'id': 'janmolendijk',
#     'type': 'user',
#     'uri': 'spotify:user:janmolendijk'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2AiLSd9HXwfFwO9g00s2hk'},
#        'href': 'https://api.spotify.com/v1/artists/2AiLSd9HXwfFwO9g00s2hk',
#        'id': '2AiLSd9HXwfFwO9g00s2hk',
#        'name': 'Boss AC',
#        'type': 'artist',
#        'uri': 'spotify:artist:2AiLSd9HXwfFwO9g00s2hk'}],
#      'available_markets': [],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/22Jy4ghiqNdwbaJOhh9SPX'},
#      'href': 'https://api.spotify.com/v1/albums/22Jy4ghiqNdwbaJOhh9SPX',
#      'id': '22Jy4ghiqNdwbaJOhh9SPX',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b27362ec15a75f1676abf6cf08aa',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e0262ec15a75f1676abf6cf08aa',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d0000485162ec15a75f1676abf6cf08aa',
#        'width': 64}],
#      'name': 'Ac para os amigos (Internacional)',
#      'release_date': '2013-09-24',
#      'release_date_precision': 'day',
#      'total_tracks': 20,
#      'type': 'album',
#      'uri': 'spotify:album:22Jy4ghiqNdwbaJOhh9SPX'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2AiLSd9HXwfFwO9g00s2hk'},
#       'href': 'https://api.spotify.com/v1/artists/2AiLSd9HXwfFwO9g00s2hk',
#       'id': '2AiLSd9HXwfFwO9g00s2hk',
#       'name': 'Boss AC',
#       'type': 'artist',
#       'uri': 'spotify:artist:2AiLSd9HXwfFwO9g00s2hk'}],
#     'available_markets': [],
#     'disc_number': 1,
#     'duration_ms': 260363,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'PT4AD1200002'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/6yvl1WAsrCdRQjuljD2eSC'},
#     'href': 'https://api.spotify.com/v1/tracks/6yvl1WAsrCdRQjuljD2eSC',
#     'id': '6yvl1WAsrCdRQjuljD2eSC',
#     'is_local': False,
#     'name': 'Hip Hop (Sou Eu e És Tu) - Ao Vivo Cmpm, Bonus',
#     'popularity': 0,
#     'preview_url': None,
#     'track': True,
#     'track_number': 14,
#     'type': 'track',
#     'uri': 'spotify:track:6yvl1WAsrCdRQjuljD2eSC'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2021-08-25T13:18:49Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/janmolendijk'},
#     'href': 'https://api.spotify.com/v1/users/janmolendijk',
#     'id': 'janmolendijk',
#     'type': 'user',
#     'uri': 'spotify:user:janmolendijk'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5eAWCfyUhZtHHtBdNk56l1'},
#        'href': 'https://api.spotify.com/v1/artists/5eAWCfyUhZtHHtBdNk56l1',
#        'id': '5eAWCfyUhZtHHtBdNk56l1',
#        'name': 'System Of A Down',
#        'type': 'artist',
#        'uri': 'spotify:artist:5eAWCfyUhZtHHtBdNk56l1'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AO',
#       'AR',
#       'AT',
#       'AU',
#       'AZ',
#       'BA',
#       'BB',
#       'BD',
#       'BE',
#       'BF',
#       'BG',
#       'BH',
#       'BI',
#       'BJ',
#       'BN',
#       'BO',
#       'BR',
#       'BS',
#       'BT',
#       'BW',
#       'BY',
#       'BZ',
#       'CA',
#       'CD',
#       'CG',
#       'CH',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CV',
#       'CW',
#       'CY',
#       'CZ',
#       'DE',
#       'DJ',
#       'DK',
#       'DM',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FJ',
#       'FM',
#       'FR',
#       'GA',
#       'GB',
#       'GD',
#       'GE',
#       'GH',
#       'GM',
#       'GN',
#       'GQ',
#       'GR',
#       'GT',
#       'GW',
#       'GY',
#       'HK',
#       'HN',
#       'HR',
#       'HT',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IQ',
#       'IS',
#       'IT',
#       'JM',
#       'JO',
#       'JP',
#       'KE',
#       'KG',
#       'KH',
#       'KI',
#       'KM',
#       'KN',
#       'KR',
#       'KW',
#       'KZ',
#       'LA',
#       'LB',
#       'LC',
#       'LI',
#       'LK',
#       'LR',
#       'LS',
#       'LT',
#       'LU',
#       'LV',
#       'LY',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MG',
#       'MH',
#       'MK',
#       'ML',
#       'MN',
#       'MO',
#       'MR',
#       'MT',
#       'MU',
#       'MV',
#       'MW',
#       'MX',
#       'MY',
#       'MZ',
#       'NA',
#       'NE',
#       'NG',
#       'NI',
#       'NL',
#       'NO',
#       'NP',
#       'NR',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PG',
#       'PH',
#       'PK',
#       'PL',
#       'PS',
#       'PT',
#       'PW',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RW',
#       'SA',
#       'SB',
#       'SC',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SL',
#       'SM',
#       'SN',
#       'SR',
#       'ST',
#       'SV',
#       'SZ',
#       'TD',
#       'TG',
#       'TH',
#       'TJ',
#       'TL',
#       'TN',
#       'TO',
#       'TR',
#       'TT',
#       'TV',
#       'TW',
#       'TZ',
#       'UA',
#       'UG',
#       'US',
#       'UY',
#       'UZ',
#       'VC',
#       'VE',
#       'VN',
#       'VU',
#       'WS',
#       'XK',
#       'ZA',
#       'ZM',
#       'ZW'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/6jWde94ln40epKIQCd8XUh'},
#      'href': 'https://api.spotify.com/v1/albums/6jWde94ln40epKIQCd8XUh',
#      'id': '6jWde94ln40epKIQCd8XUh',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b27330d45198d0c9e8841f9a9578',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e0230d45198d0c9e8841f9a9578',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d0000485130d45198d0c9e8841f9a9578',
#        'width': 64}],
#      'name': 'Toxicity',
#      'release_date': '2001-09-04',
#      'release_date_precision': 'day',
#      'total_tracks': 15,
#      'type': 'album',
#      'uri': 'spotify:album:6jWde94ln40epKIQCd8XUh'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5eAWCfyUhZtHHtBdNk56l1'},
#       'href': 'https://api.spotify.com/v1/artists/5eAWCfyUhZtHHtBdNk56l1',
#       'id': '5eAWCfyUhZtHHtBdNk56l1',
#       'name': 'System Of A Down',
#       'type': 'artist',
#       'uri': 'spotify:artist:5eAWCfyUhZtHHtBdNk56l1'}],
#     'available_markets': ['AD',
#      'AE',
#      'AG',
#      'AL',
#      'AM',
#      'AO',
#      'AR',
#      'AT',
#      'AU',
#      'AZ',
#      'BA',
#      'BB',
#      'BD',
#      'BE',
#      'BF',
#      'BG',
#      'BH',
#      'BI',
#      'BJ',
#      'BN',
#      'BO',
#      'BR',
#      'BS',
#      'BT',
#      'BW',
#      'BY',
#      'BZ',
#      'CA',
#      'CD',
#      'CG',
#      'CH',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CV',
#      'CW',
#      'CY',
#      'CZ',
#      'DE',
#      'DJ',
#      'DK',
#      'DM',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FJ',
#      'FM',
#      'FR',
#      'GA',
#      'GB',
#      'GD',
#      'GE',
#      'GH',
#      'GM',
#      'GN',
#      'GQ',
#      'GR',
#      'GT',
#      'GW',
#      'GY',
#      'HK',
#      'HN',
#      'HR',
#      'HT',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IQ',
#      'IS',
#      'IT',
#      'JM',
#      'JO',
#      'JP',
#      'KE',
#      'KG',
#      'KH',
#      'KI',
#      'KM',
#      'KN',
#      'KR',
#      'KW',
#      'KZ',
#      'LA',
#      'LB',
#      'LC',
#      'LI',
#      'LK',
#      'LR',
#      'LS',
#      'LT',
#      'LU',
#      'LV',
#      'LY',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MG',
#      'MH',
#      'MK',
#      'ML',
#      'MN',
#      'MO',
#      'MR',
#      'MT',
#      'MU',
#      'MV',
#      'MW',
#      'MX',
#      'MY',
#      'MZ',
#      'NA',
#      'NE',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NP',
#      'NR',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PG',
#      'PH',
#      'PK',
#      'PL',
#      'PS',
#      'PT',
#      'PW',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RW',
#      'SA',
#      'SB',
#      'SC',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SL',
#      'SM',
#      'SN',
#      'SR',
#      'ST',
#      'SV',
#      'SZ',
#      'TD',
#      'TG',
#      'TH',
#      'TJ',
#      'TL',
#      'TN',
#      'TO',
#      'TR',
#      'TT',
#      'TV',
#      'TW',
#      'TZ',
#      'UA',
#      'UG',
#      'US',
#      'UY',
#      'UZ',
#      'VC',
#      'VE',
#      'VN',
#      'VU',
#      'WS',
#      'XK',
#      'ZA',
#      'ZM',
#      'ZW'],
#     'disc_number': 1,
#     'duration_ms': 210240,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'USSM10107256'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/2DlHlPMa4M17kufBvI2lEN'},
#     'href': 'https://api.spotify.com/v1/tracks/2DlHlPMa4M17kufBvI2lEN',
#     'id': '2DlHlPMa4M17kufBvI2lEN',
#     'is_local': False,
#     'name': 'Chop Suey!',
#     'popularity': 80,
#     'preview_url': 'https://p.scdn.co/mp3-preview/668891dce18fb36b6dbf8f3f3f0ecf71c1f95298?cid=da00ed264eaf4f94ba2adf23ff058567',
#     'track': True,
#     'track_number': 6,
#     'type': 'track',
#     'uri': 'spotify:track:2DlHlPMa4M17kufBvI2lEN'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2021-08-25T13:19:13Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/janmolendijk'},
#     'href': 'https://api.spotify.com/v1/users/janmolendijk',
#     'id': 'janmolendijk',
#     'type': 'user',
#     'uri': 'spotify:user:janmolendijk'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0KQX2wRHV2VLjuscfJFNxB'},
#        'href': 'https://api.spotify.com/v1/artists/0KQX2wRHV2VLjuscfJFNxB',
#        'id': '0KQX2wRHV2VLjuscfJFNxB',
#        'name': 'BLØF',
#        'type': 'artist',
#        'uri': 'spotify:artist:0KQX2wRHV2VLjuscfJFNxB'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AO',
#       'AR',
#       'AT',
#       'AU',
#       'AZ',
#       'BA',
#       'BB',
#       'BD',
#       'BE',
#       'BF',
#       'BG',
#       'BH',
#       'BI',
#       'BJ',
#       'BN',
#       'BO',
#       'BR',
#       'BS',
#       'BT',
#       'BW',
#       'BY',
#       'BZ',
#       'CA',
#       'CD',
#       'CG',
#       'CH',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CV',
#       'CW',
#       'CY',
#       'CZ',
#       'DE',
#       'DJ',
#       'DK',
#       'DM',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FJ',
#       'FM',
#       'FR',
#       'GA',
#       'GB',
#       'GD',
#       'GE',
#       'GH',
#       'GM',
#       'GN',
#       'GQ',
#       'GR',
#       'GT',
#       'GW',
#       'GY',
#       'HK',
#       'HN',
#       'HR',
#       'HT',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IQ',
#       'IS',
#       'IT',
#       'JM',
#       'JO',
#       'JP',
#       'KE',
#       'KG',
#       'KH',
#       'KI',
#       'KM',
#       'KN',
#       'KR',
#       'KW',
#       'KZ',
#       'LA',
#       'LB',
#       'LC',
#       'LI',
#       'LK',
#       'LR',
#       'LS',
#       'LT',
#       'LU',
#       'LV',
#       'LY',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MG',
#       'MH',
#       'MK',
#       'ML',
#       'MN',
#       'MO',
#       'MR',
#       'MT',
#       'MU',
#       'MV',
#       'MW',
#       'MX',
#       'MY',
#       'MZ',
#       'NA',
#       'NE',
#       'NG',
#       'NI',
#       'NL',
#       'NO',
#       'NP',
#       'NR',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PG',
#       'PH',
#       'PK',
#       'PL',
#       'PS',
#       'PT',
#       'PW',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RW',
#       'SA',
#       'SB',
#       'SC',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SL',
#       'SM',
#       'SN',
#       'SR',
#       'ST',
#       'SV',
#       'SZ',
#       'TD',
#       'TG',
#       'TH',
#       'TJ',
#       'TL',
#       'TN',
#       'TO',
#       'TR',
#       'TT',
#       'TV',
#       'TW',
#       'TZ',
#       'UA',
#       'UG',
#       'US',
#       'UY',
#       'UZ',
#       'VC',
#       'VE',
#       'VN',
#       'VU',
#       'WS',
#       'XK',
#       'ZA',
#       'ZM',
#       'ZW'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/198mMFxiYJihAoJzn7cRO6'},
#      'href': 'https://api.spotify.com/v1/albums/198mMFxiYJihAoJzn7cRO6',
#      'id': '198mMFxiYJihAoJzn7cRO6',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273db2a436949d997c7ce9cb850',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02db2a436949d997c7ce9cb850',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851db2a436949d997c7ce9cb850',
#        'width': 64}],
#      'name': 'Boven',
#      'release_date': '1999-01-01',
#      'release_date_precision': 'day',
#      'total_tracks': 16,
#      'type': 'album',
#      'uri': 'spotify:album:198mMFxiYJihAoJzn7cRO6'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0KQX2wRHV2VLjuscfJFNxB'},
#       'href': 'https://api.spotify.com/v1/artists/0KQX2wRHV2VLjuscfJFNxB',
#       'id': '0KQX2wRHV2VLjuscfJFNxB',
#       'name': 'BLØF',
#       'type': 'artist',
#       'uri': 'spotify:artist:0KQX2wRHV2VLjuscfJFNxB'}],
#     'available_markets': ['AD',
#      'AL',
#      'AT',
#      'BA',
#      'BE',
#      'BG',
#      'BY',
#      'CH',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'EE',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'HR',
#      'HU',
#      'IE',
#      'IL',
#      'IS',
#      'IT',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MC',
#      'ME',
#      'MK',
#      'MT',
#      'NL',
#      'NO',
#      'PL',
#      'PT',
#      'RO',
#      'RS',
#      'SE',
#      'SI',
#      'SK',
#      'SM',
#      'TR',
#      'UA',
#      'XK'],
#     'disc_number': 1,
#     'duration_ms': 253893,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'NLA279900017'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/1buASziRLNHXcTVYFWZ8EK'},
#     'href': 'https://api.spotify.com/v1/tracks/1buASziRLNHXcTVYFWZ8EK',
#     'id': '1buASziRLNHXcTVYFWZ8EK',
#     'is_local': False,
#     'name': 'Harder Dan Ik Hebben Kan',
#     'popularity': 53,
#     'preview_url': None,
#     'track': True,
#     'track_number': 2,
#     'type': 'track',
#     'uri': 'spotify:track:1buASziRLNHXcTVYFWZ8EK'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2021-08-25T13:19:53Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/janmolendijk'},
#     'href': 'https://api.spotify.com/v1/users/janmolendijk',
#     'id': 'janmolendijk',
#     'type': 'user',
#     'uri': 'spotify:user:janmolendijk'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/58lV9VcRSjABbAbfWS6skp'},
#        'href': 'https://api.spotify.com/v1/artists/58lV9VcRSjABbAbfWS6skp',
#        'id': '58lV9VcRSjABbAbfWS6skp',
#        'name': 'Bon Jovi',
#        'type': 'artist',
#        'uri': 'spotify:artist:58lV9VcRSjABbAbfWS6skp'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AO',
#       'AR',
#       'AT',
#       'AU',
#       'AZ',
#       'BA',
#       'BB',
#       'BD',
#       'BE',
#       'BF',
#       'BG',
#       'BH',
#       'BI',
#       'BJ',
#       'BN',
#       'BO',
#       'BR',
#       'BS',
#       'BT',
#       'BW',
#       'BY',
#       'BZ',
#       'CA',
#       'CD',
#       'CG',
#       'CH',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CV',
#       'CW',
#       'CY',
#       'CZ',
#       'DE',
#       'DJ',
#       'DK',
#       'DM',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FJ',
#       'FM',
#       'FR',
#       'GA',
#       'GB',
#       'GD',
#       'GE',
#       'GH',
#       'GM',
#       'GN',
#       'GQ',
#       'GR',
#       'GT',
#       'GW',
#       'GY',
#       'HK',
#       'HN',
#       'HR',
#       'HT',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IQ',
#       'IS',
#       'IT',
#       'JM',
#       'JO',
#       'JP',
#       'KE',
#       'KG',
#       'KH',
#       'KI',
#       'KM',
#       'KN',
#       'KR',
#       'KW',
#       'KZ',
#       'LA',
#       'LB',
#       'LC',
#       'LI',
#       'LK',
#       'LR',
#       'LS',
#       'LT',
#       'LU',
#       'LV',
#       'LY',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MG',
#       'MH',
#       'MK',
#       'ML',
#       'MN',
#       'MO',
#       'MR',
#       'MT',
#       'MU',
#       'MV',
#       'MW',
#       'MX',
#       'MY',
#       'MZ',
#       'NA',
#       'NE',
#       'NG',
#       'NI',
#       'NL',
#       'NO',
#       'NP',
#       'NR',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PG',
#       'PH',
#       'PK',
#       'PL',
#       'PS',
#       'PT',
#       'PW',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RW',
#       'SA',
#       'SB',
#       'SC',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SL',
#       'SM',
#       'SN',
#       'SR',
#       'ST',
#       'SV',
#       'SZ',
#       'TD',
#       'TG',
#       'TH',
#       'TJ',
#       'TL',
#       'TN',
#       'TO',
#       'TR',
#       'TT',
#       'TV',
#       'TW',
#       'TZ',
#       'UA',
#       'UG',
#       'US',
#       'UY',
#       'UZ',
#       'VC',
#       'VE',
#       'VN',
#       'VU',
#       'WS',
#       'XK',
#       'ZA',
#       'ZM',
#       'ZW'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/7HCN56jCBXWvsTzWtnypoE'},
#      'href': 'https://api.spotify.com/v1/albums/7HCN56jCBXWvsTzWtnypoE',
#      'id': '7HCN56jCBXWvsTzWtnypoE',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273c275efed5f61bd52e14d7fa2',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02c275efed5f61bd52e14d7fa2',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851c275efed5f61bd52e14d7fa2',
#        'width': 64}],
#      'name': 'One Wild Night 2001',
#      'release_date': '2001-05-22',
#      'release_date_precision': 'day',
#      'total_tracks': 15,
#      'type': 'album',
#      'uri': 'spotify:album:7HCN56jCBXWvsTzWtnypoE'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/58lV9VcRSjABbAbfWS6skp'},
#       'href': 'https://api.spotify.com/v1/artists/58lV9VcRSjABbAbfWS6skp',
#       'id': '58lV9VcRSjABbAbfWS6skp',
#       'name': 'Bon Jovi',
#       'type': 'artist',
#       'uri': 'spotify:artist:58lV9VcRSjABbAbfWS6skp'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/66sQGl0Lhj61ADTabhWqYf'},
#       'href': 'https://api.spotify.com/v1/artists/66sQGl0Lhj61ADTabhWqYf',
#       'id': '66sQGl0Lhj61ADTabhWqYf',
#       'name': "Obie O'Brien",
#       'type': 'artist',
#       'uri': 'spotify:artist:66sQGl0Lhj61ADTabhWqYf'}],
#     'available_markets': ['AD',
#      'AE',
#      'AG',
#      'AL',
#      'AM',
#      'AO',
#      'AR',
#      'AT',
#      'AU',
#      'AZ',
#      'BA',
#      'BB',
#      'BD',
#      'BE',
#      'BF',
#      'BG',
#      'BH',
#      'BI',
#      'BJ',
#      'BN',
#      'BO',
#      'BR',
#      'BS',
#      'BT',
#      'BW',
#      'BY',
#      'BZ',
#      'CA',
#      'CD',
#      'CG',
#      'CH',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CV',
#      'CW',
#      'CY',
#      'CZ',
#      'DE',
#      'DJ',
#      'DK',
#      'DM',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FJ',
#      'FM',
#      'FR',
#      'GA',
#      'GB',
#      'GD',
#      'GE',
#      'GH',
#      'GM',
#      'GN',
#      'GQ',
#      'GR',
#      'GT',
#      'GW',
#      'GY',
#      'HK',
#      'HN',
#      'HR',
#      'HT',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IQ',
#      'IS',
#      'IT',
#      'JM',
#      'JO',
#      'JP',
#      'KE',
#      'KG',
#      'KH',
#      'KI',
#      'KM',
#      'KN',
#      'KR',
#      'KW',
#      'KZ',
#      'LA',
#      'LB',
#      'LC',
#      'LI',
#      'LK',
#      'LR',
#      'LS',
#      'LT',
#      'LU',
#      'LV',
#      'LY',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MG',
#      'MH',
#      'MK',
#      'ML',
#      'MN',
#      'MO',
#      'MR',
#      'MT',
#      'MU',
#      'MV',
#      'MW',
#      'MX',
#      'MY',
#      'MZ',
#      'NA',
#      'NE',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NP',
#      'NR',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PG',
#      'PH',
#      'PK',
#      'PL',
#      'PS',
#      'PT',
#      'PW',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RW',
#      'SA',
#      'SB',
#      'SC',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SL',
#      'SM',
#      'SN',
#      'SR',
#      'ST',
#      'SV',
#      'SZ',
#      'TD',
#      'TG',
#      'TH',
#      'TJ',
#      'TL',
#      'TN',
#      'TO',
#      'TR',
#      'TT',
#      'TV',
#      'TW',
#      'TZ',
#      'UA',
#      'UG',
#      'US',
#      'UY',
#      'UZ',
#      'VC',
#      'VE',
#      'VN',
#      'VU',
#      'WS',
#      'XK',
#      'ZA',
#      'ZM',
#      'ZW'],
#     'disc_number': 1,
#     'duration_ms': 340360,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'USIR20110160'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/2fCbzSeSz5LuWFPDXJk7sQ'},
#     'href': 'https://api.spotify.com/v1/tracks/2fCbzSeSz5LuWFPDXJk7sQ',
#     'id': '2fCbzSeSz5LuWFPDXJk7sQ',
#     'is_local': False,
#     'name': 'Rocking In The Free World - Live In Johannesburg/1995',
#     'popularity': 33,
#     'preview_url': None,
#     'track': True,
#     'track_number': 6,
#     'type': 'track',
#     'uri': 'spotify:track:2fCbzSeSz5LuWFPDXJk7sQ'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2021-08-25T13:21:42Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/janmolendijk'},
#     'href': 'https://api.spotify.com/v1/users/janmolendijk',
#     'id': 'janmolendijk',
#     'type': 'user',
#     'uri': 'spotify:user:janmolendijk'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4U7lXyKdSf1JbM1aXvsodC'},
#        'href': 'https://api.spotify.com/v1/artists/4U7lXyKdSf1JbM1aXvsodC',
#        'id': '4U7lXyKdSf1JbM1aXvsodC',
#        'name': 'La Oreja de Van Gogh',
#        'type': 'artist',
#        'uri': 'spotify:artist:4U7lXyKdSf1JbM1aXvsodC'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AO',
#       'AR',
#       'AT',
#       'AU',
#       'AZ',
#       'BA',
#       'BB',
#       'BD',
#       'BE',
#       'BF',
#       'BG',
#       'BH',
#       'BI',
#       'BJ',
#       'BN',
#       'BO',
#       'BR',
#       'BS',
#       'BT',
#       'BW',
#       'BY',
#       'BZ',
#       'CA',
#       'CD',
#       'CG',
#       'CH',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CV',
#       'CW',
#       'CY',
#       'CZ',
#       'DE',
#       'DJ',
#       'DK',
#       'DM',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FJ',
#       'FM',
#       'FR',
#       'GA',
#       'GB',
#       'GD',
#       'GE',
#       'GH',
#       'GM',
#       'GN',
#       'GQ',
#       'GR',
#       'GT',
#       'GW',
#       'GY',
#       'HK',
#       'HN',
#       'HR',
#       'HT',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IQ',
#       'IS',
#       'IT',
#       'JM',
#       'JO',
#       'JP',
#       'KE',
#       'KG',
#       'KH',
#       'KI',
#       'KM',
#       'KN',
#       'KR',
#       'KW',
#       'KZ',
#       'LA',
#       'LB',
#       'LC',
#       'LI',
#       'LK',
#       'LR',
#       'LS',
#       'LT',
#       'LU',
#       'LV',
#       'LY',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MG',
#       'MH',
#       'MK',
#       'ML',
#       'MN',
#       'MO',
#       'MR',
#       'MT',
#       'MU',
#       'MV',
#       'MW',
#       'MX',
#       'MY',
#       'MZ',
#       'NA',
#       'NE',
#       'NG',
#       'NI',
#       'NL',
#       'NO',
#       'NP',
#       'NR',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PG',
#       'PH',
#       'PK',
#       'PL',
#       'PS',
#       'PT',
#       'PW',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RW',
#       'SA',
#       'SB',
#       'SC',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SL',
#       'SM',
#       'SN',
#       'SR',
#       'ST',
#       'SV',
#       'SZ',
#       'TD',
#       'TG',
#       'TH',
#       'TJ',
#       'TL',
#       'TN',
#       'TO',
#       'TR',
#       'TT',
#       'TV',
#       'TW',
#       'TZ',
#       'UA',
#       'UG',
#       'US',
#       'UY',
#       'UZ',
#       'VC',
#       'VE',
#       'VN',
#       'VU',
#       'WS',
#       'XK',
#       'ZA',
#       'ZM',
#       'ZW'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/3HnSOodhuufrSTBnGZQ3fu'},
#      'href': 'https://api.spotify.com/v1/albums/3HnSOodhuufrSTBnGZQ3fu',
#      'id': '3HnSOodhuufrSTBnGZQ3fu',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273fb01108d92974ffab07a05fb',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02fb01108d92974ffab07a05fb',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851fb01108d92974ffab07a05fb',
#        'width': 64}],
#      'name': 'El Viaje de Copperpot',
#      'release_date': '2000-09-07',
#      'release_date_precision': 'day',
#      'total_tracks': 12,
#      'type': 'album',
#      'uri': 'spotify:album:3HnSOodhuufrSTBnGZQ3fu'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4U7lXyKdSf1JbM1aXvsodC'},
#       'href': 'https://api.spotify.com/v1/artists/4U7lXyKdSf1JbM1aXvsodC',
#       'id': '4U7lXyKdSf1JbM1aXvsodC',
#       'name': 'La Oreja de Van Gogh',
#       'type': 'artist',
#       'uri': 'spotify:artist:4U7lXyKdSf1JbM1aXvsodC'}],
#     'available_markets': ['AD',
#      'AE',
#      'AG',
#      'AL',
#      'AM',
#      'AO',
#      'AR',
#      'AT',
#      'AU',
#      'AZ',
#      'BA',
#      'BB',
#      'BD',
#      'BE',
#      'BF',
#      'BG',
#      'BH',
#      'BI',
#      'BJ',
#      'BN',
#      'BO',
#      'BR',
#      'BS',
#      'BT',
#      'BW',
#      'BY',
#      'BZ',
#      'CA',
#      'CD',
#      'CG',
#      'CH',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CV',
#      'CW',
#      'CY',
#      'CZ',
#      'DE',
#      'DJ',
#      'DK',
#      'DM',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FJ',
#      'FM',
#      'FR',
#      'GA',
#      'GB',
#      'GD',
#      'GE',
#      'GH',
#      'GM',
#      'GN',
#      'GQ',
#      'GR',
#      'GT',
#      'GW',
#      'GY',
#      'HK',
#      'HN',
#      'HR',
#      'HT',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IQ',
#      'IS',
#      'IT',
#      'JM',
#      'JO',
#      'JP',
#      'KE',
#      'KG',
#      'KH',
#      'KI',
#      'KM',
#      'KN',
#      'KR',
#      'KW',
#      'KZ',
#      'LA',
#      'LB',
#      'LC',
#      'LI',
#      'LK',
#      'LR',
#      'LS',
#      'LT',
#      'LU',
#      'LV',
#      'LY',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MG',
#      'MH',
#      'MK',
#      'ML',
#      'MN',
#      'MO',
#      'MR',
#      'MT',
#      'MU',
#      'MV',
#      'MW',
#      'MX',
#      'MY',
#      'MZ',
#      'NA',
#      'NE',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NP',
#      'NR',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PG',
#      'PH',
#      'PK',
#      'PL',
#      'PS',
#      'PT',
#      'PW',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RW',
#      'SA',
#      'SB',
#      'SC',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SL',
#      'SM',
#      'SN',
#      'SR',
#      'ST',
#      'SV',
#      'SZ',
#      'TD',
#      'TG',
#      'TH',
#      'TJ',
#      'TL',
#      'TN',
#      'TO',
#      'TR',
#      'TT',
#      'TV',
#      'TW',
#      'TZ',
#      'UA',
#      'UG',
#      'US',
#      'UY',
#      'UZ',
#      'VC',
#      'VE',
#      'VN',
#      'VU',
#      'WS',
#      'XK',
#      'ZA',
#      'ZM',
#      'ZW'],
#     'disc_number': 1,
#     'duration_ms': 247693,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'ES5110002864'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/2DNyZP4Py6f4zMASLBnIu6'},
#     'href': 'https://api.spotify.com/v1/tracks/2DNyZP4Py6f4zMASLBnIu6',
#     'id': '2DNyZP4Py6f4zMASLBnIu6',
#     'is_local': False,
#     'name': 'La Playa',
#     'popularity': 70,
#     'preview_url': 'https://p.scdn.co/mp3-preview/348f97d9f9ed78218fec718753a1ff6fbc43a029?cid=da00ed264eaf4f94ba2adf23ff058567',
#     'track': True,
#     'track_number': 4,
#     'type': 'track',
#     'uri': 'spotify:track:2DNyZP4Py6f4zMASLBnIu6'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2021-08-25T13:21:57Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/janmolendijk'},
#     'href': 'https://api.spotify.com/v1/users/janmolendijk',
#     'id': 'janmolendijk',
#     'type': 'user',
#     'uri': 'spotify:user:janmolendijk'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1vCWHaC5f2uS3yhpwWbIA6'},
#        'href': 'https://api.spotify.com/v1/artists/1vCWHaC5f2uS3yhpwWbIA6',
#        'id': '1vCWHaC5f2uS3yhpwWbIA6',
#        'name': 'Avicii',
#        'type': 'artist',
#        'uri': 'spotify:artist:1vCWHaC5f2uS3yhpwWbIA6'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AO',
#       'AR',
#       'AT',
#       'AU',
#       'AZ',
#       'BA',
#       'BB',
#       'BD',
#       'BE',
#       'BF',
#       'BG',
#       'BH',
#       'BI',
#       'BJ',
#       'BN',
#       'BO',
#       'BR',
#       'BS',
#       'BT',
#       'BW',
#       'BY',
#       'BZ',
#       'CA',
#       'CD',
#       'CG',
#       'CH',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CV',
#       'CW',
#       'CY',
#       'CZ',
#       'DE',
#       'DJ',
#       'DK',
#       'DM',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FJ',
#       'FM',
#       'FR',
#       'GA',
#       'GB',
#       'GD',
#       'GE',
#       'GH',
#       'GM',
#       'GN',
#       'GQ',
#       'GR',
#       'GT',
#       'GW',
#       'GY',
#       'HK',
#       'HN',
#       'HR',
#       'HT',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IQ',
#       'IS',
#       'IT',
#       'JM',
#       'JO',
#       'JP',
#       'KE',
#       'KG',
#       'KH',
#       'KI',
#       'KM',
#       'KN',
#       'KR',
#       'KW',
#       'KZ',
#       'LA',
#       'LB',
#       'LC',
#       'LI',
#       'LK',
#       'LR',
#       'LS',
#       'LT',
#       'LU',
#       'LV',
#       'LY',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MG',
#       'MH',
#       'MK',
#       'ML',
#       'MN',
#       'MO',
#       'MR',
#       'MT',
#       'MU',
#       'MV',
#       'MW',
#       'MY',
#       'MZ',
#       'NA',
#       'NE',
#       'NG',
#       'NI',
#       'NL',
#       'NO',
#       'NP',
#       'NR',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PG',
#       'PH',
#       'PK',
#       'PL',
#       'PS',
#       'PT',
#       'PW',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RW',
#       'SA',
#       'SB',
#       'SC',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SL',
#       'SM',
#       'SN',
#       'SR',
#       'ST',
#       'SV',
#       'SZ',
#       'TD',
#       'TG',
#       'TH',
#       'TJ',
#       'TL',
#       'TN',
#       'TO',
#       'TR',
#       'TT',
#       'TV',
#       'TW',
#       'TZ',
#       'UA',
#       'UG',
#       'US',
#       'UY',
#       'UZ',
#       'VC',
#       'VE',
#       'VN',
#       'VU',
#       'WS',
#       'XK',
#       'ZA',
#       'ZM',
#       'ZW'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/2H6i2CrWgXE1HookLu8Au0'},
#      'href': 'https://api.spotify.com/v1/albums/2H6i2CrWgXE1HookLu8Au0',
#      'id': '2H6i2CrWgXE1HookLu8Au0',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273e14f11f796cef9f9a82691a7',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02e14f11f796cef9f9a82691a7',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851e14f11f796cef9f9a82691a7',
#        'width': 64}],
#      'name': 'True',
#      'release_date': '2013-01-01',
#      'release_date_precision': 'day',
#      'total_tracks': 10,
#      'type': 'album',
#      'uri': 'spotify:album:2H6i2CrWgXE1HookLu8Au0'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1vCWHaC5f2uS3yhpwWbIA6'},
#       'href': 'https://api.spotify.com/v1/artists/1vCWHaC5f2uS3yhpwWbIA6',
#       'id': '1vCWHaC5f2uS3yhpwWbIA6',
#       'name': 'Avicii',
#       'type': 'artist',
#       'uri': 'spotify:artist:1vCWHaC5f2uS3yhpwWbIA6'}],
#     'available_markets': ['AD',
#      'AE',
#      'AG',
#      'AL',
#      'AM',
#      'AO',
#      'AR',
#      'AT',
#      'AU',
#      'AZ',
#      'BA',
#      'BB',
#      'BD',
#      'BE',
#      'BF',
#      'BG',
#      'BH',
#      'BI',
#      'BJ',
#      'BN',
#      'BO',
#      'BR',
#      'BS',
#      'BT',
#      'BW',
#      'BY',
#      'BZ',
#      'CA',
#      'CD',
#      'CG',
#      'CH',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CV',
#      'CW',
#      'CY',
#      'CZ',
#      'DE',
#      'DJ',
#      'DK',
#      'DM',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FJ',
#      'FM',
#      'FR',
#      'GA',
#      'GB',
#      'GD',
#      'GE',
#      'GH',
#      'GM',
#      'GN',
#      'GQ',
#      'GR',
#      'GT',
#      'GW',
#      'GY',
#      'HK',
#      'HN',
#      'HR',
#      'HT',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IQ',
#      'IS',
#      'IT',
#      'JM',
#      'JO',
#      'JP',
#      'KE',
#      'KG',
#      'KH',
#      'KI',
#      'KM',
#      'KN',
#      'KR',
#      'KW',
#      'KZ',
#      'LA',
#      'LB',
#      'LC',
#      'LI',
#      'LK',
#      'LR',
#      'LS',
#      'LT',
#      'LU',
#      'LV',
#      'LY',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MG',
#      'MH',
#      'MK',
#      'ML',
#      'MN',
#      'MO',
#      'MR',
#      'MT',
#      'MU',
#      'MV',
#      'MW',
#      'MY',
#      'MZ',
#      'NA',
#      'NE',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NP',
#      'NR',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PG',
#      'PH',
#      'PK',
#      'PL',
#      'PS',
#      'PT',
#      'PW',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RW',
#      'SA',
#      'SB',
#      'SC',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SL',
#      'SM',
#      'SN',
#      'SR',
#      'ST',
#      'SV',
#      'SZ',
#      'TD',
#      'TG',
#      'TH',
#      'TJ',
#      'TL',
#      'TN',
#      'TO',
#      'TR',
#      'TT',
#      'TV',
#      'TW',
#      'TZ',
#      'UA',
#      'UG',
#      'US',
#      'UY',
#      'UZ',
#      'VC',
#      'VE',
#      'VN',
#      'VU',
#      'WS',
#      'XK',
#      'ZA',
#      'ZM',
#      'ZW'],
#     'disc_number': 1,
# ...
#      'CG',
#      'CH',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CV',
#      'CW',
#      'CY',
#      'CZ',
#      'DE',
#      'DJ',
#      'DK',
#      'DM',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FJ',
#      'FM',
#      'FR',
#      'GA',
#      'GB',
#      'GD',
#      'GE',
#      'GH',
#      'GM',
#      'GN',
#      'GQ',
#      'GR',
#      'GT',
#      'GW',
#      'GY',
#      'HK',
#      'HN',
#      'HR',
#      'HT',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IQ',
#      'IS',
#      'IT',
#      'JM',
#      'JO',
#      'JP',
#      'KE',
#      'KG',
#      'KH',
#      'KI',
#      'KM',
#      'KN',
#      'KR',
#      'KW',
#      'KZ',
#      'LA',
#      'LB',
#      'LC',
#      'LI',
#      'LK',
#      'LR',
#      'LS',
#      'LT',
#      'LU',
#      'LV',
#      'LY',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MG',
#      'MH',
#      'MK',
#      'ML',
#      'MN',
#      'MO',
#      'MR',
#      'MT',
#      'MU',
#      'MV',
#      'MW',
#      'MX',
#      'MY',
#      'MZ',
#      'NA',
#      'NE',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NP',
#      'NR',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PG',
#      'PH',
#      'PK',
#      'PL',
#      'PS',
#      'PT',
#      'PW',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RW',
#      'SA',
#      'SB',
#      'SC',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SL',
#      'SM',
#      'SN',
#      'SR',
#      'ST',
#      'SV',
#      'SZ',
#      'TD',
#      'TG',
#      'TH',
#      'TJ',
#      'TL',
#      'TN',
#      'TO',
#      'TR',
#      'TT',
#      'TV',
#      'TW',
#      'TZ',
#      'UA',
#      'UG',
#      'US',
#      'UY',
#      'UZ',
#      'VC',
#      'VE',
#      'VN',
#      'VU',
#      'WS',
#      'XK',
#      'ZA',
#      'ZM',
#      'ZW'],
#     'disc_number': 1,
#     'duration_ms': 145826,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'ES5020500105'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/7MKO7rUZzjw8p87zdZDgqa'},
#     'href': 'https://api.spotify.com/v1/tracks/7MKO7rUZzjw8p87zdZDgqa',
#     'id': '7MKO7rUZzjw8p87zdZDgqa',
#     'is_local': False,
#     'name': 'Besos',
#     'popularity': 60,
#     'preview_url': 'https://p.scdn.co/mp3-preview/1d1f1a70e40e7e2abbc0ecda27d7ddea777762f6?cid=da00ed264eaf4f94ba2adf23ff058567',
#     'track': True,
#     'track_number': 5,
#     'type': 'track',
#     'uri': 'spotify:track:7MKO7rUZzjw8p87zdZDgqa'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2021-08-25T13:25:25Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/janmolendijk'},
#     'href': 'https://api.spotify.com/v1/users/janmolendijk',
#     'id': 'janmolendijk',
#     'type': 'user',
#     'uri': 'spotify:user:janmolendijk'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2poCUrtJvVVgfA2hgri1IS'},
#        'href': 'https://api.spotify.com/v1/artists/2poCUrtJvVVgfA2hgri1IS',
#        'id': '2poCUrtJvVVgfA2hgri1IS',
#        'name': 'Roupa Nova',
#        'type': 'artist',
#        'uri': 'spotify:artist:2poCUrtJvVVgfA2hgri1IS'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AO',
#       'AR',
#       'AT',
#       'AU',
#       'AZ',
#       'BA',
#       'BB',
#       'BD',
#       'BE',
#       'BF',
#       'BG',
#       'BH',
#       'BI',
#       'BJ',
#       'BN',
#       'BO',
#       'BR',
#       'BS',
#       'BT',
#       'BW',
#       'BY',
#       'BZ',
#       'CA',
#       'CD',
#       'CG',
#       'CH',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CV',
#       'CW',
#       'CY',
#       'CZ',
#       'DE',
#       'DJ',
#       'DK',
#       'DM',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FJ',
#       'FM',
#       'FR',
#       'GA',
#       'GB',
#       'GD',
#       'GE',
#       'GH',
#       'GM',
#       'GN',
#       'GQ',
#       'GR',
#       'GT',
#       'GW',
#       'GY',
#       'HK',
#       'HN',
#       'HR',
#       'HT',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IQ',
#       'IS',
#       'IT',
#       'JM',
#       'JO',
#       'JP',
#       'KE',
#       'KG',
#       'KH',
#       'KI',
#       'KM',
#       'KN',
#       'KR',
#       'KW',
#       'KZ',
#       'LA',
#       'LB',
#       'LC',
#       'LI',
#       'LK',
#       'LR',
#       'LS',
#       'LT',
#       'LU',
#       'LV',
#       'LY',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MG',
#       'MH',
#       'MK',
#       'ML',
#       'MN',
#       'MO',
#       'MR',
#       'MT',
#       'MU',
#       'MV',
#       'MW',
#       'MX',
#       'MY',
#       'MZ',
#       'NA',
#       'NE',
#       'NG',
#       'NI',
#       'NL',
#       'NO',
#       'NP',
#       'NR',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PG',
#       'PH',
#       'PK',
#       'PL',
#       'PS',
#       'PT',
#       'PW',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RW',
#       'SA',
#       'SB',
#       'SC',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SL',
#       'SM',
#       'SN',
#       'SR',
#       'ST',
#       'SV',
#       'SZ',
#       'TD',
#       'TG',
#       'TH',
#       'TJ',
#       'TL',
#       'TN',
#       'TO',
#       'TR',
#       'TT',
#       'TV',
#       'TW',
#       'TZ',
#       'UA',
#       'UG',
#       'UY',
#       'UZ',
#       'VC',
#       'VE',
#       'VN',
#       'VU',
#       'WS',
#       'XK',
#       'ZA',
#       'ZM',
#       'ZW'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/2Vk7uegp8VqG1IzZGQlJus'},
#      'href': 'https://api.spotify.com/v1/albums/2Vk7uegp8VqG1IzZGQlJus',
#      'id': '2Vk7uegp8VqG1IzZGQlJus',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273d91747916c3a75f5025ba423',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02d91747916c3a75f5025ba423',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851d91747916c3a75f5025ba423',
#        'width': 64}],
#      'name': 'Novela Hits',
#      'release_date': '1996-01-10',
#      'release_date_precision': 'day',
#      'total_tracks': 13,
#      'type': 'album',
#      'uri': 'spotify:album:2Vk7uegp8VqG1IzZGQlJus'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2poCUrtJvVVgfA2hgri1IS'},
#       'href': 'https://api.spotify.com/v1/artists/2poCUrtJvVVgfA2hgri1IS',
#       'id': '2poCUrtJvVVgfA2hgri1IS',
#       'name': 'Roupa Nova',
#       'type': 'artist',
#       'uri': 'spotify:artist:2poCUrtJvVVgfA2hgri1IS'}],
#     'available_markets': ['AD',
#      'AE',
#      'AG',
#      'AL',
#      'AM',
#      'AO',
#      'AR',
#      'AT',
#      'AU',
#      'AZ',
#      'BA',
#      'BB',
#      'BD',
#      'BE',
#      'BF',
#      'BG',
#      'BH',
#      'BI',
#      'BJ',
#      'BN',
#      'BO',
#      'BR',
#      'BS',
#      'BT',
#      'BW',
#      'BY',
#      'BZ',
#      'CA',
#      'CD',
#      'CG',
#      'CH',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CV',
#      'CW',
#      'CY',
#      'CZ',
#      'DE',
#      'DJ',
#      'DK',
#      'DM',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FJ',
#      'FM',
#      'FR',
#      'GA',
#      'GB',
#      'GD',
#      'GE',
#      'GH',
#      'GM',
#      'GN',
#      'GQ',
#      'GR',
#      'GT',
#      'GW',
#      'GY',
#      'HK',
#      'HN',
#      'HR',
#      'HT',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IQ',
#      'IS',
#      'IT',
#      'JM',
#      'JO',
#      'JP',
#      'KE',
#      'KG',
#      'KH',
#      'KI',
#      'KM',
#      'KN',
#      'KR',
#      'KW',
#      'KZ',
#      'LA',
#      'LB',
#      'LC',
#      'LI',
#      'LK',
#      'LR',
#      'LS',
#      'LT',
#      'LU',
#      'LV',
#      'LY',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MG',
#      'MH',
#      'MK',
#      'ML',
#      'MN',
#      'MO',
#      'MR',
#      'MT',
#      'MU',
#      'MV',
#      'MW',
#      'MX',
#      'MY',
#      'MZ',
#      'NA',
#      'NE',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NP',
#      'NR',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PG',
#      'PH',
#      'PK',
#      'PL',
#      'PS',
#      'PT',
#      'PW',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RW',
#      'SA',
#      'SB',
#      'SC',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SL',
#      'SM',
#      'SN',
#      'SR',
#      'ST',
#      'SV',
#      'SZ',
#      'TD',
#      'TG',
#      'TH',
#      'TJ',
#      'TL',
#      'TN',
#      'TO',
#      'TR',
#      'TT',
#      'TV',
#      'TW',
#      'TZ',
#      'UA',
#      'UG',
#      'UY',
#      'UZ',
#      'VC',
#      'VE',
#      'VN',
#      'VU',
#      'WS',
#      'XK',
#      'ZA',
#      'ZM',
#      'ZW'],
#     'disc_number': 1,
#     'duration_ms': 249226,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'BRBMG9103570'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/0wViTd3dyzUnfVfwmoJoxd'},
#     'href': 'https://api.spotify.com/v1/tracks/0wViTd3dyzUnfVfwmoJoxd',
#     'id': '0wViTd3dyzUnfVfwmoJoxd',
#     'is_local': False,
#     'name': 'Whisky à Go-Go (Ao Vivo)',
#     'popularity': 44,
#     'preview_url': 'https://p.scdn.co/mp3-preview/41c2d9380e3d19ee5f812d76c74f848dc6475623?cid=da00ed264eaf4f94ba2adf23ff058567',
#     'track': True,
#     'track_number': 7,
#     'type': 'track',
#     'uri': 'spotify:track:0wViTd3dyzUnfVfwmoJoxd'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2021-08-25T13:31:44Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/janmolendijk'},
#     'href': 'https://api.spotify.com/v1/users/janmolendijk',
#     'id': 'janmolendijk',
#     'type': 'user',
#     'uri': 'spotify:user:janmolendijk'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3WNTqH4npFMy6faS8ILdlQ'},
#        'href': 'https://api.spotify.com/v1/artists/3WNTqH4npFMy6faS8ILdlQ',
#        'id': '3WNTqH4npFMy6faS8ILdlQ',
#        'name': 'Frank & Frank',
#        'type': 'artist',
#        'uri': 'spotify:artist:3WNTqH4npFMy6faS8ILdlQ'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AO',
#       'AR',
#       'AT',
#       'AU',
#       'AZ',
#       'BA',
#       'BB',
#       'BD',
#       'BE',
#       'BF',
#       'BG',
#       'BH',
#       'BI',
#       'BJ',
#       'BN',
#       'BO',
#       'BR',
#       'BS',
#       'BT',
#       'BW',
#       'BY',
#       'BZ',
#       'CA',
#       'CD',
#       'CG',
#       'CH',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CV',
#       'CW',
#       'CY',
#       'CZ',
#       'DE',
#       'DJ',
#       'DK',
#       'DM',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FJ',
#       'FM',
#       'FR',
#       'GA',
#       'GB',
#       'GD',
#       'GE',
#       'GH',
#       'GM',
#       'GN',
#       'GQ',
#       'GR',
#       'GT',
#       'GW',
#       'GY',
#       'HK',
#       'HN',
#       'HR',
#       'HT',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IQ',
#       'IS',
#       'IT',
#       'JM',
#       'JO',
#       'JP',
#       'KE',
#       'KG',
#       'KH',
#       'KI',
#       'KM',
#       'KN',
#       'KR',
#       'KW',
#       'KZ',
#       'LA',
#       'LB',
#       'LC',
#       'LI',
#       'LK',
#       'LR',
#       'LS',
#       'LT',
#       'LU',
#       'LV',
#       'LY',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MG',
#       'MH',
#       'MK',
#       'ML',
#       'MN',
#       'MO',
#       'MR',
#       'MT',
#       'MU',
#       'MV',
#       'MW',
#       'MX',
#       'MY',
#       'MZ',
#       'NA',
#       'NE',
#       'NG',
#       'NI',
#       'NL',
#       'NO',
#       'NP',
#       'NR',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PG',
#       'PH',
#       'PK',
#       'PL',
#       'PS',
#       'PT',
#       'PW',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RW',
#       'SA',
#       'SB',
#       'SC',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SL',
#       'SM',
#       'SN',
#       'SR',
#       'ST',
#       'SV',
#       'SZ',
#       'TD',
#       'TG',
#       'TH',
#       'TJ',
#       'TL',
#       'TN',
#       'TO',
#       'TR',
#       'TT',
#       'TV',
#       'TW',
#       'TZ',
#       'UA',
#       'UG',
#       'US',
#       'UY',
#       'UZ',
#       'VC',
#       'VE',
#       'VN',
#       'VU',
#       'WS',
#       'XK',
#       'ZA',
#       'ZM',
#       'ZW'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/0DadMcoXzdMKtfAAhBEoeG'},
#      'href': 'https://api.spotify.com/v1/albums/0DadMcoXzdMKtfAAhBEoeG',
#      'id': '0DadMcoXzdMKtfAAhBEoeG',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273f9b75b0f754b3d45c9e58630',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02f9b75b0f754b3d45c9e58630',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851f9b75b0f754b3d45c9e58630',
#        'width': 64}],
#      'name': 'Frank de Boer',
#      'release_date': '2021-06-04',
#      'release_date_precision': 'day',
#      'total_tracks': 1,
#      'type': 'album',
#      'uri': 'spotify:album:0DadMcoXzdMKtfAAhBEoeG'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3WNTqH4npFMy6faS8ILdlQ'},
#       'href': 'https://api.spotify.com/v1/artists/3WNTqH4npFMy6faS8ILdlQ',
#       'id': '3WNTqH4npFMy6faS8ILdlQ',
#       'name': 'Frank & Frank',
#       'type': 'artist',
#       'uri': 'spotify:artist:3WNTqH4npFMy6faS8ILdlQ'}],
#     'available_markets': ['AD',
#      'AE',
#      'AG',
#      'AL',
#      'AM',
#      'AO',
#      'AR',
#      'AT',
#      'AU',
#      'AZ',
#      'BA',
#      'BB',
#      'BD',
#      'BE',
#      'BF',
#      'BG',
#      'BH',
#      'BI',
#      'BJ',
#      'BN',
#      'BO',
#      'BR',
#      'BS',
#      'BT',
#      'BW',
#      'BY',
#      'BZ',
#      'CA',
#      'CD',
#      'CG',
#      'CH',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CV',
#      'CW',
#      'CY',
#      'CZ',
#      'DE',
#      'DJ',
#      'DK',
#      'DM',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FJ',
#      'FM',
#      'FR',
#      'GA',
#      'GB',
#      'GD',
#      'GE',
#      'GH',
#      'GM',
#      'GN',
#      'GQ',
#      'GR',
#      'GT',
#      'GW',
#      'GY',
#      'HK',
#      'HN',
#      'HR',
#      'HT',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IQ',
#      'IS',
#      'IT',
#      'JM',
#      'JO',
#      'JP',
#      'KE',
#      'KG',
#      'KH',
#      'KI',
#      'KM',
#      'KN',
#      'KR',
#      'KW',
#      'KZ',
#      'LA',
#      'LB',
#      'LC',
#      'LI',
#      'LK',
#      'LR',
#      'LS',
#      'LT',
#      'LU',
#      'LV',
#      'LY',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MG',
#      'MH',
#      'MK',
#      'ML',
#      'MN',
#      'MO',
#      'MR',
#      'MT',
#      'MU',
#      'MV',
#      'MW',
#      'MX',
#      'MY',
#      'MZ',
#      'NA',
#      'NE',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NP',
#      'NR',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PG',
#      'PH',
#      'PK',
#      'PL',
#      'PS',
#      'PT',
#      'PW',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RW',
#      'SA',
#      'SB',
#      'SC',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SL',
#      'SM',
#      'SN',
#      'SR',
#      'ST',
#      'SV',
#      'SZ',
#      'TD',
#      'TG',
#      'TH',
#      'TJ',
#      'TL',
#      'TN',
#      'TO',
#      'TR',
#      'TT',
#      'TV',
#      'TW',
#      'TZ',
#      'UA',
#      'UG',
#      'US',
#      'UY',
#      'UZ',
#      'VC',
#      'VE',
#      'VN',
#      'VU',
#      'WS',
#      'XK',
#      'ZA',
#      'ZM',
#      'ZW'],
#     'disc_number': 1,
#     'duration_ms': 276960,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'NLQ272100051'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/54vrOV4KdIWOCrQqEYnuCB'},
#     'href': 'https://api.spotify.com/v1/tracks/54vrOV4KdIWOCrQqEYnuCB',
#     'id': '54vrOV4KdIWOCrQqEYnuCB',
#     'is_local': False,
#     'name': 'Frank de Boer',
#     'popularity': 15,
#     'preview_url': 'https://p.scdn.co/mp3-preview/51f25726dc5b3360b91bbc67694d1adbb51581bf?cid=da00ed264eaf4f94ba2adf23ff058567',
#     'track': True,
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:54vrOV4KdIWOCrQqEYnuCB'},
#    'video_thumbnail': {'url': None}}],
#  'limit': 100,
#  'next': None,
#  'offset': 0,
#  'previous': None,
#  'total': 15}

# %%
playlist.keys()
# Out:
# dict_keys(['href', 'items', 'limit', 'next', 'offset', 'previous', 'total'])

# %%
playlist['items'][0]['track']['artists'][0]['name']
# Out:
# 'Rose Royce'

# %%
playlist['total']
# Out:
# 15

# %%
len(playlist['items'])
# Out:
# 15

# %%
# all_songs_artists = list(map(get_name_artist,playlist['items']['track']['name']))
# all_songs_artists

# %%
def flatten(input_list):
    return [item for sublist in input_list for item in sublist]

# %%
#flatten(playlist)

# %%
def get_name_artist_from_list(tracks):
    return flatten(list(map(get_name_artists_from_track,tracks['items'])))

# %%
#get_name_artist(playlist)

# %% [markdown]
# # First get name and artist from 1 track

# %%
def name_artist_playlist(playlist_item):
    return get_name_artist_from_track(playlist_item['track'])

# %%
def get_n_a_from_playlist(playlist):
# Out:
#   File "<ipython-input-49-816185b23166>", line 2
#
#     ^
# SyntaxError: unexpected EOF while parsing

# %% [markdown]
# # handling larger playlists

# %%
playlist = sp.user_playlist_tracks('spotify', '4rnleEAOdmFAbRcNCgZMpY')

# %%
playlist['total']
# Out:
# 5295

# %%
len(playlist['items'])
# Out:
# 100

# %%
playlist['next']
# Out:
# 'https://api.spotify.com/v1/playlists/4rnleEAOdmFAbRcNCgZMpY/tracks?offset=100&limit=100&additional_types=track'

# %%
sp.next(playlist)
# Out:
# {'href': 'https://api.spotify.com/v1/playlists/4rnleEAOdmFAbRcNCgZMpY/tracks?offset=100&limit=100&additional_types=track',
#  'items': [{'added_at': '2016-07-05T18:39:33Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/1130225252'},
#     'href': 'https://api.spotify.com/v1/users/1130225252',
#     'id': '1130225252',
#     'type': 'user',
#     'uri': 'spotify:user:1130225252'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5lKZWd6HiSCLfnDGrq9RAm'},
#        'href': 'https://api.spotify.com/v1/artists/5lKZWd6HiSCLfnDGrq9RAm',
#        'id': '5lKZWd6HiSCLfnDGrq9RAm',
#        'name': 'Leona Lewis',
#        'type': 'artist',
#        'uri': 'spotify:artist:5lKZWd6HiSCLfnDGrq9RAm'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AO',
#       'AR',
#       'AT',
#       'AU',
#       'AZ',
#       'BA',
#       'BB',
#       'BD',
#       'BE',
#       'BF',
#       'BG',
#       'BH',
#       'BI',
#       'BJ',
#       'BN',
#       'BO',
#       'BR',
#       'BS',
#       'BT',
#       'BW',
#       'BY',
#       'BZ',
#       'CA',
#       'CD',
#       'CG',
#       'CH',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CV',
#       'CW',
#       'CY',
#       'CZ',
#       'DE',
#       'DJ',
#       'DK',
#       'DM',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FJ',
#       'FM',
#       'FR',
#       'GA',
#       'GD',
#       'GE',
#       'GH',
#       'GM',
#       'GN',
#       'GQ',
#       'GR',
#       'GT',
#       'GW',
#       'GY',
#       'HK',
#       'HN',
#       'HR',
#       'HT',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IQ',
#       'IS',
#       'IT',
#       'JM',
#       'JO',
#       'JP',
#       'KE',
#       'KG',
#       'KH',
#       'KI',
#       'KM',
#       'KN',
#       'KR',
#       'KW',
#       'KZ',
#       'LA',
#       'LB',
#       'LC',
#       'LI',
#       'LK',
#       'LR',
#       'LS',
#       'LT',
#       'LU',
#       'LV',
#       'LY',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MG',
#       'MH',
#       'MK',
#       'ML',
#       'MN',
#       'MO',
#       'MR',
#       'MT',
#       'MU',
#       'MV',
#       'MW',
#       'MX',
#       'MY',
#       'MZ',
#       'NA',
#       'NE',
#       'NG',
#       'NI',
#       'NL',
#       'NO',
#       'NP',
#       'NR',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PG',
#       'PH',
#       'PK',
#       'PL',
#       'PS',
#       'PT',
#       'PW',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RW',
#       'SA',
#       'SB',
#       'SC',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SL',
#       'SM',
#       'SN',
#       'SR',
#       'ST',
#       'SV',
#       'SZ',
#       'TD',
#       'TG',
#       'TH',
#       'TJ',
#       'TL',
#       'TN',
#       'TO',
#       'TR',
#       'TT',
#       'TV',
#       'TW',
#       'TZ',
#       'UA',
#       'UG',
#       'US',
#       'UY',
#       'UZ',
#       'VC',
#       'VE',
#       'VN',
#       'VU',
#       'WS',
#       'XK',
#       'ZA',
#       'ZM',
#       'ZW'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/0VaAFegRAAn4OCg7p4QjN5'},
#      'href': 'https://api.spotify.com/v1/albums/0VaAFegRAAn4OCg7p4QjN5',
#      'id': '0VaAFegRAAn4OCg7p4QjN5',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b27334fd9eb8cd48e518598aec55',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e0234fd9eb8cd48e518598aec55',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d0000485134fd9eb8cd48e518598aec55',
#        'width': 64}],
#      'name': 'Spirit',
#      'release_date': '2007',
#      'release_date_precision': 'year',
#      'total_tracks': 13,
#      'type': 'album',
#      'uri': 'spotify:album:0VaAFegRAAn4OCg7p4QjN5'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5lKZWd6HiSCLfnDGrq9RAm'},
#       'href': 'https://api.spotify.com/v1/artists/5lKZWd6HiSCLfnDGrq9RAm',
#       'id': '5lKZWd6HiSCLfnDGrq9RAm',
#       'name': 'Leona Lewis',
#       'type': 'artist',
#       'uri': 'spotify:artist:5lKZWd6HiSCLfnDGrq9RAm'}],
#     'available_markets': ['AD',
#      'AE',
#      'AG',
#      'AL',
#      'AM',
#      'AO',
#      'AR',
#      'AT',
#      'AU',
#      'AZ',
#      'BA',
#      'BB',
#      'BD',
#      'BE',
#      'BF',
#      'BG',
#      'BH',
#      'BI',
#      'BJ',
#      'BN',
#      'BO',
#      'BR',
#      'BS',
#      'BT',
#      'BW',
#      'BY',
#      'BZ',
#      'CA',
#      'CD',
#      'CG',
#      'CH',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CV',
#      'CW',
#      'CY',
#      'CZ',
#      'DE',
#      'DJ',
#      'DK',
#      'DM',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FJ',
#      'FM',
#      'FR',
#      'GA',
#      'GD',
#      'GE',
#      'GH',
#      'GM',
#      'GN',
#      'GQ',
#      'GR',
#      'GT',
#      'GW',
#      'GY',
#      'HK',
#      'HN',
#      'HR',
#      'HT',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IQ',
#      'IS',
#      'IT',
#      'JM',
#      'JO',
#      'JP',
#      'KE',
#      'KG',
#      'KH',
#      'KI',
#      'KM',
#      'KN',
#      'KR',
#      'KW',
#      'KZ',
#      'LA',
#      'LB',
#      'LC',
#      'LI',
#      'LK',
#      'LR',
#      'LS',
#      'LT',
#      'LU',
#      'LV',
#      'LY',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MG',
#      'MH',
#      'MK',
#      'ML',
#      'MN',
#      'MO',
#      'MR',
#      'MT',
#      'MU',
#      'MV',
#      'MW',
#      'MX',
#      'MY',
#      'MZ',
#      'NA',
#      'NE',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NP',
#      'NR',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PG',
#      'PH',
#      'PK',
#      'PL',
#      'PS',
#      'PT',
#      'PW',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RW',
#      'SA',
#      'SB',
#      'SC',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SL',
#      'SM',
#      'SN',
#      'SR',
#      'ST',
#      'SV',
#      'SZ',
#      'TD',
#      'TG',
#      'TH',
#      'TJ',
#      'TL',
#      'TN',
#      'TO',
#      'TR',
#      'TT',
#      'TV',
#      'TW',
#      'TZ',
#      'UA',
#      'UG',
#      'US',
#      'UY',
#      'UZ',
#      'VC',
#      'VE',
#      'VN',
#      'VU',
#      'WS',
#      'XK',
#      'ZA',
#      'ZM',
#      'ZW'],
#     'disc_number': 1,
#     'duration_ms': 262466,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'GBHMU0700049'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/7wZUrN8oemZfsEd1CGkbXE'},
#     'href': 'https://api.spotify.com/v1/tracks/7wZUrN8oemZfsEd1CGkbXE',
#     'id': '7wZUrN8oemZfsEd1CGkbXE',
#     'is_local': False,
#     'name': 'Bleeding Love',
#     'popularity': 74,
#     'preview_url': 'https://p.scdn.co/mp3-preview/e76d81faffd663f20b9f88ee7f510978dedf6bad?cid=da00ed264eaf4f94ba2adf23ff058567',
#     'track': True,
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:7wZUrN8oemZfsEd1CGkbXE'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2016-07-05T18:39:35Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/1130225252'},
#     'href': 'https://api.spotify.com/v1/users/1130225252',
#     'id': '1130225252',
#     'type': 'user',
#     'uri': 'spotify:user:1130225252'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0IF46mUS8NXjgHabxk2MCM'},
#        'href': 'https://api.spotify.com/v1/artists/0IF46mUS8NXjgHabxk2MCM',
#        'id': '0IF46mUS8NXjgHabxk2MCM',
#        'name': 'Kelis',
#        'type': 'artist',
#        'uri': 'spotify:artist:0IF46mUS8NXjgHabxk2MCM'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AO',
#       'AR',
#       'AT',
#       'AU',
#       'AZ',
#       'BA',
#       'BB',
#       'BD',
#       'BE',
#       'BF',
#       'BG',
#       'BH',
#       'BI',
#       'BJ',
#       'BN',
#       'BO',
#       'BR',
#       'BS',
#       'BT',
#       'BW',
#       'BY',
#       'BZ',
#       'CD',
#       'CG',
#       'CH',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CV',
#       'CW',
#       'CY',
#       'CZ',
#       'DE',
#       'DJ',
#       'DK',
#       'DM',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FJ',
#       'FM',
#       'FR',
#       'GA',
#       'GB',
#       'GD',
#       'GE',
#       'GH',
#       'GM',
#       'GN',
#       'GQ',
#       'GR',
#       'GT',
#       'GW',
#       'GY',
#       'HK',
#       'HN',
#       'HR',
#       'HT',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IQ',
#       'IS',
#       'IT',
#       'JM',
#       'JO',
#       'JP',
#       'KE',
#       'KG',
#       'KH',
#       'KI',
#       'KM',
#       'KN',
#       'KR',
#       'KW',
#       'KZ',
#       'LA',
#       'LB',
#       'LC',
#       'LI',
#       'LK',
#       'LR',
#       'LS',
#       'LT',
#       'LU',
#       'LV',
#       'LY',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MG',
#       'MH',
#       'MK',
#       'ML',
#       'MN',
#       'MO',
#       'MR',
#       'MT',
#       'MU',
#       'MV',
#       'MW',
#       'MX',
#       'MY',
#       'MZ',
#       'NA',
#       'NE',
#       'NG',
#       'NI',
#       'NL',
#       'NO',
#       'NP',
#       'NR',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PG',
#       'PH',
#       'PK',
#       'PL',
#       'PS',
#       'PT',
#       'PW',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RW',
#       'SA',
#       'SB',
#       'SC',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SL',
#       'SM',
#       'SN',
#       'SR',
#       'ST',
#       'SV',
#       'SZ',
#       'TD',
#       'TG',
#       'TH',
#       'TJ',
#       'TL',
#       'TN',
#       'TO',
#       'TR',
#       'TT',
#       'TV',
#       'TW',
#       'TZ',
#       'UA',
#       'UG',
#       'UY',
#       'UZ',
#       'VC',
#       'VE',
#       'VN',
#       'VU',
#       'WS',
#       'XK',
#       'ZA',
#       'ZM',
#       'ZW'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/7zesXMFikT4DdgkklIk3Jz'},
#      'href': 'https://api.spotify.com/v1/albums/7zesXMFikT4DdgkklIk3Jz',
#      'id': '7zesXMFikT4DdgkklIk3Jz',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273e928de086eef7d3491b4390b',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02e928de086eef7d3491b4390b',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851e928de086eef7d3491b4390b',
#        'width': 64}],
#      'name': 'Tasty',
#      'release_date': '2003-12-05',
#      'release_date_precision': 'day',
#      'total_tracks': 14,
#      'type': 'album',
#      'uri': 'spotify:album:7zesXMFikT4DdgkklIk3Jz'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0IF46mUS8NXjgHabxk2MCM'},
#       'href': 'https://api.spotify.com/v1/artists/0IF46mUS8NXjgHabxk2MCM',
#       'id': '0IF46mUS8NXjgHabxk2MCM',
#       'name': 'Kelis',
#       'type': 'artist',
#       'uri': 'spotify:artist:0IF46mUS8NXjgHabxk2MCM'}],
#     'available_markets': ['AD',
#      'AE',
#      'AG',
#      'AL',
#      'AM',
#      'AO',
#      'AR',
#      'AT',
#      'AU',
#      'AZ',
#      'BA',
#      'BB',
#      'BD',
#      'BE',
#      'BF',
#      'BG',
#      'BH',
#      'BI',
#      'BJ',
#      'BN',
#      'BO',
#      'BR',
#      'BS',
#      'BT',
#      'BW',
#      'BY',
#      'BZ',
#      'CD',
#      'CG',
#      'CH',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CV',
#      'CW',
#      'CY',
#      'CZ',
#      'DE',
#      'DJ',
#      'DK',
#      'DM',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FJ',
#      'FM',
#      'FR',
#      'GA',
#      'GB',
#      'GD',
#      'GE',
#      'GH',
#      'GM',
#      'GN',
#      'GQ',
#      'GR',
#      'GT',
#      'GW',
#      'GY',
#      'HK',
#      'HN',
#      'HR',
#      'HT',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IQ',
#      'IS',
#      'IT',
#      'JM',
#      'JO',
#      'JP',
#      'KE',
#      'KG',
#      'KH',
#      'KI',
#      'KM',
#      'KN',
#      'KR',
#      'KW',
#      'KZ',
#      'LA',
#      'LB',
#      'LC',
#      'LI',
#      'LK',
#      'LR',
#      'LS',
#      'LT',
#      'LU',
#      'LV',
#      'LY',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MG',
#      'MH',
#      'MK',
#      'ML',
#      'MN',
#      'MO',
#      'MR',
#      'MT',
#      'MU',
#      'MV',
#      'MW',
#      'MX',
#      'MY',
#      'MZ',
#      'NA',
#      'NE',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NP',
#      'NR',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PG',
#      'PH',
#      'PK',
#      'PL',
#      'PS',
#      'PT',
#      'PW',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RW',
#      'SA',
#      'SB',
#      'SC',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SL',
#      'SM',
#      'SN',
#      'SR',
#      'ST',
#      'SV',
#      'SZ',
#      'TD',
#      'TG',
#      'TH',
#      'TJ',
#      'TL',
#      'TN',
#      'TO',
#      'TR',
#      'TT',
#      'TV',
#      'TW',
#      'TZ',
#      'UA',
#      'UG',
#      'UY',
#      'UZ',
#      'VC',
#      'VE',
#      'VN',
#      'VU',
#      'WS',
#      'XK',
#      'ZA',
#      'ZM',
#      'ZW'],
#     'disc_number': 1,
#     'duration_ms': 182626,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'USAR10301131'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/2cMTIlktg3M9mXYqCPqw1J'},
#     'href': 'https://api.spotify.com/v1/tracks/2cMTIlktg3M9mXYqCPqw1J',
#     'id': '2cMTIlktg3M9mXYqCPqw1J',
#     'is_local': False,
#     'name': 'Milkshake',
#     'popularity': 67,
#     'preview_url': None,
#     'track': True,
#     'track_number': 3,
#     'type': 'track',
#     'uri': 'spotify:track:2cMTIlktg3M9mXYqCPqw1J'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2016-07-05T18:39:36Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/1130225252'},
#     'href': 'https://api.spotify.com/v1/users/1130225252',
#     'id': '1130225252',
#     'type': 'user',
#     'uri': 'spotify:user:1130225252'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'compilation',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3BmGtnKgCSGYIUhmivXKWX'},
#        'href': 'https://api.spotify.com/v1/artists/3BmGtnKgCSGYIUhmivXKWX',
#        'id': '3BmGtnKgCSGYIUhmivXKWX',
#        'name': 'Kelly Clarkson',
#        'type': 'artist',
#        'uri': 'spotify:artist:3BmGtnKgCSGYIUhmivXKWX'}],
#      'available_markets': ['CA', 'US'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/4S08bOIf2PHzp2bmP0mdaV'},
#      'href': 'https://api.spotify.com/v1/albums/4S08bOIf2PHzp2bmP0mdaV',
#      'id': '4S08bOIf2PHzp2bmP0mdaV',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2737c5196593b6ab9382a794d26',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e027c5196593b6ab9382a794d26',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048517c5196593b6ab9382a794d26',
#        'width': 64}],
#      'name': 'Greatest Hits - Chapter One',
#      'release_date': '2012-11-19',
#      'release_date_precision': 'day',
#      'total_tracks': 17,
#      'type': 'album',
#      'uri': 'spotify:album:4S08bOIf2PHzp2bmP0mdaV'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3BmGtnKgCSGYIUhmivXKWX'},
#       'href': 'https://api.spotify.com/v1/artists/3BmGtnKgCSGYIUhmivXKWX',
#       'id': '3BmGtnKgCSGYIUhmivXKWX',
#       'name': 'Kelly Clarkson',
#       'type': 'artist',
#       'uri': 'spotify:artist:3BmGtnKgCSGYIUhmivXKWX'}],
#     'available_markets': ['CA', 'US'],
#     'disc_number': 1,
#     'duration_ms': 221920,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'GBCTA1100364'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/35a4Kzyo9XY4FI9FaSIzzF'},
#     'href': 'https://api.spotify.com/v1/tracks/35a4Kzyo9XY4FI9FaSIzzF',
#     'id': '35a4Kzyo9XY4FI9FaSIzzF',
#     'is_local': False,
#     'name': "Stronger (What Doesn't Kill You)",
#     'popularity': 41,
#     'preview_url': 'https://p.scdn.co/mp3-preview/2fcbab65f0c1229f7c17e2f31abfa78f85cb0e37?cid=da00ed264eaf4f94ba2adf23ff058567',
#     'track': True,
#     'track_number': 4,
#     'type': 'track',
#     'uri': 'spotify:track:35a4Kzyo9XY4FI9FaSIzzF'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2016-07-05T18:39:40Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/1130225252'},
#     'href': 'https://api.spotify.com/v1/users/1130225252',
#     'id': '1130225252',
#     'type': 'user',
#     'uri': 'spotify:user:1130225252'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6G9bygHlCyPgNGxK2l3YdE'},
#        'href': 'https://api.spotify.com/v1/artists/6G9bygHlCyPgNGxK2l3YdE',
#        'id': '6G9bygHlCyPgNGxK2l3YdE',
#        'name': 'Vanessa Hudgens',
#        'type': 'artist',
#        'uri': 'spotify:artist:6G9bygHlCyPgNGxK2l3YdE'}],
#      'available_markets': [],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/7EbEXBOEuSmMXCeEUHGE9K'},
#      'href': 'https://api.spotify.com/v1/albums/7EbEXBOEuSmMXCeEUHGE9K',
#      'id': '7EbEXBOEuSmMXCeEUHGE9K',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273c54f414dfbc12797e9d12ff7',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02c54f414dfbc12797e9d12ff7',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851c54f414dfbc12797e9d12ff7',
#        'width': 64}],
#      'name': 'V',
#      'release_date': '2006-01-01',
#      'release_date_precision': 'day',
#      'total_tracks': 14,
#      'type': 'album',
#      'uri': 'spotify:album:7EbEXBOEuSmMXCeEUHGE9K'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6G9bygHlCyPgNGxK2l3YdE'},
#       'href': 'https://api.spotify.com/v1/artists/6G9bygHlCyPgNGxK2l3YdE',
#       'id': '6G9bygHlCyPgNGxK2l3YdE',
#       'name': 'Vanessa Hudgens',
#       'type': 'artist',
#       'uri': 'spotify:artist:6G9bygHlCyPgNGxK2l3YdE'}],
#     'available_markets': [],
#     'disc_number': 1,
#     'duration_ms': 223866,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'USHR10622383'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/5cfPxiul0cdhPYD2uzuQSg'},
#     'href': 'https://api.spotify.com/v1/tracks/5cfPxiul0cdhPYD2uzuQSg',
#     'id': '5cfPxiul0cdhPYD2uzuQSg',
#     'is_local': False,
#     'name': 'Say OK',
#     'popularity': 0,
#     'preview_url': None,
#     'track': True,
#     'track_number': 3,
#     'type': 'track',
#     'uri': 'spotify:track:5cfPxiul0cdhPYD2uzuQSg'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2016-07-05T18:39:42Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/1130225252'},
#     'href': 'https://api.spotify.com/v1/users/1130225252',
#     'id': '1130225252',
#     'type': 'user',
#     'uri': 'spotify:user:1130225252'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7rPQ2z1ji1ctJ6oGYBAo6M'},
#        'href': 'https://api.spotify.com/v1/artists/7rPQ2z1ji1ctJ6oGYBAo6M',
#        'id': '7rPQ2z1ji1ctJ6oGYBAo6M',
#        'name': 'Emily Osment',
#        'type': 'artist',
#        'uri': 'spotify:artist:7rPQ2z1ji1ctJ6oGYBAo6M'}],
#      'available_markets': [],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/6X0LpqkUEUw31n6cIQfSIe'},
#      'href': 'https://api.spotify.com/v1/albums/6X0LpqkUEUw31n6cIQfSIe',
#      'id': '6X0LpqkUEUw31n6cIQfSIe',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273468152c1b2fcff4f32349d36',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02468152c1b2fcff4f32349d36',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851468152c1b2fcff4f32349d36',
#        'width': 64}],
#      'name': 'Fight Or Flight',
#      'release_date': '2010-01-01',
#      'release_date_precision': 'day',
#      'total_tracks': 11,
#      'type': 'album',
#      'uri': 'spotify:album:6X0LpqkUEUw31n6cIQfSIe'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7rPQ2z1ji1ctJ6oGYBAo6M'},
#       'href': 'https://api.spotify.com/v1/artists/7rPQ2z1ji1ctJ6oGYBAo6M',
#       'id': '7rPQ2z1ji1ctJ6oGYBAo6M',
#       'name': 'Emily Osment',
#       'type': 'artist',
#       'uri': 'spotify:artist:7rPQ2z1ji1ctJ6oGYBAo6M'}],
#     'available_markets': [],
#     'disc_number': 1,
#     'duration_ms': 204813,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'USWU31000084'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/2w55BLEMG97Smym2V6itnx'},
#     'href': 'https://api.spotify.com/v1/tracks/2w55BLEMG97Smym2V6itnx',
#     'id': '2w55BLEMG97Smym2V6itnx',
#     'is_local': False,
#     'name': 'Lovesick',
#     'popularity': 0,
#     'preview_url': None,
#     'track': True,
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:2w55BLEMG97Smym2V6itnx'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2016-07-05T18:39:44Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/1130225252'},
#     'href': 'https://api.spotify.com/v1/users/1130225252',
#     'id': '1130225252',
#     'type': 'user',
#     'uri': 'spotify:user:1130225252'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'compilation',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7nU4hB040gTmHm45YYMvqc'},
#        'href': 'https://api.spotify.com/v1/artists/7nU4hB040gTmHm45YYMvqc',
#        'id': '7nU4hB040gTmHm45YYMvqc',
#        'name': 'Hannah Montana',
#        'type': 'artist',
#        'uri': 'spotify:artist:7nU4hB040gTmHm45YYMvqc'}],
#      'available_markets': ['AD',
#       'AE',
#       'AL',
#       'AT',
#       'BA',
#       'BE',
#       'BG',
#       'BH',
#       'CH',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'EE',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'HR',
#       'HU',
#       'IE',
#       'IL',
#       'IQ',
#       'IS',
#       'IT',
#       'JO',
#       'KW',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MC',
#       'ME',
#       'MK',
#       'MT',
#       'NL',
#       'NO',
#       'OM',
#       'PL',
#       'PT',
#       'QA',
#       'RO',
#       'RS',
#       'SA',
#       'SE',
#       'SI',
#       'SK',
#       'SM',
#       'TR',
#       'UA',
#       'XK',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/5zZMy9QhbzvAjokurBvEgd'},
#      'href': 'https://api.spotify.com/v1/albums/5zZMy9QhbzvAjokurBvEgd',
#      'id': '5zZMy9QhbzvAjokurBvEgd',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b27391617a5764e53b78d47c9be1',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e0291617a5764e53b78d47c9be1',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d0000485191617a5764e53b78d47c9be1',
#        'width': 64}],
#      'name': 'Best Of Hannah Montana',
#      'release_date': '2011-01-01',
#      'release_date_precision': 'day',
#      'total_tracks': 14,
#      'type': 'album',
#      'uri': 'spotify:album:5zZMy9QhbzvAjokurBvEgd'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7nU4hB040gTmHm45YYMvqc'},
#       'href': 'https://api.spotify.com/v1/artists/7nU4hB040gTmHm45YYMvqc',
#       'id': '7nU4hB040gTmHm45YYMvqc',
#       'name': 'Hannah Montana',
#       'type': 'artist',
#       'uri': 'spotify:artist:7nU4hB040gTmHm45YYMvqc'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AT',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'CH',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'EE',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'HR',
#      'HU',
#      'IE',
#      'IL',
#      'IQ',
#      'IS',
#      'IT',
#      'JO',
#      'KW',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MC',
#      'ME',
#      'MK',
#      'MT',
#      'NL',
#      'NO',
#      'OM',
#      'PL',
#      'PT',
#      'QA',
#      'RO',
#      'RS',
#      'SA',
#      'SE',
#      'SI',
#      'SK',
#      'SM',
#      'TR',
#      'UA',
#      'XK',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 212853,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'USWD11048367'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/3lWEKwBNo9IbE9pdKC5NU6'},
#     'href': 'https://api.spotify.com/v1/tracks/3lWEKwBNo9IbE9pdKC5NU6',
#     'id': '3lWEKwBNo9IbE9pdKC5NU6',
#     'is_local': False,
#     'name': 'Wherever I Go',
#     'popularity': 48,
#     'preview_url': None,
#     'track': True,
#     'track_number': 13,
#     'type': 'track',
#     'uri': 'spotify:track:3lWEKwBNo9IbE9pdKC5NU6'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2016-07-05T18:39:45Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/1130225252'},
#     'href': 'https://api.spotify.com/v1/users/1130225252',
#     'id': '1130225252',
#     'type': 'user',
#     'uri': 'spotify:user:1130225252'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7nU4hB040gTmHm45YYMvqc'},
#        'href': 'https://api.spotify.com/v1/artists/7nU4hB040gTmHm45YYMvqc',
#        'id': '7nU4hB040gTmHm45YYMvqc',
#        'name': 'Hannah Montana',
#        'type': 'artist',
#        'uri': 'spotify:artist:7nU4hB040gTmHm45YYMvqc'}],
#      'available_markets': ['AD',
#       'AE',
#       'AL',
#       'AT',
#       'BA',
#       'BE',
#       'BG',
#       'BH',
#       'CH',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'EE',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'HR',
#       'HU',
#       'IE',
#       'IL',
#       'IQ',
#       'IS',
#       'IT',
#       'JO',
#       'KW',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MC',
#       'ME',
#       'MK',
#       'MT',
#       'NL',
#       'NO',
#       'OM',
#       'PL',
#       'PT',
#       'QA',
#       'RO',
#       'RS',
#       'SA',
#       'SE',
#       'SI',
#       'SK',
#       'SM',
#       'TR',
#       'UA',
#       'XK',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/5sYiillHfDiNUWUHZtlzFz'},
#      'href': 'https://api.spotify.com/v1/albums/5sYiillHfDiNUWUHZtlzFz',
#      'id': '5sYiillHfDiNUWUHZtlzFz',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2732a76a49686ef868b824b9200',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e022a76a49686ef868b824b9200',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048512a76a49686ef868b824b9200',
#        'width': 64}],
#      'name': 'Hannah Montana Forever',
#      'release_date': '2010-01-01',
#      'release_date_precision': 'day',
#      'total_tracks': 11,
#      'type': 'album',
#      'uri': 'spotify:album:5sYiillHfDiNUWUHZtlzFz'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7nU4hB040gTmHm45YYMvqc'},
#       'href': 'https://api.spotify.com/v1/artists/7nU4hB040gTmHm45YYMvqc',
#       'id': '7nU4hB040gTmHm45YYMvqc',
#       'name': 'Hannah Montana',
#       'type': 'artist',
#       'uri': 'spotify:artist:7nU4hB040gTmHm45YYMvqc'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AT',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'CH',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'EE',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'HR',
#      'HU',
#      'IE',
#      'IL',
#      'IQ',
#      'IS',
#      'IT',
#      'JO',
#      'KW',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MC',
#      'ME',
#      'MK',
#      'MT',
#      'NL',
#      'NO',
#      'OM',
#      'PL',
#      'PT',
#      'QA',
#      'RO',
#      'RS',
#      'SA',
#      'SE',
#      'SI',
#      'SK',
#      'SM',
#      'TR',
#      'UA',
#      'XK',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 233466,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'USWD11048341'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/0tldYKX9sQsDs41lJxdcp8'},
#     'href': 'https://api.spotify.com/v1/tracks/0tldYKX9sQsDs41lJxdcp8',
#     'id': '0tldYKX9sQsDs41lJxdcp8',
#     'is_local': False,
#     'name': "I'll Always Remember You",
#     'popularity': 40,
#     'preview_url': None,
#     'track': True,
#     'track_number': 5,
#     'type': 'track',
#     'uri': 'spotify:track:0tldYKX9sQsDs41lJxdcp8'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2016-07-05T18:39:46Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/1130225252'},
#     'href': 'https://api.spotify.com/v1/users/1130225252',
#     'id': '1130225252',
#     'type': 'user',
#     'uri': 'spotify:user:1130225252'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6dJeKm76NjfXBNTpHmOhfO'},
#        'href': 'https://api.spotify.com/v1/artists/6dJeKm76NjfXBNTpHmOhfO',
#        'id': '6dJeKm76NjfXBNTpHmOhfO',
#        'name': 'Selena Gomez & The Scene',
#        'type': 'artist',
#        'uri': 'spotify:artist:6dJeKm76NjfXBNTpHmOhfO'}],
#      'available_markets': ['AD',
#       'AE',
#       'AM',
#       'AR',
#       'AT',
#       'AU',
#       'AZ',
#       'BA',
#       'BD',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'BY',
#       'CH',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GN',
#       'GR',
#       'GY',
#       'HK',
#       'HR',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IQ',
#       'IS',
#       'IT',
#       'JO',
#       'KH',
#       'KR',
#       'KW',
#       'KZ',
#       'LA',
#       'LB',
#       'LI',
#       'LK',
#       'LT',
#       'LU',
#       'LV',
#       'LY',
#       'MA',
#       'MC',
#       'ME',
#       'MK',
#       'MT',
#       'MU',
#       'MX',
#       'MY',
#       'NG',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PE',
#       'PH',
#       'PL',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RW',
#       'SA',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SN',
#       'TN',
#       'TR',
#       'TW',
#       'TZ',
#       'UA',
#       'VE',
#       'VN',
#       'XK',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/6r8008bnpeLNfHdYCKtPK0'},
#      'href': 'https://api.spotify.com/v1/albums/6r8008bnpeLNfHdYCKtPK0',
#      'id': '6r8008bnpeLNfHdYCKtPK0',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2731c81fdc68cd5a76ef88508ce',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e021c81fdc68cd5a76ef88508ce',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048511c81fdc68cd5a76ef88508ce',
#        'width': 64}],
#      'name': 'A Year Without Rain (International Standard Version)',
#      'release_date': '2010-01-01',
#      'release_date_precision': 'day',
#      'total_tracks': 11,
#      'type': 'album',
#      'uri': 'spotify:album:6r8008bnpeLNfHdYCKtPK0'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6dJeKm76NjfXBNTpHmOhfO'},
#       'href': 'https://api.spotify.com/v1/artists/6dJeKm76NjfXBNTpHmOhfO',
#       'id': '6dJeKm76NjfXBNTpHmOhfO',
#       'name': 'Selena Gomez & The Scene',
#       'type': 'artist',
#       'uri': 'spotify:artist:6dJeKm76NjfXBNTpHmOhfO'}],
#     'available_markets': ['AD',
#      'AE',
#      'AM',
#      'AR',
#      'AT',
#      'AU',
#      'AZ',
#      'BA',
#      'BD',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CH',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GN',
#      'GR',
#      'GY',
#      'HK',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IQ',
#      'IS',
#      'IT',
#      'JO',
#      'KH',
#      'KR',
#      'KW',
#      'KZ',
#      'LA',
#      'LB',
#      'LI',
#      'LK',
#      'LT',
#      'LU',
#      'LV',
#      'LY',
#      'MA',
#      'MC',
#      'ME',
#      'MK',
#      'MT',
#      'MU',
#      'MX',
#      'MY',
#      'NG',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RW',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SN',
#      'TN',
#      'TR',
#      'TW',
#      'TZ',
#      'UA',
#      'VE',
#      'VN',
#      'XK',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 234346,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'USHR11031313'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/0lYS1tJg3r6ATe9bRPB0Hu'},
#     'href': 'https://api.spotify.com/v1/tracks/0lYS1tJg3r6ATe9bRPB0Hu',
#     'id': '0lYS1tJg3r6ATe9bRPB0Hu',
#     'is_local': False,
#     'name': 'A Year Without Rain',
#     'popularity': 57,
#     'preview_url': None,
#     'track': True,
#     'track_number': 2,
#     'type': 'track',
#     'uri': 'spotify:track:0lYS1tJg3r6ATe9bRPB0Hu'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2016-07-05T18:39:51Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/1130225252'},
#     'href': 'https://api.spotify.com/v1/users/1130225252',
#     'id': '1130225252',
#     'type': 'user',
#     'uri': 'spotify:user:1130225252'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1uNFoZAHBGtllmzznpCI3s'},
#        'href': 'https://api.spotify.com/v1/artists/1uNFoZAHBGtllmzznpCI3s',
#        'id': '1uNFoZAHBGtllmzznpCI3s',
#        'name': 'Justin Bieber',
#        'type': 'artist',
#        'uri': 'spotify:artist:1uNFoZAHBGtllmzznpCI3s'}],
#      'available_markets': [],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/7BWK3eXcbAdwYeulyQj5Kw'},
#      'href': 'https://api.spotify.com/v1/albums/7BWK3eXcbAdwYeulyQj5Kw',
#      'id': '7BWK3eXcbAdwYeulyQj5Kw',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273adc5af517133ca221870f112',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02adc5af517133ca221870f112',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851adc5af517133ca221870f112',
#        'width': 64}],
#      'name': 'Believe (Deluxe Edition)',
#      'release_date': '2012-01-01',
#      'release_date_precision': 'day',
#      'total_tracks': 17,
#      'type': 'album',
#      'uri': 'spotify:album:7BWK3eXcbAdwYeulyQj5Kw'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1uNFoZAHBGtllmzznpCI3s'},
#       'href': 'https://api.spotify.com/v1/artists/1uNFoZAHBGtllmzznpCI3s',
#       'id': '1uNFoZAHBGtllmzznpCI3s',
#       'name': 'Justin Bieber',
#       'type': 'artist',
#       'uri': 'spotify:artist:1uNFoZAHBGtllmzznpCI3s'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/0hCNtLu0JehylgoiP8L4Gh'},
#       'href': 'https://api.spotify.com/v1/artists/0hCNtLu0JehylgoiP8L4Gh',
#       'id': '0hCNtLu0JehylgoiP8L4Gh',
#       'name': 'Nicki Minaj',
#       'type': 'artist',
#       'uri': 'spotify:artist:0hCNtLu0JehylgoiP8L4Gh'}],
#     'available_markets': [],
#     'disc_number': 1,
#     'duration_ms': 227986,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'USUM71205367'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/0KTsmr6JOuhxZuiXUha1xC'},
#     'href': 'https://api.spotify.com/v1/tracks/0KTsmr6JOuhxZuiXUha1xC',
#     'id': '0KTsmr6JOuhxZuiXUha1xC',
#     'is_local': False,
#     'name': 'Beauty And A Beat',
#     'popularity': 0,
#     'preview_url': None,
#     'track': True,
#     'track_number': 10,
#     'type': 'track',
#     'uri': 'spotify:track:0KTsmr6JOuhxZuiXUha1xC'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2016-07-05T18:39:54Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/1130225252'},
#     'href': 'https://api.spotify.com/v1/users/1130225252',
#     'id': '1130225252',
#     'type': 'user',
#     'uri': 'spotify:user:1130225252'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0TnOYISbd1XYRBk9myaseg'},
#        'href': 'https://api.spotify.com/v1/artists/0TnOYISbd1XYRBk9myaseg',
#        'id': '0TnOYISbd1XYRBk9myaseg',
#        'name': 'Pitbull',
#        'type': 'artist',
#        'uri': 'spotify:artist:0TnOYISbd1XYRBk9myaseg'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AO',
#       'AR',
#       'AT',
#       'AU',
#       'AZ',
#       'BA',
#       'BB',
#       'BD',
#       'BE',
#       'BF',
#       'BG',
#       'BH',
#       'BI',
#       'BJ',
#       'BN',
#       'BO',
#       'BR',
#       'BS',
#       'BT',
#       'BW',
#       'BY',
#       'BZ',
#       'CA',
#       'CD',
#       'CG',
#       'CH',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CV',
#       'CW',
#       'CY',
#       'CZ',
#       'DE',
#       'DJ',
#       'DK',
#       'DM',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FJ',
#       'FM',
#       'FR',
#       'GA',
#       'GB',
#       'GD',
#       'GE',
#       'GH',
#       'GM',
#       'GN',
#       'GQ',
#       'GR',
#       'GT',
#       'GW',
#       'GY',
#       'HK',
#       'HN',
#       'HR',
#       'HT',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IQ',
#       'IS',
#       'IT',
#       'JM',
#       'JO',
#       'KE',
#       'KG',
#       'KH',
#       'KI',
#       'KM',
#       'KN',
#       'KR',
#       'KW',
#       'KZ',
#       'LA',
#       'LB',
#       'LC',
#       'LI',
#       'LK',
#       'LR',
#       'LS',
#       'LT',
#       'LU',
#       'LV',
#       'LY',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MG',
#       'MH',
#       'MK',
#       'ML',
#       'MN',
#       'MO',
#       'MR',
#       'MT',
#       'MU',
#       'MV',
#       'MW',
#       'MX',
#       'MY',
#       'MZ',
#       'NA',
#       'NE',
#       'NG',
#       'NI',
#       'NL',
#       'NO',
#       'NP',
#       'NR',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PG',
#       'PH',
#       'PK',
#       'PL',
#       'PS',
#       'PT',
#       'PW',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RW',
#       'SA',
#       'SB',
#       'SC',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SL',
#       'SM',
#       'SN',
#       'SR',
#       'ST',
#       'SV',
#       'SZ',
#       'TD',
#       'TG',
#       'TH',
#       'TJ',
#       'TL',
#       'TN',
#       'TO',
#       'TR',
#       'TT',
#       'TV',
#       'TW',
#       'TZ',
#       'UA',
#       'UG',
#       'US',
#       'UY',
#       'UZ',
#       'VC',
#       'VE',
#       'VN',
#       'VU',
#       'WS',
#       'XK',
#       'ZA',
#       'ZM',
#       'ZW'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/4rG0MhkU6UojACJxkMHIXB'},
#      'href': 'https://api.spotify.com/v1/albums/4rG0MhkU6UojACJxkMHIXB',
#      'id': '4rG0MhkU6UojACJxkMHIXB',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2731dc7483a9fcfce54822a2f19',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e021dc7483a9fcfce54822a2f19',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048511dc7483a9fcfce54822a2f19',
#        'width': 64}],
#      'name': 'Planet Pit (Deluxe Version)',
#      'release_date': '2011-06-17',
#      'release_date_precision': 'day',
#      'total_tracks': 16,
#      'type': 'album',
#      'uri': 'spotify:album:4rG0MhkU6UojACJxkMHIXB'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0TnOYISbd1XYRBk9myaseg'},
#       'href': 'https://api.spotify.com/v1/artists/0TnOYISbd1XYRBk9myaseg',
#       'id': '0TnOYISbd1XYRBk9myaseg',
#       'name': 'Pitbull',
#       'type': 'artist',
#       'uri': 'spotify:artist:0TnOYISbd1XYRBk9myaseg'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/7bXgB6jMjp9ATFy66eO08Z'},
#       'href': 'https://api.spotify.com/v1/artists/7bXgB6jMjp9ATFy66eO08Z',
#       'id': '7bXgB6jMjp9ATFy66eO08Z',
#       'name': 'Chris Brown',
#       'type': 'artist',
#       'uri': 'spotify:artist:7bXgB6jMjp9ATFy66eO08Z'}],
#     'available_markets': ['AD',
#      'AE',
#      'AG',
#      'AL',
#      'AM',
#      'AO',
#      'AR',
#      'AT',
#      'AU',
#      'AZ',
#      'BA',
#      'BB',
#      'BD',
#      'BE',
#      'BF',
#      'BG',
#      'BH',
#      'BI',
#      'BJ',
#      'BN',
#      'BO',
#      'BR',
#      'BS',
#      'BT',
#      'BW',
#      'BY',
#      'BZ',
#      'CA',
#      'CD',
#      'CG',
#      'CH',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CV',
#      'CW',
#      'CY',
#      'CZ',
#      'DE',
#      'DJ',
#      'DK',
#      'DM',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FJ',
#      'FM',
#      'FR',
#      'GA',
#      'GB',
#      'GD',
#      'GE',
#      'GH',
#      'GM',
#      'GN',
#      'GQ',
#      'GR',
#      'GT',
#      'GW',
#      'GY',
#      'HK',
#      'HN',
#      'HR',
#      'HT',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IQ',
#      'IS',
#      'IT',
#      'JM',
#      'JO',
#      'KE',
#      'KG',
#      'KH',
#      'KI',
#      'KM',
#      'KN',
#      'KR',
#      'KW',
#      'KZ',
#      'LA',
#      'LB',
#      'LC',
#      'LI',
#      'LK',
#      'LR',
#      'LS',
#      'LT',
#      'LU',
#      'LV',
#      'LY',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MG',
#      'MH',
#      'MK',
#      'ML',
#      'MN',
#      'MO',
#      'MR',
#      'MT',
#      'MU',
#      'MV',
#      'MW',
#      'MX',
#      'MY',
#      'MZ',
#      'NA',
#      'NE',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NP',
#      'NR',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PG',
#      'PH',
#      'PK',
#      'PL',
#      'PS',
#      'PT',
#      'PW',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RW',
#      'SA',
#      'SB',
#      'SC',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SL',
#      'SM',
#      'SN',
#      'SR',
#      'ST',
#      'SV',
#      'SZ',
#      'TD',
#      'TG',
#      'TH',
#      'TJ',
#      'TL',
#      'TN',
#      'TO',
#      'TR',
#      'TT',
#      'TV',
#      'TW',
#      'TZ',
#      'UA',
#      'UG',
#      'US',
#      'UY',
#      'UZ',
#      'VC',
#      'VE',
#      'VN',
#      'VU',
#      'WS',
#      'XK',
#      'ZA',
#      'ZM',
#      'ZW'],
#     'disc_number': 1,
#     'duration_ms': 227280,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'USJAY1100015'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/62zFEHfAYl5kdHYOivj4BC'},
#     'href': 'https://api.spotify.com/v1/tracks/62zFEHfAYl5kdHYOivj4BC',
#     'id': '62zFEHfAYl5kdHYOivj4BC',
#     'is_local': False,
#     'name': 'International Love (feat. Chris Brown)',
#     'popularity': 74,
#     'preview_url': 'https://p.scdn.co/mp3-preview/fb03867ab24e82ece63bcf8a2778ae3b241f064d?cid=da00ed264eaf4f94ba2adf23ff058567',
#     'track': True,
#     'track_number': 8,
#     'type': 'track',
#     'uri': 'spotify:track:62zFEHfAYl5kdHYOivj4BC'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2016-07-05T18:39:55Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/1130225252'},
#     'href': 'https://api.spotify.com/v1/users/1130225252',
#     'id': '1130225252',
#     'type': 'user',
#     'uri': 'spotify:user:1130225252'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3qy9C549vuJzgevoM0ZiRA'},
#        'href': 'https://api.spotify.com/v1/artists/3qy9C549vuJzgevoM0ZiRA',
#        'id': '3qy9C549vuJzgevoM0ZiRA',
#        'name': 'Redrama',
#        'type': 'artist',
#        'uri': 'spotify:artist:3qy9C549vuJzgevoM0ZiRA'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AO',
#       'AR',
#       'AT',
#       'AU',
#       'AZ',
#       'BA',
#       'BB',
#       'BD',
#       'BE',
#       'BF',
#       'BG',
#       'BH',
#       'BI',
#       'BJ',
#       'BN',
#       'BO',
#       'BR',
#       'BS',
#       'BT',
#       'BW',
#       'BY',
#       'BZ',
#       'CA',
#       'CD',
#       'CG',
#       'CH',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CV',
#       'CW',
#       'CY',
#       'CZ',
#       'DE',
#       'DJ',
#       'DK',
#       'DM',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FJ',
#       'FM',
#       'FR',
#       'GA',
#       'GB',
#       'GD',
#       'GE',
#       'GH',
#       'GM',
#       'GN',
#       'GQ',
#       'GR',
#       'GT',
#       'GW',
#       'GY',
#       'HK',
#       'HN',
#       'HR',
#       'HT',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IQ',
#       'IS',
#       'IT',
#       'JM',
#       'JO',
#       'JP',
#       'KE',
#       'KG',
#       'KH',
#       'KI',
#       'KM',
#       'KN',
#       'KR',
#       'KW',
#       'KZ',
#       'LA',
#       'LB',
#       'LC',
#       'LI',
#       'LK',
#       'LR',
#       'LS',
#       'LT',
#       'LU',
#       'LV',
#       'LY',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MG',
#       'MH',
#       'MK',
#       'ML',
#       'MN',
#       'MO',
#       'MR',
#       'MT',
#       'MU',
#       'MV',
#       'MW',
#       'MX',
#       'MY',
#       'MZ',
#       'NA',
#       'NE',
#       'NG',
#       'NI',
#       'NL',
#       'NO',
#       'NP',
#       'NR',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PG',
#       'PH',
#       'PK',
#       'PL',
#       'PS',
#       'PT',
#       'PW',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RW',
#       'SA',
#       'SB',
#       'SC',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SL',
#       'SM',
#       'SN',
#       'SR',
#       'ST',
#       'SV',
#       'SZ',
#       'TD',
#       'TG',
#       'TH',
#       'TJ',
#       'TL',
#       'TN',
#       'TO',
#       'TR',
#       'TT',
#       'TV',
#       'TW',
#       'TZ',
#       'UA',
#       'UG',
#       'UY',
#       'UZ',
#       'VC',
#       'VE',
#       'VN',
#       'VU',
#       'WS',
#       'XK',
#       'ZA',
#       'ZM',
#       'ZW'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/2lq5RDEDjukKYQiUekDS1p'},
#      'href': 'https://api.spotify.com/v1/albums/2lq5RDEDjukKYQiUekDS1p',
#      'id': '2lq5RDEDjukKYQiUekDS1p',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2730c3cd612c65f8b89fa824453',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e020c3cd612c65f8b89fa824453',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048510c3cd612c65f8b89fa824453',
#        'width': 64}],
#      'name': 'Reflection',
#      'release_date': '2014-02-28',
#      'release_date_precision': 'day',
#      'total_tracks': 12,
#      'type': 'album',
#      'uri': 'spotify:album:2lq5RDEDjukKYQiUekDS1p'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3qy9C549vuJzgevoM0ZiRA'},
#       'href': 'https://api.spotify.com/v1/artists/3qy9C549vuJzgevoM0ZiRA',
#       'id': '3qy9C549vuJzgevoM0ZiRA',
#       'name': 'Redrama',
#       'type': 'artist',
#       'uri': 'spotify:artist:3qy9C549vuJzgevoM0ZiRA'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/5RFf1gyPc9lMOtCq2k6tLl'},
#       'href': 'https://api.spotify.com/v1/artists/5RFf1gyPc9lMOtCq2k6tLl',
#       'id': '5RFf1gyPc9lMOtCq2k6tLl',
#       'name': 'AJ McLean',
#       'type': 'artist',
#       'uri': 'spotify:artist:5RFf1gyPc9lMOtCq2k6tLl'}],
#     'available_markets': ['AD',
#      'AE',
#      'AG',
#      'AL',
#      'AM',
#      'AO',
#      'AR',
#      'AT',
#      'AU',
#      'AZ',
#      'BA',
#      'BB',
#      'BD',
#      'BE',
#      'BF',
#      'BG',
#      'BH',
#      'BI',
#      'BJ',
#      'BN',
#      'BO',
#      'BR',
#      'BS',
#      'BT',
#      'BW',
#      'BY',
#      'BZ',
#      'CA',
#      'CD',
#      'CG',
#      'CH',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CV',
#      'CW',
#      'CY',
#      'CZ',
#      'DE',
#      'DJ',
#      'DK',
#      'DM',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FJ',
#      'FM',
# ...
#      'id': '4U2EphB1FTq036JV7gKE6L',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273fe0fdb054853b5f89bf12b13',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02fe0fdb054853b5f89bf12b13',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851fe0fdb054853b5f89bf12b13',
#        'width': 64}],
#      'name': 'Just A Dream',
#      'release_date': '2010-01-01',
#      'release_date_precision': 'day',
#      'total_tracks': 2,
#      'type': 'album',
#      'uri': 'spotify:album:4U2EphB1FTq036JV7gKE6L'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2gBjLmx6zQnFGQJCAQpRgw'},
#       'href': 'https://api.spotify.com/v1/artists/2gBjLmx6zQnFGQJCAQpRgw',
#       'id': '2gBjLmx6zQnFGQJCAQpRgw',
#       'name': 'Nelly',
#       'type': 'artist',
#       'uri': 'spotify:artist:2gBjLmx6zQnFGQJCAQpRgw'}],
#     'available_markets': ['AM',
#      'AR',
#      'AT',
#      'AZ',
#      'BA',
#      'BD',
#      'BE',
#      'BG',
#      'BN',
#      'BO',
#      'BR',
#      'BY',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DO',
#      'EC',
#      'EE',
#      'FI',
#      'FJ',
#      'GN',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'KG',
#      'KH',
#      'KR',
#      'KZ',
#      'LA',
#      'LK',
#      'LT',
#      'LU',
#      'LV',
#      'ME',
#      'MK',
#      'MO',
#      'MT',
#      'MU',
#      'MY',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'PY',
#      'RO',
#      'RS',
#      'RW',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TJ',
#      'TR',
#      'TW',
#      'UA',
#      'UZ',
#      'VE',
#      'VN',
#      'XK',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 237866,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'USUM71020948'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/1xnPVj6jmYCedHG37IE2cc'},
#     'href': 'https://api.spotify.com/v1/tracks/1xnPVj6jmYCedHG37IE2cc',
#     'id': '1xnPVj6jmYCedHG37IE2cc',
#     'is_local': False,
#     'name': 'Just A Dream',
#     'popularity': 35,
#     'preview_url': None,
#     'track': True,
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:1xnPVj6jmYCedHG37IE2cc'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2016-07-05T18:48:16Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/1130225252'},
#     'href': 'https://api.spotify.com/v1/users/1130225252',
#     'id': '1130225252',
#     'type': 'user',
#     'uri': 'spotify:user:1130225252'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5EUdiv20t58GCS09VMKk7M'},
#        'href': 'https://api.spotify.com/v1/artists/5EUdiv20t58GCS09VMKk7M',
#        'id': '5EUdiv20t58GCS09VMKk7M',
#        'name': 'Katy B',
#        'type': 'artist',
#        'uri': 'spotify:artist:5EUdiv20t58GCS09VMKk7M'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AO',
#       'AR',
#       'AT',
#       'AU',
#       'AZ',
#       'BA',
#       'BB',
#       'BD',
#       'BE',
#       'BF',
#       'BG',
#       'BH',
#       'BI',
#       'BJ',
#       'BN',
#       'BO',
#       'BR',
#       'BS',
#       'BT',
#       'BW',
#       'BY',
#       'BZ',
#       'CA',
#       'CD',
#       'CG',
#       'CH',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CV',
#       'CW',
#       'CY',
#       'CZ',
#       'DE',
#       'DJ',
#       'DK',
#       'DM',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FJ',
#       'FM',
#       'FR',
#       'GA',
#       'GB',
#       'GD',
#       'GE',
#       'GH',
#       'GM',
#       'GN',
#       'GQ',
#       'GR',
#       'GT',
#       'GW',
#       'GY',
#       'HK',
#       'HN',
#       'HR',
#       'HT',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IQ',
#       'IS',
#       'IT',
#       'JM',
#       'JO',
#       'JP',
#       'KE',
#       'KG',
#       'KH',
#       'KI',
#       'KM',
#       'KN',
#       'KR',
#       'KW',
#       'KZ',
#       'LA',
#       'LB',
#       'LC',
#       'LI',
#       'LK',
#       'LR',
#       'LS',
#       'LT',
#       'LU',
#       'LV',
#       'LY',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MG',
#       'MH',
#       'MK',
#       'ML',
#       'MN',
#       'MO',
#       'MR',
#       'MT',
#       'MU',
#       'MV',
#       'MW',
#       'MX',
#       'MY',
#       'MZ',
#       'NA',
#       'NE',
#       'NG',
#       'NI',
#       'NL',
#       'NO',
#       'NP',
#       'NR',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PG',
#       'PH',
#       'PK',
#       'PL',
#       'PS',
#       'PT',
#       'PW',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RW',
#       'SA',
#       'SB',
#       'SC',
#       'SG',
#       'SI',
#       'SK',
#       'SL',
#       'SM',
#       'SN',
#       'SR',
#       'ST',
#       'SV',
#       'SZ',
#       'TD',
#       'TG',
#       'TH',
#       'TJ',
#       'TL',
#       'TN',
#       'TO',
#       'TR',
#       'TT',
#       'TV',
#       'TW',
#       'TZ',
#       'UA',
#       'UG',
#       'US',
#       'UY',
#       'UZ',
#       'VC',
#       'VE',
#       'VN',
#       'VU',
#       'WS',
#       'XK',
#       'ZA',
#       'ZM',
#       'ZW'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/1EKnf8pTCTORIjSabmZ7fg'},
#      'href': 'https://api.spotify.com/v1/albums/1EKnf8pTCTORIjSabmZ7fg',
#      'id': '1EKnf8pTCTORIjSabmZ7fg',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2730402428e85cb68e1962ed515',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e020402428e85cb68e1962ed515',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048510402428e85cb68e1962ed515',
#        'width': 64}],
#      'name': 'Crying for No Reason',
#      'release_date': '2014-01-26',
#      'release_date_precision': 'day',
#      'total_tracks': 1,
#      'type': 'album',
#      'uri': 'spotify:album:1EKnf8pTCTORIjSabmZ7fg'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5EUdiv20t58GCS09VMKk7M'},
#       'href': 'https://api.spotify.com/v1/artists/5EUdiv20t58GCS09VMKk7M',
#       'id': '5EUdiv20t58GCS09VMKk7M',
#       'name': 'Katy B',
#       'type': 'artist',
#       'uri': 'spotify:artist:5EUdiv20t58GCS09VMKk7M'}],
#     'available_markets': ['AD',
#      'AE',
#      'AG',
#      'AL',
#      'AM',
#      'AO',
#      'AR',
#      'AT',
#      'AU',
#      'AZ',
#      'BA',
#      'BB',
#      'BD',
#      'BE',
#      'BF',
#      'BG',
#      'BH',
#      'BI',
#      'BJ',
#      'BN',
#      'BO',
#      'BR',
#      'BS',
#      'BT',
#      'BW',
#      'BY',
#      'BZ',
#      'CA',
#      'CD',
#      'CG',
#      'CH',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CV',
#      'CW',
#      'CY',
#      'CZ',
#      'DE',
#      'DJ',
#      'DK',
#      'DM',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FJ',
#      'FM',
#      'FR',
#      'GA',
#      'GB',
#      'GD',
#      'GE',
#      'GH',
#      'GM',
#      'GN',
#      'GQ',
#      'GR',
#      'GT',
#      'GW',
#      'GY',
#      'HK',
#      'HN',
#      'HR',
#      'HT',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IQ',
#      'IS',
#      'IT',
#      'JM',
#      'JO',
#      'JP',
#      'KE',
#      'KG',
#      'KH',
#      'KI',
#      'KM',
#      'KN',
#      'KR',
#      'KW',
#      'KZ',
#      'LA',
#      'LB',
#      'LC',
#      'LI',
#      'LK',
#      'LR',
#      'LS',
#      'LT',
#      'LU',
#      'LV',
#      'LY',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MG',
#      'MH',
#      'MK',
#      'ML',
#      'MN',
#      'MO',
#      'MR',
#      'MT',
#      'MU',
#      'MV',
#      'MW',
#      'MX',
#      'MY',
#      'MZ',
#      'NA',
#      'NE',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NP',
#      'NR',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PG',
#      'PH',
#      'PK',
#      'PL',
#      'PS',
#      'PT',
#      'PW',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RW',
#      'SA',
#      'SB',
#      'SC',
#      'SG',
#      'SI',
#      'SK',
#      'SL',
#      'SM',
#      'SN',
#      'SR',
#      'ST',
#      'SV',
#      'SZ',
#      'TD',
#      'TG',
#      'TH',
#      'TJ',
#      'TL',
#      'TN',
#      'TO',
#      'TR',
#      'TT',
#      'TV',
#      'TW',
#      'TZ',
#      'UA',
#      'UG',
#      'US',
#      'UY',
#      'UZ',
#      'VC',
#      'VE',
#      'VN',
#      'VU',
#      'WS',
#      'XK',
#      'ZA',
#      'ZM',
#      'ZW'],
#     'disc_number': 1,
#     'duration_ms': 243240,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'GBARL1301553'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/3DDxYAT7Nuj0tfkHICWYi3'},
#     'href': 'https://api.spotify.com/v1/tracks/3DDxYAT7Nuj0tfkHICWYi3',
#     'id': '3DDxYAT7Nuj0tfkHICWYi3',
#     'is_local': False,
#     'name': 'Crying for No Reason',
#     'popularity': 30,
#     'preview_url': 'https://p.scdn.co/mp3-preview/f54e3ad0e89356c6c9a93f58417b06fd73709547?cid=da00ed264eaf4f94ba2adf23ff058567',
#     'track': True,
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:3DDxYAT7Nuj0tfkHICWYi3'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2016-07-05T18:48:21Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/1130225252'},
#     'href': 'https://api.spotify.com/v1/users/1130225252',
#     'id': '1130225252',
#     'type': 'user',
#     'uri': 'spotify:user:1130225252'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1PbBg2aYjWLKRk84zJK15x'},
#        'href': 'https://api.spotify.com/v1/artists/1PbBg2aYjWLKRk84zJK15x',
#        'id': '1PbBg2aYjWLKRk84zJK15x',
#        'name': 'Echosmith',
#        'type': 'artist',
#        'uri': 'spotify:artist:1PbBg2aYjWLKRk84zJK15x'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AO',
#       'AR',
#       'AT',
#       'AU',
#       'AZ',
#       'BA',
#       'BB',
#       'BD',
#       'BE',
#       'BF',
#       'BG',
#       'BH',
#       'BI',
#       'BJ',
#       'BN',
#       'BO',
#       'BR',
#       'BS',
#       'BW',
#       'BY',
#       'BZ',
#       'CA',
#       'CD',
#       'CG',
#       'CH',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CV',
#       'CW',
#       'CY',
#       'CZ',
#       'DE',
#       'DJ',
#       'DK',
#       'DM',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FJ',
#       'FM',
#       'FR',
#       'GA',
#       'GB',
#       'GD',
#       'GE',
#       'GH',
#       'GM',
#       'GN',
#       'GQ',
#       'GR',
#       'GT',
#       'GW',
#       'HK',
#       'HN',
#       'HR',
#       'HT',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IQ',
#       'IS',
#       'IT',
#       'JM',
#       'JO',
#       'JP',
#       'KE',
#       'KG',
#       'KH',
#       'KM',
#       'KN',
#       'KR',
#       'KW',
#       'KZ',
#       'LA',
#       'LB',
#       'LC',
#       'LI',
#       'LK',
#       'LR',
#       'LS',
#       'LT',
#       'LU',
#       'LV',
#       'LY',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MG',
#       'MK',
#       'ML',
#       'MN',
#       'MO',
#       'MR',
#       'MT',
#       'MU',
#       'MW',
#       'MX',
#       'MY',
#       'MZ',
#       'NA',
#       'NE',
#       'NG',
#       'NI',
#       'NL',
#       'NO',
#       'NP',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PG',
#       'PH',
#       'PK',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RW',
#       'SA',
#       'SC',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SL',
#       'SM',
#       'SN',
#       'ST',
#       'SV',
#       'SZ',
#       'TD',
#       'TG',
#       'TH',
#       'TJ',
#       'TL',
#       'TN',
#       'TR',
#       'TT',
#       'TW',
#       'TZ',
#       'UA',
#       'UG',
#       'US',
#       'UY',
#       'UZ',
#       'VC',
#       'VE',
#       'VN',
#       'XK',
#       'ZA',
#       'ZM',
#       'ZW'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/1oHY6eQmEG8skElDvFgKz2'},
#      'href': 'https://api.spotify.com/v1/albums/1oHY6eQmEG8skElDvFgKz2',
#      'id': '1oHY6eQmEG8skElDvFgKz2',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273106fa02aaa287ec63af85aae',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02106fa02aaa287ec63af85aae',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851106fa02aaa287ec63af85aae',
#        'width': 64}],
#      'name': 'Talking Dreams (Deluxe Edition)',
#      'release_date': '2013-10-04',
#      'release_date_precision': 'day',
#      'total_tracks': 14,
#      'type': 'album',
#      'uri': 'spotify:album:1oHY6eQmEG8skElDvFgKz2'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1PbBg2aYjWLKRk84zJK15x'},
#       'href': 'https://api.spotify.com/v1/artists/1PbBg2aYjWLKRk84zJK15x',
#       'id': '1PbBg2aYjWLKRk84zJK15x',
#       'name': 'Echosmith',
#       'type': 'artist',
#       'uri': 'spotify:artist:1PbBg2aYjWLKRk84zJK15x'}],
#     'available_markets': ['AD',
#      'AE',
#      'AG',
#      'AL',
#      'AM',
#      'AO',
#      'AR',
#      'AT',
#      'AU',
#      'AZ',
#      'BA',
#      'BB',
#      'BD',
#      'BE',
#      'BF',
#      'BG',
#      'BH',
#      'BI',
#      'BJ',
#      'BN',
#      'BO',
#      'BR',
#      'BS',
#      'BW',
#      'BY',
#      'BZ',
#      'CA',
#      'CD',
#      'CG',
#      'CH',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CV',
#      'CW',
#      'CY',
#      'CZ',
#      'DE',
#      'DJ',
#      'DK',
#      'DM',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FJ',
#      'FM',
#      'FR',
#      'GA',
#      'GB',
#      'GD',
#      'GE',
#      'GH',
#      'GM',
#      'GN',
#      'GQ',
#      'GR',
#      'GT',
#      'GW',
#      'HK',
#      'HN',
#      'HR',
#      'HT',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IQ',
#      'IS',
#      'IT',
#      'JM',
#      'JO',
#      'JP',
#      'KE',
#      'KG',
#      'KH',
#      'KM',
#      'KN',
#      'KR',
#      'KW',
#      'KZ',
#      'LA',
#      'LB',
#      'LC',
#      'LI',
#      'LK',
#      'LR',
#      'LS',
#      'LT',
#      'LU',
#      'LV',
#      'LY',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MG',
#      'MK',
#      'ML',
#      'MN',
#      'MO',
#      'MR',
#      'MT',
#      'MU',
#      'MW',
#      'MX',
#      'MY',
#      'MZ',
#      'NA',
#      'NE',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NP',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PG',
#      'PH',
#      'PK',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RW',
#      'SA',
#      'SC',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SL',
#      'SM',
#      'SN',
#      'ST',
#      'SV',
#      'SZ',
#      'TD',
#      'TG',
#      'TH',
#      'TJ',
#      'TL',
#      'TN',
#      'TR',
#      'TT',
#      'TW',
#      'TZ',
#      'UA',
#      'UG',
#      'US',
#      'UY',
#      'UZ',
#      'VC',
#      'VE',
#      'VN',
#      'XK',
#      'ZA',
#      'ZM',
#      'ZW'],
#     'disc_number': 1,
#     'duration_ms': 237626,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'USWB11301764'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/13P5rwmk2EsoFRIz9UCeh9'},
#     'href': 'https://api.spotify.com/v1/tracks/13P5rwmk2EsoFRIz9UCeh9',
#     'id': '13P5rwmk2EsoFRIz9UCeh9',
#     'is_local': False,
#     'name': 'Cool Kids',
#     'popularity': 70,
#     'preview_url': 'https://p.scdn.co/mp3-preview/e9ad57c6ad935b73a9491c8553d126e6a090aa8c?cid=da00ed264eaf4f94ba2adf23ff058567',
#     'track': True,
#     'track_number': 3,
#     'type': 'track',
#     'uri': 'spotify:track:13P5rwmk2EsoFRIz9UCeh9'},
#    'video_thumbnail': {'url': None}}],
#  'limit': 100,
#  'next': 'https://api.spotify.com/v1/playlists/4rnleEAOdmFAbRcNCgZMpY/tracks?offset=200&limit=100&additional_types=track',
#  'offset': 100,
#  'previous': 'https://api.spotify.com/v1/playlists/4rnleEAOdmFAbRcNCgZMpY/tracks?offset=0&limit=100&additional_types=track',
#  'total': 5295}

# %%
from random import randint
from time import sleep

def playlist_tracks(playlist_id):
    results = sp.user_playlist_tracks('spotify',playlist_id)
    tracks = results['items']
    while results['next'] != None:
        results = sp.next(results)
        tracks = tracks + results['items']
        sleep(randint(1,3))
    return tracks

# %%
all_tracks = playlist_tracks('4rnleEAOdmFAbRcNCgZMpY')
len(all_tracks)
# Out:
# 5295

# %% [markdown]
# # Audio Features

# %%
playlist['items'][13]['track']['name']
# Out:
# 'Girlfriend'

# %%
song_uri = playlist['items'][13]['track']['uri']

# %%
sp.audio_features(song_uri)
# Out:
# [{'danceability': 0.56,
#   'energy': 0.959,
#   'key': 7,
#   'loudness': -2.433,
#   'mode': 1,
#   'speechiness': 0.102,
#   'acousticness': 0.000738,
#   'instrumentalness': 0.000206,
#   'liveness': 0.209,
#   'valence': 0.67,
#   'tempo': 163.983,
#   'type': 'audio_features',
#   'id': '5HbCnVLXRyZVxnreOPgJCK',
#   'uri': 'spotify:track:5HbCnVLXRyZVxnreOPgJCK',
#   'track_href': 'https://api.spotify.com/v1/tracks/5HbCnVLXRyZVxnreOPgJCK',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5HbCnVLXRyZVxnreOPgJCK',
#   'duration_ms': 216600,
#   'time_signature': 4}]

# %% [markdown]
# # Function to pull out all Audio Features

# %%
sp.audio_features(song_uri)[0]['danceability']
# Out:
# 0.56

# %%
list_features = ['danceability','energy','key','loudness','speechiness','instrumentalness','liveness','valence','tempo','time_signature']

# %%
def pull_out_features(song_uri):
    pair_feat_value = []
    for feature in list_features:
        pair_feat_value.append(feature)
        pair_feat_value.append(sp.audio_features(song_uri)[0][feature])
    return pair_feat_value

# %%
lst = pull_out_features(song_uri)
lst
# Out:
# ['danceability',
#  0.56,
#  'energy',
#  0.959,
#  'key',
#  7,
#  'loudness',
#  -2.433,
#  'speechiness',
#  0.102,
#  'instrumentalness',
#  0.000206,
#  'liveness',
#  0.209,
#  'valence',
#  0.67,
#  'tempo',
#  163.983,
#  'time_signature',
#  4]

# %% [markdown]
# # Help with functions!!

# %%
def get_playlist_tracks(playlist_id):
    results = sp.user_playlist_tracks("spotify",playlist_id)
    tracks = results['items']
    while results['next']!=None:
        results = sp.next(results)
        tracks = tracks + results['items']
        sleep(randint(1,3))
    return tracks

# %%
gx_playlist = get_playlist_tracks('37i9dQZF1DWUxHPh2rEiHr')

# %%
def flatten(input_list):
    return [item for sublist in input_list for item in sublist]

def get_details_from_track(track):
    return flatten((track["name"],artist["name"], track["uri"]) for artist in track["artists"])

def get_details_from_playlist_item(playlist_item):
    return get_details_from_track(playlist_item['track'])

def get_details_from_playlist(input_playlist):
    return list(map(get_details_from_playlist_item,input_playlist))

# %%
gx_details = get_details_from_playlist(gx_playlist)

# %%
def make_df_from_playlist_details(playlist_details):
    titles = [song[0] for song in playlist_details]
    artists = [song[1] for song in playlist_details]
    uris = [(song[2].split(":"))[-1] for song in playlist_details]
    df = pd.DataFrame({'title':titles, 'artist':artists, 'uri':uris})
    
    return df

# %%
gx = make_df_from_playlist_details(gx_details)

# %%
audio_features = ['danceability', 'energy', 'key', 'loudness', 'mode', 'speechiness', 'acousticness', 'instrumentalness', 
            'liveness', 'valence', 'tempo', 'time_signature']

def add_audio_features(df):
    df['features'] = None
    for i in range(len(df)):
        song_features = sp.audio_features(df.uri[i])
        df['features'][i] = song_features[0]
        sleep(randint(1,3))
    for f in audio_features:
        df[f] = [df['features'][i][f] for i in range(len(df))]
    df.drop(['features'], axis=1, inplace=True)
    return df

# %%
gx_with_audio = add_audio_features(gx)

# %%
#gx_with_audio.drop(['features'], axis=1, inplace=True)
gx_with_audio
# Out:
#                                                 title        artist  \
# 0               Summer of Love (Shawn Mendes & Tainy)  Shawn Mendes
# 1   SG (with Ozuna, Megan Thee Stallion & LISA of ...      DJ Snake
# 2                      Voodoo (with J Balvin & Tainy)       Badshah
# 3        love nwantiti (feat. Dj Yo! & AX'EL) - Remix          CKay
# 4                 Ayo Girl (Fayahh Beat) [feat. Rema]      Robinson
# ..                                                ...           ...
# 75                                             Remedy         Leony
# 76                                             Butter           BTS
# 77                      Gata (feat. Chencho Corleone)        Anitta
# 78                                            Thunder   Gabry Ponte
# 79                              Dégaine (feat. Damso)  Aya Nakamura
#
#                        uri  danceability  energy  key  loudness  mode  \
# 0   0z8hI3OPS8ADPWtoCjjLl6         0.776   0.808   11    -4.501     1
# 1   6IPNp9PfaEqrzotY47TIWy         0.800   0.837    6    -2.807     0
# 2   4OUAXw3SXI7bUiNtKC7ErW         0.797   0.782    3    -4.658     0
# 3   4gvrJnKCKIPiacNsWVQwEU         0.579   0.596    8    -4.823     1
# 4   57Hk0AE5OhgXrPWZOhipHt         0.647   0.766    6    -4.803     1
# ..                     ...           ...     ...  ...       ...   ...
# 75  5JVA0t7r2Y7m9NaHmgaeiC         0.550   0.750    0    -3.289     1
# 76  2bgTY4UwhfBYhGT4HUYStN         0.759   0.459    8    -5.187     1
# 77  3SWjpNMVUi5UXz096NbfPr         0.518   0.799    8    -4.316     1
# 78  2USlegnFJLrVLpoVfPimKB         0.670   0.896    1    -4.673     1
# 79  5cqLFudVQryezmVFmmyRJN         0.618   0.698   10    -5.362     0
#
#     speechiness  acousticness  instrumentalness  liveness  valence    tempo  \
# 0        0.1170       0.02970          0.000127    0.1030    0.494  123.988
# 1        0.0491       0.00406          0.003130    0.0904    0.702  100.015
# 2        0.0504       0.00335          0.000000    0.1380    0.503   99.999
# 3        0.0561       0.43600          0.093800    0.0549    0.443  119.900
# 4        0.0389       0.00702          0.000000    0.0960    0.550   95.016
# ..          ...           ...               ...       ...      ...      ...
# 75       0.1460       0.05610          0.000000    0.1290    0.381  172.124
# 76       0.0948       0.00323          0.000000    0.0906    0.695  109.997
# 77       0.1230       0.01460          0.000189    0.7870    0.882   92.020
# 78       0.0580       0.03420          0.000032    0.3440    0.403  101.216
# 79       0.2720       0.18100          0.000000    0.1540    0.784  178.143
#
#     time_signature
# 0                4
# 1                4
# 2                4
# 3                3
# 4                4
# ..             ...
# 75               4
# 76               4
# 77               4
# 78               3
# 79               4
#
# [80 rows x 15 columns]

# %%
def make_audio_features_df_from_playlistID(playlist_id):
    
    def get_playlist_tracks(playlist_id):
        results = sp.user_playlist_tracks("spotify",playlist_id)
        tracks = results['items']
        while results['next']!=None:
            results = sp.next(results)
            tracks = tracks + results['items']
            sleep(randint(1,3))
        return tracks
    
    def flatten(input_list):
        return [item for sublist in input_list for item in sublist]

    def get_details_from_track(track):
        return flatten((track["name"],artist["name"], track["uri"]) for artist in track["artists"])

    def get_details_from_playlist_item(playlist_item):
        return get_details_from_track(playlist_item['track'])

    def get_details_from_playlist(input_playlist):
        return list(map(get_details_from_playlist_item,input_playlist))
    
    def make_df_from_playlist_details(playlist_details):
        titles = [song[0] for song in playlist_details]
        artists = [song[1] for song in playlist_details]
        uris = [song[2] for song in playlist_details]
        return pd.DataFrame({'title':titles, 'artist':artists, 'uri':uris})
    
    playlist = get_playlist_tracks(playlist_id)
    details = get_details_from_playlist(playlist)
    df = make_df_from_playlist_details(details)
    
    audio_features = ['danceability', 'energy', 'key', 'loudness', 'mode', 'speechiness', 'acousticness', 'instrumentalness', 
            'liveness', 'valence', 'tempo', 'time_signature']

    def add_audio_features(df):
        df['features'] = None
        for i in range(len(df)):
            song_features = sp.audio_features(df.uri[i])
            df['features'][i] = song_features[0]
            sleep(randint(1,3))
        for f in audio_features:
            df[f] = [df['features'][i][f] for i in range(len(df))]
        df.drop(['features'], axis=1, inplace=True)
        return df
    
    df_with_audio_features = add_audio_features(df)
    
    return df_with_audio_features

# %%
def make_audio_features_df_from_playlistID(playlist_id):
    
    playlist = get_playlist_tracks(playlist_id)
    details = get_details_from_playlist(playlist)
    df = make_df_from_playlist_details(details)
    
    audio_features = ['danceability', 'energy', 'key', 'loudness', 'mode', 'speechiness', 'acousticness', 'instrumentalness', 
            'liveness', 'valence', 'tempo', 'time_signature']
    
    df_with_audio_features = add_audio_features(df)
    
    return df_with_audio_features

# %%
def add_playlist(playlist_id, songs_df):
    df = make_audio_features_df_from_playlistID(playlist_id)
    new_df = pd.concat([songs_df, df], axis=0)
    new_df.drop_duplicates(subset=['title'], keep='first', inplace=True)
    new_df.reset_index(inplace=True, drop=True)
    return new_df
