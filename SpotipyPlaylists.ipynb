# %%
#!pip install spotipy

# %%
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials

# %%
secrets_file = open("SpotifySecret.txt","r")

# %%
string = secrets_file.read()

# %%
string.split('\n')
# Out:
# ['cid:da00ed264eaf4f94ba2adf23ff058567',
#  'cs:80b98527a70043438b54ed1ce6460e5c',
#  '']

# %%
secrets_dict={}
for line in string.split('\n'):
    if len(line)>0:
        secrets_dict[line.split(':')[0]]=line.split(':')[1]

# %%
secrets_dict
# Out:
# {'cid': 'da00ed264eaf4f94ba2adf23ff058567',
#  'cs': '80b98527a70043438b54ed1ce6460e5c'}

# %%
sp = spotipy.Spotify(auth_manager=SpotifyClientCredentials(client_id=secrets_dict['cid'],client_secret=secrets_dict['cs']))

# %%
results = sp.search(q='The Cure',limit=50)
results
# Out:
# {'tracks': {'href': 'https://api.spotify.com/v1/search?query=The+Cure&type=track&offset=0&limit=50',
#   'items': [{'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1HY2Jd0NmPuamShAr6KMms'},
#        'href': 'https://api.spotify.com/v1/artists/1HY2Jd0NmPuamShAr6KMms',
#        'id': '1HY2Jd0NmPuamShAr6KMms',
#        'name': 'Lady Gaga',
#        'type': 'artist',
#        'uri': 'spotify:artist:1HY2Jd0NmPuamShAr6KMms'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AO',
#       'AR',
#       'AT',
#       'AU',
#       'AZ',
#       'BA',
#       'BB',
#       'BD',
#       'BE',
#       'BF',
#       'BG',
#       'BH',
#       'BI',
#       'BJ',
#       'BN',
#       'BO',
#       'BR',
#       'BS',
#       'BT',
#       'BW',
#       'BY',
#       'BZ',
#       'CA',
#       'CD',
#       'CG',
#       'CH',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CV',
#       'CW',
#       'CY',
#       'CZ',
#       'DE',
#       'DJ',
#       'DK',
#       'DM',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FJ',
#       'FM',
#       'FR',
#       'GA',
#       'GB',
#       'GD',
#       'GE',
#       'GH',
#       'GM',
#       'GN',
#       'GQ',
#       'GR',
#       'GT',
#       'GW',
#       'GY',
#       'HK',
#       'HN',
#       'HR',
#       'HT',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IQ',
#       'IS',
#       'IT',
#       'JM',
#       'JO',
#       'JP',
#       'KE',
#       'KG',
#       'KH',
#       'KI',
#       'KM',
#       'KN',
#       'KR',
#       'KW',
#       'KZ',
#       'LA',
#       'LB',
#       'LC',
#       'LI',
#       'LK',
#       'LR',
#       'LS',
#       'LT',
#       'LU',
#       'LV',
#       'LY',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MG',
#       'MH',
#       'MK',
#       'ML',
#       'MN',
#       'MO',
#       'MR',
#       'MT',
#       'MU',
#       'MV',
#       'MW',
#       'MX',
#       'MY',
#       'MZ',
#       'NA',
#       'NE',
#       'NG',
#       'NI',
#       'NL',
#       'NO',
#       'NP',
#       'NR',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PG',
#       'PH',
#       'PK',
#       'PL',
#       'PS',
#       'PT',
#       'PW',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RW',
#       'SA',
#       'SB',
#       'SC',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SL',
#       'SM',
#       'SN',
#       'SR',
#       'ST',
#       'SV',
#       'SZ',
#       'TD',
#       'TG',
#       'TH',
#       'TJ',
#       'TL',
#       'TN',
#       'TO',
#       'TR',
#       'TT',
#       'TV',
#       'TW',
#       'TZ',
#       'UA',
#       'UG',
#       'US',
#       'UY',
#       'UZ',
#       'VC',
#       'VE',
#       'VN',
#       'VU',
#       'WS',
#       'XK',
#       'ZA',
#       'ZM',
#       'ZW'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/2yaSZnZhaxsbQ5xhgGbw3g'},
#      'href': 'https://api.spotify.com/v1/albums/2yaSZnZhaxsbQ5xhgGbw3g',
#      'id': '2yaSZnZhaxsbQ5xhgGbw3g',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b27331cc5716a5c922b0482787b7',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e0231cc5716a5c922b0482787b7',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d0000485131cc5716a5c922b0482787b7',
#        'width': 64}],
#      'name': 'The Cure',
#      'release_date': '2017-04-16',
#      'release_date_precision': 'day',
#      'total_tracks': 1,
#      'type': 'album',
#      'uri': 'spotify:album:2yaSZnZhaxsbQ5xhgGbw3g'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1HY2Jd0NmPuamShAr6KMms'},
#       'href': 'https://api.spotify.com/v1/artists/1HY2Jd0NmPuamShAr6KMms',
#       'id': '1HY2Jd0NmPuamShAr6KMms',
#       'name': 'Lady Gaga',
#       'type': 'artist',
#       'uri': 'spotify:artist:1HY2Jd0NmPuamShAr6KMms'}],
#     'available_markets': ['AD',
#      'AE',
#      'AG',
#      'AL',
#      'AM',
#      'AO',
#      'AR',
#      'AT',
#      'AU',
#      'AZ',
#      'BA',
#      'BB',
#      'BD',
#      'BE',
#      'BF',
#      'BG',
#      'BH',
#      'BI',
#      'BJ',
#      'BN',
#      'BO',
#      'BR',
#      'BS',
#      'BT',
#      'BW',
#      'BY',
#      'BZ',
#      'CA',
#      'CD',
#      'CG',
#      'CH',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CV',
#      'CW',
#      'CY',
#      'CZ',
#      'DE',
#      'DJ',
#      'DK',
#      'DM',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FJ',
#      'FM',
#      'FR',
#      'GA',
#      'GB',
#      'GD',
#      'GE',
#      'GH',
#      'GM',
#      'GN',
#      'GQ',
#      'GR',
#      'GT',
#      'GW',
#      'GY',
#      'HK',
#      'HN',
#      'HR',
#      'HT',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IQ',
#      'IS',
#      'IT',
#      'JM',
#      'JO',
#      'JP',
#      'KE',
#      'KG',
#      'KH',
#      'KI',
#      'KM',
#      'KN',
#      'KR',
#      'KW',
#      'KZ',
#      'LA',
#      'LB',
#      'LC',
#      'LI',
#      'LK',
#      'LR',
#      'LS',
#      'LT',
#      'LU',
#      'LV',
#      'LY',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MG',
#      'MH',
#      'MK',
#      'ML',
#      'MN',
#      'MO',
#      'MR',
#      'MT',
#      'MU',
#      'MV',
#      'MW',
#      'MX',
#      'MY',
#      'MZ',
#      'NA',
#      'NE',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NP',
#      'NR',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PG',
#      'PH',
#      'PK',
#      'PL',
#      'PS',
#      'PT',
#      'PW',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RW',
#      'SA',
#      'SB',
#      'SC',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SL',
#      'SM',
#      'SN',
#      'SR',
#      'ST',
#      'SV',
#      'SZ',
#      'TD',
#      'TG',
#      'TH',
#      'TJ',
#      'TL',
#      'TN',
#      'TO',
#      'TR',
#      'TT',
#      'TV',
#      'TW',
#      'TZ',
#      'UA',
#      'UG',
#      'US',
#      'UY',
#      'UZ',
#      'VC',
#      'VE',
#      'VN',
#      'VU',
#      'WS',
#      'XK',
#      'ZA',
#      'ZM',
#      'ZW'],
#     'disc_number': 1,
#     'duration_ms': 211363,
#     'explicit': False,
#     'external_ids': {'isrc': 'USUM71703782'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/34oB5r0lcN3fYWCs2uA1k5'},
#     'href': 'https://api.spotify.com/v1/tracks/34oB5r0lcN3fYWCs2uA1k5',
#     'id': '34oB5r0lcN3fYWCs2uA1k5',
#     'is_local': False,
#     'name': 'The Cure',
#     'popularity': 67,
#     'preview_url': 'https://p.scdn.co/mp3-preview/75aa09f7973992a4f30e286afd60f316e462cb99?cid=da00ed264eaf4f94ba2adf23ff058567',
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:34oB5r0lcN3fYWCs2uA1k5'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7bu3H8JO7d0UbMoVzbo70s'},
#        'href': 'https://api.spotify.com/v1/artists/7bu3H8JO7d0UbMoVzbo70s',
#        'id': '7bu3H8JO7d0UbMoVzbo70s',
#        'name': 'The Cure',
#        'type': 'artist',
#        'uri': 'spotify:artist:7bu3H8JO7d0UbMoVzbo70s'}],
#      'available_markets': ['CA', 'US'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/37Q22g0n9PzBLX6lNddrIa'},
#      'href': 'https://api.spotify.com/v1/albums/37Q22g0n9PzBLX6lNddrIa',
#      'id': '37Q22g0n9PzBLX6lNddrIa',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2737f22337546d61faca55e0f4f',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e027f22337546d61faca55e0f4f',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048517f22337546d61faca55e0f4f',
#        'width': 64}],
#      'name': 'Kiss Me, Kiss Me, Kiss Me',
#      'release_date': '1987-05-25',
#      'release_date_precision': 'day',
#      'total_tracks': 17,
#      'type': 'album',
#      'uri': 'spotify:album:37Q22g0n9PzBLX6lNddrIa'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7bu3H8JO7d0UbMoVzbo70s'},
#       'href': 'https://api.spotify.com/v1/artists/7bu3H8JO7d0UbMoVzbo70s',
#       'id': '7bu3H8JO7d0UbMoVzbo70s',
#       'name': 'The Cure',
#       'type': 'artist',
#       'uri': 'spotify:artist:7bu3H8JO7d0UbMoVzbo70s'}],
#     'available_markets': ['CA', 'US'],
#     'disc_number': 1,
#     'duration_ms': 212000,
#     'explicit': False,
#     'external_ids': {'isrc': 'USEE18700009'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/76GlO5H5RT6g7y0gev86Nk'},
#     'href': 'https://api.spotify.com/v1/tracks/76GlO5H5RT6g7y0gev86Nk',
#     'id': '76GlO5H5RT6g7y0gev86Nk',
#     'is_local': False,
#     'name': 'Just like Heaven',
#     'popularity': 70,
#     'preview_url': 'https://p.scdn.co/mp3-preview/ef101f28ecd0df21cc7726ee48c1e6c7879f7d48?cid=da00ed264eaf4f94ba2adf23ff058567',
#     'track_number': 8,
#     'type': 'track',
#     'uri': 'spotify:track:76GlO5H5RT6g7y0gev86Nk'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6h4DZCXvwXapWw1C2vygaC'},
#        'href': 'https://api.spotify.com/v1/artists/6h4DZCXvwXapWw1C2vygaC',
#        'id': '6h4DZCXvwXapWw1C2vygaC',
#        'name': 'Sam Lans!',
#        'type': 'artist',
#        'uri': 'spotify:artist:6h4DZCXvwXapWw1C2vygaC'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AM',
#       'AO',
#       'AR',
#       'AT',
#       'AU',
#       'AZ',
#       'BB',
#       'BD',
#       'BE',
#       'BF',
#       'BG',
#       'BH',
#       'BI',
#       'BJ',
#       'BN',
#       'BO',
#       'BR',
#       'BS',
#       'BT',
#       'BW',
#       'BZ',
#       'CA',
#       'CG',
#       'CH',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CV',
#       'CW',
#       'CY',
#       'CZ',
#       'DE',
#       'DJ',
#       'DK',
#       'DM',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FJ',
#       'FM',
#       'FR',
#       'GA',
#       'GB',
#       'GD',
#       'GE',
#       'GH',
#       'GM',
#       'GN',
#       'GQ',
#       'GR',
#       'GT',
#       'GW',
#       'GY',
#       'HK',
#       'HN',
#       'HT',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JM',
#       'JO',
#       'JP',
#       'KE',
#       'KG',
#       'KH',
#       'KI',
#       'KM',
#       'KN',
#       'KR',
#       'KW',
#       'KZ',
#       'LA',
#       'LB',
#       'LC',
#       'LI',
#       'LK',
#       'LS',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'MG',
#       'MH',
#       'ML',
#       'MN',
#       'MO',
#       'MR',
#       'MT',
#       'MU',
#       'MV',
#       'MW',
#       'MX',
#       'MY',
#       'MZ',
#       'NA',
#       'NE',
#       'NG',
#       'NI',
#       'NL',
#       'NO',
#       'NP',
#       'NR',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PG',
#       'PH',
#       'PK',
#       'PL',
#       'PS',
#       'PT',
#       'PW',
#       'PY',
#       'QA',
#       'RO',
#       'RW',
#       'SA',
#       'SB',
#       'SC',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SL',
#       'SM',
#       'SN',
#       'SR',
#       'ST',
#       'SV',
#       'SZ',
#       'TD',
#       'TG',
#       'TH',
#       'TJ',
#       'TL',
#       'TN',
#       'TO',
#       'TR',
#       'TT',
#       'TV',
#       'TW',
#       'TZ',
#       'UA',
#       'UG',
#       'US',
#       'UY',
#       'UZ',
#       'VC',
#       'VE',
#       'VN',
#       'VU',
#       'WS',
#       'ZA',
#       'ZM'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/09F3pYMyjgdEj2rOD4aZhx'},
#      'href': 'https://api.spotify.com/v1/albums/09F3pYMyjgdEj2rOD4aZhx',
#      'id': '09F3pYMyjgdEj2rOD4aZhx',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273eae50582ee86f25f5504abd5',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02eae50582ee86f25f5504abd5',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851eae50582ee86f25f5504abd5',
#        'width': 64}],
#      'name': 'Mk Ultra',
#      'release_date': '2017-10-06',
#      'release_date_precision': 'day',
#      'total_tracks': 13,
#      'type': 'album',
#      'uri': 'spotify:album:09F3pYMyjgdEj2rOD4aZhx'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6h4DZCXvwXapWw1C2vygaC'},
#       'href': 'https://api.spotify.com/v1/artists/6h4DZCXvwXapWw1C2vygaC',
#       'id': '6h4DZCXvwXapWw1C2vygaC',
#       'name': 'Sam Lans!',
#       'type': 'artist',
#       'uri': 'spotify:artist:6h4DZCXvwXapWw1C2vygaC'}],
#     'available_markets': ['AD',
#      'AE',
#      'AG',
#      'AM',
#      'AO',
#      'AR',
#      'AT',
#      'AU',
#      'AZ',
#      'BB',
#      'BD',
#      'BE',
#      'BF',
#      'BG',
#      'BH',
#      'BI',
#      'BJ',
#      'BN',
#      'BO',
#      'BR',
#      'BS',
#      'BT',
#      'BW',
#      'BZ',
#      'CA',
#      'CG',
#      'CH',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CV',
#      'CW',
#      'CY',
#      'CZ',
#      'DE',
#      'DJ',
#      'DK',
#      'DM',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FJ',
#      'FM',
#      'FR',
#      'GA',
#      'GB',
#      'GD',
#      'GE',
#      'GH',
#      'GM',
#      'GN',
#      'GQ',
#      'GR',
#      'GT',
#      'GW',
#      'GY',
#      'HK',
#      'HN',
#      'HT',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JM',
#      'JO',
#      'JP',
#      'KE',
#      'KG',
#      'KH',
#      'KI',
#      'KM',
#      'KN',
#      'KR',
#      'KW',
#      'KZ',
#      'LA',
#      'LB',
#      'LC',
#      'LI',
#      'LK',
#      'LS',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'MG',
#      'MH',
#      'ML',
#      'MN',
#      'MO',
#      'MR',
#      'MT',
#      'MU',
#      'MV',
#      'MW',
#      'MX',
#      'MY',
#      'MZ',
#      'NA',
#      'NE',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NP',
#      'NR',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PG',
#      'PH',
#      'PK',
#      'PL',
#      'PS',
#      'PT',
#      'PW',
#      'PY',
#      'QA',
#      'RO',
#      'RW',
#      'SA',
#      'SB',
#      'SC',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SL',
#      'SM',
#      'SN',
#      'SR',
#      'ST',
#      'SV',
#      'SZ',
#      'TD',
#      'TG',
#      'TH',
#      'TJ',
#      'TL',
#      'TN',
#      'TO',
#      'TR',
#      'TT',
#      'TV',
#      'TW',
#      'TZ',
#      'UA',
#      'UG',
#      'US',
#      'UY',
#      'UZ',
#      'VC',
#      'VE',
#      'VN',
#      'VU',
#      'WS',
#      'ZA',
#      'ZM'],
#     'disc_number': 1,
#     'duration_ms': 186959,
#     'explicit': True,
#     'external_ids': {'isrc': 'TCADJ1714578'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/3EeKXJWkNTQTqqzRehTG7H'},
#     'href': 'https://api.spotify.com/v1/tracks/3EeKXJWkNTQTqqzRehTG7H',
#     'id': '3EeKXJWkNTQTqqzRehTG7H',
#     'is_local': False,
#     'name': 'The Cure',
#     'popularity': 59,
#     'preview_url': 'https://p.scdn.co/mp3-preview/dd9cb0ba5f9ef3f9a62414bedcc8f9089927c3aa?cid=da00ed264eaf4f94ba2adf23ff058567',
#     'track_number': 13,
#     'type': 'track',
#     'uri': 'spotify:track:3EeKXJWkNTQTqqzRehTG7H'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7bu3H8JO7d0UbMoVzbo70s'},
#        'href': 'https://api.spotify.com/v1/artists/7bu3H8JO7d0UbMoVzbo70s',
#        'id': '7bu3H8JO7d0UbMoVzbo70s',
#        'name': 'The Cure',
#        'type': 'artist',
#        'uri': 'spotify:artist:7bu3H8JO7d0UbMoVzbo70s'}],
#      'available_markets': ['CA', 'US'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/3x1CmNdXWU0DzpTZXFFRZu'},
#      'href': 'https://api.spotify.com/v1/albums/3x1CmNdXWU0DzpTZXFFRZu',
#      'id': '3x1CmNdXWU0DzpTZXFFRZu',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273e410fa31e3dfcc7521cde86d',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02e410fa31e3dfcc7521cde86d',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851e410fa31e3dfcc7521cde86d',
#        'width': 64}],
#      'name': 'Wish',
#      'release_date': '1992-04-21',
#      'release_date_precision': 'day',
#      'total_tracks': 12,
#      'type': 'album',
#      'uri': 'spotify:album:3x1CmNdXWU0DzpTZXFFRZu'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7bu3H8JO7d0UbMoVzbo70s'},
#       'href': 'https://api.spotify.com/v1/artists/7bu3H8JO7d0UbMoVzbo70s',
#       'id': '7bu3H8JO7d0UbMoVzbo70s',
#       'name': 'The Cure',
#       'type': 'artist',
#       'uri': 'spotify:artist:7bu3H8JO7d0UbMoVzbo70s'}],
#     'available_markets': ['CA', 'US'],
#     'disc_number': 1,
#     'duration_ms': 214400,
#     'explicit': False,
#     'external_ids': {'isrc': 'USEE10180267'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/263aNAQCeFSWipk896byo6'},
#     'href': 'https://api.spotify.com/v1/tracks/263aNAQCeFSWipk896byo6',
#     'id': '263aNAQCeFSWipk896byo6',
#     'is_local': False,
#     'name': "Friday I'm in Love",
#     'popularity': 70,
#     'preview_url': 'https://p.scdn.co/mp3-preview/958e347444599fa593cb2d86459e67ad18719c72?cid=da00ed264eaf4f94ba2adf23ff058567',
#     'track_number': 7,
#     'type': 'track',
#     'uri': 'spotify:track:263aNAQCeFSWipk896byo6'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1WgXqy2Dd70QQOU7Ay074N'},
#        'href': 'https://api.spotify.com/v1/artists/1WgXqy2Dd70QQOU7Ay074N',
#        'id': '1WgXqy2Dd70QQOU7Ay074N',
#        'name': 'AURORA',
#        'type': 'artist',
#        'uri': 'spotify:artist:1WgXqy2Dd70QQOU7Ay074N'}],
#      'available_markets': ['AG',
#       'AU',
#       'BB',
#       'BS',
#       'BZ',
#       'CA',
#       'CR',
#       'CW',
#       'DM',
#       'DO',
#       'GD',
#       'GT',
#       'HN',
#       'HT',
#       'JM',
#       'KN',
#       'LC',
#       'MX',
#       'NI',
#       'NZ',
#       'PA',
#       'SV',
#       'TT',
#       'US',
#       'VC',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/5z1xjvymitc0DJETtvVmaX'},
#      'href': 'https://api.spotify.com/v1/albums/5z1xjvymitc0DJETtvVmaX',
#      'id': '5z1xjvymitc0DJETtvVmaX',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b27313e38f3da42937aba61956f0',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e0213e38f3da42937aba61956f0',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d0000485113e38f3da42937aba61956f0',
#        'width': 64}],
#      'name': 'The Gods We Can Touch',
#      'release_date': '2022-01-21',
#      'release_date_precision': 'day',
#      'total_tracks': 15,
#      'type': 'album',
#      'uri': 'spotify:album:5z1xjvymitc0DJETtvVmaX'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1WgXqy2Dd70QQOU7Ay074N'},
#       'href': 'https://api.spotify.com/v1/artists/1WgXqy2Dd70QQOU7Ay074N',
#       'id': '1WgXqy2Dd70QQOU7Ay074N',
#       'name': 'AURORA',
#       'type': 'artist',
#       'uri': 'spotify:artist:1WgXqy2Dd70QQOU7Ay074N'}],
#     'available_markets': ['AG',
#      'AU',
#      'BB',
#      'BS',
#      'BZ',
#      'CA',
#      'CR',
#      'CW',
#      'DM',
#      'DO',
#      'GD',
#      'GT',
#      'HN',
#      'HT',
#      'JM',
#      'KN',
#      'LC',
#      'MX',
#      'NI',
#      'NZ',
#      'PA',
#      'SV',
#      'TT',
#      'US',
#      'VC',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 201640,
#     'explicit': False,
#     'external_ids': {'isrc': 'GBUM72100848'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/33WTgxRdPBQQpVCMXpNxhO'},
#     'href': 'https://api.spotify.com/v1/tracks/33WTgxRdPBQQpVCMXpNxhO',
#     'id': '33WTgxRdPBQQpVCMXpNxhO',
#     'is_local': False,
#     'name': 'Cure For Me',
#     'popularity': 70,
#     'preview_url': 'https://p.scdn.co/mp3-preview/9b1b3f299c3474ee7b660db915904c2adfd58706?cid=da00ed264eaf4f94ba2adf23ff058567',
#     'track_number': 4,
#     'type': 'track',
#     'uri': 'spotify:track:33WTgxRdPBQQpVCMXpNxhO'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7bu3H8JO7d0UbMoVzbo70s'},
#        'href': 'https://api.spotify.com/v1/artists/7bu3H8JO7d0UbMoVzbo70s',
#        'id': '7bu3H8JO7d0UbMoVzbo70s',
#        'name': 'The Cure',
#        'type': 'artist',
#        'uri': 'spotify:artist:7bu3H8JO7d0UbMoVzbo70s'}],
#      'available_markets': ['CA', 'US'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/6vQB3ZBxnQPP3jQcGV2qzg'},
#      'href': 'https://api.spotify.com/v1/albums/6vQB3ZBxnQPP3jQcGV2qzg',
#      'id': '6vQB3ZBxnQPP3jQcGV2qzg',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273c7ca2db25ad377e022bc3975',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02c7ca2db25ad377e022bc3975',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851c7ca2db25ad377e022bc3975',
#        'width': 64}],
#      'name': 'Disintegration (Deluxe Edition)',
#      'release_date': '1989-05-02',
#      'release_date_precision': 'day',
#      'total_tracks': 44,
#      'type': 'album',
#      'uri': 'spotify:album:6vQB3ZBxnQPP3jQcGV2qzg'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7bu3H8JO7d0UbMoVzbo70s'},
#       'href': 'https://api.spotify.com/v1/artists/7bu3H8JO7d0UbMoVzbo70s',
#       'id': '7bu3H8JO7d0UbMoVzbo70s',
#       'name': 'The Cure',
#       'type': 'artist',
#       'uri': 'spotify:artist:7bu3H8JO7d0UbMoVzbo70s'}],
#     'available_markets': ['CA', 'US'],
#     'disc_number': 1,
#     'duration_ms': 209573,
#     'explicit': False,
#     'external_ids': {'isrc': 'USEE10901455'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/0X5C4WjQNubRysTkHOubz3'},
#     'href': 'https://api.spotify.com/v1/tracks/0X5C4WjQNubRysTkHOubz3',
#     'id': '0X5C4WjQNubRysTkHOubz3',
#     'is_local': False,
#     'name': 'Lovesong - 2010 Remaster',
#     'popularity': 63,
#     'preview_url': 'https://p.scdn.co/mp3-preview/f9b7d686922b260b092b2c8e5186d40e2c63fd06?cid=da00ed264eaf4f94ba2adf23ff058567',
#     'track_number': 4,
#     'type': 'track',
#     'uri': 'spotify:track:0X5C4WjQNubRysTkHOubz3'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7bu3H8JO7d0UbMoVzbo70s'},
#        'href': 'https://api.spotify.com/v1/artists/7bu3H8JO7d0UbMoVzbo70s',
#        'id': '7bu3H8JO7d0UbMoVzbo70s',
#        'name': 'The Cure',
#        'type': 'artist',
#        'uri': 'spotify:artist:7bu3H8JO7d0UbMoVzbo70s'}],
#      'available_markets': ['CA', 'US'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/7gPql7GFpBMOxeO80vMMsC'},
#      'href': 'https://api.spotify.com/v1/albums/7gPql7GFpBMOxeO80vMMsC',
#      'id': '7gPql7GFpBMOxeO80vMMsC',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2735d0d65102be8606e439e54cc',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e025d0d65102be8606e439e54cc',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048515d0d65102be8606e439e54cc',
#        'width': 64}],
#      'name': 'Three Imaginary Boys (Deluxe Edition)',
#      'release_date': '1979-05-11',
#      'release_date_precision': 'day',
#      'total_tracks': 33,
#      'type': 'album',
#      'uri': 'spotify:album:7gPql7GFpBMOxeO80vMMsC'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7bu3H8JO7d0UbMoVzbo70s'},
#       'href': 'https://api.spotify.com/v1/artists/7bu3H8JO7d0UbMoVzbo70s',
#       'id': '7bu3H8JO7d0UbMoVzbo70s',
#       'name': 'The Cure',
#       'type': 'artist',
#       'uri': 'spotify:artist:7bu3H8JO7d0UbMoVzbo70s'}],
#     'available_markets': ['CA', 'US'],
#     'disc_number': 1,
#     'duration_ms': 157533,
#     'explicit': False,
#     'external_ids': {'isrc': 'USEE10413404'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/4dneV7C1yDt9UtyxrQY375'},
#     'href': 'https://api.spotify.com/v1/tracks/4dneV7C1yDt9UtyxrQY375',
#     'id': '4dneV7C1yDt9UtyxrQY375',
#     'is_local': False,
#     'name': "Boys Don't Cry - Single Version",
#     'popularity': 67,
#     'preview_url': 'https://p.scdn.co/mp3-preview/7fedf0d2730a71fcc3870f4e09ec4d5464969414?cid=da00ed264eaf4f94ba2adf23ff058567',
#     'track_number': 29,
#     'type': 'track',
#     'uri': 'spotify:track:4dneV7C1yDt9UtyxrQY375'},
#    {'album': {'album_type': 'compilation',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7bu3H8JO7d0UbMoVzbo70s'},
#        'href': 'https://api.spotify.com/v1/artists/7bu3H8JO7d0UbMoVzbo70s',
#        'id': '7bu3H8JO7d0UbMoVzbo70s',
#        'name': 'The Cure',
#        'type': 'artist',
#        'uri': 'spotify:artist:7bu3H8JO7d0UbMoVzbo70s'}],
#      'available_markets': ['CA', 'US'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/34ozkv3AkFksZD8srOmOrX'},
#      'href': 'https://api.spotify.com/v1/albums/34ozkv3AkFksZD8srOmOrX',
#      'id': '34ozkv3AkFksZD8srOmOrX',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2730447ba639949dd26478decf6',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e020447ba639949dd26478decf6',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048510447ba639949dd26478decf6',
#        'width': 64}],
#      'name': 'Greatest Hits',
#      'release_date': '2001-11-13',
#      'release_date_precision': 'day',
#      'total_tracks': 18,
#      'type': 'album',
#      'uri': 'spotify:album:34ozkv3AkFksZD8srOmOrX'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7bu3H8JO7d0UbMoVzbo70s'},
#       'href': 'https://api.spotify.com/v1/artists/7bu3H8JO7d0UbMoVzbo70s',
#       'id': '7bu3H8JO7d0UbMoVzbo70s',
#       'name': 'The Cure',
#       'type': 'artist',
#       'uri': 'spotify:artist:7bu3H8JO7d0UbMoVzbo70s'}],
#     'available_markets': ['CA', 'US'],
#     'disc_number': 1,
#     'duration_ms': 208333,
#     'explicit': False,
#     'external_ids': {'isrc': 'GBALB8900003'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/7K71priwuwcWwbgfHVQJdq'},
#     'href': 'https://api.spotify.com/v1/tracks/7K71priwuwcWwbgfHVQJdq',
#     'id': '7K71priwuwcWwbgfHVQJdq',
#     'is_local': False,
#     'name': 'Lovesong',
#     'popularity': 52,
#     'preview_url': 'https://p.scdn.co/mp3-preview/20f86da3c82de45a2f1800970976f4bb7975f951?cid=da00ed264eaf4f94ba2adf23ff058567',
#     'track_number': 11,
#     'type': 'track',
#     'uri': 'spotify:track:7K71priwuwcWwbgfHVQJdq'},
#    {'album': {'album_type': 'compilation',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7bu3H8JO7d0UbMoVzbo70s'},
#        'href': 'https://api.spotify.com/v1/artists/7bu3H8JO7d0UbMoVzbo70s',
#        'id': '7bu3H8JO7d0UbMoVzbo70s',
#        'name': 'The Cure',
#        'type': 'artist',
#        'uri': 'spotify:artist:7bu3H8JO7d0UbMoVzbo70s'}],
#      'available_markets': ['CA', 'US'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/34ozkv3AkFksZD8srOmOrX'},
#      'href': 'https://api.spotify.com/v1/albums/34ozkv3AkFksZD8srOmOrX',
#      'id': '34ozkv3AkFksZD8srOmOrX',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2730447ba639949dd26478decf6',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e020447ba639949dd26478decf6',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048510447ba639949dd26478decf6',
#        'width': 64}],
#      'name': 'Greatest Hits',
#      'release_date': '2001-11-13',
#      'release_date_precision': 'day',
#      'total_tracks': 18,
#      'type': 'album',
#      'uri': 'spotify:album:34ozkv3AkFksZD8srOmOrX'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7bu3H8JO7d0UbMoVzbo70s'},
#       'href': 'https://api.spotify.com/v1/artists/7bu3H8JO7d0UbMoVzbo70s',
#       'id': '7bu3H8JO7d0UbMoVzbo70s',
#       'name': 'The Cure',
#       'type': 'artist',
#       'uri': 'spotify:artist:7bu3H8JO7d0UbMoVzbo70s'}],
#     'available_markets': ['CA', 'US'],
#     'disc_number': 1,
#     'duration_ms': 157053,
#     'explicit': False,
#     'external_ids': {'isrc': 'GBALB7800001'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/2RKDbMwtJgKc76H9oPo7Cl'},
#     'href': 'https://api.spotify.com/v1/tracks/2RKDbMwtJgKc76H9oPo7Cl',
#     'id': '2RKDbMwtJgKc76H9oPo7Cl',
#     'is_local': False,
#     'name': "Boys Don't Cry",
#     'popularity': 60,
#     'preview_url': 'https://p.scdn.co/mp3-preview/9e77982ee6467aa9430fa5ee44e010313b21e85b?cid=da00ed264eaf4f94ba2adf23ff058567',
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:2RKDbMwtJgKc76H9oPo7Cl'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7bu3H8JO7d0UbMoVzbo70s'},
#        'href': 'https://api.spotify.com/v1/artists/7bu3H8JO7d0UbMoVzbo70s',
#        'id': '7bu3H8JO7d0UbMoVzbo70s',
#        'name': 'The Cure',
#        'type': 'artist',
#        'uri': 'spotify:artist:7bu3H8JO7d0UbMoVzbo70s'}],
#      'available_markets': ['CA', 'US'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/6vQB3ZBxnQPP3jQcGV2qzg'},
#      'href': 'https://api.spotify.com/v1/albums/6vQB3ZBxnQPP3jQcGV2qzg',
#      'id': '6vQB3ZBxnQPP3jQcGV2qzg',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273c7ca2db25ad377e022bc3975',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02c7ca2db25ad377e022bc3975',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851c7ca2db25ad377e022bc3975',
#        'width': 64}],
#      'name': 'Disintegration (Deluxe Edition)',
#      'release_date': '1989-05-02',
#      'release_date_precision': 'day',
#      'total_tracks': 44,
#      'type': 'album',
#      'uri': 'spotify:album:6vQB3ZBxnQPP3jQcGV2qzg'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7bu3H8JO7d0UbMoVzbo70s'},
#       'href': 'https://api.spotify.com/v1/artists/7bu3H8JO7d0UbMoVzbo70s',
#       'id': '7bu3H8JO7d0UbMoVzbo70s',
#       'name': 'The Cure',
#       'type': 'artist',
#       'uri': 'spotify:artist:7bu3H8JO7d0UbMoVzbo70s'}],
#     'available_markets': ['CA', 'US'],
#     'disc_number': 1,
#     'duration_ms': 448466,
#     'explicit': False,
#     'external_ids': {'isrc': 'USEE10901453'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/1tuwC1Ob5vnYZhvg3zyzJg'},
#     'href': 'https://api.spotify.com/v1/tracks/1tuwC1Ob5vnYZhvg3zyzJg',
#     'id': '1tuwC1Ob5vnYZhvg3zyzJg',
#     'is_local': False,
#     'name': 'Pictures of You - 2010 Remaster',
#     'popularity': 58,
#     'preview_url': 'https://p.scdn.co/mp3-preview/3fd2102e7fb1fc4b60cb00c39dfa436cb90a4b41?cid=da00ed264eaf4f94ba2adf23ff058567',
#     'track_number': 2,
#     'type': 'track',
#     'uri': 'spotify:track:1tuwC1Ob5vnYZhvg3zyzJg'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7bu3H8JO7d0UbMoVzbo70s'},
#        'href': 'https://api.spotify.com/v1/artists/7bu3H8JO7d0UbMoVzbo70s',
#        'id': '7bu3H8JO7d0UbMoVzbo70s',
#        'name': 'The Cure',
#        'type': 'artist',
#        'uri': 'spotify:artist:7bu3H8JO7d0UbMoVzbo70s'}],
#      'available_markets': ['CA', 'US'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/2KWHRfKSRpgsxNGIl2nQva'},
#      'href': 'https://api.spotify.com/v1/albums/2KWHRfKSRpgsxNGIl2nQva',
#      'id': '2KWHRfKSRpgsxNGIl2nQva',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b27329935216b69c7721582eab4c',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e0229935216b69c7721582eab4c',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d0000485129935216b69c7721582eab4c',
#        'width': 64}],
#      'name': 'Seventeen Seconds',
#      'release_date': '1980-04-18',
#      'release_date_precision': 'day',
#      'total_tracks': 10,
#      'type': 'album',
#      'uri': 'spotify:album:2KWHRfKSRpgsxNGIl2nQva'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7bu3H8JO7d0UbMoVzbo70s'},
#       'href': 'https://api.spotify.com/v1/artists/7bu3H8JO7d0UbMoVzbo70s',
#       'id': '7bu3H8JO7d0UbMoVzbo70s',
#       'name': 'The Cure',
#       'type': 'artist',
#       'uri': 'spotify:artist:7bu3H8JO7d0UbMoVzbo70s'}],
#     'available_markets': ['CA', 'US'],
#     'disc_number': 1,
#     'duration_ms': 184293,
#     'explicit': False,
#     'external_ids': {'isrc': 'USEE10500789'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/6lGRiGJcWg1WiPLi7KoQvq'},
#     'href': 'https://api.spotify.com/v1/tracks/6lGRiGJcWg1WiPLi7KoQvq',
#     'id': '6lGRiGJcWg1WiPLi7KoQvq',
#     'is_local': False,
#     'name': 'M - 2006 Remaster',
#     'popularity': 46,
#     'preview_url': 'https://p.scdn.co/mp3-preview/1033261503363a3963fcee0bb04d661edaed77c1?cid=da00ed264eaf4f94ba2adf23ff058567',
#     'track_number': 8,
#     'type': 'track',
#     'uri': 'spotify:track:6lGRiGJcWg1WiPLi7KoQvq'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7bu3H8JO7d0UbMoVzbo70s'},
#        'href': 'https://api.spotify.com/v1/artists/7bu3H8JO7d0UbMoVzbo70s',
#        'id': '7bu3H8JO7d0UbMoVzbo70s',
#        'name': 'The Cure',
#        'type': 'artist',
#        'uri': 'spotify:artist:7bu3H8JO7d0UbMoVzbo70s'}],
#      'available_markets': ['CA', 'US'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/6HhpmJekzDCRu2K64ZbWqw'},
#      'href': 'https://api.spotify.com/v1/albums/6HhpmJekzDCRu2K64ZbWqw',
#      'id': '6HhpmJekzDCRu2K64ZbWqw',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2731b54add5c2a3a337e512941b',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e021b54add5c2a3a337e512941b',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048511b54add5c2a3a337e512941b',
#        'width': 64}],
#      'name': 'The Head on the Door',
#      'release_date': '1985-08-26',
#      'release_date_precision': 'day',
#      'total_tracks': 10,
#      'type': 'album',
#      'uri': 'spotify:album:6HhpmJekzDCRu2K64ZbWqw'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7bu3H8JO7d0UbMoVzbo70s'},
#       'href': 'https://api.spotify.com/v1/artists/7bu3H8JO7d0UbMoVzbo70s',
#       'id': '7bu3H8JO7d0UbMoVzbo70s',
#       'name': 'The Cure',
#       'type': 'artist',
#       'uri': 'spotify:artist:7bu3H8JO7d0UbMoVzbo70s'}],
#     'available_markets': ['CA', 'US'],
#     'disc_number': 1,
#     'duration_ms': 203266,
#     'explicit': False,
#     'external_ids': {'isrc': 'USEE10608884'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/7ABE6G4uQxbNtYgVrpBBPA'},
#     'href': 'https://api.spotify.com/v1/tracks/7ABE6G4uQxbNtYgVrpBBPA',
#     'id': '7ABE6G4uQxbNtYgVrpBBPA',
#     'is_local': False,
#     'name': 'Close to Me - 2006 Remaster',
#     'popularity': 63,
#     'preview_url': 'https://p.scdn.co/mp3-preview/c296ae38843f51f32552788b1adcb28b872c312f?cid=da00ed264eaf4f94ba2adf23ff058567',
#     'track_number': 7,
#     'type': 'track',
#     'uri': 'spotify:track:7ABE6G4uQxbNtYgVrpBBPA'},
#    {'album': {'album_type': 'compilation',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7bu3H8JO7d0UbMoVzbo70s'},
#        'href': 'https://api.spotify.com/v1/artists/7bu3H8JO7d0UbMoVzbo70s',
#        'id': '7bu3H8JO7d0UbMoVzbo70s',
#        'name': 'The Cure',
#        'type': 'artist',
#        'uri': 'spotify:artist:7bu3H8JO7d0UbMoVzbo70s'}],
#      'available_markets': ['CA', 'US'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/0BRThmbAV1p2CxAuxgpHRj'},
#      'href': 'https://api.spotify.com/v1/albums/0BRThmbAV1p2CxAuxgpHRj',
#      'id': '0BRThmbAV1p2CxAuxgpHRj',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2732780880a9583a363c28c60d5',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e022780880a9583a363c28c60d5',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048512780880a9583a363c28c60d5',
#        'width': 64}],
#      'name': 'Galore',
#      'release_date': '1997-10-17',
#      'release_date_precision': 'day',
#      'total_tracks': 18,
#      'type': 'album',
#      'uri': 'spotify:album:0BRThmbAV1p2CxAuxgpHRj'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7bu3H8JO7d0UbMoVzbo70s'},
#       'href': 'https://api.spotify.com/v1/artists/7bu3H8JO7d0UbMoVzbo70s',
#       'id': '7bu3H8JO7d0UbMoVzbo70s',
#       'name': 'The Cure',
#       'type': 'artist',
#       'uri': 'spotify:artist:7bu3H8JO7d0UbMoVzbo70s'}],
#     'available_markets': ['CA', 'US'],
#     'disc_number': 1,
#     'duration_ms': 288026,
#     'explicit': False,
#     'external_ids': {'isrc': 'USEE19000007'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/5CgHsJyqFuW1U0E3d4Eyi6'},
#     'href': 'https://api.spotify.com/v1/tracks/5CgHsJyqFuW1U0E3d4Eyi6',
#     'id': '5CgHsJyqFuW1U0E3d4Eyi6',
#     'is_local': False,
#     'name': 'Pictures of You',
#     'popularity': 48,
#     'preview_url': 'https://p.scdn.co/mp3-preview/04ee76e1e16d6abefa15e5a67c12f8aaeaa313b7?cid=da00ed264eaf4f94ba2adf23ff058567',
#     'track_number': 8,
#     'type': 'track',
#     'uri': 'spotify:track:5CgHsJyqFuW1U0E3d4Eyi6'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7bu3H8JO7d0UbMoVzbo70s'},
#        'href': 'https://api.spotify.com/v1/artists/7bu3H8JO7d0UbMoVzbo70s',
#        'id': '7bu3H8JO7d0UbMoVzbo70s',
#        'name': 'The Cure',
#        'type': 'artist',
#        'uri': 'spotify:artist:7bu3H8JO7d0UbMoVzbo70s'}],
#      'available_markets': ['CA', 'US'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/4Uq47onfCEj5en94jpHovk'},
#      'href': 'https://api.spotify.com/v1/albums/4Uq47onfCEj5en94jpHovk',
#      'id': '4Uq47onfCEj5en94jpHovk',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b27396e854c582f5213d51793cc2',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e0296e854c582f5213d51793cc2',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d0000485196e854c582f5213d51793cc2',
#        'width': 64}],
#      'name': 'The Head on the Door (Deluxed Edition)',
#      'release_date': '1985-08-26',
#      'release_date_precision': 'day',
#      'total_tracks': 28,
#      'type': 'album',
#      'uri': 'spotify:album:4Uq47onfCEj5en94jpHovk'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7bu3H8JO7d0UbMoVzbo70s'},
#       'href': 'https://api.spotify.com/v1/artists/7bu3H8JO7d0UbMoVzbo70s',
#       'id': '7bu3H8JO7d0UbMoVzbo70s',
#       'name': 'The Cure',
#       'type': 'artist',
#       'uri': 'spotify:artist:7bu3H8JO7d0UbMoVzbo70s'}],
#     'available_markets': ['CA', 'US'],
#     'disc_number': 1,
#     'duration_ms': 177986,
#     'explicit': False,
#     'external_ids': {'isrc': 'USEE10608886'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/07CyrZF9eVd02zzIse7tZA'},
#     'href': 'https://api.spotify.com/v1/tracks/07CyrZF9eVd02zzIse7tZA',
#     'id': '07CyrZF9eVd02zzIse7tZA',
#     'is_local': False,
#     'name': 'In Between Days - 2006 Remaster',
#     'popularity': 59,
#     'preview_url': 'https://p.scdn.co/mp3-preview/21569cc17cecfcfe601ead64427b705c5b220a0b?cid=da00ed264eaf4f94ba2adf23ff058567',
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:07CyrZF9eVd02zzIse7tZA'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7bu3H8JO7d0UbMoVzbo70s'},
#        'href': 'https://api.spotify.com/v1/artists/7bu3H8JO7d0UbMoVzbo70s',
#        'id': '7bu3H8JO7d0UbMoVzbo70s',
#        'name': 'The Cure',
#        'type': 'artist',
#        'uri': 'spotify:artist:7bu3H8JO7d0UbMoVzbo70s'}],
#      'available_markets': ['CA', 'US'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/1T7A6Dt7KktX7pOw4I4Jzj'},
#      'href': 'https://api.spotify.com/v1/albums/1T7A6Dt7KktX7pOw4I4Jzj',
#      'id': '1T7A6Dt7KktX7pOw4I4Jzj',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b27399027d2948260fdb37436d5d',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e0299027d2948260fdb37436d5d',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d0000485199027d2948260fdb37436d5d',
#        'width': 64}],
#      'name': 'Seventeen Seconds (Deluxe Edition)',
#      'release_date': '1980-04-18',
#      'release_date_precision': 'day',
#      'total_tracks': 25,
#      'type': 'album',
#      'uri': 'spotify:album:1T7A6Dt7KktX7pOw4I4Jzj'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7bu3H8JO7d0UbMoVzbo70s'},
#       'href': 'https://api.spotify.com/v1/artists/7bu3H8JO7d0UbMoVzbo70s',
#       'id': '7bu3H8JO7d0UbMoVzbo70s',
#       'name': 'The Cure',
#       'type': 'artist',
#       'uri': 'spotify:artist:7bu3H8JO7d0UbMoVzbo70s'}],
#     'available_markets': ['CA', 'US'],
#     'disc_number': 1,
#     'duration_ms': 354933,
#     'explicit': False,
#     'external_ids': {'isrc': 'USEE10500788'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/3O4TPMOgChXOerSdB5WENH'},
#     'href': 'https://api.spotify.com/v1/tracks/3O4TPMOgChXOerSdB5WENH',
#     'id': '3O4TPMOgChXOerSdB5WENH',
#     'is_local': False,
#     'name': 'A Forest - 2006 Remaster',
#     'popularity': 57,
#     'preview_url': 'https://p.scdn.co/mp3-preview/3cb92ffc0db9c7cd8480ccc28308e26478a52a81?cid=da00ed264eaf4f94ba2adf23ff058567',
#     'track_number': 7,
#     'type': 'track',
#     'uri': 'spotify:track:3O4TPMOgChXOerSdB5WENH'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7bu3H8JO7d0UbMoVzbo70s'},
#        'href': 'https://api.spotify.com/v1/artists/7bu3H8JO7d0UbMoVzbo70s',
#        'id': '7bu3H8JO7d0UbMoVzbo70s',
#        'name': 'The Cure',
#        'type': 'artist',
#        'uri': 'spotify:artist:7bu3H8JO7d0UbMoVzbo70s'}],
#      'available_markets': ['CA', 'US'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/6vQB3ZBxnQPP3jQcGV2qzg'},
#      'href': 'https://api.spotify.com/v1/albums/6vQB3ZBxnQPP3jQcGV2qzg',
#      'id': '6vQB3ZBxnQPP3jQcGV2qzg',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273c7ca2db25ad377e022bc3975',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02c7ca2db25ad377e022bc3975',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851c7ca2db25ad377e022bc3975',
#        'width': 64}],
#      'name': 'Disintegration (Deluxe Edition)',
#      'release_date': '1989-05-02',
#      'release_date_precision': 'day',
#      'total_tracks': 44,
#      'type': 'album',
#      'uri': 'spotify:album:6vQB3ZBxnQPP3jQcGV2qzg'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7bu3H8JO7d0UbMoVzbo70s'},
#       'href': 'https://api.spotify.com/v1/artists/7bu3H8JO7d0UbMoVzbo70s',
#       'id': '7bu3H8JO7d0UbMoVzbo70s',
#       'name': 'The Cure',
#       'type': 'artist',
#       'uri': 'spotify:artist:7bu3H8JO7d0UbMoVzbo70s'}],
#     'available_markets': ['CA', 'US'],
#     'disc_number': 1,
#     'duration_ms': 249880,
#     'explicit': False,
#     'external_ids': {'isrc': 'USEE10901457'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/4d4oXk7O2lEhZ83ivV93li'},
#     'href': 'https://api.spotify.com/v1/tracks/4d4oXk7O2lEhZ83ivV93li',
#     'id': '4d4oXk7O2lEhZ83ivV93li',
#     'is_local': False,
#     'name': 'Lullaby - 2010 Remaster',
#     'popularity': 56,
#     'preview_url': 'https://p.scdn.co/mp3-preview/5e9958a03f344620bd8a4344d8f5160adc6d09aa?cid=da00ed264eaf4f94ba2adf23ff058567',
#     'track_number': 6,
#     'type': 'track',
#     'uri': 'spotify:track:4d4oXk7O2lEhZ83ivV93li'},
#    {'album': {'album_type': 'compilation',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0LyfQWJT6nXafLPZqxe9Of'},
#        'href': 'https://api.spotify.com/v1/artists/0LyfQWJT6nXafLPZqxe9Of',
#        'id': '0LyfQWJT6nXafLPZqxe9Of',
#        'name': 'Various Artists',
#        'type': 'artist',
#        'uri': 'spotify:artist:0LyfQWJT6nXafLPZqxe9Of'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AO',
#       'AR',
#       'AT',
#       'AU',
#       'AZ',
#       'BA',
#       'BB',
#       'BD',
#       'BE',
#       'BF',
#       'BG',
#       'BH',
#       'BI',
#       'BJ',
#       'BN',
#       'BO',
#       'BR',
#       'BS',
#       'BT',
#       'BW',
#       'BY',
#       'BZ',
#       'CA',
#       'CD',
#       'CG',
#       'CH',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CV',
#       'CW',
#       'CY',
#       'CZ',
#       'DE',
#       'DJ',
#       'DK',
#       'DM',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FJ',
#       'FM',
#       'FR',
#       'GA',
#       'GB',
#       'GD',
#       'GE',
#       'GH',
#       'GM',
#       'GN',
#       'GQ',
#       'GR',
#       'GT',
#       'GW',
#       'GY',
#       'HK',
#       'HN',
#       'HR',
#       'HT',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IQ',
#       'IS',
#       'IT',
#       'JM',
#       'JO',
#       'JP',
#       'KE',
#       'KG',
#       'KH',
#       'KI',
#       'KM',
#       'KN',
#       'KR',
#       'KW',
#       'KZ',
#       'LA',
#       'LB',
#       'LC',
#       'LI',
#       'LK',
#       'LR',
#       'LS',
#       'LT',
#       'LU',
#       'LV',
#       'LY',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MG',
#       'MH',
#       'MK',
#       'ML',
#       'MN',
#       'MO',
#       'MR',
#       'MT',
#       'MU',
#       'MV',
#       'MW',
#       'MX',
#       'MY',
#       'MZ',
#       'NA',
#       'NE',
#       'NG',
#       'NI',
#       'NL',
#       'NO',
#       'NP',
#       'NR',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PG',
#       'PH',
#       'PK',
#       'PL',
#       'PS',
#       'PT',
#       'PW',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RW',
#       'SA',
#       'SB',
#       'SC',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SL',
#       'SM',
#       'SN',
#       'SR',
#       'ST',
#       'SV',
#       'SZ',
#       'TD',
#       'TG',
#       'TH',
#       'TJ',
#       'TL',
#       'TN',
#       'TO',
#       'TR',
#       'TT',
#       'TV',
#       'TW',
#       'TZ',
#       'UA',
#       'UG',
#       'US',
#       'UY',
#       'UZ',
#       'VC',
#       'VE',
#       'VN',
#       'VU',
#       'WS',
#       'XK',
#       'ZA',
#       'ZM',
#       'ZW'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/3y7Mwv7UqhABQqsGlzSL6n'},
#      'href': 'https://api.spotify.com/v1/albums/3y7Mwv7UqhABQqsGlzSL6n',
#      'id': '3y7Mwv7UqhABQqsGlzSL6n',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b27308d27bfc2ff1a7b11b66c65c',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e0208d27bfc2ff1a7b11b66c65c',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d0000485108d27bfc2ff1a7b11b66c65c',
#        'width': 64}],
#      'name': 'The Crow Original Motion Picture Soundtrack',
#      'release_date': '1994-03-25',
#      'release_date_precision': 'day',
#      'total_tracks': 14,
#      'type': 'album',
#      'uri': 'spotify:album:3y7Mwv7UqhABQqsGlzSL6n'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7bu3H8JO7d0UbMoVzbo70s'},
#       'href': 'https://api.spotify.com/v1/artists/7bu3H8JO7d0UbMoVzbo70s',
#       'id': '7bu3H8JO7d0UbMoVzbo70s',
#       'name': 'The Cure',
#       'type': 'artist',
#       'uri': 'spotify:artist:7bu3H8JO7d0UbMoVzbo70s'}],
#     'available_markets': ['AD',
#      'AE',
#      'AG',
#      'AL',
#      'AM',
#      'AO',
#      'AR',
#      'AT',
#      'AU',
#      'AZ',
#      'BA',
#      'BB',
#      'BD',
#      'BE',
#      'BF',
#      'BG',
#      'BH',
#      'BI',
#      'BJ',
#      'BN',
#      'BO',
#      'BR',
#      'BS',
#      'BT',
#      'BW',
#      'BY',
#      'BZ',
#      'CA',
#      'CD',
#      'CG',
#      'CH',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CV',
#      'CW',
# ...
#       'IN',
#       'IQ',
#       'IS',
#       'IT',
#       'JM',
#       'JO',
#       'JP',
#       'KE',
#       'KG',
#       'KH',
#       'KI',
#       'KM',
#       'KN',
#       'KR',
#       'KW',
#       'KZ',
#       'LA',
#       'LB',
#       'LC',
#       'LI',
#       'LK',
#       'LR',
#       'LS',
#       'LT',
#       'LU',
#       'LV',
#       'LY',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MG',
#       'MH',
#       'MK',
#       'ML',
#       'MN',
#       'MO',
#       'MR',
#       'MT',
#       'MU',
#       'MV',
#       'MW',
#       'MX',
#       'MY',
#       'MZ',
#       'NA',
#       'NE',
#       'NG',
#       'NI',
#       'NL',
#       'NO',
#       'NP',
#       'NR',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PG',
#       'PH',
#       'PK',
#       'PL',
#       'PS',
#       'PT',
#       'PW',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RW',
#       'SA',
#       'SB',
#       'SC',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SL',
#       'SM',
#       'SN',
#       'SR',
#       'ST',
#       'SV',
#       'SZ',
#       'TD',
#       'TG',
#       'TH',
#       'TJ',
#       'TL',
#       'TN',
#       'TO',
#       'TR',
#       'TT',
#       'TV',
#       'TW',
#       'TZ',
#       'UA',
#       'UG',
#       'US',
#       'UY',
#       'UZ',
#       'VC',
#       'VE',
#       'VN',
#       'VU',
#       'WS',
#       'XK',
#       'ZA',
#       'ZM',
#       'ZW'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/23FGerfaTcQOlEdySv5Wdq'},
#      'href': 'https://api.spotify.com/v1/albums/23FGerfaTcQOlEdySv5Wdq',
#      'id': '23FGerfaTcQOlEdySv5Wdq',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2730e344b28681e6ee72eb67f78',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e020e344b28681e6ee72eb67f78',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048510e344b28681e6ee72eb67f78',
#        'width': 64}],
#      'name': 'Cures What Ails Ya',
#      'release_date': '2020-06-10',
#      'release_date_precision': 'day',
#      'total_tracks': 12,
#      'type': 'album',
#      'uri': 'spotify:album:23FGerfaTcQOlEdySv5Wdq'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5k979N1TnPncUyqlXlaRSv'},
#       'href': 'https://api.spotify.com/v1/artists/5k979N1TnPncUyqlXlaRSv',
#       'id': '5k979N1TnPncUyqlXlaRSv',
#       'name': 'The Longest Johns',
#       'type': 'artist',
#       'uri': 'spotify:artist:5k979N1TnPncUyqlXlaRSv'}],
#     'available_markets': ['AD',
#      'AE',
#      'AG',
#      'AL',
#      'AM',
#      'AO',
#      'AR',
#      'AT',
#      'AU',
#      'AZ',
#      'BA',
#      'BB',
#      'BD',
#      'BE',
#      'BF',
#      'BG',
#      'BH',
#      'BI',
#      'BJ',
#      'BN',
#      'BO',
#      'BR',
#      'BS',
#      'BT',
#      'BW',
#      'BY',
#      'BZ',
#      'CA',
#      'CD',
#      'CG',
#      'CH',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CV',
#      'CW',
#      'CY',
#      'CZ',
#      'DE',
#      'DJ',
#      'DK',
#      'DM',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FJ',
#      'FM',
#      'FR',
#      'GA',
#      'GB',
#      'GD',
#      'GE',
#      'GH',
#      'GM',
#      'GN',
#      'GQ',
#      'GR',
#      'GT',
#      'GW',
#      'GY',
#      'HK',
#      'HN',
#      'HR',
#      'HT',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IQ',
#      'IS',
#      'IT',
#      'JM',
#      'JO',
#      'JP',
#      'KE',
#      'KG',
#      'KH',
#      'KI',
#      'KM',
#      'KN',
#      'KR',
#      'KW',
#      'KZ',
#      'LA',
#      'LB',
#      'LC',
#      'LI',
#      'LK',
#      'LR',
#      'LS',
#      'LT',
#      'LU',
#      'LV',
#      'LY',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MG',
#      'MH',
#      'MK',
#      'ML',
#      'MN',
#      'MO',
#      'MR',
#      'MT',
#      'MU',
#      'MV',
#      'MW',
#      'MX',
#      'MY',
#      'MZ',
#      'NA',
#      'NE',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NP',
#      'NR',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PG',
#      'PH',
#      'PK',
#      'PL',
#      'PS',
#      'PT',
#      'PW',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RW',
#      'SA',
#      'SB',
#      'SC',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SL',
#      'SM',
#      'SN',
#      'SR',
#      'ST',
#      'SV',
#      'SZ',
#      'TD',
#      'TG',
#      'TH',
#      'TJ',
#      'TL',
#      'TN',
#      'TO',
#      'TR',
#      'TT',
#      'TV',
#      'TW',
#      'TZ',
#      'UA',
#      'UG',
#      'US',
#      'UY',
#      'UZ',
#      'VC',
#      'VE',
#      'VN',
#      'VU',
#      'WS',
#      'XK',
#      'ZA',
#      'ZM',
#      'ZW'],
#     'disc_number': 1,
#     'duration_ms': 248940,
#     'explicit': False,
#     'external_ids': {'isrc': 'UKPGJ1800036'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/38FCXf9CTcH9MJKn3WsJ7x'},
#     'href': 'https://api.spotify.com/v1/tracks/38FCXf9CTcH9MJKn3WsJ7x',
#     'id': '38FCXf9CTcH9MJKn3WsJ7x',
#     'is_local': False,
#     'name': 'Oak & Ash & Thorn',
#     'popularity': 54,
#     'preview_url': 'https://p.scdn.co/mp3-preview/8c9746de9261a41061753da4b6cea0f99df782bc?cid=da00ed264eaf4f94ba2adf23ff058567',
#     'track_number': 8,
#     'type': 'track',
#     'uri': 'spotify:track:38FCXf9CTcH9MJKn3WsJ7x'},
#    {'album': {'album_type': 'compilation',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7bu3H8JO7d0UbMoVzbo70s'},
#        'href': 'https://api.spotify.com/v1/artists/7bu3H8JO7d0UbMoVzbo70s',
#        'id': '7bu3H8JO7d0UbMoVzbo70s',
#        'name': 'The Cure',
#        'type': 'artist',
#        'uri': 'spotify:artist:7bu3H8JO7d0UbMoVzbo70s'}],
#      'available_markets': ['CA', 'US'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/34ozkv3AkFksZD8srOmOrX'},
#      'href': 'https://api.spotify.com/v1/albums/34ozkv3AkFksZD8srOmOrX',
#      'id': '34ozkv3AkFksZD8srOmOrX',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2730447ba639949dd26478decf6',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e020447ba639949dd26478decf6',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048510447ba639949dd26478decf6',
#        'width': 64}],
#      'name': 'Greatest Hits',
#      'release_date': '2001-11-13',
#      'release_date_precision': 'day',
#      'total_tracks': 18,
#      'type': 'album',
#      'uri': 'spotify:album:34ozkv3AkFksZD8srOmOrX'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7bu3H8JO7d0UbMoVzbo70s'},
#       'href': 'https://api.spotify.com/v1/artists/7bu3H8JO7d0UbMoVzbo70s',
#       'id': '7bu3H8JO7d0UbMoVzbo70s',
#       'name': 'The Cure',
#       'type': 'artist',
#       'uri': 'spotify:artist:7bu3H8JO7d0UbMoVzbo70s'}],
#     'available_markets': ['CA', 'US'],
#     'disc_number': 1,
#     'duration_ms': 207653,
#     'explicit': False,
#     'external_ids': {'isrc': 'GBAKW0100362'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/49hCuCAtKKVR8K0y3sZilW'},
#     'href': 'https://api.spotify.com/v1/tracks/49hCuCAtKKVR8K0y3sZilW',
#     'id': '49hCuCAtKKVR8K0y3sZilW',
#     'is_local': False,
#     'name': 'Just Say Yes',
#     'popularity': 29,
#     'preview_url': 'https://p.scdn.co/mp3-preview/144e8b43a940fd0e429f0cb24b3686b14681cfb2?cid=da00ed264eaf4f94ba2adf23ff058567',
#     'track_number': 18,
#     'type': 'track',
#     'uri': 'spotify:track:49hCuCAtKKVR8K0y3sZilW'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0Z88iXWc4YVhtu1eFtsGk6'},
#        'href': 'https://api.spotify.com/v1/artists/0Z88iXWc4YVhtu1eFtsGk6',
#        'id': '0Z88iXWc4YVhtu1eFtsGk6',
#        'name': 'Wolves At The Gate',
#        'type': 'artist',
#        'uri': 'spotify:artist:0Z88iXWc4YVhtu1eFtsGk6'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AO',
#       'AR',
#       'AT',
#       'AU',
#       'AZ',
#       'BA',
#       'BB',
#       'BD',
#       'BE',
#       'BF',
#       'BG',
#       'BH',
#       'BI',
#       'BJ',
#       'BN',
#       'BO',
#       'BR',
#       'BS',
#       'BT',
#       'BW',
#       'BY',
#       'BZ',
#       'CA',
#       'CD',
#       'CG',
#       'CH',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CV',
#       'CW',
#       'CY',
#       'CZ',
#       'DE',
#       'DJ',
#       'DK',
#       'DM',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FJ',
#       'FM',
#       'FR',
#       'GA',
#       'GB',
#       'GD',
#       'GE',
#       'GH',
#       'GM',
#       'GN',
#       'GQ',
#       'GR',
#       'GT',
#       'GW',
#       'GY',
#       'HK',
#       'HN',
#       'HR',
#       'HT',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IQ',
#       'IS',
#       'IT',
#       'JM',
#       'JO',
#       'JP',
#       'KE',
#       'KG',
#       'KH',
#       'KI',
#       'KM',
#       'KN',
#       'KR',
#       'KW',
#       'KZ',
#       'LA',
#       'LB',
#       'LC',
#       'LI',
#       'LK',
#       'LR',
#       'LS',
#       'LT',
#       'LU',
#       'LV',
#       'LY',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MG',
#       'MH',
#       'MK',
#       'ML',
#       'MN',
#       'MO',
#       'MR',
#       'MT',
#       'MU',
#       'MV',
#       'MW',
#       'MX',
#       'MY',
#       'MZ',
#       'NA',
#       'NE',
#       'NG',
#       'NI',
#       'NL',
#       'NO',
#       'NP',
#       'NR',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PG',
#       'PH',
#       'PK',
#       'PL',
#       'PS',
#       'PT',
#       'PW',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RW',
#       'SA',
#       'SB',
#       'SC',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SL',
#       'SM',
#       'SN',
#       'SR',
#       'ST',
#       'SV',
#       'SZ',
#       'TD',
#       'TG',
#       'TH',
#       'TJ',
#       'TL',
#       'TN',
#       'TO',
#       'TR',
#       'TT',
#       'TV',
#       'TW',
#       'TZ',
#       'UA',
#       'UG',
#       'US',
#       'UY',
#       'UZ',
#       'VC',
#       'VE',
#       'VN',
#       'VU',
#       'WS',
#       'XK',
#       'ZA',
#       'ZM',
#       'ZW'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/6L8gLKCluioceYP7WNmcol'},
#      'href': 'https://api.spotify.com/v1/albums/6L8gLKCluioceYP7WNmcol',
#      'id': '6L8gLKCluioceYP7WNmcol',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273dc4299ee6013d5522734c4e7',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02dc4299ee6013d5522734c4e7',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851dc4299ee6013d5522734c4e7',
#        'width': 64}],
#      'name': 'Eclipse',
#      'release_date': '2019-07-26',
#      'release_date_precision': 'day',
#      'total_tracks': 13,
#      'type': 'album',
#      'uri': 'spotify:album:6L8gLKCluioceYP7WNmcol'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0Z88iXWc4YVhtu1eFtsGk6'},
#       'href': 'https://api.spotify.com/v1/artists/0Z88iXWc4YVhtu1eFtsGk6',
#       'id': '0Z88iXWc4YVhtu1eFtsGk6',
#       'name': 'Wolves At The Gate',
#       'type': 'artist',
#       'uri': 'spotify:artist:0Z88iXWc4YVhtu1eFtsGk6'}],
#     'available_markets': ['AD',
#      'AE',
#      'AG',
#      'AL',
#      'AM',
#      'AO',
#      'AR',
#      'AT',
#      'AU',
#      'AZ',
#      'BA',
#      'BB',
#      'BD',
#      'BE',
#      'BF',
#      'BG',
#      'BH',
#      'BI',
#      'BJ',
#      'BN',
#      'BO',
#      'BR',
#      'BS',
#      'BT',
#      'BW',
#      'BY',
#      'BZ',
#      'CA',
#      'CD',
#      'CG',
#      'CH',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CV',
#      'CW',
#      'CY',
#      'CZ',
#      'DE',
#      'DJ',
#      'DK',
#      'DM',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FJ',
#      'FM',
#      'FR',
#      'GA',
#      'GB',
#      'GD',
#      'GE',
#      'GH',
#      'GM',
#      'GN',
#      'GQ',
#      'GR',
#      'GT',
#      'GW',
#      'GY',
#      'HK',
#      'HN',
#      'HR',
#      'HT',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IQ',
#      'IS',
#      'IT',
#      'JM',
#      'JO',
#      'JP',
#      'KE',
#      'KG',
#      'KH',
#      'KI',
#      'KM',
#      'KN',
#      'KR',
#      'KW',
#      'KZ',
#      'LA',
#      'LB',
#      'LC',
#      'LI',
#      'LK',
#      'LR',
#      'LS',
#      'LT',
#      'LU',
#      'LV',
#      'LY',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MG',
#      'MH',
#      'MK',
#      'ML',
#      'MN',
#      'MO',
#      'MR',
#      'MT',
#      'MU',
#      'MV',
#      'MW',
#      'MX',
#      'MY',
#      'MZ',
#      'NA',
#      'NE',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NP',
#      'NR',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PG',
#      'PH',
#      'PK',
#      'PL',
#      'PS',
#      'PT',
#      'PW',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RW',
#      'SA',
#      'SB',
#      'SC',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SL',
#      'SM',
#      'SN',
#      'SR',
#      'ST',
#      'SV',
#      'SZ',
#      'TD',
#      'TG',
#      'TH',
#      'TJ',
#      'TL',
#      'TN',
#      'TO',
#      'TR',
#      'TT',
#      'TV',
#      'TW',
#      'TZ',
#      'UA',
#      'UG',
#      'US',
#      'UY',
#      'UZ',
#      'VC',
#      'VE',
#      'VN',
#      'VU',
#      'WS',
#      'XK',
#      'ZA',
#      'ZM',
#      'ZW'],
#     'disc_number': 1,
#     'duration_ms': 256693,
#     'explicit': False,
#     'external_ids': {'isrc': 'QMGVJ1900011'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/3bimN1JcQkbLWcUJexAEyh'},
#     'href': 'https://api.spotify.com/v1/tracks/3bimN1JcQkbLWcUJexAEyh',
#     'id': '3bimN1JcQkbLWcUJexAEyh',
#     'is_local': False,
#     'name': 'The Cure',
#     'popularity': 36,
#     'preview_url': 'https://p.scdn.co/mp3-preview/27120fe278e19dd9288d1f4883a0d9860f7a02ff?cid=da00ed264eaf4f94ba2adf23ff058567',
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:3bimN1JcQkbLWcUJexAEyh'},
#    {'album': {'album_type': 'compilation',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7bu3H8JO7d0UbMoVzbo70s'},
#        'href': 'https://api.spotify.com/v1/artists/7bu3H8JO7d0UbMoVzbo70s',
#        'id': '7bu3H8JO7d0UbMoVzbo70s',
#        'name': 'The Cure',
#        'type': 'artist',
#        'uri': 'spotify:artist:7bu3H8JO7d0UbMoVzbo70s'}],
#      'available_markets': ['CA', 'US'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/0BRThmbAV1p2CxAuxgpHRj'},
#      'href': 'https://api.spotify.com/v1/albums/0BRThmbAV1p2CxAuxgpHRj',
#      'id': '0BRThmbAV1p2CxAuxgpHRj',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2732780880a9583a363c28c60d5',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e022780880a9583a363c28c60d5',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048512780880a9583a363c28c60d5',
#        'width': 64}],
#      'name': 'Galore',
#      'release_date': '1997-10-17',
#      'release_date_precision': 'day',
#      'total_tracks': 18,
#      'type': 'album',
#      'uri': 'spotify:album:0BRThmbAV1p2CxAuxgpHRj'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7bu3H8JO7d0UbMoVzbo70s'},
#       'href': 'https://api.spotify.com/v1/artists/7bu3H8JO7d0UbMoVzbo70s',
#       'id': '7bu3H8JO7d0UbMoVzbo70s',
#       'name': 'The Cure',
#       'type': 'artist',
#       'uri': 'spotify:artist:7bu3H8JO7d0UbMoVzbo70s'}],
#     'available_markets': ['CA', 'US'],
#     'disc_number': 1,
#     'duration_ms': 361866,
#     'explicit': False,
#     'external_ids': {'isrc': 'GBALB9700001'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/03IHSEzItu1iHXaelC9tZy'},
#     'href': 'https://api.spotify.com/v1/tracks/03IHSEzItu1iHXaelC9tZy',
#     'id': '03IHSEzItu1iHXaelC9tZy',
#     'is_local': False,
#     'name': 'Wrong Number - Single Mix',
#     'popularity': 28,
#     'preview_url': 'https://p.scdn.co/mp3-preview/9706e93df53fbc897f44ee89c1d5ad8041ac9223?cid=da00ed264eaf4f94ba2adf23ff058567',
#     'track_number': 18,
#     'type': 'track',
#     'uri': 'spotify:track:03IHSEzItu1iHXaelC9tZy'}],
#   'limit': 50,
#   'next': 'https://api.spotify.com/v1/search?query=The+Cure&type=track&offset=50&limit=50',
#   'offset': 0,
#   'previous': None,
#   'total': 10713}}

# %%
results.keys()
# Out:
# dict_keys(['tracks'])

# %%
results['tracks']['href']
# Out:
# 'https://api.spotify.com/v1/search?query=The+Cure&type=track&offset=0&limit=50'

# %%
len(results['tracks']['items'])
# Out:
# 50

# %%
results['tracks']['items']
# Out:
# [{'album': {'album_type': 'single',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1HY2Jd0NmPuamShAr6KMms'},
#      'href': 'https://api.spotify.com/v1/artists/1HY2Jd0NmPuamShAr6KMms',
#      'id': '1HY2Jd0NmPuamShAr6KMms',
#      'name': 'Lady Gaga',
#      'type': 'artist',
#      'uri': 'spotify:artist:1HY2Jd0NmPuamShAr6KMms'}],
#    'available_markets': ['AD',
#     'AE',
#     'AG',
#     'AL',
#     'AM',
#     'AO',
#     'AR',
#     'AT',
#     'AU',
#     'AZ',
#     'BA',
#     'BB',
#     'BD',
#     'BE',
#     'BF',
#     'BG',
#     'BH',
#     'BI',
#     'BJ',
#     'BN',
#     'BO',
#     'BR',
#     'BS',
#     'BT',
#     'BW',
#     'BY',
#     'BZ',
#     'CA',
#     'CD',
#     'CG',
#     'CH',
#     'CI',
#     'CL',
#     'CM',
#     'CO',
#     'CR',
#     'CV',
#     'CW',
#     'CY',
#     'CZ',
#     'DE',
#     'DJ',
#     'DK',
#     'DM',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FJ',
#     'FM',
#     'FR',
#     'GA',
#     'GB',
#     'GD',
#     'GE',
#     'GH',
#     'GM',
#     'GN',
#     'GQ',
#     'GR',
#     'GT',
#     'GW',
#     'GY',
#     'HK',
#     'HN',
#     'HR',
#     'HT',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IQ',
#     'IS',
#     'IT',
#     'JM',
#     'JO',
#     'JP',
#     'KE',
#     'KG',
#     'KH',
#     'KI',
#     'KM',
#     'KN',
#     'KR',
#     'KW',
#     'KZ',
#     'LA',
#     'LB',
#     'LC',
#     'LI',
#     'LK',
#     'LR',
#     'LS',
#     'LT',
#     'LU',
#     'LV',
#     'LY',
#     'MA',
#     'MC',
#     'MD',
#     'ME',
#     'MG',
#     'MH',
#     'MK',
#     'ML',
#     'MN',
#     'MO',
#     'MR',
#     'MT',
#     'MU',
#     'MV',
#     'MW',
#     'MX',
#     'MY',
#     'MZ',
#     'NA',
#     'NE',
#     'NG',
#     'NI',
#     'NL',
#     'NO',
#     'NP',
#     'NR',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PG',
#     'PH',
#     'PK',
#     'PL',
#     'PS',
#     'PT',
#     'PW',
#     'PY',
#     'QA',
#     'RO',
#     'RS',
#     'RW',
#     'SA',
#     'SB',
#     'SC',
#     'SE',
#     'SG',
#     'SI',
#     'SK',
#     'SL',
#     'SM',
#     'SN',
#     'SR',
#     'ST',
#     'SV',
#     'SZ',
#     'TD',
#     'TG',
#     'TH',
#     'TJ',
#     'TL',
#     'TN',
#     'TO',
#     'TR',
#     'TT',
#     'TV',
#     'TW',
#     'TZ',
#     'UA',
#     'UG',
#     'US',
#     'UY',
#     'UZ',
#     'VC',
#     'VE',
#     'VN',
#     'VU',
#     'WS',
#     'XK',
#     'ZA',
#     'ZM',
#     'ZW'],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/2yaSZnZhaxsbQ5xhgGbw3g'},
#    'href': 'https://api.spotify.com/v1/albums/2yaSZnZhaxsbQ5xhgGbw3g',
#    'id': '2yaSZnZhaxsbQ5xhgGbw3g',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b27331cc5716a5c922b0482787b7',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/ab67616d00001e0231cc5716a5c922b0482787b7',
#      'width': 300},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/ab67616d0000485131cc5716a5c922b0482787b7',
#      'width': 64}],
#    'name': 'The Cure',
#    'release_date': '2017-04-16',
#    'release_date_precision': 'day',
#    'total_tracks': 1,
#    'type': 'album',
#    'uri': 'spotify:album:2yaSZnZhaxsbQ5xhgGbw3g'},
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1HY2Jd0NmPuamShAr6KMms'},
#     'href': 'https://api.spotify.com/v1/artists/1HY2Jd0NmPuamShAr6KMms',
#     'id': '1HY2Jd0NmPuamShAr6KMms',
#     'name': 'Lady Gaga',
#     'type': 'artist',
#     'uri': 'spotify:artist:1HY2Jd0NmPuamShAr6KMms'}],
#   'available_markets': ['AD',
#    'AE',
#    'AG',
#    'AL',
#    'AM',
#    'AO',
#    'AR',
#    'AT',
#    'AU',
#    'AZ',
#    'BA',
#    'BB',
#    'BD',
#    'BE',
#    'BF',
#    'BG',
#    'BH',
#    'BI',
#    'BJ',
#    'BN',
#    'BO',
#    'BR',
#    'BS',
#    'BT',
#    'BW',
#    'BY',
#    'BZ',
#    'CA',
#    'CD',
#    'CG',
#    'CH',
#    'CI',
#    'CL',
#    'CM',
#    'CO',
#    'CR',
#    'CV',
#    'CW',
#    'CY',
#    'CZ',
#    'DE',
#    'DJ',
#    'DK',
#    'DM',
#    'DO',
#    'DZ',
#    'EC',
#    'EE',
#    'EG',
#    'ES',
#    'FI',
#    'FJ',
#    'FM',
#    'FR',
#    'GA',
#    'GB',
#    'GD',
#    'GE',
#    'GH',
#    'GM',
#    'GN',
#    'GQ',
#    'GR',
#    'GT',
#    'GW',
#    'GY',
#    'HK',
#    'HN',
#    'HR',
#    'HT',
#    'HU',
#    'ID',
#    'IE',
#    'IL',
#    'IN',
#    'IQ',
#    'IS',
#    'IT',
#    'JM',
#    'JO',
#    'JP',
#    'KE',
#    'KG',
#    'KH',
#    'KI',
#    'KM',
#    'KN',
#    'KR',
#    'KW',
#    'KZ',
#    'LA',
#    'LB',
#    'LC',
#    'LI',
#    'LK',
#    'LR',
#    'LS',
#    'LT',
#    'LU',
#    'LV',
#    'LY',
#    'MA',
#    'MC',
#    'MD',
#    'ME',
#    'MG',
#    'MH',
#    'MK',
#    'ML',
#    'MN',
#    'MO',
#    'MR',
#    'MT',
#    'MU',
#    'MV',
#    'MW',
#    'MX',
#    'MY',
#    'MZ',
#    'NA',
#    'NE',
#    'NG',
#    'NI',
#    'NL',
#    'NO',
#    'NP',
#    'NR',
#    'NZ',
#    'OM',
#    'PA',
#    'PE',
#    'PG',
#    'PH',
#    'PK',
#    'PL',
#    'PS',
#    'PT',
#    'PW',
#    'PY',
#    'QA',
#    'RO',
#    'RS',
#    'RW',
#    'SA',
#    'SB',
#    'SC',
#    'SE',
#    'SG',
#    'SI',
#    'SK',
#    'SL',
#    'SM',
#    'SN',
#    'SR',
#    'ST',
#    'SV',
#    'SZ',
#    'TD',
#    'TG',
#    'TH',
#    'TJ',
#    'TL',
#    'TN',
#    'TO',
#    'TR',
#    'TT',
#    'TV',
#    'TW',
#    'TZ',
#    'UA',
#    'UG',
#    'US',
#    'UY',
#    'UZ',
#    'VC',
#    'VE',
#    'VN',
#    'VU',
#    'WS',
#    'XK',
#    'ZA',
#    'ZM',
#    'ZW'],
#   'disc_number': 1,
#   'duration_ms': 211363,
#   'explicit': False,
#   'external_ids': {'isrc': 'USUM71703782'},
#   'external_urls': {'spotify': 'https://open.spotify.com/track/34oB5r0lcN3fYWCs2uA1k5'},
#   'href': 'https://api.spotify.com/v1/tracks/34oB5r0lcN3fYWCs2uA1k5',
#   'id': '34oB5r0lcN3fYWCs2uA1k5',
#   'is_local': False,
#   'name': 'The Cure',
#   'popularity': 67,
#   'preview_url': 'https://p.scdn.co/mp3-preview/75aa09f7973992a4f30e286afd60f316e462cb99?cid=da00ed264eaf4f94ba2adf23ff058567',
#   'track_number': 1,
#   'type': 'track',
#   'uri': 'spotify:track:34oB5r0lcN3fYWCs2uA1k5'},
#  {'album': {'album_type': 'album',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7bu3H8JO7d0UbMoVzbo70s'},
#      'href': 'https://api.spotify.com/v1/artists/7bu3H8JO7d0UbMoVzbo70s',
#      'id': '7bu3H8JO7d0UbMoVzbo70s',
#      'name': 'The Cure',
#      'type': 'artist',
#      'uri': 'spotify:artist:7bu3H8JO7d0UbMoVzbo70s'}],
#    'available_markets': ['CA', 'US'],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/37Q22g0n9PzBLX6lNddrIa'},
#    'href': 'https://api.spotify.com/v1/albums/37Q22g0n9PzBLX6lNddrIa',
#    'id': '37Q22g0n9PzBLX6lNddrIa',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b2737f22337546d61faca55e0f4f',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/ab67616d00001e027f22337546d61faca55e0f4f',
#      'width': 300},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/ab67616d000048517f22337546d61faca55e0f4f',
#      'width': 64}],
#    'name': 'Kiss Me, Kiss Me, Kiss Me',
#    'release_date': '1987-05-25',
#    'release_date_precision': 'day',
#    'total_tracks': 17,
#    'type': 'album',
#    'uri': 'spotify:album:37Q22g0n9PzBLX6lNddrIa'},
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7bu3H8JO7d0UbMoVzbo70s'},
#     'href': 'https://api.spotify.com/v1/artists/7bu3H8JO7d0UbMoVzbo70s',
#     'id': '7bu3H8JO7d0UbMoVzbo70s',
#     'name': 'The Cure',
#     'type': 'artist',
#     'uri': 'spotify:artist:7bu3H8JO7d0UbMoVzbo70s'}],
#   'available_markets': ['CA', 'US'],
#   'disc_number': 1,
#   'duration_ms': 212000,
#   'explicit': False,
#   'external_ids': {'isrc': 'USEE18700009'},
#   'external_urls': {'spotify': 'https://open.spotify.com/track/76GlO5H5RT6g7y0gev86Nk'},
#   'href': 'https://api.spotify.com/v1/tracks/76GlO5H5RT6g7y0gev86Nk',
#   'id': '76GlO5H5RT6g7y0gev86Nk',
#   'is_local': False,
#   'name': 'Just like Heaven',
#   'popularity': 70,
#   'preview_url': 'https://p.scdn.co/mp3-preview/ef101f28ecd0df21cc7726ee48c1e6c7879f7d48?cid=da00ed264eaf4f94ba2adf23ff058567',
#   'track_number': 8,
#   'type': 'track',
#   'uri': 'spotify:track:76GlO5H5RT6g7y0gev86Nk'},
#  {'album': {'album_type': 'album',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6h4DZCXvwXapWw1C2vygaC'},
#      'href': 'https://api.spotify.com/v1/artists/6h4DZCXvwXapWw1C2vygaC',
#      'id': '6h4DZCXvwXapWw1C2vygaC',
#      'name': 'Sam Lans!',
#      'type': 'artist',
#      'uri': 'spotify:artist:6h4DZCXvwXapWw1C2vygaC'}],
#    'available_markets': ['AD',
#     'AE',
#     'AG',
#     'AM',
#     'AO',
#     'AR',
#     'AT',
#     'AU',
#     'AZ',
#     'BB',
#     'BD',
#     'BE',
#     'BF',
#     'BG',
#     'BH',
#     'BI',
#     'BJ',
#     'BN',
#     'BO',
#     'BR',
#     'BS',
#     'BT',
#     'BW',
#     'BZ',
#     'CA',
#     'CG',
#     'CH',
#     'CL',
#     'CM',
#     'CO',
#     'CR',
#     'CV',
#     'CW',
#     'CY',
#     'CZ',
#     'DE',
#     'DJ',
#     'DK',
#     'DM',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FJ',
#     'FM',
#     'FR',
#     'GA',
#     'GB',
#     'GD',
#     'GE',
#     'GH',
#     'GM',
#     'GN',
#     'GQ',
#     'GR',
#     'GT',
#     'GW',
#     'GY',
#     'HK',
#     'HN',
#     'HT',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IS',
#     'IT',
#     'JM',
#     'JO',
#     'JP',
#     'KE',
#     'KG',
#     'KH',
#     'KI',
#     'KM',
#     'KN',
#     'KR',
#     'KW',
#     'KZ',
#     'LA',
#     'LB',
#     'LC',
#     'LI',
#     'LK',
#     'LS',
#     'LT',
#     'LU',
#     'LV',
#     'MA',
#     'MC',
#     'MD',
#     'MG',
#     'MH',
#     'ML',
#     'MN',
#     'MO',
#     'MR',
#     'MT',
#     'MU',
#     'MV',
#     'MW',
#     'MX',
#     'MY',
#     'MZ',
#     'NA',
#     'NE',
#     'NG',
#     'NI',
#     'NL',
#     'NO',
#     'NP',
#     'NR',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PG',
#     'PH',
#     'PK',
#     'PL',
#     'PS',
#     'PT',
#     'PW',
#     'PY',
#     'QA',
#     'RO',
#     'RW',
#     'SA',
#     'SB',
#     'SC',
#     'SE',
#     'SG',
#     'SI',
#     'SK',
#     'SL',
#     'SM',
#     'SN',
#     'SR',
#     'ST',
#     'SV',
#     'SZ',
#     'TD',
#     'TG',
#     'TH',
#     'TJ',
#     'TL',
#     'TN',
#     'TO',
#     'TR',
#     'TT',
#     'TV',
#     'TW',
#     'TZ',
#     'UA',
#     'UG',
#     'US',
#     'UY',
#     'UZ',
#     'VC',
#     'VE',
#     'VN',
#     'VU',
#     'WS',
#     'ZA',
#     'ZM'],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/09F3pYMyjgdEj2rOD4aZhx'},
#    'href': 'https://api.spotify.com/v1/albums/09F3pYMyjgdEj2rOD4aZhx',
#    'id': '09F3pYMyjgdEj2rOD4aZhx',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b273eae50582ee86f25f5504abd5',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/ab67616d00001e02eae50582ee86f25f5504abd5',
#      'width': 300},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/ab67616d00004851eae50582ee86f25f5504abd5',
#      'width': 64}],
#    'name': 'Mk Ultra',
#    'release_date': '2017-10-06',
#    'release_date_precision': 'day',
#    'total_tracks': 13,
#    'type': 'album',
#    'uri': 'spotify:album:09F3pYMyjgdEj2rOD4aZhx'},
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6h4DZCXvwXapWw1C2vygaC'},
#     'href': 'https://api.spotify.com/v1/artists/6h4DZCXvwXapWw1C2vygaC',
#     'id': '6h4DZCXvwXapWw1C2vygaC',
#     'name': 'Sam Lans!',
#     'type': 'artist',
#     'uri': 'spotify:artist:6h4DZCXvwXapWw1C2vygaC'}],
#   'available_markets': ['AD',
#    'AE',
#    'AG',
#    'AM',
#    'AO',
#    'AR',
#    'AT',
#    'AU',
#    'AZ',
#    'BB',
#    'BD',
#    'BE',
#    'BF',
#    'BG',
#    'BH',
#    'BI',
#    'BJ',
#    'BN',
#    'BO',
#    'BR',
#    'BS',
#    'BT',
#    'BW',
#    'BZ',
#    'CA',
#    'CG',
#    'CH',
#    'CL',
#    'CM',
#    'CO',
#    'CR',
#    'CV',
#    'CW',
#    'CY',
#    'CZ',
#    'DE',
#    'DJ',
#    'DK',
#    'DM',
#    'DO',
#    'DZ',
#    'EC',
#    'EE',
#    'EG',
#    'ES',
#    'FI',
#    'FJ',
#    'FM',
#    'FR',
#    'GA',
#    'GB',
#    'GD',
#    'GE',
#    'GH',
#    'GM',
#    'GN',
#    'GQ',
#    'GR',
#    'GT',
#    'GW',
#    'GY',
#    'HK',
#    'HN',
#    'HT',
#    'HU',
#    'ID',
#    'IE',
#    'IL',
#    'IN',
#    'IS',
#    'IT',
#    'JM',
#    'JO',
#    'JP',
#    'KE',
#    'KG',
#    'KH',
#    'KI',
#    'KM',
#    'KN',
#    'KR',
#    'KW',
#    'KZ',
#    'LA',
#    'LB',
#    'LC',
#    'LI',
#    'LK',
#    'LS',
#    'LT',
#    'LU',
#    'LV',
#    'MA',
#    'MC',
#    'MD',
#    'MG',
#    'MH',
#    'ML',
#    'MN',
#    'MO',
#    'MR',
#    'MT',
#    'MU',
#    'MV',
#    'MW',
#    'MX',
#    'MY',
#    'MZ',
#    'NA',
#    'NE',
#    'NG',
#    'NI',
#    'NL',
#    'NO',
#    'NP',
#    'NR',
#    'NZ',
#    'OM',
#    'PA',
#    'PE',
#    'PG',
#    'PH',
#    'PK',
#    'PL',
#    'PS',
#    'PT',
#    'PW',
#    'PY',
#    'QA',
#    'RO',
#    'RW',
#    'SA',
#    'SB',
#    'SC',
#    'SE',
#    'SG',
#    'SI',
#    'SK',
#    'SL',
#    'SM',
#    'SN',
#    'SR',
#    'ST',
#    'SV',
#    'SZ',
#    'TD',
#    'TG',
#    'TH',
#    'TJ',
#    'TL',
#    'TN',
#    'TO',
#    'TR',
#    'TT',
#    'TV',
#    'TW',
#    'TZ',
#    'UA',
#    'UG',
#    'US',
#    'UY',
#    'UZ',
#    'VC',
#    'VE',
#    'VN',
#    'VU',
#    'WS',
#    'ZA',
#    'ZM'],
#   'disc_number': 1,
#   'duration_ms': 186959,
#   'explicit': True,
#   'external_ids': {'isrc': 'TCADJ1714578'},
#   'external_urls': {'spotify': 'https://open.spotify.com/track/3EeKXJWkNTQTqqzRehTG7H'},
#   'href': 'https://api.spotify.com/v1/tracks/3EeKXJWkNTQTqqzRehTG7H',
#   'id': '3EeKXJWkNTQTqqzRehTG7H',
#   'is_local': False,
#   'name': 'The Cure',
#   'popularity': 59,
#   'preview_url': 'https://p.scdn.co/mp3-preview/dd9cb0ba5f9ef3f9a62414bedcc8f9089927c3aa?cid=da00ed264eaf4f94ba2adf23ff058567',
#   'track_number': 13,
#   'type': 'track',
#   'uri': 'spotify:track:3EeKXJWkNTQTqqzRehTG7H'},
#  {'album': {'album_type': 'album',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7bu3H8JO7d0UbMoVzbo70s'},
#      'href': 'https://api.spotify.com/v1/artists/7bu3H8JO7d0UbMoVzbo70s',
#      'id': '7bu3H8JO7d0UbMoVzbo70s',
#      'name': 'The Cure',
#      'type': 'artist',
#      'uri': 'spotify:artist:7bu3H8JO7d0UbMoVzbo70s'}],
#    'available_markets': ['CA', 'US'],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/3x1CmNdXWU0DzpTZXFFRZu'},
#    'href': 'https://api.spotify.com/v1/albums/3x1CmNdXWU0DzpTZXFFRZu',
#    'id': '3x1CmNdXWU0DzpTZXFFRZu',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b273e410fa31e3dfcc7521cde86d',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/ab67616d00001e02e410fa31e3dfcc7521cde86d',
#      'width': 300},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/ab67616d00004851e410fa31e3dfcc7521cde86d',
#      'width': 64}],
#    'name': 'Wish',
#    'release_date': '1992-04-21',
#    'release_date_precision': 'day',
#    'total_tracks': 12,
#    'type': 'album',
#    'uri': 'spotify:album:3x1CmNdXWU0DzpTZXFFRZu'},
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7bu3H8JO7d0UbMoVzbo70s'},
#     'href': 'https://api.spotify.com/v1/artists/7bu3H8JO7d0UbMoVzbo70s',
#     'id': '7bu3H8JO7d0UbMoVzbo70s',
#     'name': 'The Cure',
#     'type': 'artist',
#     'uri': 'spotify:artist:7bu3H8JO7d0UbMoVzbo70s'}],
#   'available_markets': ['CA', 'US'],
#   'disc_number': 1,
#   'duration_ms': 214400,
#   'explicit': False,
#   'external_ids': {'isrc': 'USEE10180267'},
#   'external_urls': {'spotify': 'https://open.spotify.com/track/263aNAQCeFSWipk896byo6'},
#   'href': 'https://api.spotify.com/v1/tracks/263aNAQCeFSWipk896byo6',
#   'id': '263aNAQCeFSWipk896byo6',
#   'is_local': False,
#   'name': "Friday I'm in Love",
#   'popularity': 70,
#   'preview_url': 'https://p.scdn.co/mp3-preview/958e347444599fa593cb2d86459e67ad18719c72?cid=da00ed264eaf4f94ba2adf23ff058567',
#   'track_number': 7,
#   'type': 'track',
#   'uri': 'spotify:track:263aNAQCeFSWipk896byo6'},
#  {'album': {'album_type': 'album',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1WgXqy2Dd70QQOU7Ay074N'},
#      'href': 'https://api.spotify.com/v1/artists/1WgXqy2Dd70QQOU7Ay074N',
#      'id': '1WgXqy2Dd70QQOU7Ay074N',
#      'name': 'AURORA',
#      'type': 'artist',
#      'uri': 'spotify:artist:1WgXqy2Dd70QQOU7Ay074N'}],
#    'available_markets': ['AG',
#     'AU',
#     'BB',
#     'BS',
#     'BZ',
#     'CA',
#     'CR',
#     'CW',
#     'DM',
#     'DO',
#     'GD',
#     'GT',
#     'HN',
#     'HT',
#     'JM',
#     'KN',
#     'LC',
#     'MX',
#     'NI',
#     'NZ',
#     'PA',
#     'SV',
#     'TT',
#     'US',
#     'VC',
#     'ZA'],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/5z1xjvymitc0DJETtvVmaX'},
#    'href': 'https://api.spotify.com/v1/albums/5z1xjvymitc0DJETtvVmaX',
#    'id': '5z1xjvymitc0DJETtvVmaX',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b27313e38f3da42937aba61956f0',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/ab67616d00001e0213e38f3da42937aba61956f0',
#      'width': 300},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/ab67616d0000485113e38f3da42937aba61956f0',
#      'width': 64}],
#    'name': 'The Gods We Can Touch',
#    'release_date': '2022-01-21',
#    'release_date_precision': 'day',
#    'total_tracks': 15,
#    'type': 'album',
#    'uri': 'spotify:album:5z1xjvymitc0DJETtvVmaX'},
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1WgXqy2Dd70QQOU7Ay074N'},
#     'href': 'https://api.spotify.com/v1/artists/1WgXqy2Dd70QQOU7Ay074N',
#     'id': '1WgXqy2Dd70QQOU7Ay074N',
#     'name': 'AURORA',
#     'type': 'artist',
#     'uri': 'spotify:artist:1WgXqy2Dd70QQOU7Ay074N'}],
#   'available_markets': ['AG',
#    'AU',
#    'BB',
#    'BS',
#    'BZ',
#    'CA',
#    'CR',
#    'CW',
#    'DM',
#    'DO',
#    'GD',
#    'GT',
#    'HN',
#    'HT',
#    'JM',
#    'KN',
#    'LC',
#    'MX',
#    'NI',
#    'NZ',
#    'PA',
#    'SV',
#    'TT',
#    'US',
#    'VC',
#    'ZA'],
#   'disc_number': 1,
#   'duration_ms': 201640,
#   'explicit': False,
#   'external_ids': {'isrc': 'GBUM72100848'},
#   'external_urls': {'spotify': 'https://open.spotify.com/track/33WTgxRdPBQQpVCMXpNxhO'},
#   'href': 'https://api.spotify.com/v1/tracks/33WTgxRdPBQQpVCMXpNxhO',
#   'id': '33WTgxRdPBQQpVCMXpNxhO',
#   'is_local': False,
#   'name': 'Cure For Me',
#   'popularity': 70,
#   'preview_url': 'https://p.scdn.co/mp3-preview/9b1b3f299c3474ee7b660db915904c2adfd58706?cid=da00ed264eaf4f94ba2adf23ff058567',
#   'track_number': 4,
#   'type': 'track',
#   'uri': 'spotify:track:33WTgxRdPBQQpVCMXpNxhO'},
#  {'album': {'album_type': 'album',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7bu3H8JO7d0UbMoVzbo70s'},
#      'href': 'https://api.spotify.com/v1/artists/7bu3H8JO7d0UbMoVzbo70s',
#      'id': '7bu3H8JO7d0UbMoVzbo70s',
#      'name': 'The Cure',
#      'type': 'artist',
#      'uri': 'spotify:artist:7bu3H8JO7d0UbMoVzbo70s'}],
#    'available_markets': ['CA', 'US'],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/6vQB3ZBxnQPP3jQcGV2qzg'},
#    'href': 'https://api.spotify.com/v1/albums/6vQB3ZBxnQPP3jQcGV2qzg',
#    'id': '6vQB3ZBxnQPP3jQcGV2qzg',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b273c7ca2db25ad377e022bc3975',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/ab67616d00001e02c7ca2db25ad377e022bc3975',
#      'width': 300},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/ab67616d00004851c7ca2db25ad377e022bc3975',
#      'width': 64}],
#    'name': 'Disintegration (Deluxe Edition)',
#    'release_date': '1989-05-02',
#    'release_date_precision': 'day',
#    'total_tracks': 44,
#    'type': 'album',
#    'uri': 'spotify:album:6vQB3ZBxnQPP3jQcGV2qzg'},
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7bu3H8JO7d0UbMoVzbo70s'},
#     'href': 'https://api.spotify.com/v1/artists/7bu3H8JO7d0UbMoVzbo70s',
#     'id': '7bu3H8JO7d0UbMoVzbo70s',
#     'name': 'The Cure',
#     'type': 'artist',
#     'uri': 'spotify:artist:7bu3H8JO7d0UbMoVzbo70s'}],
#   'available_markets': ['CA', 'US'],
#   'disc_number': 1,
#   'duration_ms': 209573,
#   'explicit': False,
#   'external_ids': {'isrc': 'USEE10901455'},
#   'external_urls': {'spotify': 'https://open.spotify.com/track/0X5C4WjQNubRysTkHOubz3'},
#   'href': 'https://api.spotify.com/v1/tracks/0X5C4WjQNubRysTkHOubz3',
#   'id': '0X5C4WjQNubRysTkHOubz3',
#   'is_local': False,
#   'name': 'Lovesong - 2010 Remaster',
#   'popularity': 63,
#   'preview_url': 'https://p.scdn.co/mp3-preview/f9b7d686922b260b092b2c8e5186d40e2c63fd06?cid=da00ed264eaf4f94ba2adf23ff058567',
#   'track_number': 4,
#   'type': 'track',
#   'uri': 'spotify:track:0X5C4WjQNubRysTkHOubz3'},
#  {'album': {'album_type': 'album',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7bu3H8JO7d0UbMoVzbo70s'},
#      'href': 'https://api.spotify.com/v1/artists/7bu3H8JO7d0UbMoVzbo70s',
#      'id': '7bu3H8JO7d0UbMoVzbo70s',
#      'name': 'The Cure',
#      'type': 'artist',
#      'uri': 'spotify:artist:7bu3H8JO7d0UbMoVzbo70s'}],
#    'available_markets': ['CA', 'US'],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/7gPql7GFpBMOxeO80vMMsC'},
#    'href': 'https://api.spotify.com/v1/albums/7gPql7GFpBMOxeO80vMMsC',
#    'id': '7gPql7GFpBMOxeO80vMMsC',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b2735d0d65102be8606e439e54cc',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/ab67616d00001e025d0d65102be8606e439e54cc',
#      'width': 300},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/ab67616d000048515d0d65102be8606e439e54cc',
#      'width': 64}],
#    'name': 'Three Imaginary Boys (Deluxe Edition)',
#    'release_date': '1979-05-11',
#    'release_date_precision': 'day',
#    'total_tracks': 33,
#    'type': 'album',
#    'uri': 'spotify:album:7gPql7GFpBMOxeO80vMMsC'},
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7bu3H8JO7d0UbMoVzbo70s'},
#     'href': 'https://api.spotify.com/v1/artists/7bu3H8JO7d0UbMoVzbo70s',
#     'id': '7bu3H8JO7d0UbMoVzbo70s',
#     'name': 'The Cure',
#     'type': 'artist',
#     'uri': 'spotify:artist:7bu3H8JO7d0UbMoVzbo70s'}],
#   'available_markets': ['CA', 'US'],
#   'disc_number': 1,
#   'duration_ms': 157533,
#   'explicit': False,
#   'external_ids': {'isrc': 'USEE10413404'},
#   'external_urls': {'spotify': 'https://open.spotify.com/track/4dneV7C1yDt9UtyxrQY375'},
#   'href': 'https://api.spotify.com/v1/tracks/4dneV7C1yDt9UtyxrQY375',
#   'id': '4dneV7C1yDt9UtyxrQY375',
#   'is_local': False,
#   'name': "Boys Don't Cry - Single Version",
#   'popularity': 67,
#   'preview_url': 'https://p.scdn.co/mp3-preview/7fedf0d2730a71fcc3870f4e09ec4d5464969414?cid=da00ed264eaf4f94ba2adf23ff058567',
#   'track_number': 29,
#   'type': 'track',
#   'uri': 'spotify:track:4dneV7C1yDt9UtyxrQY375'},
#  {'album': {'album_type': 'compilation',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7bu3H8JO7d0UbMoVzbo70s'},
#      'href': 'https://api.spotify.com/v1/artists/7bu3H8JO7d0UbMoVzbo70s',
#      'id': '7bu3H8JO7d0UbMoVzbo70s',
#      'name': 'The Cure',
#      'type': 'artist',
#      'uri': 'spotify:artist:7bu3H8JO7d0UbMoVzbo70s'}],
#    'available_markets': ['CA', 'US'],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/34ozkv3AkFksZD8srOmOrX'},
#    'href': 'https://api.spotify.com/v1/albums/34ozkv3AkFksZD8srOmOrX',
#    'id': '34ozkv3AkFksZD8srOmOrX',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b2730447ba639949dd26478decf6',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/ab67616d00001e020447ba639949dd26478decf6',
#      'width': 300},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/ab67616d000048510447ba639949dd26478decf6',
#      'width': 64}],
#    'name': 'Greatest Hits',
#    'release_date': '2001-11-13',
#    'release_date_precision': 'day',
#    'total_tracks': 18,
#    'type': 'album',
#    'uri': 'spotify:album:34ozkv3AkFksZD8srOmOrX'},
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7bu3H8JO7d0UbMoVzbo70s'},
#     'href': 'https://api.spotify.com/v1/artists/7bu3H8JO7d0UbMoVzbo70s',
#     'id': '7bu3H8JO7d0UbMoVzbo70s',
#     'name': 'The Cure',
#     'type': 'artist',
#     'uri': 'spotify:artist:7bu3H8JO7d0UbMoVzbo70s'}],
#   'available_markets': ['CA', 'US'],
#   'disc_number': 1,
#   'duration_ms': 208333,
#   'explicit': False,
#   'external_ids': {'isrc': 'GBALB8900003'},
#   'external_urls': {'spotify': 'https://open.spotify.com/track/7K71priwuwcWwbgfHVQJdq'},
#   'href': 'https://api.spotify.com/v1/tracks/7K71priwuwcWwbgfHVQJdq',
#   'id': '7K71priwuwcWwbgfHVQJdq',
#   'is_local': False,
#   'name': 'Lovesong',
#   'popularity': 52,
#   'preview_url': 'https://p.scdn.co/mp3-preview/20f86da3c82de45a2f1800970976f4bb7975f951?cid=da00ed264eaf4f94ba2adf23ff058567',
#   'track_number': 11,
#   'type': 'track',
#   'uri': 'spotify:track:7K71priwuwcWwbgfHVQJdq'},
#  {'album': {'album_type': 'compilation',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7bu3H8JO7d0UbMoVzbo70s'},
#      'href': 'https://api.spotify.com/v1/artists/7bu3H8JO7d0UbMoVzbo70s',
#      'id': '7bu3H8JO7d0UbMoVzbo70s',
#      'name': 'The Cure',
#      'type': 'artist',
#      'uri': 'spotify:artist:7bu3H8JO7d0UbMoVzbo70s'}],
#    'available_markets': ['CA', 'US'],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/34ozkv3AkFksZD8srOmOrX'},
#    'href': 'https://api.spotify.com/v1/albums/34ozkv3AkFksZD8srOmOrX',
#    'id': '34ozkv3AkFksZD8srOmOrX',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b2730447ba639949dd26478decf6',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/ab67616d00001e020447ba639949dd26478decf6',
#      'width': 300},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/ab67616d000048510447ba639949dd26478decf6',
#      'width': 64}],
#    'name': 'Greatest Hits',
#    'release_date': '2001-11-13',
#    'release_date_precision': 'day',
#    'total_tracks': 18,
#    'type': 'album',
#    'uri': 'spotify:album:34ozkv3AkFksZD8srOmOrX'},
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7bu3H8JO7d0UbMoVzbo70s'},
#     'href': 'https://api.spotify.com/v1/artists/7bu3H8JO7d0UbMoVzbo70s',
#     'id': '7bu3H8JO7d0UbMoVzbo70s',
#     'name': 'The Cure',
#     'type': 'artist',
#     'uri': 'spotify:artist:7bu3H8JO7d0UbMoVzbo70s'}],
#   'available_markets': ['CA', 'US'],
#   'disc_number': 1,
#   'duration_ms': 157053,
#   'explicit': False,
#   'external_ids': {'isrc': 'GBALB7800001'},
#   'external_urls': {'spotify': 'https://open.spotify.com/track/2RKDbMwtJgKc76H9oPo7Cl'},
#   'href': 'https://api.spotify.com/v1/tracks/2RKDbMwtJgKc76H9oPo7Cl',
#   'id': '2RKDbMwtJgKc76H9oPo7Cl',
#   'is_local': False,
#   'name': "Boys Don't Cry",
#   'popularity': 60,
#   'preview_url': 'https://p.scdn.co/mp3-preview/9e77982ee6467aa9430fa5ee44e010313b21e85b?cid=da00ed264eaf4f94ba2adf23ff058567',
#   'track_number': 1,
#   'type': 'track',
#   'uri': 'spotify:track:2RKDbMwtJgKc76H9oPo7Cl'},
#  {'album': {'album_type': 'album',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7bu3H8JO7d0UbMoVzbo70s'},
#      'href': 'https://api.spotify.com/v1/artists/7bu3H8JO7d0UbMoVzbo70s',
#      'id': '7bu3H8JO7d0UbMoVzbo70s',
#      'name': 'The Cure',
#      'type': 'artist',
#      'uri': 'spotify:artist:7bu3H8JO7d0UbMoVzbo70s'}],
#    'available_markets': ['CA', 'US'],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/6vQB3ZBxnQPP3jQcGV2qzg'},
#    'href': 'https://api.spotify.com/v1/albums/6vQB3ZBxnQPP3jQcGV2qzg',
#    'id': '6vQB3ZBxnQPP3jQcGV2qzg',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b273c7ca2db25ad377e022bc3975',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/ab67616d00001e02c7ca2db25ad377e022bc3975',
#      'width': 300},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/ab67616d00004851c7ca2db25ad377e022bc3975',
#      'width': 64}],
#    'name': 'Disintegration (Deluxe Edition)',
#    'release_date': '1989-05-02',
#    'release_date_precision': 'day',
#    'total_tracks': 44,
#    'type': 'album',
#    'uri': 'spotify:album:6vQB3ZBxnQPP3jQcGV2qzg'},
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7bu3H8JO7d0UbMoVzbo70s'},
#     'href': 'https://api.spotify.com/v1/artists/7bu3H8JO7d0UbMoVzbo70s',
#     'id': '7bu3H8JO7d0UbMoVzbo70s',
#     'name': 'The Cure',
#     'type': 'artist',
#     'uri': 'spotify:artist:7bu3H8JO7d0UbMoVzbo70s'}],
#   'available_markets': ['CA', 'US'],
#   'disc_number': 1,
#   'duration_ms': 448466,
#   'explicit': False,
#   'external_ids': {'isrc': 'USEE10901453'},
#   'external_urls': {'spotify': 'https://open.spotify.com/track/1tuwC1Ob5vnYZhvg3zyzJg'},
#   'href': 'https://api.spotify.com/v1/tracks/1tuwC1Ob5vnYZhvg3zyzJg',
#   'id': '1tuwC1Ob5vnYZhvg3zyzJg',
#   'is_local': False,
#   'name': 'Pictures of You - 2010 Remaster',
#   'popularity': 58,
#   'preview_url': 'https://p.scdn.co/mp3-preview/3fd2102e7fb1fc4b60cb00c39dfa436cb90a4b41?cid=da00ed264eaf4f94ba2adf23ff058567',
#   'track_number': 2,
#   'type': 'track',
#   'uri': 'spotify:track:1tuwC1Ob5vnYZhvg3zyzJg'},
#  {'album': {'album_type': 'album',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7bu3H8JO7d0UbMoVzbo70s'},
#      'href': 'https://api.spotify.com/v1/artists/7bu3H8JO7d0UbMoVzbo70s',
#      'id': '7bu3H8JO7d0UbMoVzbo70s',
#      'name': 'The Cure',
#      'type': 'artist',
#      'uri': 'spotify:artist:7bu3H8JO7d0UbMoVzbo70s'}],
#    'available_markets': ['CA', 'US'],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/2KWHRfKSRpgsxNGIl2nQva'},
#    'href': 'https://api.spotify.com/v1/albums/2KWHRfKSRpgsxNGIl2nQva',
#    'id': '2KWHRfKSRpgsxNGIl2nQva',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b27329935216b69c7721582eab4c',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/ab67616d00001e0229935216b69c7721582eab4c',
#      'width': 300},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/ab67616d0000485129935216b69c7721582eab4c',
#      'width': 64}],
#    'name': 'Seventeen Seconds',
#    'release_date': '1980-04-18',
#    'release_date_precision': 'day',
#    'total_tracks': 10,
#    'type': 'album',
#    'uri': 'spotify:album:2KWHRfKSRpgsxNGIl2nQva'},
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7bu3H8JO7d0UbMoVzbo70s'},
#     'href': 'https://api.spotify.com/v1/artists/7bu3H8JO7d0UbMoVzbo70s',
#     'id': '7bu3H8JO7d0UbMoVzbo70s',
#     'name': 'The Cure',
#     'type': 'artist',
#     'uri': 'spotify:artist:7bu3H8JO7d0UbMoVzbo70s'}],
#   'available_markets': ['CA', 'US'],
#   'disc_number': 1,
#   'duration_ms': 184293,
#   'explicit': False,
#   'external_ids': {'isrc': 'USEE10500789'},
#   'external_urls': {'spotify': 'https://open.spotify.com/track/6lGRiGJcWg1WiPLi7KoQvq'},
#   'href': 'https://api.spotify.com/v1/tracks/6lGRiGJcWg1WiPLi7KoQvq',
#   'id': '6lGRiGJcWg1WiPLi7KoQvq',
#   'is_local': False,
#   'name': 'M - 2006 Remaster',
#   'popularity': 46,
#   'preview_url': 'https://p.scdn.co/mp3-preview/1033261503363a3963fcee0bb04d661edaed77c1?cid=da00ed264eaf4f94ba2adf23ff058567',
#   'track_number': 8,
#   'type': 'track',
#   'uri': 'spotify:track:6lGRiGJcWg1WiPLi7KoQvq'},
#  {'album': {'album_type': 'album',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7bu3H8JO7d0UbMoVzbo70s'},
#      'href': 'https://api.spotify.com/v1/artists/7bu3H8JO7d0UbMoVzbo70s',
#      'id': '7bu3H8JO7d0UbMoVzbo70s',
#      'name': 'The Cure',
#      'type': 'artist',
#      'uri': 'spotify:artist:7bu3H8JO7d0UbMoVzbo70s'}],
#    'available_markets': ['CA', 'US'],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/6HhpmJekzDCRu2K64ZbWqw'},
#    'href': 'https://api.spotify.com/v1/albums/6HhpmJekzDCRu2K64ZbWqw',
#    'id': '6HhpmJekzDCRu2K64ZbWqw',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b2731b54add5c2a3a337e512941b',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/ab67616d00001e021b54add5c2a3a337e512941b',
#      'width': 300},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/ab67616d000048511b54add5c2a3a337e512941b',
#      'width': 64}],
#    'name': 'The Head on the Door',
#    'release_date': '1985-08-26',
#    'release_date_precision': 'day',
#    'total_tracks': 10,
#    'type': 'album',
#    'uri': 'spotify:album:6HhpmJekzDCRu2K64ZbWqw'},
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7bu3H8JO7d0UbMoVzbo70s'},
#     'href': 'https://api.spotify.com/v1/artists/7bu3H8JO7d0UbMoVzbo70s',
#     'id': '7bu3H8JO7d0UbMoVzbo70s',
#     'name': 'The Cure',
#     'type': 'artist',
#     'uri': 'spotify:artist:7bu3H8JO7d0UbMoVzbo70s'}],
#   'available_markets': ['CA', 'US'],
#   'disc_number': 1,
#   'duration_ms': 203266,
#   'explicit': False,
#   'external_ids': {'isrc': 'USEE10608884'},
#   'external_urls': {'spotify': 'https://open.spotify.com/track/7ABE6G4uQxbNtYgVrpBBPA'},
#   'href': 'https://api.spotify.com/v1/tracks/7ABE6G4uQxbNtYgVrpBBPA',
#   'id': '7ABE6G4uQxbNtYgVrpBBPA',
#   'is_local': False,
#   'name': 'Close to Me - 2006 Remaster',
#   'popularity': 63,
#   'preview_url': 'https://p.scdn.co/mp3-preview/c296ae38843f51f32552788b1adcb28b872c312f?cid=da00ed264eaf4f94ba2adf23ff058567',
#   'track_number': 7,
#   'type': 'track',
#   'uri': 'spotify:track:7ABE6G4uQxbNtYgVrpBBPA'},
#  {'album': {'album_type': 'compilation',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7bu3H8JO7d0UbMoVzbo70s'},
#      'href': 'https://api.spotify.com/v1/artists/7bu3H8JO7d0UbMoVzbo70s',
#      'id': '7bu3H8JO7d0UbMoVzbo70s',
#      'name': 'The Cure',
#      'type': 'artist',
#      'uri': 'spotify:artist:7bu3H8JO7d0UbMoVzbo70s'}],
#    'available_markets': ['CA', 'US'],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/0BRThmbAV1p2CxAuxgpHRj'},
#    'href': 'https://api.spotify.com/v1/albums/0BRThmbAV1p2CxAuxgpHRj',
#    'id': '0BRThmbAV1p2CxAuxgpHRj',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b2732780880a9583a363c28c60d5',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/ab67616d00001e022780880a9583a363c28c60d5',
#      'width': 300},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/ab67616d000048512780880a9583a363c28c60d5',
#      'width': 64}],
#    'name': 'Galore',
#    'release_date': '1997-10-17',
#    'release_date_precision': 'day',
#    'total_tracks': 18,
#    'type': 'album',
#    'uri': 'spotify:album:0BRThmbAV1p2CxAuxgpHRj'},
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7bu3H8JO7d0UbMoVzbo70s'},
#     'href': 'https://api.spotify.com/v1/artists/7bu3H8JO7d0UbMoVzbo70s',
#     'id': '7bu3H8JO7d0UbMoVzbo70s',
#     'name': 'The Cure',
#     'type': 'artist',
#     'uri': 'spotify:artist:7bu3H8JO7d0UbMoVzbo70s'}],
#   'available_markets': ['CA', 'US'],
#   'disc_number': 1,
#   'duration_ms': 288026,
#   'explicit': False,
#   'external_ids': {'isrc': 'USEE19000007'},
#   'external_urls': {'spotify': 'https://open.spotify.com/track/5CgHsJyqFuW1U0E3d4Eyi6'},
#   'href': 'https://api.spotify.com/v1/tracks/5CgHsJyqFuW1U0E3d4Eyi6',
#   'id': '5CgHsJyqFuW1U0E3d4Eyi6',
#   'is_local': False,
#   'name': 'Pictures of You',
#   'popularity': 48,
#   'preview_url': 'https://p.scdn.co/mp3-preview/04ee76e1e16d6abefa15e5a67c12f8aaeaa313b7?cid=da00ed264eaf4f94ba2adf23ff058567',
#   'track_number': 8,
#   'type': 'track',
#   'uri': 'spotify:track:5CgHsJyqFuW1U0E3d4Eyi6'},
#  {'album': {'album_type': 'album',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7bu3H8JO7d0UbMoVzbo70s'},
#      'href': 'https://api.spotify.com/v1/artists/7bu3H8JO7d0UbMoVzbo70s',
#      'id': '7bu3H8JO7d0UbMoVzbo70s',
#      'name': 'The Cure',
#      'type': 'artist',
#      'uri': 'spotify:artist:7bu3H8JO7d0UbMoVzbo70s'}],
#    'available_markets': ['CA', 'US'],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/4Uq47onfCEj5en94jpHovk'},
#    'href': 'https://api.spotify.com/v1/albums/4Uq47onfCEj5en94jpHovk',
#    'id': '4Uq47onfCEj5en94jpHovk',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b27396e854c582f5213d51793cc2',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/ab67616d00001e0296e854c582f5213d51793cc2',
#      'width': 300},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/ab67616d0000485196e854c582f5213d51793cc2',
#      'width': 64}],
#    'name': 'The Head on the Door (Deluxed Edition)',
#    'release_date': '1985-08-26',
#    'release_date_precision': 'day',
#    'total_tracks': 28,
#    'type': 'album',
#    'uri': 'spotify:album:4Uq47onfCEj5en94jpHovk'},
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7bu3H8JO7d0UbMoVzbo70s'},
#     'href': 'https://api.spotify.com/v1/artists/7bu3H8JO7d0UbMoVzbo70s',
#     'id': '7bu3H8JO7d0UbMoVzbo70s',
#     'name': 'The Cure',
#     'type': 'artist',
#     'uri': 'spotify:artist:7bu3H8JO7d0UbMoVzbo70s'}],
#   'available_markets': ['CA', 'US'],
#   'disc_number': 1,
#   'duration_ms': 177986,
#   'explicit': False,
#   'external_ids': {'isrc': 'USEE10608886'},
#   'external_urls': {'spotify': 'https://open.spotify.com/track/07CyrZF9eVd02zzIse7tZA'},
#   'href': 'https://api.spotify.com/v1/tracks/07CyrZF9eVd02zzIse7tZA',
#   'id': '07CyrZF9eVd02zzIse7tZA',
#   'is_local': False,
#   'name': 'In Between Days - 2006 Remaster',
#   'popularity': 59,
#   'preview_url': 'https://p.scdn.co/mp3-preview/21569cc17cecfcfe601ead64427b705c5b220a0b?cid=da00ed264eaf4f94ba2adf23ff058567',
#   'track_number': 1,
#   'type': 'track',
#   'uri': 'spotify:track:07CyrZF9eVd02zzIse7tZA'},
#  {'album': {'album_type': 'album',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7bu3H8JO7d0UbMoVzbo70s'},
#      'href': 'https://api.spotify.com/v1/artists/7bu3H8JO7d0UbMoVzbo70s',
#      'id': '7bu3H8JO7d0UbMoVzbo70s',
#      'name': 'The Cure',
#      'type': 'artist',
#      'uri': 'spotify:artist:7bu3H8JO7d0UbMoVzbo70s'}],
#    'available_markets': ['CA', 'US'],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/1T7A6Dt7KktX7pOw4I4Jzj'},
#    'href': 'https://api.spotify.com/v1/albums/1T7A6Dt7KktX7pOw4I4Jzj',
#    'id': '1T7A6Dt7KktX7pOw4I4Jzj',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b27399027d2948260fdb37436d5d',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/ab67616d00001e0299027d2948260fdb37436d5d',
#      'width': 300},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/ab67616d0000485199027d2948260fdb37436d5d',
#      'width': 64}],
#    'name': 'Seventeen Seconds (Deluxe Edition)',
#    'release_date': '1980-04-18',
#    'release_date_precision': 'day',
#    'total_tracks': 25,
#    'type': 'album',
#    'uri': 'spotify:album:1T7A6Dt7KktX7pOw4I4Jzj'},
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7bu3H8JO7d0UbMoVzbo70s'},
#     'href': 'https://api.spotify.com/v1/artists/7bu3H8JO7d0UbMoVzbo70s',
#     'id': '7bu3H8JO7d0UbMoVzbo70s',
#     'name': 'The Cure',
#     'type': 'artist',
#     'uri': 'spotify:artist:7bu3H8JO7d0UbMoVzbo70s'}],
#   'available_markets': ['CA', 'US'],
#   'disc_number': 1,
#   'duration_ms': 354933,
#   'explicit': False,
#   'external_ids': {'isrc': 'USEE10500788'},
#   'external_urls': {'spotify': 'https://open.spotify.com/track/3O4TPMOgChXOerSdB5WENH'},
#   'href': 'https://api.spotify.com/v1/tracks/3O4TPMOgChXOerSdB5WENH',
#   'id': '3O4TPMOgChXOerSdB5WENH',
#   'is_local': False,
#   'name': 'A Forest - 2006 Remaster',
#   'popularity': 57,
#   'preview_url': 'https://p.scdn.co/mp3-preview/3cb92ffc0db9c7cd8480ccc28308e26478a52a81?cid=da00ed264eaf4f94ba2adf23ff058567',
#   'track_number': 7,
#   'type': 'track',
#   'uri': 'spotify:track:3O4TPMOgChXOerSdB5WENH'},
#  {'album': {'album_type': 'album',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7bu3H8JO7d0UbMoVzbo70s'},
#      'href': 'https://api.spotify.com/v1/artists/7bu3H8JO7d0UbMoVzbo70s',
#      'id': '7bu3H8JO7d0UbMoVzbo70s',
#      'name': 'The Cure',
#      'type': 'artist',
#      'uri': 'spotify:artist:7bu3H8JO7d0UbMoVzbo70s'}],
#    'available_markets': ['CA', 'US'],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/6vQB3ZBxnQPP3jQcGV2qzg'},
#    'href': 'https://api.spotify.com/v1/albums/6vQB3ZBxnQPP3jQcGV2qzg',
#    'id': '6vQB3ZBxnQPP3jQcGV2qzg',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b273c7ca2db25ad377e022bc3975',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/ab67616d00001e02c7ca2db25ad377e022bc3975',
#      'width': 300},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/ab67616d00004851c7ca2db25ad377e022bc3975',
#      'width': 64}],
#    'name': 'Disintegration (Deluxe Edition)',
#    'release_date': '1989-05-02',
#    'release_date_precision': 'day',
#    'total_tracks': 44,
#    'type': 'album',
#    'uri': 'spotify:album:6vQB3ZBxnQPP3jQcGV2qzg'},
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7bu3H8JO7d0UbMoVzbo70s'},
#     'href': 'https://api.spotify.com/v1/artists/7bu3H8JO7d0UbMoVzbo70s',
#     'id': '7bu3H8JO7d0UbMoVzbo70s',
#     'name': 'The Cure',
#     'type': 'artist',
#     'uri': 'spotify:artist:7bu3H8JO7d0UbMoVzbo70s'}],
#   'available_markets': ['CA', 'US'],
#   'disc_number': 1,
#   'duration_ms': 249880,
#   'explicit': False,
#   'external_ids': {'isrc': 'USEE10901457'},
#   'external_urls': {'spotify': 'https://open.spotify.com/track/4d4oXk7O2lEhZ83ivV93li'},
#   'href': 'https://api.spotify.com/v1/tracks/4d4oXk7O2lEhZ83ivV93li',
#   'id': '4d4oXk7O2lEhZ83ivV93li',
#   'is_local': False,
#   'name': 'Lullaby - 2010 Remaster',
#   'popularity': 56,
#   'preview_url': 'https://p.scdn.co/mp3-preview/5e9958a03f344620bd8a4344d8f5160adc6d09aa?cid=da00ed264eaf4f94ba2adf23ff058567',
#   'track_number': 6,
#   'type': 'track',
#   'uri': 'spotify:track:4d4oXk7O2lEhZ83ivV93li'},
#  {'album': {'album_type': 'compilation',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0LyfQWJT6nXafLPZqxe9Of'},
#      'href': 'https://api.spotify.com/v1/artists/0LyfQWJT6nXafLPZqxe9Of',
#      'id': '0LyfQWJT6nXafLPZqxe9Of',
#      'name': 'Various Artists',
#      'type': 'artist',
#      'uri': 'spotify:artist:0LyfQWJT6nXafLPZqxe9Of'}],
#    'available_markets': ['AD',
#     'AE',
#     'AG',
#     'AL',
#     'AM',
#     'AO',
#     'AR',
#     'AT',
#     'AU',
#     'AZ',
#     'BA',
#     'BB',
#     'BD',
#     'BE',
#     'BF',
#     'BG',
#     'BH',
#     'BI',
#     'BJ',
#     'BN',
#     'BO',
#     'BR',
#     'BS',
#     'BT',
#     'BW',
#     'BY',
#     'BZ',
#     'CA',
#     'CD',
#     'CG',
#     'CH',
#     'CI',
#     'CL',
#     'CM',
#     'CO',
#     'CR',
#     'CV',
#     'CW',
#     'CY',
#     'CZ',
#     'DE',
#     'DJ',
#     'DK',
#     'DM',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FJ',
#     'FM',
#     'FR',
#     'GA',
#     'GB',
#     'GD',
#     'GE',
#     'GH',
#     'GM',
#     'GN',
#     'GQ',
#     'GR',
#     'GT',
#     'GW',
#     'GY',
#     'HK',
#     'HN',
#     'HR',
#     'HT',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IQ',
#     'IS',
#     'IT',
#     'JM',
#     'JO',
#     'JP',
#     'KE',
#     'KG',
#     'KH',
#     'KI',
#     'KM',
#     'KN',
#     'KR',
#     'KW',
#     'KZ',
#     'LA',
#     'LB',
#     'LC',
#     'LI',
#     'LK',
#     'LR',
#     'LS',
#     'LT',
#     'LU',
#     'LV',
#     'LY',
#     'MA',
#     'MC',
#     'MD',
#     'ME',
#     'MG',
#     'MH',
#     'MK',
#     'ML',
#     'MN',
#     'MO',
#     'MR',
#     'MT',
#     'MU',
#     'MV',
#     'MW',
#     'MX',
#     'MY',
#     'MZ',
#     'NA',
#     'NE',
#     'NG',
#     'NI',
#     'NL',
#     'NO',
#     'NP',
#     'NR',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PG',
#     'PH',
#     'PK',
#     'PL',
#     'PS',
#     'PT',
#     'PW',
#     'PY',
#     'QA',
#     'RO',
#     'RS',
#     'RW',
#     'SA',
#     'SB',
#     'SC',
#     'SE',
#     'SG',
#     'SI',
#     'SK',
#     'SL',
#     'SM',
#     'SN',
#     'SR',
#     'ST',
#     'SV',
#     'SZ',
#     'TD',
#     'TG',
#     'TH',
#     'TJ',
#     'TL',
#     'TN',
#     'TO',
#     'TR',
#     'TT',
#     'TV',
#     'TW',
#     'TZ',
#     'UA',
#     'UG',
#     'US',
#     'UY',
#     'UZ',
#     'VC',
#     'VE',
#     'VN',
#     'VU',
#     'WS',
#     'XK',
#     'ZA',
#     'ZM',
#     'ZW'],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/3y7Mwv7UqhABQqsGlzSL6n'},
#    'href': 'https://api.spotify.com/v1/albums/3y7Mwv7UqhABQqsGlzSL6n',
#    'id': '3y7Mwv7UqhABQqsGlzSL6n',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b27308d27bfc2ff1a7b11b66c65c',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/ab67616d00001e0208d27bfc2ff1a7b11b66c65c',
#      'width': 300},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/ab67616d0000485108d27bfc2ff1a7b11b66c65c',
#      'width': 64}],
#    'name': 'The Crow Original Motion Picture Soundtrack',
#    'release_date': '1994-03-25',
#    'release_date_precision': 'day',
#    'total_tracks': 14,
#    'type': 'album',
#    'uri': 'spotify:album:3y7Mwv7UqhABQqsGlzSL6n'},
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7bu3H8JO7d0UbMoVzbo70s'},
#     'href': 'https://api.spotify.com/v1/artists/7bu3H8JO7d0UbMoVzbo70s',
#     'id': '7bu3H8JO7d0UbMoVzbo70s',
#     'name': 'The Cure',
#     'type': 'artist',
#     'uri': 'spotify:artist:7bu3H8JO7d0UbMoVzbo70s'}],
#   'available_markets': ['AD',
#    'AE',
#    'AG',
#    'AL',
#    'AM',
#    'AO',
#    'AR',
#    'AT',
#    'AU',
#    'AZ',
#    'BA',
#    'BB',
#    'BD',
#    'BE',
#    'BF',
#    'BG',
#    'BH',
#    'BI',
#    'BJ',
#    'BN',
#    'BO',
#    'BR',
#    'BS',
#    'BT',
#    'BW',
#    'BY',
#    'BZ',
#    'CA',
#    'CD',
#    'CG',
#    'CH',
#    'CI',
#    'CL',
#    'CM',
#    'CO',
#    'CR',
#    'CV',
#    'CW',
#    'CY',
#    'CZ',
#    'DE',
#    'DJ',
#    'DK',
#    'DM',
#    'DO',
#    'DZ',
#    'EC',
#    'EE',
#    'EG',
#    'ES',
#    'FI',
#    'FJ',
#    'FM',
#    'FR',
#    'GA',
#    'GB',
#    'GD',
#    'GE',
#    'GH',
#    'GM',
#    'GN',
#    'GQ',
#    'GR',
#    'GT',
#    'GW',
#    'GY',
#    'HK',
#    'HN',
#    'HR',
#    'HT',
#    'HU',
#    'ID',
#    'IE',
#    'IL',
#    'IN',
#    'IQ',
#    'IS',
#    'IT',
#    'JM',
#    'JO',
#    'JP',
#    'KE',
#    'KG',
#    'KH',
#    'KI',
#    'KM',
#    'KN',
#    'KR',
#    'KW',
#    'KZ',
#    'LA',
#    'LB',
#    'LC',
#    'LI',
#    'LK',
#    'LR',
#    'LS',
#    'LT',
#    'LU',
#    'LV',
#    'LY',
#    'MA',
#    'MC',
#    'MD',
#    'ME',
#    'MG',
#    'MH',
#    'MK',
#    'ML',
#    'MN',
#    'MO',
#    'MR',
#    'MT',
#    'MU',
#    'MV',
#    'MW',
#    'MX',
#    'MY',
#    'MZ',
#    'NA',
#    'NE',
#    'NG',
#    'NI',
#    'NL',
#    'NO',
#    'NP',
#    'NR',
#    'NZ',
#    'OM',
#    'PA',
#    'PE',
#    'PG',
#    'PH',
#    'PK',
#    'PL',
#    'PS',
#    'PT',
#    'PW',
#    'PY',
#    'QA',
#    'RO',
#    'RS',
#    'RW',
#    'SA',
#    'SB',
#    'SC',
#    'SE',
#    'SG',
#    'SI',
#    'SK',
#    'SL',
#    'SM',
#    'SN',
#    'SR',
#    'ST',
#    'SV',
#    'SZ',
#    'TD',
#    'TG',
#    'TH',
#    'TJ',
#    'TL',
#    'TN',
#    'TO',
#    'TR',
#    'TT',
#    'TV',
#    'TW',
#    'TZ',
#    'UA',
#    'UG',
#    'US',
#    'UY',
#    'UZ',
#    'VC',
#    'VE',
#    'VN',
#    'VU',
#    'WS',
#    'XK',
#    'ZA',
#    'ZM',
#    'ZW'],
#   'disc_number': 1,
#   'duration_ms': 398933,
#   'explicit': False,
#   'external_ids': {'isrc': 'USAT20180654'},
#   'external_urls': {'spotify': 'https://open.spotify.com/track/0tHOTQBn2M4CD2dcyHivth'},
#   'href': 'https://api.spotify.com/v1/tracks/0tHOTQBn2M4CD2dcyHivth',
#   'id': '0tHOTQBn2M4CD2dcyHivth',
#   'is_local': False,
#   'name': 'Burn',
#   'popularity': 56,
#   'preview_url': 'https://p.scdn.co/mp3-preview/5512a684c60087e42ed0516b38383a56d752cb61?cid=da00ed264eaf4f94ba2adf23ff058567',
#   'track_number': 1,
#   'type': 'track',
#   'uri': 'spotify:track:0tHOTQBn2M4CD2dcyHivth'},
#  {'album': {'album_type': 'album',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7bu3H8JO7d0UbMoVzbo70s'},
#      'href': 'https://api.spotify.com/v1/artists/7bu3H8JO7d0UbMoVzbo70s',
#      'id': '7bu3H8JO7d0UbMoVzbo70s',
#      'name': 'The Cure',
#      'type': 'artist',
#      'uri': 'spotify:artist:7bu3H8JO7d0UbMoVzbo70s'}],
#    'available_markets': ['CA', 'US'],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/6vQB3ZBxnQPP3jQcGV2qzg'},
#    'href': 'https://api.spotify.com/v1/albums/6vQB3ZBxnQPP3jQcGV2qzg',
#    'id': '6vQB3ZBxnQPP3jQcGV2qzg',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b273c7ca2db25ad377e022bc3975',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/ab67616d00001e02c7ca2db25ad377e022bc3975',
#      'width': 300},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/ab67616d00004851c7ca2db25ad377e022bc3975',
#      'width': 64}],
#    'name': 'Disintegration (Deluxe Edition)',
#    'release_date': '1989-05-02',
#    'release_date_precision': 'day',
#    'total_tracks': 44,
#    'type': 'album',
#    'uri': 'spotify:album:6vQB3ZBxnQPP3jQcGV2qzg'},
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7bu3H8JO7d0UbMoVzbo70s'},
#     'href': 'https://api.spotify.com/v1/artists/7bu3H8JO7d0UbMoVzbo70s',
#     'id': '7bu3H8JO7d0UbMoVzbo70s',
#     'name': 'The Cure',
#     'type': 'artist',
#     'uri': 'spotify:artist:7bu3H8JO7d0UbMoVzbo70s'}],
#   'available_markets': ['CA', 'US'],
#   'disc_number': 1,
#   'duration_ms': 499973,
#   'explicit': False,
#   'external_ids': {'isrc': 'USEE10901461'},
#   'external_urls': {'spotify': 'https://open.spotify.com/track/0zY8t5dC1KQXcPUKByWMJM'},
# ...
#    'UA',
#    'UG',
#    'US',
#    'UY',
#    'UZ',
#    'VC',
#    'VE',
#    'VN',
#    'VU',
#    'WS',
#    'XK',
#    'ZA',
#    'ZM',
#    'ZW'],
#   'disc_number': 1,
#   'duration_ms': 198857,
#   'explicit': False,
#   'external_ids': {'isrc': 'QZHNB1938775'},
#   'external_urls': {'spotify': 'https://open.spotify.com/track/7fxs7nifYb7b2XOzSvkPBj'},
#   'href': 'https://api.spotify.com/v1/tracks/7fxs7nifYb7b2XOzSvkPBj',
#   'id': '7fxs7nifYb7b2XOzSvkPBj',
#   'is_local': False,
#   'name': 'The Cure',
#   'popularity': 39,
#   'preview_url': 'https://p.scdn.co/mp3-preview/1e551dd4753f4c429d4cbbd91ea2f35d372dbe09?cid=da00ed264eaf4f94ba2adf23ff058567',
#   'track_number': 1,
#   'type': 'track',
#   'uri': 'spotify:track:7fxs7nifYb7b2XOzSvkPBj'},
#  {'album': {'album_type': 'album',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5k979N1TnPncUyqlXlaRSv'},
#      'href': 'https://api.spotify.com/v1/artists/5k979N1TnPncUyqlXlaRSv',
#      'id': '5k979N1TnPncUyqlXlaRSv',
#      'name': 'The Longest Johns',
#      'type': 'artist',
#      'uri': 'spotify:artist:5k979N1TnPncUyqlXlaRSv'}],
#    'available_markets': ['AD',
#     'AE',
#     'AG',
#     'AL',
#     'AM',
#     'AO',
#     'AR',
#     'AT',
#     'AU',
#     'AZ',
#     'BA',
#     'BB',
#     'BD',
#     'BE',
#     'BF',
#     'BG',
#     'BH',
#     'BI',
#     'BJ',
#     'BN',
#     'BO',
#     'BR',
#     'BS',
#     'BT',
#     'BW',
#     'BY',
#     'BZ',
#     'CA',
#     'CD',
#     'CG',
#     'CH',
#     'CI',
#     'CL',
#     'CM',
#     'CO',
#     'CR',
#     'CV',
#     'CW',
#     'CY',
#     'CZ',
#     'DE',
#     'DJ',
#     'DK',
#     'DM',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FJ',
#     'FM',
#     'FR',
#     'GA',
#     'GB',
#     'GD',
#     'GE',
#     'GH',
#     'GM',
#     'GN',
#     'GQ',
#     'GR',
#     'GT',
#     'GW',
#     'GY',
#     'HK',
#     'HN',
#     'HR',
#     'HT',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IQ',
#     'IS',
#     'IT',
#     'JM',
#     'JO',
#     'JP',
#     'KE',
#     'KG',
#     'KH',
#     'KI',
#     'KM',
#     'KN',
#     'KR',
#     'KW',
#     'KZ',
#     'LA',
#     'LB',
#     'LC',
#     'LI',
#     'LK',
#     'LR',
#     'LS',
#     'LT',
#     'LU',
#     'LV',
#     'LY',
#     'MA',
#     'MC',
#     'MD',
#     'ME',
#     'MG',
#     'MH',
#     'MK',
#     'ML',
#     'MN',
#     'MO',
#     'MR',
#     'MT',
#     'MU',
#     'MV',
#     'MW',
#     'MX',
#     'MY',
#     'MZ',
#     'NA',
#     'NE',
#     'NG',
#     'NI',
#     'NL',
#     'NO',
#     'NP',
#     'NR',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PG',
#     'PH',
#     'PK',
#     'PL',
#     'PS',
#     'PT',
#     'PW',
#     'PY',
#     'QA',
#     'RO',
#     'RS',
#     'RW',
#     'SA',
#     'SB',
#     'SC',
#     'SE',
#     'SG',
#     'SI',
#     'SK',
#     'SL',
#     'SM',
#     'SN',
#     'SR',
#     'ST',
#     'SV',
#     'SZ',
#     'TD',
#     'TG',
#     'TH',
#     'TJ',
#     'TL',
#     'TN',
#     'TO',
#     'TR',
#     'TT',
#     'TV',
#     'TW',
#     'TZ',
#     'UA',
#     'UG',
#     'US',
#     'UY',
#     'UZ',
#     'VC',
#     'VE',
#     'VN',
#     'VU',
#     'WS',
#     'XK',
#     'ZA',
#     'ZM',
#     'ZW'],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/23FGerfaTcQOlEdySv5Wdq'},
#    'href': 'https://api.spotify.com/v1/albums/23FGerfaTcQOlEdySv5Wdq',
#    'id': '23FGerfaTcQOlEdySv5Wdq',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b2730e344b28681e6ee72eb67f78',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/ab67616d00001e020e344b28681e6ee72eb67f78',
#      'width': 300},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/ab67616d000048510e344b28681e6ee72eb67f78',
#      'width': 64}],
#    'name': 'Cures What Ails Ya',
#    'release_date': '2020-06-10',
#    'release_date_precision': 'day',
#    'total_tracks': 12,
#    'type': 'album',
#    'uri': 'spotify:album:23FGerfaTcQOlEdySv5Wdq'},
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5k979N1TnPncUyqlXlaRSv'},
#     'href': 'https://api.spotify.com/v1/artists/5k979N1TnPncUyqlXlaRSv',
#     'id': '5k979N1TnPncUyqlXlaRSv',
#     'name': 'The Longest Johns',
#     'type': 'artist',
#     'uri': 'spotify:artist:5k979N1TnPncUyqlXlaRSv'}],
#   'available_markets': ['AD',
#    'AE',
#    'AG',
#    'AL',
#    'AM',
#    'AO',
#    'AR',
#    'AT',
#    'AU',
#    'AZ',
#    'BA',
#    'BB',
#    'BD',
#    'BE',
#    'BF',
#    'BG',
#    'BH',
#    'BI',
#    'BJ',
#    'BN',
#    'BO',
#    'BR',
#    'BS',
#    'BT',
#    'BW',
#    'BY',
#    'BZ',
#    'CA',
#    'CD',
#    'CG',
#    'CH',
#    'CI',
#    'CL',
#    'CM',
#    'CO',
#    'CR',
#    'CV',
#    'CW',
#    'CY',
#    'CZ',
#    'DE',
#    'DJ',
#    'DK',
#    'DM',
#    'DO',
#    'DZ',
#    'EC',
#    'EE',
#    'EG',
#    'ES',
#    'FI',
#    'FJ',
#    'FM',
#    'FR',
#    'GA',
#    'GB',
#    'GD',
#    'GE',
#    'GH',
#    'GM',
#    'GN',
#    'GQ',
#    'GR',
#    'GT',
#    'GW',
#    'GY',
#    'HK',
#    'HN',
#    'HR',
#    'HT',
#    'HU',
#    'ID',
#    'IE',
#    'IL',
#    'IN',
#    'IQ',
#    'IS',
#    'IT',
#    'JM',
#    'JO',
#    'JP',
#    'KE',
#    'KG',
#    'KH',
#    'KI',
#    'KM',
#    'KN',
#    'KR',
#    'KW',
#    'KZ',
#    'LA',
#    'LB',
#    'LC',
#    'LI',
#    'LK',
#    'LR',
#    'LS',
#    'LT',
#    'LU',
#    'LV',
#    'LY',
#    'MA',
#    'MC',
#    'MD',
#    'ME',
#    'MG',
#    'MH',
#    'MK',
#    'ML',
#    'MN',
#    'MO',
#    'MR',
#    'MT',
#    'MU',
#    'MV',
#    'MW',
#    'MX',
#    'MY',
#    'MZ',
#    'NA',
#    'NE',
#    'NG',
#    'NI',
#    'NL',
#    'NO',
#    'NP',
#    'NR',
#    'NZ',
#    'OM',
#    'PA',
#    'PE',
#    'PG',
#    'PH',
#    'PK',
#    'PL',
#    'PS',
#    'PT',
#    'PW',
#    'PY',
#    'QA',
#    'RO',
#    'RS',
#    'RW',
#    'SA',
#    'SB',
#    'SC',
#    'SE',
#    'SG',
#    'SI',
#    'SK',
#    'SL',
#    'SM',
#    'SN',
#    'SR',
#    'ST',
#    'SV',
#    'SZ',
#    'TD',
#    'TG',
#    'TH',
#    'TJ',
#    'TL',
#    'TN',
#    'TO',
#    'TR',
#    'TT',
#    'TV',
#    'TW',
#    'TZ',
#    'UA',
#    'UG',
#    'US',
#    'UY',
#    'UZ',
#    'VC',
#    'VE',
#    'VN',
#    'VU',
#    'WS',
#    'XK',
#    'ZA',
#    'ZM',
#    'ZW'],
#   'disc_number': 1,
#   'duration_ms': 248940,
#   'explicit': False,
#   'external_ids': {'isrc': 'UKPGJ1800036'},
#   'external_urls': {'spotify': 'https://open.spotify.com/track/38FCXf9CTcH9MJKn3WsJ7x'},
#   'href': 'https://api.spotify.com/v1/tracks/38FCXf9CTcH9MJKn3WsJ7x',
#   'id': '38FCXf9CTcH9MJKn3WsJ7x',
#   'is_local': False,
#   'name': 'Oak & Ash & Thorn',
#   'popularity': 54,
#   'preview_url': 'https://p.scdn.co/mp3-preview/8c9746de9261a41061753da4b6cea0f99df782bc?cid=da00ed264eaf4f94ba2adf23ff058567',
#   'track_number': 8,
#   'type': 'track',
#   'uri': 'spotify:track:38FCXf9CTcH9MJKn3WsJ7x'},
#  {'album': {'album_type': 'compilation',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7bu3H8JO7d0UbMoVzbo70s'},
#      'href': 'https://api.spotify.com/v1/artists/7bu3H8JO7d0UbMoVzbo70s',
#      'id': '7bu3H8JO7d0UbMoVzbo70s',
#      'name': 'The Cure',
#      'type': 'artist',
#      'uri': 'spotify:artist:7bu3H8JO7d0UbMoVzbo70s'}],
#    'available_markets': ['CA', 'US'],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/34ozkv3AkFksZD8srOmOrX'},
#    'href': 'https://api.spotify.com/v1/albums/34ozkv3AkFksZD8srOmOrX',
#    'id': '34ozkv3AkFksZD8srOmOrX',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b2730447ba639949dd26478decf6',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/ab67616d00001e020447ba639949dd26478decf6',
#      'width': 300},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/ab67616d000048510447ba639949dd26478decf6',
#      'width': 64}],
#    'name': 'Greatest Hits',
#    'release_date': '2001-11-13',
#    'release_date_precision': 'day',
#    'total_tracks': 18,
#    'type': 'album',
#    'uri': 'spotify:album:34ozkv3AkFksZD8srOmOrX'},
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7bu3H8JO7d0UbMoVzbo70s'},
#     'href': 'https://api.spotify.com/v1/artists/7bu3H8JO7d0UbMoVzbo70s',
#     'id': '7bu3H8JO7d0UbMoVzbo70s',
#     'name': 'The Cure',
#     'type': 'artist',
#     'uri': 'spotify:artist:7bu3H8JO7d0UbMoVzbo70s'}],
#   'available_markets': ['CA', 'US'],
#   'disc_number': 1,
#   'duration_ms': 207653,
#   'explicit': False,
#   'external_ids': {'isrc': 'GBAKW0100362'},
#   'external_urls': {'spotify': 'https://open.spotify.com/track/49hCuCAtKKVR8K0y3sZilW'},
#   'href': 'https://api.spotify.com/v1/tracks/49hCuCAtKKVR8K0y3sZilW',
#   'id': '49hCuCAtKKVR8K0y3sZilW',
#   'is_local': False,
#   'name': 'Just Say Yes',
#   'popularity': 29,
#   'preview_url': 'https://p.scdn.co/mp3-preview/144e8b43a940fd0e429f0cb24b3686b14681cfb2?cid=da00ed264eaf4f94ba2adf23ff058567',
#   'track_number': 18,
#   'type': 'track',
#   'uri': 'spotify:track:49hCuCAtKKVR8K0y3sZilW'},
#  {'album': {'album_type': 'album',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0Z88iXWc4YVhtu1eFtsGk6'},
#      'href': 'https://api.spotify.com/v1/artists/0Z88iXWc4YVhtu1eFtsGk6',
#      'id': '0Z88iXWc4YVhtu1eFtsGk6',
#      'name': 'Wolves At The Gate',
#      'type': 'artist',
#      'uri': 'spotify:artist:0Z88iXWc4YVhtu1eFtsGk6'}],
#    'available_markets': ['AD',
#     'AE',
#     'AG',
#     'AL',
#     'AM',
#     'AO',
#     'AR',
#     'AT',
#     'AU',
#     'AZ',
#     'BA',
#     'BB',
#     'BD',
#     'BE',
#     'BF',
#     'BG',
#     'BH',
#     'BI',
#     'BJ',
#     'BN',
#     'BO',
#     'BR',
#     'BS',
#     'BT',
#     'BW',
#     'BY',
#     'BZ',
#     'CA',
#     'CD',
#     'CG',
#     'CH',
#     'CI',
#     'CL',
#     'CM',
#     'CO',
#     'CR',
#     'CV',
#     'CW',
#     'CY',
#     'CZ',
#     'DE',
#     'DJ',
#     'DK',
#     'DM',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FJ',
#     'FM',
#     'FR',
#     'GA',
#     'GB',
#     'GD',
#     'GE',
#     'GH',
#     'GM',
#     'GN',
#     'GQ',
#     'GR',
#     'GT',
#     'GW',
#     'GY',
#     'HK',
#     'HN',
#     'HR',
#     'HT',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IQ',
#     'IS',
#     'IT',
#     'JM',
#     'JO',
#     'JP',
#     'KE',
#     'KG',
#     'KH',
#     'KI',
#     'KM',
#     'KN',
#     'KR',
#     'KW',
#     'KZ',
#     'LA',
#     'LB',
#     'LC',
#     'LI',
#     'LK',
#     'LR',
#     'LS',
#     'LT',
#     'LU',
#     'LV',
#     'LY',
#     'MA',
#     'MC',
#     'MD',
#     'ME',
#     'MG',
#     'MH',
#     'MK',
#     'ML',
#     'MN',
#     'MO',
#     'MR',
#     'MT',
#     'MU',
#     'MV',
#     'MW',
#     'MX',
#     'MY',
#     'MZ',
#     'NA',
#     'NE',
#     'NG',
#     'NI',
#     'NL',
#     'NO',
#     'NP',
#     'NR',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PG',
#     'PH',
#     'PK',
#     'PL',
#     'PS',
#     'PT',
#     'PW',
#     'PY',
#     'QA',
#     'RO',
#     'RS',
#     'RW',
#     'SA',
#     'SB',
#     'SC',
#     'SE',
#     'SG',
#     'SI',
#     'SK',
#     'SL',
#     'SM',
#     'SN',
#     'SR',
#     'ST',
#     'SV',
#     'SZ',
#     'TD',
#     'TG',
#     'TH',
#     'TJ',
#     'TL',
#     'TN',
#     'TO',
#     'TR',
#     'TT',
#     'TV',
#     'TW',
#     'TZ',
#     'UA',
#     'UG',
#     'US',
#     'UY',
#     'UZ',
#     'VC',
#     'VE',
#     'VN',
#     'VU',
#     'WS',
#     'XK',
#     'ZA',
#     'ZM',
#     'ZW'],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/6L8gLKCluioceYP7WNmcol'},
#    'href': 'https://api.spotify.com/v1/albums/6L8gLKCluioceYP7WNmcol',
#    'id': '6L8gLKCluioceYP7WNmcol',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b273dc4299ee6013d5522734c4e7',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/ab67616d00001e02dc4299ee6013d5522734c4e7',
#      'width': 300},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/ab67616d00004851dc4299ee6013d5522734c4e7',
#      'width': 64}],
#    'name': 'Eclipse',
#    'release_date': '2019-07-26',
#    'release_date_precision': 'day',
#    'total_tracks': 13,
#    'type': 'album',
#    'uri': 'spotify:album:6L8gLKCluioceYP7WNmcol'},
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0Z88iXWc4YVhtu1eFtsGk6'},
#     'href': 'https://api.spotify.com/v1/artists/0Z88iXWc4YVhtu1eFtsGk6',
#     'id': '0Z88iXWc4YVhtu1eFtsGk6',
#     'name': 'Wolves At The Gate',
#     'type': 'artist',
#     'uri': 'spotify:artist:0Z88iXWc4YVhtu1eFtsGk6'}],
#   'available_markets': ['AD',
#    'AE',
#    'AG',
#    'AL',
#    'AM',
#    'AO',
#    'AR',
#    'AT',
#    'AU',
#    'AZ',
#    'BA',
#    'BB',
#    'BD',
#    'BE',
#    'BF',
#    'BG',
#    'BH',
#    'BI',
#    'BJ',
#    'BN',
#    'BO',
#    'BR',
#    'BS',
#    'BT',
#    'BW',
#    'BY',
#    'BZ',
#    'CA',
#    'CD',
#    'CG',
#    'CH',
#    'CI',
#    'CL',
#    'CM',
#    'CO',
#    'CR',
#    'CV',
#    'CW',
#    'CY',
#    'CZ',
#    'DE',
#    'DJ',
#    'DK',
#    'DM',
#    'DO',
#    'DZ',
#    'EC',
#    'EE',
#    'EG',
#    'ES',
#    'FI',
#    'FJ',
#    'FM',
#    'FR',
#    'GA',
#    'GB',
#    'GD',
#    'GE',
#    'GH',
#    'GM',
#    'GN',
#    'GQ',
#    'GR',
#    'GT',
#    'GW',
#    'GY',
#    'HK',
#    'HN',
#    'HR',
#    'HT',
#    'HU',
#    'ID',
#    'IE',
#    'IL',
#    'IN',
#    'IQ',
#    'IS',
#    'IT',
#    'JM',
#    'JO',
#    'JP',
#    'KE',
#    'KG',
#    'KH',
#    'KI',
#    'KM',
#    'KN',
#    'KR',
#    'KW',
#    'KZ',
#    'LA',
#    'LB',
#    'LC',
#    'LI',
#    'LK',
#    'LR',
#    'LS',
#    'LT',
#    'LU',
#    'LV',
#    'LY',
#    'MA',
#    'MC',
#    'MD',
#    'ME',
#    'MG',
#    'MH',
#    'MK',
#    'ML',
#    'MN',
#    'MO',
#    'MR',
#    'MT',
#    'MU',
#    'MV',
#    'MW',
#    'MX',
#    'MY',
#    'MZ',
#    'NA',
#    'NE',
#    'NG',
#    'NI',
#    'NL',
#    'NO',
#    'NP',
#    'NR',
#    'NZ',
#    'OM',
#    'PA',
#    'PE',
#    'PG',
#    'PH',
#    'PK',
#    'PL',
#    'PS',
#    'PT',
#    'PW',
#    'PY',
#    'QA',
#    'RO',
#    'RS',
#    'RW',
#    'SA',
#    'SB',
#    'SC',
#    'SE',
#    'SG',
#    'SI',
#    'SK',
#    'SL',
#    'SM',
#    'SN',
#    'SR',
#    'ST',
#    'SV',
#    'SZ',
#    'TD',
#    'TG',
#    'TH',
#    'TJ',
#    'TL',
#    'TN',
#    'TO',
#    'TR',
#    'TT',
#    'TV',
#    'TW',
#    'TZ',
#    'UA',
#    'UG',
#    'US',
#    'UY',
#    'UZ',
#    'VC',
#    'VE',
#    'VN',
#    'VU',
#    'WS',
#    'XK',
#    'ZA',
#    'ZM',
#    'ZW'],
#   'disc_number': 1,
#   'duration_ms': 256693,
#   'explicit': False,
#   'external_ids': {'isrc': 'QMGVJ1900011'},
#   'external_urls': {'spotify': 'https://open.spotify.com/track/3bimN1JcQkbLWcUJexAEyh'},
#   'href': 'https://api.spotify.com/v1/tracks/3bimN1JcQkbLWcUJexAEyh',
#   'id': '3bimN1JcQkbLWcUJexAEyh',
#   'is_local': False,
#   'name': 'The Cure',
#   'popularity': 36,
#   'preview_url': 'https://p.scdn.co/mp3-preview/27120fe278e19dd9288d1f4883a0d9860f7a02ff?cid=da00ed264eaf4f94ba2adf23ff058567',
#   'track_number': 1,
#   'type': 'track',
#   'uri': 'spotify:track:3bimN1JcQkbLWcUJexAEyh'},
#  {'album': {'album_type': 'compilation',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7bu3H8JO7d0UbMoVzbo70s'},
#      'href': 'https://api.spotify.com/v1/artists/7bu3H8JO7d0UbMoVzbo70s',
#      'id': '7bu3H8JO7d0UbMoVzbo70s',
#      'name': 'The Cure',
#      'type': 'artist',
#      'uri': 'spotify:artist:7bu3H8JO7d0UbMoVzbo70s'}],
#    'available_markets': ['CA', 'US'],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/0BRThmbAV1p2CxAuxgpHRj'},
#    'href': 'https://api.spotify.com/v1/albums/0BRThmbAV1p2CxAuxgpHRj',
#    'id': '0BRThmbAV1p2CxAuxgpHRj',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b2732780880a9583a363c28c60d5',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/ab67616d00001e022780880a9583a363c28c60d5',
#      'width': 300},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/ab67616d000048512780880a9583a363c28c60d5',
#      'width': 64}],
#    'name': 'Galore',
#    'release_date': '1997-10-17',
#    'release_date_precision': 'day',
#    'total_tracks': 18,
#    'type': 'album',
#    'uri': 'spotify:album:0BRThmbAV1p2CxAuxgpHRj'},
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7bu3H8JO7d0UbMoVzbo70s'},
#     'href': 'https://api.spotify.com/v1/artists/7bu3H8JO7d0UbMoVzbo70s',
#     'id': '7bu3H8JO7d0UbMoVzbo70s',
#     'name': 'The Cure',
#     'type': 'artist',
#     'uri': 'spotify:artist:7bu3H8JO7d0UbMoVzbo70s'}],
#   'available_markets': ['CA', 'US'],
#   'disc_number': 1,
#   'duration_ms': 361866,
#   'explicit': False,
#   'external_ids': {'isrc': 'GBALB9700001'},
#   'external_urls': {'spotify': 'https://open.spotify.com/track/03IHSEzItu1iHXaelC9tZy'},
#   'href': 'https://api.spotify.com/v1/tracks/03IHSEzItu1iHXaelC9tZy',
#   'id': '03IHSEzItu1iHXaelC9tZy',
#   'is_local': False,
#   'name': 'Wrong Number - Single Mix',
#   'popularity': 28,
#   'preview_url': 'https://p.scdn.co/mp3-preview/9706e93df53fbc897f44ee89c1d5ad8041ac9223?cid=da00ed264eaf4f94ba2adf23ff058567',
#   'track_number': 18,
#   'type': 'track',
#   'uri': 'spotify:track:03IHSEzItu1iHXaelC9tZy'}]

# %%
results['tracks']['limit']
# Out:
# 50

# %%
results['tracks']['next']
# Out:
# 'https://api.spotify.com/v1/search?query=The+Cure&type=track&offset=50&limit=50'

# %%
results['tracks']['offset']
# Out:
# 0

# %%
results['tracks']['previous']

# %%
len(results['tracks']['items'])
# Out:
# 50

# %%
results['tracks']['items'][0]
# Out:
# {'album': {'album_type': 'single',
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1HY2Jd0NmPuamShAr6KMms'},
#     'href': 'https://api.spotify.com/v1/artists/1HY2Jd0NmPuamShAr6KMms',
#     'id': '1HY2Jd0NmPuamShAr6KMms',
#     'name': 'Lady Gaga',
#     'type': 'artist',
#     'uri': 'spotify:artist:1HY2Jd0NmPuamShAr6KMms'}],
#   'available_markets': ['AD',
#    'AE',
#    'AG',
#    'AL',
#    'AM',
#    'AO',
#    'AR',
#    'AT',
#    'AU',
#    'AZ',
#    'BA',
#    'BB',
#    'BD',
#    'BE',
#    'BF',
#    'BG',
#    'BH',
#    'BI',
#    'BJ',
#    'BN',
#    'BO',
#    'BR',
#    'BS',
#    'BT',
#    'BW',
#    'BY',
#    'BZ',
#    'CA',
#    'CD',
#    'CG',
#    'CH',
#    'CI',
#    'CL',
#    'CM',
#    'CO',
#    'CR',
#    'CV',
#    'CW',
#    'CY',
#    'CZ',
#    'DE',
#    'DJ',
#    'DK',
#    'DM',
#    'DO',
#    'DZ',
#    'EC',
#    'EE',
#    'EG',
#    'ES',
#    'FI',
#    'FJ',
#    'FM',
#    'FR',
#    'GA',
#    'GB',
#    'GD',
#    'GE',
#    'GH',
#    'GM',
#    'GN',
#    'GQ',
#    'GR',
#    'GT',
#    'GW',
#    'GY',
#    'HK',
#    'HN',
#    'HR',
#    'HT',
#    'HU',
#    'ID',
#    'IE',
#    'IL',
#    'IN',
#    'IQ',
#    'IS',
#    'IT',
#    'JM',
#    'JO',
#    'JP',
#    'KE',
#    'KG',
#    'KH',
#    'KI',
#    'KM',
#    'KN',
#    'KR',
#    'KW',
#    'KZ',
#    'LA',
#    'LB',
#    'LC',
#    'LI',
#    'LK',
#    'LR',
#    'LS',
#    'LT',
#    'LU',
#    'LV',
#    'LY',
#    'MA',
#    'MC',
#    'MD',
#    'ME',
#    'MG',
#    'MH',
#    'MK',
#    'ML',
#    'MN',
#    'MO',
#    'MR',
#    'MT',
#    'MU',
#    'MV',
#    'MW',
#    'MX',
#    'MY',
#    'MZ',
#    'NA',
#    'NE',
#    'NG',
#    'NI',
#    'NL',
#    'NO',
#    'NP',
#    'NR',
#    'NZ',
#    'OM',
#    'PA',
#    'PE',
#    'PG',
#    'PH',
#    'PK',
#    'PL',
#    'PS',
#    'PT',
#    'PW',
#    'PY',
#    'QA',
#    'RO',
#    'RS',
#    'RW',
#    'SA',
#    'SB',
#    'SC',
#    'SE',
#    'SG',
#    'SI',
#    'SK',
#    'SL',
#    'SM',
#    'SN',
#    'SR',
#    'ST',
#    'SV',
#    'SZ',
#    'TD',
#    'TG',
#    'TH',
#    'TJ',
#    'TL',
#    'TN',
#    'TO',
#    'TR',
#    'TT',
#    'TV',
#    'TW',
#    'TZ',
#    'UA',
#    'UG',
#    'US',
#    'UY',
#    'UZ',
#    'VC',
#    'VE',
#    'VN',
#    'VU',
#    'WS',
#    'XK',
#    'ZA',
#    'ZM',
#    'ZW'],
#   'external_urls': {'spotify': 'https://open.spotify.com/album/2yaSZnZhaxsbQ5xhgGbw3g'},
#   'href': 'https://api.spotify.com/v1/albums/2yaSZnZhaxsbQ5xhgGbw3g',
#   'id': '2yaSZnZhaxsbQ5xhgGbw3g',
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab67616d0000b27331cc5716a5c922b0482787b7',
#     'width': 640},
#    {'height': 300,
#     'url': 'https://i.scdn.co/image/ab67616d00001e0231cc5716a5c922b0482787b7',
#     'width': 300},
#    {'height': 64,
#     'url': 'https://i.scdn.co/image/ab67616d0000485131cc5716a5c922b0482787b7',
#     'width': 64}],
#   'name': 'The Cure',
#   'release_date': '2017-04-16',
#   'release_date_precision': 'day',
#   'total_tracks': 1,
#   'type': 'album',
#   'uri': 'spotify:album:2yaSZnZhaxsbQ5xhgGbw3g'},
#  'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1HY2Jd0NmPuamShAr6KMms'},
#    'href': 'https://api.spotify.com/v1/artists/1HY2Jd0NmPuamShAr6KMms',
#    'id': '1HY2Jd0NmPuamShAr6KMms',
#    'name': 'Lady Gaga',
#    'type': 'artist',
#    'uri': 'spotify:artist:1HY2Jd0NmPuamShAr6KMms'}],
#  'available_markets': ['AD',
#   'AE',
#   'AG',
#   'AL',
#   'AM',
#   'AO',
#   'AR',
#   'AT',
#   'AU',
#   'AZ',
#   'BA',
#   'BB',
#   'BD',
#   'BE',
#   'BF',
#   'BG',
#   'BH',
#   'BI',
#   'BJ',
#   'BN',
#   'BO',
#   'BR',
#   'BS',
#   'BT',
#   'BW',
#   'BY',
#   'BZ',
#   'CA',
#   'CD',
#   'CG',
#   'CH',
#   'CI',
#   'CL',
#   'CM',
#   'CO',
#   'CR',
#   'CV',
#   'CW',
#   'CY',
#   'CZ',
#   'DE',
#   'DJ',
#   'DK',
#   'DM',
#   'DO',
#   'DZ',
#   'EC',
#   'EE',
#   'EG',
#   'ES',
#   'FI',
#   'FJ',
#   'FM',
#   'FR',
#   'GA',
#   'GB',
#   'GD',
#   'GE',
#   'GH',
#   'GM',
#   'GN',
#   'GQ',
#   'GR',
#   'GT',
#   'GW',
#   'GY',
#   'HK',
#   'HN',
#   'HR',
#   'HT',
#   'HU',
#   'ID',
#   'IE',
#   'IL',
#   'IN',
#   'IQ',
#   'IS',
#   'IT',
#   'JM',
#   'JO',
#   'JP',
#   'KE',
#   'KG',
#   'KH',
#   'KI',
#   'KM',
#   'KN',
#   'KR',
#   'KW',
#   'KZ',
#   'LA',
#   'LB',
#   'LC',
#   'LI',
#   'LK',
#   'LR',
#   'LS',
#   'LT',
#   'LU',
#   'LV',
#   'LY',
#   'MA',
#   'MC',
#   'MD',
#   'ME',
#   'MG',
#   'MH',
#   'MK',
#   'ML',
#   'MN',
#   'MO',
#   'MR',
#   'MT',
#   'MU',
#   'MV',
#   'MW',
#   'MX',
#   'MY',
#   'MZ',
#   'NA',
#   'NE',
#   'NG',
#   'NI',
#   'NL',
#   'NO',
#   'NP',
#   'NR',
#   'NZ',
#   'OM',
#   'PA',
#   'PE',
#   'PG',
#   'PH',
#   'PK',
#   'PL',
#   'PS',
#   'PT',
#   'PW',
#   'PY',
#   'QA',
#   'RO',
#   'RS',
#   'RW',
#   'SA',
#   'SB',
#   'SC',
#   'SE',
#   'SG',
#   'SI',
#   'SK',
#   'SL',
#   'SM',
#   'SN',
#   'SR',
#   'ST',
#   'SV',
#   'SZ',
#   'TD',
#   'TG',
#   'TH',
#   'TJ',
#   'TL',
#   'TN',
#   'TO',
#   'TR',
#   'TT',
#   'TV',
#   'TW',
#   'TZ',
#   'UA',
#   'UG',
#   'US',
#   'UY',
#   'UZ',
#   'VC',
#   'VE',
#   'VN',
#   'VU',
#   'WS',
#   'XK',
#   'ZA',
#   'ZM',
#   'ZW'],
#  'disc_number': 1,
#  'duration_ms': 211363,
#  'explicit': False,
#  'external_ids': {'isrc': 'USUM71703782'},
#  'external_urls': {'spotify': 'https://open.spotify.com/track/34oB5r0lcN3fYWCs2uA1k5'},
#  'href': 'https://api.spotify.com/v1/tracks/34oB5r0lcN3fYWCs2uA1k5',
#  'id': '34oB5r0lcN3fYWCs2uA1k5',
#  'is_local': False,
#  'name': 'The Cure',
#  'popularity': 67,
#  'preview_url': 'https://p.scdn.co/mp3-preview/75aa09f7973992a4f30e286afd60f316e462cb99?cid=da00ed264eaf4f94ba2adf23ff058567',
#  'track_number': 1,
#  'type': 'track',
#  'uri': 'spotify:track:34oB5r0lcN3fYWCs2uA1k5'}

# %%
results['tracks']['items'][0].keys()
# Out:
# dict_keys(['album', 'artists', 'available_markets', 'disc_number', 'duration_ms', 'explicit', 'external_ids', 'external_urls', 'href', 'id', 'is_local', 'name', 'popularity', 'preview_url', 'track_number', 'type', 'uri'])

# %%
results['tracks']['items'][0]['album']
# Out:
# {'album_type': 'single',
#  'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1HY2Jd0NmPuamShAr6KMms'},
#    'href': 'https://api.spotify.com/v1/artists/1HY2Jd0NmPuamShAr6KMms',
#    'id': '1HY2Jd0NmPuamShAr6KMms',
#    'name': 'Lady Gaga',
#    'type': 'artist',
#    'uri': 'spotify:artist:1HY2Jd0NmPuamShAr6KMms'}],
#  'available_markets': ['AD',
#   'AE',
#   'AG',
#   'AL',
#   'AM',
#   'AO',
#   'AR',
#   'AT',
#   'AU',
#   'AZ',
#   'BA',
#   'BB',
#   'BD',
#   'BE',
#   'BF',
#   'BG',
#   'BH',
#   'BI',
#   'BJ',
#   'BN',
#   'BO',
#   'BR',
#   'BS',
#   'BT',
#   'BW',
#   'BY',
#   'BZ',
#   'CA',
#   'CD',
#   'CG',
#   'CH',
#   'CI',
#   'CL',
#   'CM',
#   'CO',
#   'CR',
#   'CV',
#   'CW',
#   'CY',
#   'CZ',
#   'DE',
#   'DJ',
#   'DK',
#   'DM',
#   'DO',
#   'DZ',
#   'EC',
#   'EE',
#   'EG',
#   'ES',
#   'FI',
#   'FJ',
#   'FM',
#   'FR',
#   'GA',
#   'GB',
#   'GD',
#   'GE',
#   'GH',
#   'GM',
#   'GN',
#   'GQ',
#   'GR',
#   'GT',
#   'GW',
#   'GY',
#   'HK',
#   'HN',
#   'HR',
#   'HT',
#   'HU',
#   'ID',
#   'IE',
#   'IL',
#   'IN',
#   'IQ',
#   'IS',
#   'IT',
#   'JM',
#   'JO',
#   'JP',
#   'KE',
#   'KG',
#   'KH',
#   'KI',
#   'KM',
#   'KN',
#   'KR',
#   'KW',
#   'KZ',
#   'LA',
#   'LB',
#   'LC',
#   'LI',
#   'LK',
#   'LR',
#   'LS',
#   'LT',
#   'LU',
#   'LV',
#   'LY',
#   'MA',
#   'MC',
#   'MD',
#   'ME',
#   'MG',
#   'MH',
#   'MK',
#   'ML',
#   'MN',
#   'MO',
#   'MR',
#   'MT',
#   'MU',
#   'MV',
#   'MW',
#   'MX',
#   'MY',
#   'MZ',
#   'NA',
#   'NE',
#   'NG',
#   'NI',
#   'NL',
#   'NO',
#   'NP',
#   'NR',
#   'NZ',
#   'OM',
#   'PA',
#   'PE',
#   'PG',
#   'PH',
#   'PK',
#   'PL',
#   'PS',
#   'PT',
#   'PW',
#   'PY',
#   'QA',
#   'RO',
#   'RS',
#   'RW',
#   'SA',
#   'SB',
#   'SC',
#   'SE',
#   'SG',
#   'SI',
#   'SK',
#   'SL',
#   'SM',
#   'SN',
#   'SR',
#   'ST',
#   'SV',
#   'SZ',
#   'TD',
#   'TG',
#   'TH',
#   'TJ',
#   'TL',
#   'TN',
#   'TO',
#   'TR',
#   'TT',
#   'TV',
#   'TW',
#   'TZ',
#   'UA',
#   'UG',
#   'US',
#   'UY',
#   'UZ',
#   'VC',
#   'VE',
#   'VN',
#   'VU',
#   'WS',
#   'XK',
#   'ZA',
#   'ZM',
#   'ZW'],
#  'external_urls': {'spotify': 'https://open.spotify.com/album/2yaSZnZhaxsbQ5xhgGbw3g'},
#  'href': 'https://api.spotify.com/v1/albums/2yaSZnZhaxsbQ5xhgGbw3g',
#  'id': '2yaSZnZhaxsbQ5xhgGbw3g',
#  'images': [{'height': 640,
#    'url': 'https://i.scdn.co/image/ab67616d0000b27331cc5716a5c922b0482787b7',
#    'width': 640},
#   {'height': 300,
#    'url': 'https://i.scdn.co/image/ab67616d00001e0231cc5716a5c922b0482787b7',
#    'width': 300},
#   {'height': 64,
#    'url': 'https://i.scdn.co/image/ab67616d0000485131cc5716a5c922b0482787b7',
#    'width': 64}],
#  'name': 'The Cure',
#  'release_date': '2017-04-16',
#  'release_date_precision': 'day',
#  'total_tracks': 1,
#  'type': 'album',
#  'uri': 'spotify:album:2yaSZnZhaxsbQ5xhgGbw3g'}

# %%
results['tracks']['items'][0]['album'].keys()
# Out:
# dict_keys(['album_type', 'artists', 'available_markets', 'external_urls', 'href', 'id', 'images', 'name', 'release_date', 'release_date_precision', 'total_tracks', 'type', 'uri'])

# %%
results['tracks']['items'][0]['album']['name']
# Out:
# 'The Cure'

# %%
results['tracks']['items'][0]['album']['artists']
# Out:
# [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1HY2Jd0NmPuamShAr6KMms'},
#   'href': 'https://api.spotify.com/v1/artists/1HY2Jd0NmPuamShAr6KMms',
#   'id': '1HY2Jd0NmPuamShAr6KMms',
#   'name': 'Lady Gaga',
#   'type': 'artist',
#   'uri': 'spotify:artist:1HY2Jd0NmPuamShAr6KMms'}]

# %%
results['tracks']['items'][0]['album']['total_tracks']
# Out:
# 1

# %%
results['tracks']['items'][0]['name']
# Out:
# 'The Cure'

# %%
results['tracks']['items'][0]['artists']
# Out:
# [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1HY2Jd0NmPuamShAr6KMms'},
#   'href': 'https://api.spotify.com/v1/artists/1HY2Jd0NmPuamShAr6KMms',
#   'id': '1HY2Jd0NmPuamShAr6KMms',
#   'name': 'Lady Gaga',
#   'type': 'artist',
#   'uri': 'spotify:artist:1HY2Jd0NmPuamShAr6KMms'}]

# %%
results['tracks']['items'][0]['id']
# Out:
# '34oB5r0lcN3fYWCs2uA1k5'

# %%
results['tracks']['items'][0]['popularity']
# Out:
# 67

# %% [markdown]
# # Function to get name of song and artist

# %%
def get_name_artist(track):
    return [(track['name'],artist['name']) for artist in track['artists']]

# %%
my_track = results['tracks']['items'][0]

# %%
get_name_artist(my_track)
# Out:
# [('The Cure', 'Lady Gaga')]

# %%
all_songs_artists = list(map(get_name_artist,results['tracks']['items']))
all_songs_artists
# Out:
# [[('The Cure', 'Lady Gaga')],
#  [('Just like Heaven', 'The Cure')],
#  [('The Cure', 'Sam Lans!')],
#  [("Friday I'm in Love", 'The Cure')],
#  [('Cure For Me', 'AURORA')],
#  [('Lovesong - 2010 Remaster', 'The Cure')],
#  [("Boys Don't Cry - Single Version", 'The Cure')],
#  [('Lovesong', 'The Cure')],
#  [("Boys Don't Cry", 'The Cure')],
#  [('Pictures of You - 2010 Remaster', 'The Cure')],
#  [('M - 2006 Remaster', 'The Cure')],
#  [('Close to Me - 2006 Remaster', 'The Cure')],
#  [('Pictures of You', 'The Cure')],
#  [('In Between Days - 2006 Remaster', 'The Cure')],
#  [('A Forest - 2006 Remaster', 'The Cure')],
#  [('Lullaby - 2010 Remaster', 'The Cure')],
#  [('Burn', 'The Cure')],
#  [('Disintegration - 2010 Remaster', 'The Cure')],
#  [('The Cure', 'Watkins Family Hour')],
#  [('The Cure', 'Wake Up Hate')],
#  [('Plainsong - 2010 Remaster', 'The Cure')],
#  [('Charlotte Sometimes - Single Version', 'The Cure')],
#  [('The Cure', 'Unspoken')],
#  [('Just like Heaven - 2006 Remaster', 'The Cure')],
#  [('The Cure', 'Little Mix')],
#  [('Cure for the Itch', 'Linkin Park')],
#  [('Six Different Ways - 2006 Remaster', 'The Cure')],
#  [('Fascination Street - 2010 Remaster', 'The Cure')],
#  [('The Cure', 'Mark Battles'),
#   ('The Cure', 'King Los'),
#   ('The Cure', 'Forever M.C.')],
#  [('A Letter to Elise', 'The Cure')],
#  [('A Night like This - 2006 Remaster', 'The Cure')],
#  [('Cold - 2005 Remaster', 'The Cure')],
#  [('The Cure', 'Jadu Heart')],
#  [('The Lovecats', 'The Cure')],
#  [("Let's Go To Bed", 'The Cure')],
#  [("Jumping Someone Else's Train - Single Version", 'The Cure')],
#  [('The Cure', 'William Singe')],
#  [('Lose My Mind (feat. Mr Gabriel)', 'Jai Wolf')],
#  [('The Walk', 'The Cure'), ('The Walk', 'Mark Saunders')],
#  [('10:15 Saturday Night - 2005 Remaster', 'The Cure')],
#  [('The Cure', "Melody's Echo Chamber")],
#  [('High', 'The Cure')],
#  [('Cut - 1990 Demo', 'The Cure')],
#  [('The Cure', 'Nas')],
#  [('Fire in Cairo - 2005 Remaster', 'The Cure')],
#  [('The Cure', 'Wake Up Hate')],
#  [('Oak & Ash & Thorn', 'The Longest Johns')],
#  [('Just Say Yes', 'The Cure')],
#  [('The Cure', 'Wolves At The Gate')],
#  [('Wrong Number - Single Mix', 'The Cure')]]

# %%
#flattening the list
def flatten(input_list):
    return [item for sublist in input_list for item in sublist]

# %%
flatten(all_songs_artists)
# Out:
# [('The Cure', 'Lady Gaga'),
#  ('Just like Heaven', 'The Cure'),
#  ('The Cure', 'Sam Lans!'),
#  ("Friday I'm in Love", 'The Cure'),
#  ('Cure For Me', 'AURORA'),
#  ('Lovesong - 2010 Remaster', 'The Cure'),
#  ("Boys Don't Cry - Single Version", 'The Cure'),
#  ('Lovesong', 'The Cure'),
#  ("Boys Don't Cry", 'The Cure'),
#  ('Pictures of You - 2010 Remaster', 'The Cure'),
#  ('M - 2006 Remaster', 'The Cure'),
#  ('Close to Me - 2006 Remaster', 'The Cure'),
#  ('Pictures of You', 'The Cure'),
#  ('In Between Days - 2006 Remaster', 'The Cure'),
#  ('A Forest - 2006 Remaster', 'The Cure'),
#  ('Lullaby - 2010 Remaster', 'The Cure'),
#  ('Burn', 'The Cure'),
#  ('Disintegration - 2010 Remaster', 'The Cure'),
#  ('The Cure', 'Watkins Family Hour'),
#  ('The Cure', 'Wake Up Hate'),
#  ('Plainsong - 2010 Remaster', 'The Cure'),
#  ('Charlotte Sometimes - Single Version', 'The Cure'),
#  ('The Cure', 'Unspoken'),
#  ('Just like Heaven - 2006 Remaster', 'The Cure'),
#  ('The Cure', 'Little Mix'),
#  ('Cure for the Itch', 'Linkin Park'),
#  ('Six Different Ways - 2006 Remaster', 'The Cure'),
#  ('Fascination Street - 2010 Remaster', 'The Cure'),
#  ('The Cure', 'Mark Battles'),
#  ('The Cure', 'King Los'),
#  ('The Cure', 'Forever M.C.'),
#  ('A Letter to Elise', 'The Cure'),
#  ('A Night like This - 2006 Remaster', 'The Cure'),
#  ('Cold - 2005 Remaster', 'The Cure'),
#  ('The Cure', 'Jadu Heart'),
#  ('The Lovecats', 'The Cure'),
#  ("Let's Go To Bed", 'The Cure'),
#  ("Jumping Someone Else's Train - Single Version", 'The Cure'),
#  ('The Cure', 'William Singe'),
#  ('Lose My Mind (feat. Mr Gabriel)', 'Jai Wolf'),
#  ('The Walk', 'The Cure'),
#  ('The Walk', 'Mark Saunders'),
#  ('10:15 Saturday Night - 2005 Remaster', 'The Cure'),
#  ('The Cure', "Melody's Echo Chamber"),
#  ('High', 'The Cure'),
#  ('Cut - 1990 Demo', 'The Cure'),
#  ('The Cure', 'Nas'),
#  ('Fire in Cairo - 2005 Remaster', 'The Cure'),
#  ('The Cure', 'Wake Up Hate'),
#  ('Oak & Ash & Thorn', 'The Longest Johns'),
#  ('Just Say Yes', 'The Cure'),
#  ('The Cure', 'Wolves At The Gate'),
#  ('Wrong Number - Single Mix', 'The Cure')]

# %%
def get_name_artist_from_list(tracks):
    return flatten(list(map(get_name_artist,tracks['items'])))

# %%
get_name_artist_from_list(results['tracks'])
# Out:
# [('The Cure', 'Lady Gaga'),
#  ('Just like Heaven', 'The Cure'),
#  ('The Cure', 'Sam Lans!'),
#  ("Friday I'm in Love", 'The Cure'),
#  ('Cure For Me', 'AURORA'),
#  ('Lovesong - 2010 Remaster', 'The Cure'),
#  ("Boys Don't Cry - Single Version", 'The Cure'),
#  ('Lovesong', 'The Cure'),
#  ("Boys Don't Cry", 'The Cure'),
#  ('Pictures of You - 2010 Remaster', 'The Cure'),
#  ('M - 2006 Remaster', 'The Cure'),
#  ('Close to Me - 2006 Remaster', 'The Cure'),
#  ('Pictures of You', 'The Cure'),
#  ('In Between Days - 2006 Remaster', 'The Cure'),
#  ('A Forest - 2006 Remaster', 'The Cure'),
#  ('Lullaby - 2010 Remaster', 'The Cure'),
#  ('Burn', 'The Cure'),
#  ('Disintegration - 2010 Remaster', 'The Cure'),
#  ('The Cure', 'Watkins Family Hour'),
#  ('The Cure', 'Wake Up Hate'),
#  ('Plainsong - 2010 Remaster', 'The Cure'),
#  ('Charlotte Sometimes - Single Version', 'The Cure'),
#  ('The Cure', 'Unspoken'),
#  ('Just like Heaven - 2006 Remaster', 'The Cure'),
#  ('The Cure', 'Little Mix'),
#  ('Cure for the Itch', 'Linkin Park'),
#  ('Six Different Ways - 2006 Remaster', 'The Cure'),
#  ('Fascination Street - 2010 Remaster', 'The Cure'),
#  ('The Cure', 'Mark Battles'),
#  ('The Cure', 'King Los'),
#  ('The Cure', 'Forever M.C.'),
#  ('A Letter to Elise', 'The Cure'),
#  ('A Night like This - 2006 Remaster', 'The Cure'),
#  ('Cold - 2005 Remaster', 'The Cure'),
#  ('The Cure', 'Jadu Heart'),
#  ('The Lovecats', 'The Cure'),
#  ("Let's Go To Bed", 'The Cure'),
#  ("Jumping Someone Else's Train - Single Version", 'The Cure'),
#  ('The Cure', 'William Singe'),
#  ('Lose My Mind (feat. Mr Gabriel)', 'Jai Wolf'),
#  ('The Walk', 'The Cure'),
#  ('The Walk', 'Mark Saunders'),
#  ('10:15 Saturday Night - 2005 Remaster', 'The Cure'),
#  ('The Cure', "Melody's Echo Chamber"),
#  ('High', 'The Cure'),
#  ('Cut - 1990 Demo', 'The Cure'),
#  ('The Cure', 'Nas'),
#  ('Fire in Cairo - 2005 Remaster', 'The Cure'),
#  ('The Cure', 'Wake Up Hate'),
#  ('Oak & Ash & Thorn', 'The Longest Johns'),
#  ('Just Say Yes', 'The Cure'),
#  ('The Cure', 'Wolves At The Gate'),
#  ('Wrong Number - Single Mix', 'The Cure')]

# %% [markdown]
# # Playlists

# %%
playlist = sp.user_playlist_tracks("spotify", "1UV8OzKszYVhBHoyUAuSvV")

# %%
#playlist

# %%
playlist.keys()
# Out:
# dict_keys(['href', 'items', 'limit', 'next', 'offset', 'previous', 'total'])

# %%
playlist['items'][0]['track']['artists'][0]['name']
# Out:
# 'Rose Royce'

# %%
playlist['total']
# Out:
# 15

# %%
len(playlist['items'])
# Out:
# 15

# %%
# all_songs_artists = list(map(get_name_artist,playlist['items']['track']['name']))
# all_songs_artists

# %%
def flatten(input_list):
    return [item for sublist in input_list for item in sublist]

# %%
#flatten(playlist)

# %%
def get_name_artist_from_list(tracks):
    return flatten(list(map(get_name_artist_from_track,tracks['items'])))

# %%
#get_name_artist(playlist)

# %% [markdown]
# # First get name and artist from 1 track

# %%
def name_artist_playlist(playlist_item):
    return get_name_artist_from_track(playlist_item['track'])

# %%
#def get_n_a_from_playlist(playlist):

# %% [markdown]
# # handling larger playlists

# %%
playlist = sp.user_playlist_tracks('spotify', '4rnleEAOdmFAbRcNCgZMpY')

# %%
playlist['total']
# Out:
# 5295

# %%
len(playlist['items'])
# Out:
# 100

# %%
playlist['next']
# Out:
# 'https://api.spotify.com/v1/playlists/4rnleEAOdmFAbRcNCgZMpY/tracks?offset=100&limit=100&additional_types=track'

# %%
#sp.next(playlist)

# %%
from random import randint
from time import sleep

def playlist_tracks(playlist_id):
    results = sp.user_playlist_tracks('spotify',playlist_id)
    tracks = results['items']
    while results['next'] != None:
        results = sp.next(results)
        tracks = tracks + results['items']
        sleep(randint(1,3))
    return tracks

# %%
all_tracks = playlist_tracks('4rnleEAOdmFAbRcNCgZMpY')
len(all_tracks)
# Out:
# 5295

# %% [markdown]
# # Audio Features

# %%
playlist['items'][13]['track']['name']
# Out:
# 'Girlfriend'

# %%
song_uri = playlist['items'][13]['track']['uri']

# %%
sp.audio_features(song_uri)
# Out:
# [{'danceability': 0.56,
#   'energy': 0.959,
#   'key': 7,
#   'loudness': -2.433,
#   'mode': 1,
#   'speechiness': 0.102,
#   'acousticness': 0.000738,
#   'instrumentalness': 0.000206,
#   'liveness': 0.209,
#   'valence': 0.67,
#   'tempo': 163.983,
#   'type': 'audio_features',
#   'id': '5HbCnVLXRyZVxnreOPgJCK',
#   'uri': 'spotify:track:5HbCnVLXRyZVxnreOPgJCK',
#   'track_href': 'https://api.spotify.com/v1/tracks/5HbCnVLXRyZVxnreOPgJCK',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5HbCnVLXRyZVxnreOPgJCK',
#   'duration_ms': 216600,
#   'time_signature': 4}]

# %% [markdown]
# # Function to pull out all Audio Features

# %%
sp.audio_features(song_uri)[0]['danceability']
# Out:
# 0.56

# %%
list_features = ['danceability','energy','key','loudness','speechiness','instrumentalness','liveness','valence','tempo','time_signature']

# %%
def pull_out_features(song_uri):
    pair_feat_value = []
    for feature in list_features:
        pair_feat_value.append(feature)
        pair_feat_value.append(sp.audio_features(song_uri)[0][feature])
    return pair_feat_value

# %%
lst = pull_out_features(song_uri)
lst
# Out:
# ['danceability',
#  0.56,
#  'energy',
#  0.959,
#  'key',
#  7,
#  'loudness',
#  -2.433,
#  'speechiness',
#  0.102,
#  'instrumentalness',
#  0.000206,
#  'liveness',
#  0.209,
#  'valence',
#  0.67,
#  'tempo',
#  163.983,
#  'time_signature',
#  4]

# %% [markdown]
# # Help with functions!!

# %%
def get_playlist_tracks(playlist_id):
    results = sp.user_playlist_tracks("spotify",playlist_id)
    tracks = results['items']
    while results['next']!=None:
        results = sp.next(results)
        tracks = tracks + results['items']
        sleep(randint(1,3))
    return tracks

# %%
gx_playlist = get_playlist_tracks('37i9dQZF1DWUxHPh2rEiHr')

# %%
def flatten(input_list):
    return [item for sublist in input_list for item in sublist]

def get_details_from_track(track):
    return flatten((track["name"],artist["name"], track["uri"]) for artist in track["artists"])

def get_details_from_playlist_item(playlist_item):
    return get_details_from_track(playlist_item['track'])

def get_details_from_playlist(input_playlist):
    return list(map(get_details_from_playlist_item,input_playlist))

# %%
gx_details = get_details_from_playlist(gx_playlist)

# %%
def make_df_from_playlist_details(playlist_details):
    titles = [song[0] for song in playlist_details]
    artists = [song[1] for song in playlist_details]
    uris = [(song[2].split(":"))[-1] for song in playlist_details]
    df = pd.DataFrame({'title':titles, 'artist':artists, 'uri':uris})
    
    return df

# %%
gx = make_df_from_playlist_details(gx_details)

# %%
audio_features = ['danceability', 'energy', 'key', 'loudness', 'mode', 'speechiness', 'acousticness', 'instrumentalness', 
            'liveness', 'valence', 'tempo', 'time_signature']

def add_audio_features(df):
    df['features'] = None
    for i in range(len(df)):
        song_features = sp.audio_features(df.uri[i])
        df['features'][i] = song_features[0]
        sleep(randint(1,3))
    for f in audio_features:
        df[f] = [df['features'][i][f] for i in range(len(df))]
    df.drop(['features'], axis=1, inplace=True)
    return df

# %%
gx_with_audio = add_audio_features(gx)

# %%
#gx_with_audio.drop(['features'], axis=1, inplace=True)
gx_with_audio
# Out:
#                                                 title         artist  \
# 0               Quevedo: Bzrp Music Sessions, Vol. 52       Bizarrap
# 1                      Que Sera Sera (Law Nebka Sawa)    Hiba Tawaji
# 2                       Calm Down (with Selena Gomez)           Rema
# 3                                     Me Porto Bonito      Bad Bunny
# 4                      For My Hand (feat. Ed Sheeran)      Burna Boy
# ..                                                ...            ...
# 75                                            Brother       Anuel AA
# 76  SG (with Ozuna, Megan Thee Stallion & LISA of ...       DJ Snake
# 77                                          Mujeriego    Ryan Castro
# 78                                          DANÇARINA  PEDRO SAMPAIO
# 79                                      Qué Más Pues?       J Balvin
#
#                        uri  danceability  energy  key  loudness  mode  \
# 0   2tTmW7RDtMQtBk7m2rYeSw         0.621   0.782    2    -5.548     1
# 1   7DwNsMz0MNNoHsKIZWjj73         0.592   0.801    4    -3.129     0
# 2   0WtM2NBVQNNJLh6scP13H8         0.801   0.806   11    -5.206     1
# 3   6Sq7ltF9Qa7SNFBsV5Cogx         0.911   0.712    1    -5.105     0
# 4   0HaRLPnr887lcQM2YQzkff         0.870   0.479    9    -7.779     1
# ..                     ...           ...     ...  ...       ...   ...
# 75  3M23T72K5eqHI2GzdFMMHE         0.592   0.625   10    -6.203     0
# 76  6IPNp9PfaEqrzotY47TIWy         0.800   0.837    6    -2.807     0
# 77  78kygHp1dvW1kncYjBgbe1         0.758   0.621    9    -8.033     1
# 78  5zNxUkUW9WiV5oyg6gh2wB         0.778   0.571    9    -4.776     0
# 79  6hf0RpxTbOprT5nnwzkk8e         0.891   0.819    8    -3.964     1
#
#     speechiness  acousticness  instrumentalness  liveness  valence    tempo  \
# 0        0.0440       0.01250          0.033000    0.2300    0.550  128.033
# 1        0.1980       0.14600          0.000000    0.1800    0.413   99.739
# 2        0.0381       0.38200          0.000669    0.1140    0.802  106.999
# 3        0.0817       0.09010          0.000027    0.0933    0.425   92.005
# 4        0.1650       0.16100          0.000157    0.2090    0.717  104.059
# ..          ...           ...               ...       ...      ...      ...
# 75       0.2000       0.61800          0.000097    0.2870    0.555  166.018
# 76       0.0491       0.00406          0.003130    0.0904    0.702  100.015
# 77       0.1250       0.06280          0.000000    0.0809    0.920   79.949
# 78       0.0788       0.04230          0.000000    0.0964    0.554  134.999
# 79       0.1060       0.02610          0.000354    0.1730    0.768  101.968
#
#     time_signature
# 0                4
# 1                4
# 2                4
# 3                4
# 4                4
# ..             ...
# 75               4
# 76               4
# 77               4
# 78               4
# 79               4
#
# [80 rows x 15 columns]

# %%
def make_audio_features_df_from_playlistID(playlist_id):
    
    def get_playlist_tracks(playlist_id):
        results = sp.user_playlist_tracks("spotify",playlist_id)
        tracks = results['items']
        while results['next']!=None:
            results = sp.next(results)
            tracks = tracks + results['items']
            sleep(randint(1,3))
        return tracks
    
    def flatten(input_list):
        return [item for sublist in input_list for item in sublist]

    def get_details_from_track(track):
        return flatten((track["name"],artist["name"], track["uri"]) for artist in track["artists"])

    def get_details_from_playlist_item(playlist_item):
        return get_details_from_track(playlist_item['track'])

    def get_details_from_playlist(input_playlist):
        return list(map(get_details_from_playlist_item,input_playlist))
    
    def make_df_from_playlist_details(playlist_details):
        titles = [song[0] for song in playlist_details]
        artists = [song[1] for song in playlist_details]
        uris = [song[2] for song in playlist_details]
        return pd.DataFrame({'title':titles, 'artist':artists, 'uri':uris})
    
    playlist = get_playlist_tracks(playlist_id)
    details = get_details_from_playlist(playlist)
    df = make_df_from_playlist_details(details)
    
    audio_features = ['danceability', 'energy', 'key', 'loudness', 'mode', 'speechiness', 'acousticness', 'instrumentalness', 
            'liveness', 'valence', 'tempo', 'time_signature']

    def add_audio_features(df):
        df['features'] = None
        for i in range(len(df)):
            song_features = sp.audio_features(df.uri[i])
            df['features'][i] = song_features[0]
            sleep(randint(1,3))
        for f in audio_features:
            df[f] = [df['features'][i][f] for i in range(len(df))]
        df.drop(['features'], axis=1, inplace=True)
        return df
    
    df_with_audio_features = add_audio_features(df)
    
    return df_with_audio_features

# %%
def make_audio_features_df_from_playlistID(playlist_id):
    
    playlist = get_playlist_tracks(playlist_id)
    details = get_details_from_playlist(playlist)
    df = make_df_from_playlist_details(details)
    
    audio_features = ['danceability', 'energy', 'key', 'loudness', 'mode', 'speechiness', 'acousticness', 'instrumentalness', 
            'liveness', 'valence', 'tempo', 'time_signature']
    
    df_with_audio_features = add_audio_features(df)
    
    return df_with_audio_features

# %%
def add_playlist(playlist_id, songs_df):
    df = make_audio_features_df_from_playlistID(playlist_id)
    new_df = pd.concat([songs_df, df], axis=0)
    new_df.drop_duplicates(subset=['title'], keep='first', inplace=True)
    new_df.reset_index(inplace=True, drop=True)
    return new_df
