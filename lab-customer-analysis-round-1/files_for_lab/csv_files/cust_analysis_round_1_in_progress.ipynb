# %%
import pandas as pd

# %% [markdown]
# # import data from files

# %%
file1 = pd.read_csv('file1.csv')
file2 = pd.read_csv('file2.csv')
file3 = pd.read_csv('file3.csv')

# %% [markdown]
# ## first look at data

# %%
display(file1.head())
display(file2.head())
display(file3.head())
# Out:
#   Customer          ST GENDER             Education Customer Lifetime Value  \
# 0  RB50392  Washington    NaN                Master                     NaN
# 1  QZ44356     Arizona      F              Bachelor              697953.59%
# 2  AI49188      Nevada      F              Bachelor             1288743.17%
# 3  WW63253  California      M              Bachelor              764586.18%
# 4  GA49547  Washington      M  High School or Below              536307.65%
#
#     Income  Monthly Premium Auto Number of Open Complaints     Policy Type  \
# 0      0.0                1000.0                    1/0/00   Personal Auto
# 1      0.0                  94.0                    1/0/00   Personal Auto
# 2  48767.0                 108.0                    1/0/00   Personal Auto
# 3      0.0                 106.0                    1/0/00  Corporate Auto
# 4  36357.0                  68.0                    1/0/00   Personal Auto
#
#    Vehicle Class  Total Claim Amount
# ...

# %% [markdown]
# ## Comparing column names for each dataframe

# %%
display(file1.columns)           #showing list of column names
display(file2.head(0))
file3.head(0)
# Out:
# Index(['Customer', 'ST', 'GENDER', 'Education', 'Customer Lifetime Value',
#        'Income', 'Monthly Premium Auto', 'Number of Open Complaints',
#        'Policy Type', 'Vehicle Class', 'Total Claim Amount'],
#       dtype='object')
# Empty DataFrame
# Columns: [Customer, ST, GENDER, Education, Customer Lifetime Value, Income, Monthly Premium Auto, Number of Open Complaints, Total Claim Amount, Policy Type, Vehicle Class]
# Index: []
# Empty DataFrame
# Columns: [Customer, State, Customer Lifetime Value, Education, Gender, Income, Monthly Premium Auto, Number of Open Complaints, Policy Type, Total Claim Amount, Vehicle Class]
# Index: []

# %% [markdown]
# ## Standardizing column titles --  lowercase all titles (snakecase)

# %%
cols1 = []
for i in range(len(file1.columns)):
    cols1.append(file1.columns[i].lower().replace(' ', '_'))
file1.columns = cols1

# %%
cols2 = []
for i in range(len(file2.columns)):
    cols2.append(file2.columns[i].lower().replace(' ', '_'))
file2.columns = cols2

# %%
cols3 = []
for i in range(len(file3.columns)):
    cols3.append(file3.columns[i].lower().replace(' ', '_'))
file3.columns = cols3

# %%
display(file1.columns)           #showing list of column names
display(file2.head(0))
file3.head(0)
# Out:
# Index(['customer', 'st', 'gender', 'education', 'customer_lifetime_value',
#        'income', 'monthly_premium_auto', 'number_of_open_complaints',
#        'policy_type', 'vehicle_class', 'total_claim_amount'],
#       dtype='object')
# Empty DataFrame
# Columns: [customer, st, gender, education, customer_lifetime_value, income, monthly_premium_auto, number_of_open_complaints, total_claim_amount, policy_type, vehicle_class]
# Index: []
# Empty DataFrame
# Columns: [customer, state, customer_lifetime_value, education, gender, income, monthly_premium_auto, number_of_open_complaints, policy_type, total_claim_amount, vehicle_class]
# Index: []

# %%
file3=file3.rename({'state':'st'}, axis=1)

# %% [markdown]
# ## rearranging order of columns to be all the same as file1

# %%
file2=file2[file1.columns]
file3=file3[file1.columns]

# %% [markdown]
# ## getting rid of % symbol and changing dtype to numerical

# %%
file1['customer_lifetime_value'] = file1['customer_lifetime_value'].str.replace('%','')
file2['customer_lifetime_value'] = file2['customer_lifetime_value'].str.replace('%','')

# %%
file1['customer_lifetime_value'] = pd.to_numeric(file1['customer_lifetime_value'], errors = 'coerce')/100
file2['customer_lifetime_value'] = pd.to_numeric(file2['customer_lifetime_value'], errors = 'coerce')/100

# %%
file1.dtypes
# Out:
# customer                      object
# st                            object
# gender                        object
# education                     object
# customer_lifetime_value      float64
# income                       float64
# monthly_premium_auto         float64
# number_of_open_complaints     object
# policy_type                   object
# vehicle_class                 object
# total_claim_amount           float64
# dtype: object

# %% [markdown]
# ## concatenating all data together in 1 dataframe

# %%
data = pd.concat([file1, file2, file3], axis = 0)
data
# Out:
#      customer          st gender             education  \
# 0     RB50392  Washington    NaN                Master
# 1     QZ44356     Arizona      F              Bachelor
# 2     AI49188      Nevada      F              Bachelor
# 3     WW63253  California      M              Bachelor
# 4     GA49547  Washington      M  High School or Below
# ...       ...         ...    ...                   ...
# 7065  LA72316  California      M              Bachelor
# 7066  PK87824  California      F               College
# 7067  TD14365  California      M              Bachelor
# 7068  UP19263  California      M               College
# 7069  Y167826  California      M               College
#
#       customer_lifetime_value   income  monthly_premium_auto  \
# 0                         NaN      0.0                1000.0
# 1                 6979.535900      0.0                  94.0
# 2                12887.431700  48767.0                 108.0
# ...

# %% [markdown]
# ## finding numerical and categorical columns

# %%
data.select_dtypes(include=np.number)
# Out:
#       customer_lifetime_value   income  monthly_premium_auto  \
# 0                         NaN      0.0                1000.0
# 1                 6979.535900      0.0                  94.0
# 2                12887.431700  48767.0                 108.0
# 3                 7645.861800      0.0                 106.0
# 4                 5363.076500  36357.0                  68.0
# ...                       ...      ...                   ...
# 7065             23405.987980  71941.0                  73.0
# 7066              3096.511217  21604.0                  79.0
# 7067              8163.890428      0.0                  85.0
# 7068              7524.442436  21941.0                  96.0
# 7069              2611.836866      0.0                  77.0
#
#       total_claim_amount
# 0               2.704934
# 1            1131.464935
# 2             566.472247
# 3             529.881344
# 4              17.269323
# ...                  ...
# 7065          198.234764
# ...

# %%
data.select_dtypes(include=object)
# Out:
#      customer          st gender             education  \
# 0     RB50392  Washington    NaN                Master
# 1     QZ44356     Arizona      F              Bachelor
# 2     AI49188      Nevada      F              Bachelor
# 3     WW63253  California      M              Bachelor
# 4     GA49547  Washington      M  High School or Below
# ...       ...         ...    ...                   ...
# 7065  LA72316  California      M              Bachelor
# 7066  PK87824  California      F               College
# 7067  TD14365  California      M              Bachelor
# 7068  UP19263  California      M               College
# 7069  Y167826  California      M               College
#
#      number_of_open_complaints     policy_type  vehicle_class
# 0                       1/0/00   Personal Auto  Four-Door Car
# 1                       1/0/00   Personal Auto  Four-Door Car
# 2                       1/0/00   Personal Auto   Two-Door Car
# ...

# %% [markdown]
# ## Dropping columns education and number_of_open_complaints (as instructed)

# %%
data.drop(['education','number_of_open_complaints'], axis = 1, inplace=True)

# %%
data
# Out:
#      customer          st gender  customer_lifetime_value   income  \
# 0     RB50392  Washington    NaN                      NaN      0.0
# 1     QZ44356     Arizona      F              6979.535900      0.0
# 2     AI49188      Nevada      F             12887.431700  48767.0
# 3     WW63253  California      M              7645.861800      0.0
# 4     GA49547  Washington      M              5363.076500  36357.0
# ...       ...         ...    ...                      ...      ...
# 7065  LA72316  California      M             23405.987980  71941.0
# 7066  PK87824  California      F              3096.511217  21604.0
# 7067  TD14365  California      M              8163.890428      0.0
# 7068  UP19263  California      M              7524.442436  21941.0
# 7069  Y167826  California      M              2611.836866      0.0
#
#       monthly_premium_auto     policy_type  vehicle_class  total_claim_amount
# 0                   1000.0   Personal Auto  Four-Door Car            2.704934
# ...

# %% [markdown]
# ## drop duplicated rows

# %%
data.duplicated().sum()
# Out:
# 2939

# %%
data.drop_duplicates()
# Out:
#      customer          st gender  customer_lifetime_value   income  \
# 0     RB50392  Washington    NaN                      NaN      0.0
# 1     QZ44356     Arizona      F              6979.535900      0.0
# 2     AI49188      Nevada      F             12887.431700  48767.0
# 3     WW63253  California      M              7645.861800      0.0
# 4     GA49547  Washington      M              5363.076500  36357.0
# ...       ...         ...    ...                      ...      ...
# 7065  LA72316  California      M             23405.987980  71941.0
# 7066  PK87824  California      F              3096.511217  21604.0
# 7067  TD14365  California      M              8163.890428      0.0
# 7068  UP19263  California      M              7524.442436  21941.0
# 7069  Y167826  California      M              2611.836866      0.0
#
#       monthly_premium_auto     policy_type  vehicle_class  total_claim_amount
# 0                   1000.0   Personal Auto  Four-Door Car            2.704934
# ...

# %%
data['gender'].value_counts(dropna=False)
# Out:
# F         4560
# M         4368
# NaN       3059
# Male        40
# female      30
# Femal       17
# Name: gender, dtype: int64

# %%
data['gender'].dtype
# Out:
# dtype('O')

# %%
data['gender']=data['gender'].fillna('F')

# %%
for item in data['gender']:
    item.replace('Male','M')
data['gender'].value_counts(dropna=False)
# Out:
# F         7619
# M         4368
# Male        40
# female      30
# Femal       17
# Name: gender, dtype: int64
