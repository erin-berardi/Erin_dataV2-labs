# %%
Client ID da00ed264eaf4f94ba2adf23ff058567
Client Secret 80b98527a70043438b54ed1ce6460e5c

# %%
# !pip install spotipy
# Out:
# ...
#      |████████████████████████████████| 62 kB 1.1 MB/s eta 0:00:011
# ...
#      |████████████████████████████████| 138 kB 4.7 MB/s eta 0:00:01
# ...
#   Attempting uninstall: urllib3
#     Found existing installation: urllib3 1.25.9
#     Uninstalling urllib3-1.25.9:
#       Successfully uninstalled urllib3-1.25.9
#   Attempting uninstall: requests
#     Found existing installation: requests 2.24.0
#     Uninstalling requests-2.24.0:
#       Successfully uninstalled requests-2.24.0
# ...

# %%
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials

# %%
secrets_file = open("SpotifySecret.txt","r")

# %%
string = secrets_file.read()

# %%
string.split('\n')
# Out:
# ['cid:da00ed264eaf4f94ba2adf23ff058567',
#  'cs:80b98527a70043438b54ed1ce6460e5c',
#  '']

# %%
secrets_dict={}
for line in string.split('\n'):
    if len(line)>0:
        secrets_dict[line.split(':')[0]]=line.split(':')[1]

# %%
secrets_dict
# Out:
# {'cid': 'da00ed264eaf4f94ba2adf23ff058567',
#  'cs': '80b98527a70043438b54ed1ce6460e5c'}

# %%
sp = spotipy.Spotify(auth_manager=SpotifyClientCredentials(client_id=secrets_dict['cid'],client_secret=secrets_dict['cs']))

# %%
results = sp.search(q='Daft Punk',limit=50)
results
# Out:
# {'tracks': {'href': 'https://api.spotify.com/v1/search?query=Daft+Punk&type=track&offset=0&limit=50',
#   'items': [{'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1Xyo4u8uXC1ZmMpatF05PJ'},
#        'href': 'https://api.spotify.com/v1/artists/1Xyo4u8uXC1ZmMpatF05PJ',
#        'id': '1Xyo4u8uXC1ZmMpatF05PJ',
#        'name': 'The Weeknd',
#        'type': 'artist',
#        'uri': 'spotify:artist:1Xyo4u8uXC1ZmMpatF05PJ'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AO',
#       'AR',
#       'AT',
#       'AU',
#       'AZ',
#       'BA',
#       'BB',
#       'BD',
#       'BE',
#       'BF',
#       'BG',
#       'BH',
#       'BI',
#       'BJ',
#       'BN',
#       'BO',
#       'BR',
#       'BS',
#       'BT',
#       'BW',
#       'BY',
#       'BZ',
#       'CA',
#       'CD',
#       'CG',
#       'CH',
#       'CI',
#       'CL',
#       'CM',
# ...
